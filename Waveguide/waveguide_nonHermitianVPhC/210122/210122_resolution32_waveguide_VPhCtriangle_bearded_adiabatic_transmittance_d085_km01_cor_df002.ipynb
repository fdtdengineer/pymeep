# %% [markdown]
# https://github.com/NanoComp/meep/blob/master/python/examples/straight-waveguide.ipynb
#
# https://stackoverflow.com/questions/29454002/filenotfounderror-errno-2-no-such-file-or-directory-ffmpeg

# %%
import math
import meep as mp
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from matplotlib import rc
rc('text', usetex=False)
#plt.rcParams['font.family'] = 'Times New Roman'#使用するフォント
#plt.rcParams['mathtext.fontset'] = 'stix' # math fontの設定
plt.rcParams['font.family']= 'sans-serif'
plt.rcParams['font.sans-serif'] = ['Arial']
plt.rcParams["font.size"] = 15 # 全体のフォントサイズが変更されます。
plt.rcParams['xtick.direction'] = 'in'#x軸の目盛線が内向き('in')か外向き('out')か双方向か('inout')
plt.rcParams['ytick.direction'] = 'in'#y軸の目盛線が内向き('in')か外向き('out')か双方向か('inout')
# Out:
# Using MPI version 3.1, 1 processes

# %%
def eps_to_eps(eps_A_r,eps_A_i):
    eps_A = eps_A_r + 1.j*eps_A_i
    eps_Ainv = 1 / eps_A

    eps_Ainv_r = eps_Ainv.real
    eps_Ainv_i = -eps_Ainv.imag

    #print(eps_Ainv_r, eps_Ainv_i)

    eps_B_r = eps_A_r + 1/eps_Ainv_r * (eps_Ainv_i**2) / (eps_Ainv_r**2 + eps_Ainv_i**2)
    eps_B_i = 0

    eps_B = eps_B_r + 1.j*eps_B_i
    eps_Binv = 1 / eps_B

    eps_Binv_r = eps_Binv.real
    eps_Binv_i = -eps_Binv.imag

    #print(eps_Binv_r, eps_Binv_i)
    return eps_B_r, eps_B_i

# %%
def phc_trans(PhC = True, lengthPhC = 100, decay_check=0, T_decay=500):
    """
    <変数の説明>
    PhC...PhC(フォトニック決勝)を配置するかどうか。Falseで直線導波路
    lengthPhC...PhC導波方向の長さ
    widthPhC...PhC垂直方向の幅。PMLと被ってるので適当。
    ConnectionWaveguide...PhCに接続するSi導波路(棒の部分)の長さ
    wgi...導波路の幅を調整する。1で丸穴一個分空いてることを意味する。0.7とかにすると狭くなってバンドの形が変わる、っていうのはDaii君の研究とも絡む。
    r...穴の半径。ふつうはa/4くらい。meepだと格子定数は1で固定だから、格子定数との比を入力すればOK
    n_eff...屈折率。2次元だと2.5~2.7くらいにしておくと3次元のSi系(n_Si=3.48)と結果が近くなる。違う材料を使うときは要調整、通常はdefaultで大丈夫。
    fcen...入力光（ガウシアンビーム）の中心周波数。知りたいPhCバンドの周波数近くに設定する
    df...入力光（ガウシアンビーム）の半値幅（で合ってる？）
    nfreq...入力光（ガウシアンビーム）のきめ細かさ
    resolution...メッシュの細かさ。2^nにすると計算が軽くなるらしい。
    T_dacay...反復計算数。小さいと誤差が増え、大きいと時間がかかる。sim.run(until_after_sources=...)で計算時間を見積もってから変えるとよさそう
    decay_check...解の収束をどこで判定するか、位置を指定。defaultでOK

    <備考>
    ・meepでは格子定数aはパラメータに含まれないので設定不要
    　誘電体を使うときは入力するらしい（スケール依存性が出るから）
    ・THzやnmは使用せず、すべて規格化周波数で入力する (周波数はωa/2πcで直す)
    """
    ##### setting of parameters #####
    a = 1 # CADに移行しやすいように予め設定しておく
    widthPhC = 10
    ConnectionWaveguide = 5
    wgi = 1/2 #/np.sqrt(3)/2
    whetero = 1/np.sqrt(3)/4
    r = 1/4
    d_0 = 0.85*a
    yshift = -np.sqrt(3)/4*a #1/(np.sqrt(3)) #+ 1/6*np.sqrt(3)/2*d_0

    #n_eff = 2.6

    eps_A_r = 2.6**2
    eps_A_i = 0.1
    eps_B_r, eps_B_i = eps_to_eps(eps_A_r,eps_A_i)

    fcen = 0.305
    df = 0.02
    nfreq = 500 # number of frequencies at which to compute flux
    resolution = 32

    connect = 0
    #####
    length = lengthPhC + 2*ConnectionWaveguide
    width = widthPhC
    Nx = int(lengthPhC)
    Ny = int(widthPhC)

    # settings of imaginary part
    normalized_frequency = 0.305
    #extinction_coefficient = 0.2

    ##### settings of geometry #####
    # initialization
    cell = mp.Vector3(length,width*np.sqrt(3),0)

    # Si waveguide
    waveguide = mp.Block(mp.Vector3(mp.inf,wgi*np.sqrt(3),mp.inf),
                            center=mp.Vector3(),
                            material=mp.Medium(epsilon=eps_B_r))
    geometry = [waveguide]

    # PhC
    if PhC:
        # triangle
        tri_u = [
                mp.Vector3(-np.sqrt(3)/2,-1/2)*d_0/np.sqrt(3),
                mp.Vector3( np.sqrt(3)/2,-1/2)*d_0/np.sqrt(3),
                mp.Vector3(            0,   1)*d_0/np.sqrt(3),
                ]
        tri_d = [
                mp.Vector3(-np.sqrt(3)/2,-1/2)*d_0/np.sqrt(3)*(-1),
                mp.Vector3( np.sqrt(3)/2,-1/2)*d_0/np.sqrt(3)*(-1),
                mp.Vector3(            0,   1)*d_0/np.sqrt(3)*(-1),
                ]

        # slab
        blk_above = mp.Block(mp.Vector3(lengthPhC,widthPhC*np.sqrt(3),mp.inf),
                                center=mp.Vector3(0, widthPhC*np.sqrt(3)/2 + 0*(yshift + 1/(2*np.sqrt(3))), 0),
                                material=mp.Medium(epsilon=eps_B_r, D_conductivity=0*2*np.pi*normalized_frequency*eps_B_i / eps_B_r))
        geometry.append(blk_above)
        blk_below = mp.Block(mp.Vector3(lengthPhC,widthPhC*np.sqrt(3),mp.inf),
                                center=mp.Vector3(0,-widthPhC*np.sqrt(3)/2 + 0*(yshift + 1/(2*np.sqrt(3))), 0),
                                material=mp.Medium(epsilon=eps_A_r, D_conductivity=2*np.pi*normalized_frequency*eps_A_i / eps_A_r))
        geometry.append(blk_below)
        
        # arrange air-holes
        for j in range(Ny):
            for i in range(Nx+1):
                shift_y = np.sqrt(3)
                geometry.append(mp.Prism(tri_d, height = 1, center=mp.Vector3(i-(Nx+1)/2, yshift + 1/(np.sqrt(3)) + shift_y*(j+1/2))))                
                geometry.append(mp.Prism(tri_u, height = 1, center=mp.Vector3(i-(Nx+1)/2, yshift -(1/(np.sqrt(3)) + shift_y*(j+1/2)))))            
                geometry.append(mp.Prism(tri_d, height = 1, center=mp.Vector3(i-Nx/2, yshift +  1/(np.sqrt(3)) + shift_y*j )))

            if j == 0:
                for i in range(connect,Nx+1-connect):
                    geometry.append(mp.Prism(tri_u, height = 1, center=mp.Vector3(i-Nx/2, yshift - (1/(np.sqrt(3)) + shift_y*j))))
            else:
                for i in range(Nx+1):
                    geometry.append(mp.Prism(tri_u, height = 1, center=mp.Vector3(i-Nx/2, yshift - (1/(np.sqrt(3)) + shift_y*j))))
                    
        for i in range(1,Nx+1):
            geometry.append(mp.Prism(tri_u, height = 1, center=mp.Vector3(i-(Nx+1)/2, yshift - (1/(np.sqrt(3)) + shift_y*(-1/2)))))
        #geometry.append(mp.Prism(tri_d, height = 1, center=mp.Vector3(1, 0)))


                #geometry.append(mp.Cylinder(r, center=mp.Vector3(i-N/2,-wgi*np.sqrt(3)/2)))

    # Gaussian
    sources = [mp.Source(mp.GaussianSource(fcen, fwidth=df),
                            component=mp.Hz,
                            center=mp.Vector3(-length/2 +1,0),
                            size=mp.Vector3(0,wgi*np.sqrt(3)))
                ]

    # PML
    pml_layers = [mp.PML(1.0)]

    # z-symmetry (上下対称なら計算が軽くなる。対称性が無いなら消す)
    #sym = [mp.Mirror(mp.Y, phase=-1)]
    

    ####
    sim = mp.Simulation(cell_size=cell,
                        boundary_layers=pml_layers,
                        geometry=geometry,
                        sources=sources,
                        #symmetries=sym,
                        resolution=resolution)

    #tran_in = mp.FluxRegion(center=mp.Vector3(-lengthPhC/2-1,0),size=mp.Vector3(0, 2*wgi))
    tran_out = mp.FluxRegion(center=mp.Vector3(length/2-3/2,0),size=mp.Vector3(0, 2*wgi))
    #trans_in = sim.add_flux(fcen, df, nfreq, tran_in)
    trans_out = sim.add_flux(fcen, df, nfreq, tran_out)

    # show geometry
    # %matplotlib inline
    f = plt.figure(dpi=500, figsize=(8,16))
    sim.plot2D(ax=f.gca())
    plt.show()    

    #sim.run(until_after_sources=mp.stop_when_fields_decayed(50, mp.Hz, mp.Vector3(decay_check), 1e-3))
    sim.run(until=T_decay)

    freqs = mp.get_flux_freqs(trans_out)
    #psd_in = mp.get_fluxes(trans_in)
    psd_out = mp.get_fluxes(trans_out)

    return freqs, psd_out

# %%
freqs_wo, psd_out_wo = phc_trans(PhC = False, lengthPhC = 20, decay_check=10, T_decay=500)
freqs_w,  psd_out_w  = phc_trans(PhC = True, lengthPhC = 50, decay_check=20, T_decay=10000)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00101614 s
# Working in 2D dimensions.
# Computational cell is 30 x 17.3125 x 0 with resolution 32
#      block, center = (0,0,0)
#           size (1e+20,0.866025,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (6.76148,6.76148,6.76148)
# time for set_epsilon = 0.749135 s
# -----------
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# FloatProgress(value=0.0, description='0% done ', max=500.0)
# Meep progress: 10.40625/500.0 = 2.1% done in 4.0s, 188.2s to go
# on time step 668 (time=10.4375), 0.00598906 s/step
# Meep progress: 21.40625/500.0 = 4.3% done in 8.0s, 179.1s to go
# on time step 1370 (time=21.4062), 0.00569843 s/step
# Meep progress: 33.359375/500.0 = 6.7% done in 12.0s, 168.0s to go
# on time step 2135 (time=33.3594), 0.0052305 s/step
# Meep progress: 45.375/500.0 = 9.1% done in 16.0s, 160.5s to go
# on time step 2904 (time=45.375), 0.00520457 s/step
# Meep progress: 58.5/500.0 = 11.7% done in 20.0s, 151.1s to go
# on time step 3744 (time=58.5), 0.00476288 s/step
# Meep progress: 69.921875/500.0 = 14.0% done in 24.0s, 147.8s to go
# on time step 4475 (time=69.9219), 0.00547698 s/step
# Meep progress: 80.75/500.0 = 16.1% done in 28.0s, 145.5s to go
# on time step 5168 (time=80.75), 0.00577375 s/step
# Meep progress: 94.296875/500.0 = 18.9% done in 32.0s, 137.8s to go
# on time step 6035 (time=94.2969), 0.0046151 s/step
# Meep progress: 107.609375/500.0 = 21.5% done in 36.0s, 131.4s to go
# on time step 6887 (time=107.609), 0.00469754 s/step
# Meep progress: 118.203125/500.0 = 23.6% done in 40.0s, 129.3s to go
# on time step 7565 (time=118.203), 0.00590964 s/step
# Meep progress: 122.984375/500.0 = 24.6% done in 44.0s, 135.0s to go
# on time step 7871 (time=122.984), 0.0131065 s/step
# Meep progress: 126.515625/500.0 = 25.3% done in 48.1s, 141.9s to go
# on time step 8097 (time=126.516), 0.0177359 s/step
# Meep progress: 130.03125/500.0 = 26.0% done in 52.1s, 148.1s to go
# on time step 8322 (time=130.031), 0.0177823 s/step
# Meep progress: 134.390625/500.0 = 26.9% done in 56.1s, 152.5s to go
# on time step 8602 (time=134.406), 0.0143029 s/step
# Meep progress: 140.359375/500.0 = 28.1% done in 60.1s, 153.9s to go
# on time step 8985 (time=140.391), 0.0104549 s/step
# Meep progress: 152.765625/500.0 = 30.6% done in 64.1s, 145.7s to go
# on time step 9778 (time=152.781), 0.00505356 s/step
# Meep progress: 166.328125/500.0 = 33.3% done in 68.1s, 136.6s to go
# on time step 10647 (time=166.359), 0.00460337 s/step
# Meep progress: 179.53125/500.0 = 35.9% done in 72.1s, 128.7s to go
# on time step 11492 (time=179.562), 0.00473481 s/step
# Meep progress: 193.171875/500.0 = 38.6% done in 76.1s, 120.9s to go
# on time step 12365 (time=193.203), 0.00458279 s/step
# Meep progress: 207.421875/500.0 = 41.5% done in 80.1s, 113.0s to go
# on time step 13277 (time=207.453), 0.00438688 s/step
# Meep progress: 219.046875/500.0 = 43.8% done in 84.1s, 107.9s to go
# on time step 14022 (time=219.094), 0.00537504 s/step
# Meep progress: 232.671875/500.0 = 46.5% done in 88.1s, 101.2s to go
# on time step 14893 (time=232.703), 0.0046033 s/step
# Meep progress: 245.40625/500.0 = 49.1% done in 92.1s, 95.5s to go
# on time step 15711 (time=245.484), 0.00489016 s/step
# Meep progress: 258.03125/500.0 = 51.6% done in 96.1s, 90.1s to go
# on time step 16520 (time=258.125), 0.00494987 s/step
# Meep progress: 271.453125/500.0 = 54.3% done in 100.1s, 84.3s to go
# on time step 17379 (time=271.547), 0.004661 s/step
# Meep progress: 284.75/500.0 = 57.0% done in 104.1s, 78.7s to go
# on time step 18230 (time=284.844), 0.00470293 s/step
# Meep progress: 298.015625/500.0 = 59.6% done in 108.1s, 73.3s to go
# on time step 19079 (time=298.109), 0.00471283 s/step
# Meep progress: 311.34375/500.0 = 62.3% done in 112.1s, 67.9s to go
# on time step 19932 (time=311.438), 0.00469205 s/step
# Meep progress: 323.453125/500.0 = 64.7% done in 116.1s, 63.4s to go
# on time step 20707 (time=323.547), 0.00516254 s/step
# Meep progress: 335.390625/500.0 = 67.1% done in 120.1s, 58.9s to go
# on time step 21471 (time=335.484), 0.00523807 s/step
# Meep progress: 349.703125/500.0 = 69.9% done in 124.1s, 53.3s to go
# on time step 22388 (time=349.812), 0.00436562 s/step
# Meep progress: 364.28125/500.0 = 72.9% done in 128.1s, 47.7s to go
# on time step 23321 (time=364.391), 0.00429108 s/step
# Meep progress: 377.453125/500.0 = 75.5% done in 132.1s, 42.9s to go
# on time step 24164 (time=377.562), 0.00475015 s/step
# Meep progress: 391.953125/500.0 = 78.4% done in 136.1s, 37.5s to go
# on time step 25093 (time=392.078), 0.00430809 s/step
# Meep progress: 404.921875/500.0 = 81.0% done in 140.1s, 32.9s to go
# on time step 25923 (time=405.047), 0.00482227 s/step
# Meep progress: 418.546875/500.0 = 83.7% done in 144.1s, 28.0s to go
# on time step 26795 (time=418.672), 0.00458953 s/step
# Meep progress: 431.8125/500.0 = 86.4% done in 148.1s, 23.4s to go
# on time step 27643 (time=431.922), 0.00471734 s/step
# Meep progress: 443.78125/500.0 = 88.8% done in 152.1s, 19.3s to go
# on time step 28408 (time=443.875), 0.00523198 s/step
# Meep progress: 458.5/500.0 = 91.7% done in 156.1s, 14.1s to go
# on time step 29352 (time=458.625), 0.00423975 s/step
# Meep progress: 473.15625/500.0 = 94.6% done in 160.1s, 9.1s to go
# on time step 30287 (time=473.234), 0.00427873 s/step
# Meep progress: 486.140625/500.0 = 97.2% done in 164.1s, 4.7s to go
# on time step 31120 (time=486.25), 0.00480873 s/step
# Meep progress: 499.796875/500.0 = 100.0% done in 168.1s, 0.1s to go
# on time step 31996 (time=499.938), 0.00456859 s/step
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# run 0 finished at t = 500.0 (32000 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.101439 s
# Working in 2D dimensions.
# Computational cell is 60 x 17.3125 x 0 with resolution 32
#      block, center = (0,0,0)
#           size (1e+20,0.866025,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (6.76148,6.76148,6.76148)
#      block, center = (0,8.66025,0)
#           size (50,17.3205,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (6.76148,6.76148,6.76148)
#      block, center = (0,-8.66025,0)
#           size (50,17.3205,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (6.76,6.76,6.76)
#      prism, center = (-25.5,1.01036,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-25.075,1.25574,-0.5)
#           (-25.925,1.25574,-0.5)
#           (-25.5,0.519615,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      prism, center = (-25.5,-1.87639,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-25.925,-2.12176,-0.5)
#           (-25.075,-2.12176,-0.5)
#           (-25.5,-1.38564,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      prism, center = (-25,0.144338,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-24.575,0.389711,-0.5)
#           (-25.425,0.389711,-0.5)
#           (-25,-0.34641,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      prism, center = (-24.5,1.01036,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-24.075,1.25574,-0.5)
#           (-24.925,1.25574,-0.5)
#           (-24.5,0.519615,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      prism, center = (-24.5,-1.87639,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-24.925,-2.12176,-0.5)
#           (-24.075,-2.12176,-0.5)
#           (-24.5,-1.38564,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      prism, center = (-24,0.144338,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-23.575,0.389711,-0.5)
#           (-24.425,0.389711,-0.5)
#           (-24,-0.34641,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      prism, center = (-23.5,1.01036,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-23.075,1.25574,-0.5)
#           (-23.925,1.25574,-0.5)
#           (-23.5,0.519615,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      ...(+ 2083 objects not shown)...
# subpixel-averaging is 42.884% done, 5.33001 s remaining
# subpixel-averaging is 81.4688% done, 0.912331 s remaining
# subpixel-averaging is 43.1045% done, 5.28816 s remaining
# subpixel-averaging is 82.3507% done, 0.858532 s remaining
# subpixel-averaging is 46.1913% done, 4.66892 s remaining
# subpixel-averaging is 85.8784% done, 0.658306 s remaining
# time for set_epsilon = 31.7021 s
# time for set_conductivity = 0.505158 s
# time for set_conductivity = 0.507519 s
# time for set_conductivity = 0.512636 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=10000.0)
# 29.2s, 451.9s to go
# on time step 615124 (time=9611.31), 0.0288786 s/step
# Meep progress: 9612.0625/10000.0 = 96.1% done in 11133.2s, 449.3s to go
# on time step 615293 (time=9613.95), 0.0237934 s/step
# Meep progress: 9614.6875/10000.0 = 96.1% done in 11137.3s, 446.3s to go
# on time step 615459 (time=9616.55), 0.0241545 s/step
# Meep progress: 9617.34375/10000.0 = 96.2% done in 11141.3s, 443.3s to go
# on time step 615637 (time=9619.33), 0.0225798 s/step
# Meep progress: 9619.984375/10000.0 = 96.2% done in 11145.3s, 440.3s to go
# on time step 615803 (time=9621.92), 0.0241236 s/step
# Meep progress: 9622.609375/10000.0 = 96.2% done in 11149.3s, 437.3s to go
# on time step 615968 (time=9624.5), 0.0243001 s/step
# Meep progress: 9624.953125/10000.0 = 96.2% done in 11153.3s, 434.6s to go
# on time step 616083 (time=9626.3), 0.0348475 s/step
# Meep progress: 9626.96875/10000.0 = 96.3% done in 11157.3s, 432.3s to go
# on time step 616232 (time=9628.62), 0.0268582 s/step
# Meep progress: 9629.328125/10000.0 = 96.3% done in 11161.4s, 429.6s to go
# on time step 616382 (time=9630.97), 0.0267725 s/step
# Meep progress: 9631.6875/10000.0 = 96.3% done in 11165.4s, 427.0s to go
# on time step 616541 (time=9633.45), 0.0252503 s/step
# Meep progress: 9634.171875/10000.0 = 96.3% done in 11169.4s, 424.1s to go
# on time step 616694 (time=9635.84), 0.026214 s/step
# Meep progress: 9636.53125/10000.0 = 96.4% done in 11173.4s, 421.4s to go
# on time step 616840 (time=9638.12), 0.0274442 s/step
# Meep progress: 9638.859375/10000.0 = 96.4% done in 11177.4s, 418.8s to go
# on time step 616978 (time=9640.28), 0.0290114 s/step
# Meep progress: 9640.875/10000.0 = 96.4% done in 11181.4s, 416.5s to go
# on time step 617131 (time=9642.67), 0.0262168 s/step
# Meep progress: 9643.5/10000.0 = 96.4% done in 11185.4s, 413.5s to go
# on time step 617286 (time=9645.09), 0.0259369 s/step
# Meep progress: 9645.921875/10000.0 = 96.5% done in 11189.5s, 410.7s to go
# on time step 617458 (time=9647.78), 0.0232753 s/step
# Meep progress: 9648.578125/10000.0 = 96.5% done in 11193.5s, 407.7s to go
# on time step 617634 (time=9650.53), 0.0228403 s/step
# Meep progress: 9651.34375/10000.0 = 96.5% done in 11197.5s, 404.5s to go
# on time step 617812 (time=9653.31), 0.0225755 s/step
# Meep progress: 9654.125/10000.0 = 96.5% done in 11201.5s, 401.3s to go
# on time step 617989 (time=9656.08), 0.0226071 s/step
# Meep progress: 9656.890625/10000.0 = 96.6% done in 11205.5s, 398.1s to go
# on time step 618165 (time=9658.83), 0.0227842 s/step
# Meep progress: 9659.640625/10000.0 = 96.6% done in 11209.5s, 395.0s to go
# on time step 618344 (time=9661.62), 0.0224658 s/step
# Meep progress: 9662.453125/10000.0 = 96.6% done in 11213.5s, 391.7s to go
# on time step 618513 (time=9664.27), 0.0237342 s/step
# Meep progress: 9665.0/10000.0 = 96.7% done in 11217.5s, 388.8s to go
# on time step 618660 (time=9666.56), 0.0272994 s/step
# Meep progress: 9667.28125/10000.0 = 96.7% done in 11221.6s, 386.2s to go
# on time step 618826 (time=9669.16), 0.0241911 s/step
# Meep progress: 9669.859375/10000.0 = 96.7% done in 11225.6s, 383.3s to go
# on time step 618971 (time=9671.42), 0.0276945 s/step
# Meep progress: 9672.203125/10000.0 = 96.7% done in 11229.6s, 380.6s to go
# on time step 619147 (time=9674.17), 0.0227573 s/step
# Meep progress: 9674.96875/10000.0 = 96.7% done in 11233.6s, 377.4s to go
# on time step 619321 (time=9676.89), 0.0230164 s/step
# Meep progress: 9677.6875/10000.0 = 96.8% done in 11237.6s, 374.3s to go
# on time step 619495 (time=9679.61), 0.0230079 s/step
# Meep progress: 9680.40625/10000.0 = 96.8% done in 11241.6s, 371.1s to go
# on time step 619650 (time=9682.03), 0.0258121 s/step
# Meep progress: 9682.75/10000.0 = 96.8% done in 11245.6s, 368.5s to go
# on time step 619808 (time=9684.5), 0.0254441 s/step
# Meep progress: 9684.890625/10000.0 = 96.8% done in 11249.6s, 366.0s to go
# on time step 619931 (time=9686.42), 0.0327155 s/step
# Meep progress: 9687.125/10000.0 = 96.9% done in 11253.6s, 363.5s to go
# on time step 620085 (time=9688.83), 0.0260554 s/step
# Meep progress: 9689.609375/10000.0 = 96.9% done in 11257.7s, 360.6s to go
# on time step 620258 (time=9691.53), 0.0231579 s/step
# Meep progress: 9692.25/10000.0 = 96.9% done in 11261.7s, 357.6s to go
# on time step 620431 (time=9694.23), 0.0231885 s/step
# Meep progress: 9695.0/10000.0 = 97.0% done in 11265.7s, 354.4s to go
# on time step 620603 (time=9696.92), 0.0232934 s/step
# Meep progress: 9697.71875/10000.0 = 97.0% done in 11269.7s, 351.3s to go
# on time step 620774 (time=9699.59), 0.0234703 s/step
# Meep progress: 9700.25/10000.0 = 97.0% done in 11273.7s, 348.4s to go
# on time step 620933 (time=9702.08), 0.0251769 s/step
# Meep progress: 9702.875/10000.0 = 97.0% done in 11277.7s, 345.3s to go
# on time step 621097 (time=9704.64), 0.0244984 s/step
# Meep progress: 9705.390625/10000.0 = 97.1% done in 11281.7s, 342.5s to go
# on time step 621263 (time=9707.23), 0.0241008 s/step
# Meep progress: 9708.03125/10000.0 = 97.1% done in 11285.7s, 339.4s to go
# on time step 621422 (time=9709.72), 0.0252447 s/step
# Meep progress: 9710.1875/10000.0 = 97.1% done in 11289.7s, 337.0s to go
# on time step 621530 (time=9711.41), 0.0372157 s/step
# Meep progress: 9711.984375/10000.0 = 97.1% done in 11293.8s, 334.9s to go
# on time step 621661 (time=9713.45), 0.030607 s/step
# Meep progress: 9714.25/10000.0 = 97.1% done in 11297.8s, 332.3s to go
# on time step 621836 (time=9716.19), 0.0228927 s/step
# Meep progress: 9716.9375/10000.0 = 97.2% done in 11301.8s, 329.2s to go
# on time step 621971 (time=9718.3), 0.0296502 s/step
# Meep progress: 9718.796875/10000.0 = 97.2% done in 11305.8s, 327.1s to go
# on time step 622086 (time=9720.09), 0.0348759 s/step
# Meep progress: 9720.796875/10000.0 = 97.2% done in 11309.9s, 324.8s to go
# on time step 622241 (time=9722.52), 0.0258363 s/step
# Meep progress: 9723.28125/10000.0 = 97.2% done in 11313.9s, 322.0s to go
# on time step 622411 (time=9725.17), 0.023565 s/step
# Meep progress: 9725.953125/10000.0 = 97.3% done in 11317.9s, 318.9s to go
# on time step 622585 (time=9727.89), 0.0230219 s/step
# Meep progress: 9728.75/10000.0 = 97.3% done in 11321.9s, 315.7s to go
# on time step 622764 (time=9730.69), 0.0224542 s/step
# Meep progress: 9731.53125/10000.0 = 97.3% done in 11325.9s, 312.5s to go
# on time step 622935 (time=9733.36), 0.0234688 s/step
# Meep progress: 9734.125/10000.0 = 97.3% done in 11329.9s, 309.5s to go
# on time step 623103 (time=9735.98), 0.023851 s/step
# Meep progress: 9736.828125/10000.0 = 97.4% done in 11333.9s, 306.3s to go
# on time step 623265 (time=9738.52), 0.0247494 s/step
# Meep progress: 9739.328125/10000.0 = 97.4% done in 11337.9s, 303.5s to go
# on time step 623441 (time=9741.27), 0.0227443 s/step
# Meep progress: 9742.109375/10000.0 = 97.4% done in 11341.9s, 300.2s to go
# on time step 623619 (time=9744.05), 0.0225947 s/step
# Meep progress: 9744.890625/10000.0 = 97.4% done in 11345.9s, 297.0s to go
# on time step 623797 (time=9746.83), 0.0225348 s/step
# Meep progress: 9747.671875/10000.0 = 97.5% done in 11350.0s, 293.8s to go
# on time step 623976 (time=9749.62), 0.0224338 s/step
# Meep progress: 9750.46875/10000.0 = 97.5% done in 11354.0s, 290.6s to go
# on time step 624155 (time=9752.42), 0.0224239 s/step
# Meep progress: 9753.109375/10000.0 = 97.5% done in 11358.0s, 287.5s to go
# on time step 624290 (time=9754.53), 0.0296653 s/step
# Meep progress: 9755.140625/10000.0 = 97.6% done in 11362.0s, 285.2s to go
# on time step 624438 (time=9756.84), 0.0271361 s/step
# Meep progress: 9757.546875/10000.0 = 97.6% done in 11366.0s, 282.4s to go
# on time step 624599 (time=9759.36), 0.0249445 s/step
# Meep progress: 9759.984375/10000.0 = 97.6% done in 11370.0s, 279.6s to go
# on time step 624744 (time=9761.62), 0.0276435 s/step
# Meep progress: 9762.359375/10000.0 = 97.6% done in 11374.1s, 276.9s to go
# on time step 624898 (time=9764.03), 0.0259974 s/step
# Meep progress: 9764.8125/10000.0 = 97.6% done in 11378.1s, 274.0s to go
# on time step 625045 (time=9766.33), 0.0274033 s/step
# Meep progress: 9766.65625/10000.0 = 97.7% done in 11382.1s, 271.9s to go
# on time step 625112 (time=9767.38), 0.0599262 s/step
# Meep progress: 9767.78125/10000.0 = 97.7% done in 11386.1s, 270.7s to go
# on time step 625221 (time=9769.08), 0.0370775 s/step
# Meep progress: 9769.625/10000.0 = 97.7% done in 11390.2s, 268.6s to go
# on time step 625300 (time=9770.31), 0.0514325 s/step
# Meep progress: 9770.640625/10000.0 = 97.7% done in 11394.2s, 267.5s to go
# on time step 625368 (time=9771.38), 0.0593959 s/step
# Meep progress: 9772.03125/10000.0 = 97.7% done in 11398.2s, 265.9s to go
# on time step 625521 (time=9773.77), 0.0261464 s/step
# Meep progress: 9774.421875/10000.0 = 97.7% done in 11402.2s, 263.1s to go
# on time step 625656 (time=9775.88), 0.0297271 s/step
# Meep progress: 9776.484375/10000.0 = 97.8% done in 11406.2s, 260.8s to go
# on time step 625804 (time=9778.19), 0.0271673 s/step
# Meep progress: 9778.859375/10000.0 = 97.8% done in 11410.2s, 258.0s to go
# on time step 625957 (time=9780.58), 0.026209 s/step
# Meep progress: 9781.203125/10000.0 = 97.8% done in 11414.2s, 255.3s to go
# on time step 626106 (time=9782.91), 0.0268736 s/step
# Meep progress: 9783.46875/10000.0 = 97.8% done in 11418.3s, 252.7s to go
# on time step 626243 (time=9785.05), 0.0292944 s/step
# Meep progress: 9785.78125/10000.0 = 97.9% done in 11422.3s, 250.0s to go
# on time step 626395 (time=9787.42), 0.0265375 s/step
# Meep progress: 9788.125/10000.0 = 97.9% done in 11426.3s, 247.3s to go
# on time step 626536 (time=9789.62), 0.0284806 s/step
# Meep progress: 9790.15625/10000.0 = 97.9% done in 11430.3s, 245.0s to go
# on time step 626656 (time=9791.5), 0.0334639 s/step
# Meep progress: 9792.09375/10000.0 = 97.9% done in 11434.3s, 242.8s to go
# on time step 626782 (time=9793.47), 0.0319602 s/step
# Meep progress: 9794.046875/10000.0 = 97.9% done in 11438.3s, 240.5s to go
# on time step 626912 (time=9795.5), 0.0308537 s/step
# Meep progress: 9795.96875/10000.0 = 98.0% done in 11442.4s, 238.3s to go
# on time step 627040 (time=9797.5), 0.0313566 s/step
# Meep progress: 9798.265625/10000.0 = 98.0% done in 11446.4s, 235.7s to go
# on time step 627215 (time=9800.23), 0.0229293 s/step
# Meep progress: 9800.953125/10000.0 = 98.0% done in 11450.4s, 232.5s to go
# on time step 627370 (time=9802.66), 0.0258163 s/step
# Meep progress: 9803.125/10000.0 = 98.0% done in 11454.4s, 230.0s to go
# on time step 627506 (time=9804.78), 0.0295581 s/step
# Meep progress: 9805.484375/10000.0 = 98.1% done in 11458.4s, 227.3s to go
# on time step 627670 (time=9807.34), 0.0244629 s/step
# Meep progress: 9807.921875/10000.0 = 98.1% done in 11462.5s, 224.5s to go
# on time step 627795 (time=9809.3), 0.0321296 s/step
# Meep progress: 9809.953125/10000.0 = 98.1% done in 11466.5s, 222.1s to go
# on time step 627951 (time=9811.73), 0.0257513 s/step
# Meep progress: 9812.453125/10000.0 = 98.1% done in 11470.5s, 219.2s to go
# on time step 628100 (time=9814.06), 0.026859 s/step
# Meep progress: 9814.78125/10000.0 = 98.1% done in 11474.6s, 216.5s to go
# on time step 628255 (time=9816.48), 0.0258601 s/step
# Meep progress: 9817.25/10000.0 = 98.2% done in 11478.6s, 213.7s to go
# on time step 628386 (time=9818.53), 0.0307801 s/step
# Meep progress: 9818.9375/10000.0 = 98.2% done in 11482.6s, 211.7s to go
# on time step 628506 (time=9820.41), 0.0333786 s/step
# Meep progress: 9821.0625/10000.0 = 98.2% done in 11486.6s, 209.3s to go
# on time step 628660 (time=9822.81), 0.0263021 s/step
# Meep progress: 9823.375/10000.0 = 98.2% done in 11490.7s, 206.6s to go
# on time step 628803 (time=9825.05), 0.0280524 s/step
# Meep progress: 9825.90625/10000.0 = 98.3% done in 11494.7s, 203.7s to go
# on time step 628930 (time=9827.03), 0.0315826 s/step
# Meep progress: 9827.609375/10000.0 = 98.3% done in 11498.7s, 201.7s to go
# on time step 629055 (time=9828.98), 0.0320191 s/step
# Meep progress: 9829.65625/10000.0 = 98.3% done in 11502.7s, 199.3s to go
# on time step 629204 (time=9831.31), 0.0269659 s/step
# Meep progress: 9832.0/10000.0 = 98.3% done in 11506.7s, 196.6s to go
# on time step 629357 (time=9833.7), 0.0262177 s/step
# Meep progress: 9834.375/10000.0 = 98.3% done in 11510.7s, 193.9s to go
# on time step 629516 (time=9836.19), 0.0252144 s/step
# Meep progress: 9836.984375/10000.0 = 98.4% done in 11514.8s, 190.8s to go
# on time step 629686 (time=9838.84), 0.0235661 s/step
# Meep progress: 9839.671875/10000.0 = 98.4% done in 11518.8s, 187.7s to go
# on time step 629859 (time=9841.55), 0.0232504 s/step
# Meep progress: 9842.34375/10000.0 = 98.4% done in 11522.8s, 184.6s to go
# on time step 630025 (time=9844.14), 0.0241942 s/step
# Meep progress: 9844.96875/10000.0 = 98.4% done in 11526.8s, 181.5s to go
# on time step 630196 (time=9846.81), 0.0234621 s/step
# Meep progress: 9847.640625/10000.0 = 98.5% done in 11530.8s, 178.4s to go
# on time step 630378 (time=9849.66), 0.0220159 s/step
# Meep progress: 9850.5/10000.0 = 98.5% done in 11534.8s, 175.1s to go
# on time step 630533 (time=9852.08), 0.0261287 s/step
# Meep progress: 9852.703125/10000.0 = 98.5% done in 11538.8s, 172.5s to go
# on time step 630679 (time=9854.36), 0.0276438 s/step
# Meep progress: 9855.03125/10000.0 = 98.6% done in 11542.8s, 169.8s to go
# on time step 630842 (time=9856.91), 0.0246659 s/step
# Meep progress: 9857.59375/10000.0 = 98.6% done in 11546.8s, 166.8s to go
# on time step 631006 (time=9859.47), 0.0245094 s/step
# Meep progress: 9860.25/10000.0 = 98.6% done in 11550.9s, 163.7s to go
# on time step 631173 (time=9862.08), 0.0240857 s/step
# Meep progress: 9862.546875/10000.0 = 98.6% done in 11554.9s, 161.0s to go
# on time step 631316 (time=9864.31), 0.027975 s/step
# Meep progress: 9865.125/10000.0 = 98.7% done in 11558.9s, 158.0s to go
# on time step 631487 (time=9866.98), 0.0234451 s/step
# Meep progress: 9867.75/10000.0 = 98.7% done in 11562.9s, 155.0s to go
# on time step 631664 (time=9869.75), 0.0226065 s/step
# Meep progress: 9870.5625/10000.0 = 98.7% done in 11566.9s, 151.7s to go
# on time step 631849 (time=9872.64), 0.0217344 s/step
# Meep progress: 9873.453125/10000.0 = 98.7% done in 11570.9s, 148.3s to go
# on time step 632016 (time=9875.25), 0.024 s/step
# Meep progress: 9875.875/10000.0 = 98.8% done in 11574.9s, 145.5s to go
# on time step 632154 (time=9877.41), 0.0292116 s/step
# Meep progress: 9877.90625/10000.0 = 98.8% done in 11578.9s, 143.1s to go
# on time step 632306 (time=9879.78), 0.0263448 s/step
# Meep progress: 9880.265625/10000.0 = 98.8% done in 11583.0s, 140.4s to go
# on time step 632434 (time=9881.78), 0.0313895 s/step
# Meep progress: 9882.390625/10000.0 = 98.8% done in 11587.0s, 137.9s to go
# on time step 632594 (time=9884.28), 0.0251031 s/step
# Meep progress: 9885.109375/10000.0 = 98.9% done in 11591.0s, 134.7s to go
# on time step 632776 (time=9887.12), 0.0220858 s/step
# Meep progress: 9887.71875/10000.0 = 98.9% done in 11595.0s, 131.7s to go
# on time step 632946 (time=9889.78), 0.0235725 s/step
# Meep progress: 9890.59375/10000.0 = 98.9% done in 11599.0s, 128.3s to go
# on time step 633136 (time=9892.75), 0.0211006 s/step
# Meep progress: 9893.546875/10000.0 = 98.9% done in 11603.0s, 124.8s to go
# on time step 633318 (time=9895.59), 0.022026 s/step
# Meep progress: 9896.328125/10000.0 = 99.0% done in 11607.0s, 121.6s to go
# on time step 633496 (time=9898.38), 0.0225432 s/step
# Meep progress: 9899.203125/10000.0 = 99.0% done in 11611.1s, 118.2s to go
# on time step 633675 (time=9901.17), 0.0224221 s/step
# Meep progress: 9901.921875/10000.0 = 99.0% done in 11615.1s, 115.0s to go
# on time step 633841 (time=9903.77), 0.0241405 s/step
# Meep progress: 9904.453125/10000.0 = 99.0% done in 11619.1s, 112.1s to go
# on time step 634008 (time=9906.38), 0.0239677 s/step
# Meep progress: 9907.1875/10000.0 = 99.1% done in 11623.1s, 108.9s to go
# on time step 634189 (time=9909.2), 0.0221885 s/step
# Meep progress: 9909.984375/10000.0 = 99.1% done in 11627.1s, 105.6s to go
# on time step 634372 (time=9912.06), 0.0220733 s/step
# Meep progress: 9912.828125/10000.0 = 99.1% done in 11631.1s, 102.3s to go
# on time step 634538 (time=9914.66), 0.0242209 s/step
# Meep progress: 9915.3125/10000.0 = 99.2% done in 11635.1s, 99.4s to go
# on time step 634694 (time=9917.09), 0.0257281 s/step
# Meep progress: 9917.765625/10000.0 = 99.2% done in 11639.1s, 96.5s to go
# on time step 634859 (time=9919.67), 0.0243057 s/step
# Meep progress: 9920.34375/10000.0 = 99.2% done in 11643.1s, 93.5s to go
# on time step 635032 (time=9922.38), 0.0232271 s/step
# Meep progress: 9923.109375/10000.0 = 99.2% done in 11647.2s, 90.2s to go
# on time step 635212 (time=9925.19), 0.0223443 s/step
# Meep progress: 9925.875/10000.0 = 99.3% done in 11651.2s, 87.0s to go
# on time step 635355 (time=9927.42), 0.027978 s/step
# Meep progress: 9928.125/10000.0 = 99.3% done in 11655.2s, 84.4s to go
# on time step 635530 (time=9930.16), 0.0228837 s/step
# Meep progress: 9930.875/10000.0 = 99.3% done in 11659.2s, 81.2s to go
# on time step 635688 (time=9932.62), 0.0253264 s/step
# Meep progress: 9933.359375/10000.0 = 99.3% done in 11663.2s, 78.2s to go
# on time step 635857 (time=9935.27), 0.023788 s/step
# Meep progress: 9936.0/10000.0 = 99.4% done in 11667.2s, 75.2s to go
# on time step 636030 (time=9937.97), 0.0231973 s/step
# Meep progress: 9938.703125/10000.0 = 99.4% done in 11671.2s, 72.0s to go
# on time step 636202 (time=9940.66), 0.0233516 s/step
# Meep progress: 9941.375/10000.0 = 99.4% done in 11675.2s, 68.8s to go
# on time step 636384 (time=9943.5), 0.022092 s/step
# Meep progress: 9944.25/10000.0 = 99.4% done in 11679.3s, 65.5s to go
# on time step 636564 (time=9946.31), 0.022296 s/step
# Meep progress: 9947.109375/10000.0 = 99.5% done in 11683.3s, 62.1s to go
# on time step 636753 (time=9949.27), 0.0212208 s/step
# Meep progress: 9949.96875/10000.0 = 99.5% done in 11687.3s, 58.8s to go
# on time step 636933 (time=9952.08), 0.02232 s/step
# Meep progress: 9952.8125/10000.0 = 99.5% done in 11691.3s, 55.4s to go
# on time step 637115 (time=9954.92), 0.0220893 s/step
# Meep progress: 9955.453125/10000.0 = 99.6% done in 11695.3s, 52.3s to go
# on time step 637262 (time=9957.22), 0.0273434 s/step
# Meep progress: 9957.65625/10000.0 = 99.6% done in 11699.3s, 49.7s to go
# on time step 637376 (time=9959), 0.0351399 s/step
# Meep progress: 9959.53125/10000.0 = 99.6% done in 11703.3s, 47.6s to go
# on time step 637523 (time=9961.3), 0.0272671 s/step
# Meep progress: 9961.953125/10000.0 = 99.6% done in 11707.3s, 44.7s to go
# on time step 637693 (time=9963.95), 0.0235903 s/step
# Meep progress: 9964.671875/10000.0 = 99.6% done in 11711.3s, 41.5s to go
# on time step 637873 (time=9966.77), 0.0222227 s/step
# Meep progress: 9967.5/10000.0 = 99.7% done in 11715.4s, 38.2s to go
# on time step 638051 (time=9969.55), 0.0225161 s/step
# Meep progress: 9970.25/10000.0 = 99.7% done in 11719.4s, 35.0s to go
# on time step 638226 (time=9972.28), 0.0229152 s/step
# Meep progress: 9972.953125/10000.0 = 99.7% done in 11723.4s, 31.8s to go
# on time step 638374 (time=9974.59), 0.0271102 s/step
# Meep progress: 9975.203125/10000.0 = 99.8% done in 11727.4s, 29.2s to go
# on time step 638535 (time=9977.11), 0.0249029 s/step
# Meep progress: 9977.84375/10000.0 = 99.8% done in 11731.4s, 26.1s to go
# on time step 638701 (time=9979.7), 0.0241593 s/step
# Meep progress: 9980.375/10000.0 = 99.8% done in 11735.4s, 23.1s to go
# on time step 638862 (time=9982.22), 0.0248497 s/step
# Meep progress: 9982.84375/10000.0 = 99.8% done in 11739.4s, 20.2s to go
# on time step 639016 (time=9984.62), 0.0260129 s/step
# Meep progress: 9985.28125/10000.0 = 99.9% done in 11743.4s, 17.3s to go
# on time step 639190 (time=9987.34), 0.0230697 s/step
# Meep progress: 9988.03125/10000.0 = 99.9% done in 11747.4s, 14.1s to go
# on time step 639345 (time=9989.77), 0.0258921 s/step
# Meep progress: 9990.390625/10000.0 = 99.9% done in 11751.4s, 11.3s to go
# on time step 639491 (time=9992.05), 0.0275271 s/step
# Meep progress: 9992.421875/10000.0 = 99.9% done in 11755.5s, 8.9s to go
# on time step 639608 (time=9993.88), 0.0342257 s/step
# Meep progress: 9994.296875/10000.0 = 99.9% done in 11759.5s, 6.7s to go
# on time step 639738 (time=9995.91), 0.0309713 s/step
# Meep progress: 9996.328125/10000.0 = 100.0% done in 11763.5s, 4.3s to go
# on time step 639853 (time=9997.7), 0.034919 s/step
# Meep progress: 9998.234375/10000.0 = 100.0% done in 11767.5s, 2.1s to go
# run 0 finished at t = 10000.0 (640000 timesteps)

# %%
plt.plot(freqs_wo,psd_out_wo)
plt.grid(True)

# %%
plt.plot(freqs_w,psd_out_w)
plt.grid(True)

# %%
plt.plot(np.array(freqs_w), np.array(psd_out_w)/np.array(psd_out_wo))
plt.xlabel("Frequency[c/a]")
plt.ylabel("Transmittance[c/a]")
plt.yscale('log')
plt.grid(True)
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
plt.plot(np.array(freqs_w), np.array(psd_out_w)/np.array(psd_out_wo))
plt.xlabel("Frequency[c/a]")
plt.ylabel("Transmittance[c/a]")
plt.yscale('log')
plt.grid(True)

# %%
a = 470
c_const = 299792458

freqs = a / np.array(freqs_w)
#freqs
plt.plot(freqs, np.array(psd_out_w)/np.array(psd_out_wo))
plt.scatter(freqs, np.array(psd_out_w)/np.array(psd_out_wo))
plt.xlabel("Frequency[c/a]")
plt.ylabel("Transmittance[c/a]")
#plt.xlim([0.28,0.30])
plt.yscale('log')
plt.grid(True)

# %%
freqs = a / np.array(freqs_w)
#freqs
plt.plot(freqs, np.array(psd_out_w)/np.array(psd_out_wo))
plt.scatter(freqs, np.array(psd_out_w)/np.array(psd_out_wo))
plt.xlabel("Frequency[c/a]")
plt.ylabel("Transmittance[c/a]")
plt.xlim([1450,1600])
plt.yscale('log')
plt.ylim([1e-4,1e-1])
plt.grid(True)

# %%
freqs = a / np.array(freqs_w)
#freqs
plt.plot(freqs, np.array(psd_out_w)/np.array(psd_out_wo))
plt.scatter(freqs, np.array(psd_out_w)/np.array(psd_out_wo))
plt.xlabel("Frequency[c/a]")
plt.ylabel("Transmittance[c/a]")
plt.xlim([1450,1600])
plt.yscale('log')
plt.ylim([1e-4,1e-2])
plt.grid(True)

# %%
df = pd.DataFrame()
df["wavelength"] = freqs
df["transmittance"] = np.array(psd_out_w)/np.array(psd_out_wo)
df.to_csv("210122_resolution16_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d085_km01_cor.ipynb")

# %%
df
# Out:
#        wavelength  transmittance
# 0     2350.000000       0.075326
# 1     2349.530000       0.075350
# 2     2349.060188       0.075379
# 3     2348.590564       0.075425
# 4     2348.121127       0.075477
# ...           ...            ...
# 4995  1175.470282       0.093933
# 4996  1175.352676       0.094882
# 4997  1175.235094       0.095807
# 4998  1175.117535       0.096707
# 4999  1175.000000       0.097589
#
# [5000 rows x 2 columns]
