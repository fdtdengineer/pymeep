# %% [markdown]
# https://github.com/NanoComp/meep/blob/master/python/examples/straight-waveguide.ipynb
#
# https://stackoverflow.com/questions/29454002/filenotfounderror-errno-2-no-such-file-or-directory-ffmpeg

# %%
import math
import meep as mp
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from matplotlib import rc
rc('text', usetex=False)
#plt.rcParams['font.family'] = 'Times New Roman'#使用するフォント
#plt.rcParams['mathtext.fontset'] = 'stix' # math fontの設定
plt.rcParams['font.family']= 'sans-serif'
plt.rcParams['font.sans-serif'] = ['Arial']
plt.rcParams["font.size"] = 15 # 全体のフォントサイズが変更されます。
plt.rcParams['xtick.direction'] = 'in'#x軸の目盛線が内向き('in')か外向き('out')か双方向か('inout')
plt.rcParams['ytick.direction'] = 'in'#y軸の目盛線が内向き('in')か外向き('out')か双方向か('inout')
# Out:
# Using MPI version 3.1, 1 processes

# %%
def eps_to_eps(eps_A_r,eps_A_i):
    eps_A = eps_A_r + 1.j*eps_A_i
    eps_Ainv = 1 / eps_A

    eps_Ainv_r = eps_Ainv.real
    eps_Ainv_i = -eps_Ainv.imag

    #print(eps_Ainv_r, eps_Ainv_i)

    eps_B_r = eps_A_r + 1/eps_Ainv_r * (eps_Ainv_i**2) / (eps_Ainv_r**2 + eps_Ainv_i**2)
    eps_B_i = 0

    eps_B = eps_B_r + 1.j*eps_B_i
    eps_Binv = 1 / eps_B

    eps_Binv_r = eps_Binv.real
    eps_Binv_i = -eps_Binv.imag

    #print(eps_Binv_r, eps_Binv_i)
    return eps_B_r, eps_B_i

# %%
def phc_trans(PhC = True, lengthPhC = 100, decay_check=0, T_decay=500):
    """
    <変数の説明>
    PhC...PhC(フォトニック決勝)を配置するかどうか。Falseで直線導波路
    lengthPhC...PhC導波方向の長さ
    widthPhC...PhC垂直方向の幅。PMLと被ってるので適当。
    ConnectionWaveguide...PhCに接続するSi導波路(棒の部分)の長さ
    wgi...導波路の幅を調整する。1で丸穴一個分空いてることを意味する。0.7とかにすると狭くなってバンドの形が変わる、っていうのはDaii君の研究とも絡む。
    r...穴の半径。ふつうはa/4くらい。meepだと格子定数は1で固定だから、格子定数との比を入力すればOK
    n_eff...屈折率。2次元だと2.5~2.7くらいにしておくと3次元のSi系(n_Si=3.48)と結果が近くなる。違う材料を使うときは要調整、通常はdefaultで大丈夫。
    fcen...入力光（ガウシアンビーム）の中心周波数。知りたいPhCバンドの周波数近くに設定する
    df...入力光（ガウシアンビーム）の半値幅（で合ってる？）
    nfreq...入力光（ガウシアンビーム）のきめ細かさ
    resolution...メッシュの細かさ。2^nにすると計算が軽くなるらしい。
    T_dacay...反復計算数。小さいと誤差が増え、大きいと時間がかかる。sim.run(until_after_sources=...)で計算時間を見積もってから変えるとよさそう
    decay_check...解の収束をどこで判定するか、位置を指定。defaultでOK

    <備考>
    ・meepでは格子定数aはパラメータに含まれないので設定不要
    　誘電体を使うときは入力するらしい（スケール依存性が出るから）
    ・THzやnmは使用せず、すべて規格化周波数で入力する (周波数はωa/2πcで直す)
    """
    ##### setting of parameters #####
    a = 1 # CADに移行しやすいように予め設定しておく
    widthPhC = 10
    ConnectionWaveguide = 5
    wgi = 1/2 #/np.sqrt(3)/2
    whetero = 1/np.sqrt(3)/4
    r = 1/4
    d_0 = 0.85*a
    yshift = -np.sqrt(3)/4*a #1/(np.sqrt(3)) #+ 1/6*np.sqrt(3)/2*d_0

    #n_eff = 2.6

    eps_A_r = 2.6**2
    eps_A_i = 0.1
    eps_B_r, eps_B_i = eps_to_eps(eps_A_r,eps_A_i)

    fcen = 0.305
    df = 0.02
    nfreq = 500 # number of frequencies at which to compute flux
    resolution = 16

    connect = 0
    #####
    length = lengthPhC + 2*ConnectionWaveguide
    width = widthPhC
    Nx = int(lengthPhC)
    Ny = int(widthPhC)

    # settings of imaginary part
    normalized_frequency = 0.305
    #extinction_coefficient = 0.2

    ##### settings of geometry #####
    # initialization
    cell = mp.Vector3(length,width*np.sqrt(3),0)

    # Si waveguide
    waveguide = mp.Block(mp.Vector3(mp.inf,wgi*np.sqrt(3),mp.inf),
                            center=mp.Vector3(),
                            material=mp.Medium(epsilon=eps_B_r))
    geometry = [waveguide]

    # PhC
    if PhC:
        # triangle
        tri_u = [
                mp.Vector3(-np.sqrt(3)/2,-1/2)*d_0/np.sqrt(3),
                mp.Vector3( np.sqrt(3)/2,-1/2)*d_0/np.sqrt(3),
                mp.Vector3(            0,   1)*d_0/np.sqrt(3),
                ]
        tri_d = [
                mp.Vector3(-np.sqrt(3)/2,-1/2)*d_0/np.sqrt(3)*(-1),
                mp.Vector3( np.sqrt(3)/2,-1/2)*d_0/np.sqrt(3)*(-1),
                mp.Vector3(            0,   1)*d_0/np.sqrt(3)*(-1),
                ]

        # slab
        blk_above = mp.Block(mp.Vector3(lengthPhC,widthPhC*np.sqrt(3),mp.inf),
                                center=mp.Vector3(0, widthPhC*np.sqrt(3)/2 + 0*(yshift + 1/(2*np.sqrt(3))), 0),
                                material=mp.Medium(epsilon=eps_B_r, D_conductivity=0*2*np.pi*normalized_frequency*eps_B_i / eps_B_r))
        geometry.append(blk_above)
        blk_below = mp.Block(mp.Vector3(lengthPhC,widthPhC*np.sqrt(3),mp.inf),
                                center=mp.Vector3(0,-widthPhC*np.sqrt(3)/2 + 0*(yshift + 1/(2*np.sqrt(3))), 0),
                                material=mp.Medium(epsilon=eps_A_r, D_conductivity=2*np.pi*normalized_frequency*eps_A_i / eps_A_r))
        geometry.append(blk_below)
        
        # arrange air-holes
        for j in range(Ny):
            for i in range(Nx+1):
                shift_y = np.sqrt(3)
                geometry.append(mp.Prism(tri_d, height = 1, center=mp.Vector3(i-(Nx+1)/2, yshift + 1/(np.sqrt(3)) + shift_y*(j+1/2))))                
                geometry.append(mp.Prism(tri_u, height = 1, center=mp.Vector3(i-(Nx+1)/2, yshift -(1/(np.sqrt(3)) + shift_y*(j+1/2)))))            
                geometry.append(mp.Prism(tri_d, height = 1, center=mp.Vector3(i-Nx/2, yshift +  1/(np.sqrt(3)) + shift_y*j )))

            if j == 0:
                for i in range(connect,Nx+1-connect):
                    geometry.append(mp.Prism(tri_u, height = 1, center=mp.Vector3(i-Nx/2, yshift - (1/(np.sqrt(3)) + shift_y*j))))
            else:
                for i in range(Nx+1):
                    geometry.append(mp.Prism(tri_u, height = 1, center=mp.Vector3(i-Nx/2, yshift - (1/(np.sqrt(3)) + shift_y*j))))
                    
        for i in range(1,Nx+1):
            geometry.append(mp.Prism(tri_u, height = 1, center=mp.Vector3(i-(Nx+1)/2, yshift - (1/(np.sqrt(3)) + shift_y*(-1/2)))))
        #geometry.append(mp.Prism(tri_d, height = 1, center=mp.Vector3(1, 0)))


                #geometry.append(mp.Cylinder(r, center=mp.Vector3(i-N/2,-wgi*np.sqrt(3)/2)))

    # Gaussian
    sources = [mp.Source(mp.GaussianSource(fcen, fwidth=df),
                            component=mp.Hz,
                            center=mp.Vector3(-length/2 +1,0),
                            size=mp.Vector3(0,wgi*np.sqrt(3)))
                ]

    # PML
    pml_layers = [mp.PML(1.0)]

    # z-symmetry (上下対称なら計算が軽くなる。対称性が無いなら消す)
    #sym = [mp.Mirror(mp.Y, phase=-1)]
    

    ####
    sim = mp.Simulation(cell_size=cell,
                        boundary_layers=pml_layers,
                        geometry=geometry,
                        sources=sources,
                        #symmetries=sym,
                        resolution=resolution)

    #tran_in = mp.FluxRegion(center=mp.Vector3(-lengthPhC/2-1,0),size=mp.Vector3(0, 2*wgi))
    tran_out = mp.FluxRegion(center=mp.Vector3(length/2-3/2,0),size=mp.Vector3(0, 2*wgi))
    #trans_in = sim.add_flux(fcen, df, nfreq, tran_in)
    trans_out = sim.add_flux(fcen, df, nfreq, tran_out)

    # show geometry
    # %matplotlib inline
    f = plt.figure(dpi=500, figsize=(8,16))
    sim.plot2D(ax=f.gca())
    plt.show()    

    #sim.run(until_after_sources=mp.stop_when_fields_decayed(50, mp.Hz, mp.Vector3(decay_check), 1e-3))
    sim.run(until=T_decay)

    freqs = mp.get_flux_freqs(trans_out)
    #psd_in = mp.get_fluxes(trans_in)
    psd_out = mp.get_fluxes(trans_out)

    return freqs, psd_out

# %%
freqs_wo, psd_out_wo = phc_trans(PhC = False, lengthPhC = 20, decay_check=10, T_decay=500)
freqs_w,  psd_out_w  = phc_trans(PhC = True, lengthPhC = 50, decay_check=20, T_decay=10000)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000193834 s
# Working in 2D dimensions.
# Computational cell is 30 x 17.3125 x 0 with resolution 16
#      block, center = (0,0,0)
#           size (1e+20,0.866025,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (6.76148,6.76148,6.76148)
# time for set_epsilon = 0.208614 s
# -----------
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# FloatProgress(value=0.0, description='0% done ', max=500.0)
# Meep progress: 119.0/500.0 = 23.8% done in 4.0s, 12.8s to go
# on time step 3812 (time=119.125), 0.00104937 s/step
# Meep progress: 240.75/500.0 = 48.1% done in 8.0s, 8.6s to go
# on time step 7709 (time=240.906), 0.00102675 s/step
# Meep progress: 353.84375/500.0 = 70.8% done in 12.0s, 5.0s to go
# on time step 11327 (time=353.969), 0.00110586 s/step
# Meep progress: 473.75/500.0 = 94.8% done in 16.0s, 0.9s to go
# on time step 15166 (time=473.938), 0.0010421 s/step
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# run 0 finished at t = 500.0 (16000 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.093143 s
# Working in 2D dimensions.
# Computational cell is 60 x 17.3125 x 0 with resolution 16
#      block, center = (0,0,0)
#           size (1e+20,0.866025,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (6.76148,6.76148,6.76148)
#      block, center = (0,8.66025,0)
#           size (50,17.3205,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (6.76148,6.76148,6.76148)
#      block, center = (0,-8.66025,0)
#           size (50,17.3205,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (6.76,6.76,6.76)
#      prism, center = (-25.5,1.01036,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-25.075,1.25574,-0.5)
#           (-25.925,1.25574,-0.5)
#           (-25.5,0.519615,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      prism, center = (-25.5,-1.87639,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-25.925,-2.12176,-0.5)
#           (-25.075,-2.12176,-0.5)
#           (-25.5,-1.38564,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      prism, center = (-25,0.144338,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-24.575,0.389711,-0.5)
#           (-25.425,0.389711,-0.5)
#           (-25,-0.34641,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      prism, center = (-24.5,1.01036,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-24.075,1.25574,-0.5)
#           (-24.925,1.25574,-0.5)
#           (-24.5,0.519615,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      prism, center = (-24.5,-1.87639,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-24.925,-2.12176,-0.5)
#           (-24.075,-2.12176,-0.5)
#           (-24.5,-1.38564,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      prism, center = (-24,0.144338,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-23.575,0.389711,-0.5)
#           (-24.425,0.389711,-0.5)
#           (-24,-0.34641,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      prism, center = (-23.5,1.01036,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-23.075,1.25574,-0.5)
#           (-23.925,1.25574,-0.5)
#           (-23.5,0.519615,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      ...(+ 2083 objects not shown)...
# subpixel-averaging is 84.8847% done, 0.712388 s remaining
# time for set_epsilon = 13.6488 s
# time for set_conductivity = 0.20231 s
# time for set_conductivity = 0.177607 s
# time for set_conductivity = 0.186746 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=10000.0)
# 387653 s/step
# Meep progress: 4358.0/10000.0 = 43.6% done in 544.3s, 704.6s to go
# on time step 139494 (time=4359.19), 0.00390348 s/step
# Meep progress: 4389.28125/10000.0 = 43.9% done in 548.3s, 700.8s to go
# on time step 140497 (time=4390.53), 0.00399343 s/step
# Meep progress: 4420.75/10000.0 = 44.2% done in 552.3s, 697.0s to go
# on time step 141507 (time=4422.09), 0.00396399 s/step
# Meep progress: 4452.75/10000.0 = 44.5% done in 556.3s, 693.0s to go
# on time step 142529 (time=4454.03), 0.00391407 s/step
# Meep progress: 4488.3125/10000.0 = 44.9% done in 560.3s, 688.0s to go
# on time step 143677 (time=4489.91), 0.00348692 s/step
# Meep progress: 4514.3125/10000.0 = 45.1% done in 564.3s, 685.7s to go
# on time step 144504 (time=4515.75), 0.00483835 s/step
# Meep progress: 4548.53125/10000.0 = 45.5% done in 568.3s, 681.1s to go
# on time step 145595 (time=4549.84), 0.00367224 s/step
# Meep progress: 4581.71875/10000.0 = 45.8% done in 572.3s, 676.8s to go
# on time step 146663 (time=4583.22), 0.00374621 s/step
# Meep progress: 4615.625/10000.0 = 46.2% done in 576.3s, 672.2s to go
# on time step 147749 (time=4617.16), 0.00368477 s/step
# Meep progress: 4648.96875/10000.0 = 46.5% done in 580.3s, 667.9s to go
# on time step 148818 (time=4650.56), 0.00374268 s/step
# Meep progress: 4683.90625/10000.0 = 46.8% done in 584.3s, 663.1s to go
# on time step 149938 (time=4685.56), 0.00357326 s/step
# Meep progress: 4719.75/10000.0 = 47.2% done in 588.3s, 658.1s to go
# on time step 151084 (time=4721.38), 0.00349177 s/step
# Meep progress: 4756.09375/10000.0 = 47.6% done in 592.3s, 653.0s to go
# on time step 152251 (time=4757.84), 0.00342937 s/step
# Meep progress: 4792.28125/10000.0 = 47.9% done in 596.3s, 648.0s to go
# on time step 153406 (time=4793.94), 0.00346627 s/step
# Meep progress: 4828.03125/10000.0 = 48.3% done in 600.3s, 643.0s to go
# on time step 154549 (time=4829.66), 0.0035 s/step
# Meep progress: 4863.78125/10000.0 = 48.6% done in 604.3s, 638.1s to go
# on time step 155692 (time=4865.38), 0.00350061 s/step
# Meep progress: 4898.5/10000.0 = 49.0% done in 608.3s, 633.5s to go
# on time step 156808 (time=4900.25), 0.00358634 s/step
# Meep progress: 4934.1875/10000.0 = 49.3% done in 612.3s, 628.6s to go
# on time step 157948 (time=4935.88), 0.0035088 s/step
# Meep progress: 4969.9375/10000.0 = 49.7% done in 616.3s, 623.7s to go
# on time step 159094 (time=4971.69), 0.0034916 s/step
# Meep progress: 5005.40625/10000.0 = 50.1% done in 620.3s, 618.9s to go
# on time step 160224 (time=5007), 0.00354149 s/step
# Meep progress: 5041.15625/10000.0 = 50.4% done in 624.3s, 614.1s to go
# on time step 161374 (time=5042.94), 0.00347886 s/step
# Meep progress: 5076.40625/10000.0 = 50.8% done in 628.3s, 609.4s to go
# on time step 162501 (time=5078.16), 0.00355261 s/step
# Meep progress: 5111.84375/10000.0 = 51.1% done in 632.3s, 604.6s to go
# on time step 163633 (time=5113.53), 0.00353499 s/step
# Meep progress: 5147.71875/10000.0 = 51.5% done in 636.3s, 599.8s to go
# on time step 164780 (time=5149.38), 0.00348984 s/step
# Meep progress: 5183.53125/10000.0 = 51.8% done in 640.3s, 595.0s to go
# on time step 165924 (time=5185.12), 0.0034989 s/step
# Meep progress: 5218.90625/10000.0 = 52.2% done in 644.3s, 590.2s to go
# on time step 167061 (time=5220.66), 0.00351965 s/step
# Meep progress: 5254.53125/10000.0 = 52.5% done in 648.3s, 585.5s to go
# on time step 168194 (time=5256.06), 0.00353605 s/step
# Meep progress: 5289.96875/10000.0 = 52.9% done in 652.3s, 580.8s to go
# on time step 169337 (time=5291.78), 0.00350105 s/step
# Meep progress: 5326.25/10000.0 = 53.3% done in 656.3s, 575.9s to go
# on time step 170493 (time=5327.91), 0.00346166 s/step
# Meep progress: 5362.3125/10000.0 = 53.6% done in 660.3s, 571.1s to go
# on time step 171652 (time=5364.12), 0.00345268 s/step
# Meep progress: 5398.125/10000.0 = 54.0% done in 664.3s, 566.3s to go
# on time step 172799 (time=5399.97), 0.00348902 s/step
# Meep progress: 5433.8125/10000.0 = 54.3% done in 668.3s, 561.6s to go
# on time step 173940 (time=5435.62), 0.00350708 s/step
# Meep progress: 5470.0/10000.0 = 54.7% done in 672.3s, 556.8s to go
# on time step 175098 (time=5471.81), 0.00345587 s/step
# Meep progress: 5505.875/10000.0 = 55.1% done in 676.3s, 552.0s to go
# on time step 176243 (time=5507.59), 0.0034955 s/step
# Meep progress: 5542.34375/10000.0 = 55.4% done in 680.3s, 547.2s to go
# on time step 177419 (time=5544.34), 0.00340325 s/step
# Meep progress: 5578.375/10000.0 = 55.8% done in 684.3s, 542.4s to go
# on time step 178572 (time=5580.38), 0.00346935 s/step
# Meep progress: 5613.875/10000.0 = 56.1% done in 688.3s, 537.8s to go
# on time step 179700 (time=5615.62), 0.00354641 s/step
# Meep progress: 5650.78125/10000.0 = 56.5% done in 692.3s, 532.9s to go
# on time step 180886 (time=5652.69), 0.00337381 s/step
# Meep progress: 5685.6875/10000.0 = 56.9% done in 696.3s, 528.4s to go
# on time step 181997 (time=5687.41), 0.00360212 s/step
# Meep progress: 5721.375/10000.0 = 57.2% done in 700.3s, 523.7s to go
# on time step 183140 (time=5723.12), 0.00350131 s/step
# Meep progress: 5757.25/10000.0 = 57.6% done in 704.3s, 519.0s to go
# on time step 184286 (time=5758.94), 0.00349187 s/step
# Meep progress: 5793.28125/10000.0 = 57.9% done in 708.3s, 514.3s to go
# on time step 185446 (time=5795.19), 0.00344865 s/step
# Meep progress: 5829.3125/10000.0 = 58.3% done in 712.3s, 509.6s to go
# on time step 186592 (time=5831), 0.0034906 s/step
# Meep progress: 5865.625/10000.0 = 58.7% done in 716.3s, 504.9s to go
# on time step 187760 (time=5867.5), 0.00342525 s/step
# Meep progress: 5901.15625/10000.0 = 59.0% done in 720.3s, 500.3s to go
# on time step 188893 (time=5902.91), 0.00353674 s/step
# Meep progress: 5936.15625/10000.0 = 59.4% done in 724.3s, 495.9s to go
# on time step 190021 (time=5938.16), 0.00354841 s/step
# Meep progress: 5971.34375/10000.0 = 59.7% done in 728.3s, 491.4s to go
# on time step 191141 (time=5973.16), 0.00357359 s/step
# Meep progress: 6006.78125/10000.0 = 60.1% done in 732.3s, 486.8s to go
# on time step 192280 (time=6008.75), 0.00351212 s/step
# Meep progress: 6042.84375/10000.0 = 60.4% done in 736.3s, 482.2s to go
# on time step 193432 (time=6044.75), 0.00347632 s/step
# Meep progress: 6078.5/10000.0 = 60.8% done in 740.3s, 477.6s to go
# on time step 194572 (time=6080.38), 0.00351019 s/step
# Meep progress: 6114.34375/10000.0 = 61.1% done in 744.3s, 473.0s to go
# on time step 195719 (time=6116.22), 0.00348829 s/step
# Meep progress: 6149.4375/10000.0 = 61.5% done in 748.3s, 468.6s to go
# on time step 196842 (time=6151.31), 0.00356408 s/step
# Meep progress: 6184.25/10000.0 = 61.8% done in 752.3s, 464.2s to go
# on time step 197962 (time=6186.31), 0.00357271 s/step
# Meep progress: 6219.71875/10000.0 = 62.2% done in 756.4s, 459.7s to go
# on time step 199089 (time=6221.53), 0.00355216 s/step
# Meep progress: 6253.71875/10000.0 = 62.5% done in 760.4s, 455.5s to go
# on time step 200182 (time=6255.69), 0.00366136 s/step
# Meep progress: 6286.90625/10000.0 = 62.9% done in 764.4s, 451.4s to go
# on time step 201241 (time=6288.78), 0.00377789 s/step
# Meep progress: 6320.625/10000.0 = 63.2% done in 768.4s, 447.3s to go
# on time step 202318 (time=6322.44), 0.00371531 s/step
# Meep progress: 6354.65625/10000.0 = 63.5% done in 772.4s, 443.1s to go
# on time step 203412 (time=6356.62), 0.00365654 s/step
# Meep progress: 6389.9375/10000.0 = 63.9% done in 776.4s, 438.6s to go
# on time step 204534 (time=6391.69), 0.0035666 s/step
# Meep progress: 6425.65625/10000.0 = 64.3% done in 780.4s, 434.1s to go
# on time step 205672 (time=6427.25), 0.00351663 s/step
# Meep progress: 6460.625/10000.0 = 64.6% done in 784.4s, 429.7s to go
# on time step 206796 (time=6462.38), 0.00355903 s/step
# Meep progress: 6496.21875/10000.0 = 65.0% done in 788.4s, 425.2s to go
# on time step 207943 (time=6498.22), 0.0034882 s/step
# Meep progress: 6531.53125/10000.0 = 65.3% done in 792.4s, 420.8s to go
# on time step 209064 (time=6533.25), 0.00356917 s/step
# Meep progress: 6566.375/10000.0 = 65.7% done in 796.4s, 416.4s to go
# on time step 210184 (time=6568.25), 0.0035729 s/step
# Meep progress: 6602.375/10000.0 = 66.0% done in 800.4s, 411.9s to go
# on time step 211335 (time=6604.22), 0.00347546 s/step
# Meep progress: 6638.09375/10000.0 = 66.4% done in 804.4s, 407.4s to go
# on time step 212486 (time=6640.19), 0.00347569 s/step
# Meep progress: 6673.46875/10000.0 = 66.7% done in 808.4s, 403.0s to go
# on time step 213611 (time=6675.34), 0.00355621 s/step
# Meep progress: 6709.5625/10000.0 = 67.1% done in 812.4s, 398.4s to go
# on time step 214761 (time=6711.28), 0.00348 s/step
# Meep progress: 6745.8125/10000.0 = 67.5% done in 816.4s, 393.8s to go
# on time step 215926 (time=6747.69), 0.00343504 s/step
# Meep progress: 6781.75/10000.0 = 67.8% done in 820.4s, 389.3s to go
# on time step 217081 (time=6783.78), 0.00346337 s/step
# Meep progress: 6817.59375/10000.0 = 68.2% done in 824.4s, 384.8s to go
# on time step 218226 (time=6819.56), 0.00349535 s/step
# Meep progress: 6853.40625/10000.0 = 68.5% done in 828.4s, 380.3s to go
# on time step 219370 (time=6855.31), 0.00349677 s/step
# Meep progress: 6889.8125/10000.0 = 68.9% done in 832.4s, 375.8s to go
# on time step 220533 (time=6891.66), 0.00343951 s/step
# Meep progress: 6925.8125/10000.0 = 69.3% done in 836.4s, 371.3s to go
# on time step 221686 (time=6927.69), 0.003471 s/step
# Meep progress: 6961.625/10000.0 = 69.6% done in 840.4s, 366.8s to go
# on time step 222831 (time=6963.47), 0.0034951 s/step
# Meep progress: 6996.71875/10000.0 = 70.0% done in 844.4s, 362.5s to go
# on time step 223962 (time=6998.81), 0.00353859 s/step
# Meep progress: 7032.4375/10000.0 = 70.3% done in 848.4s, 358.0s to go
# on time step 225100 (time=7034.38), 0.00351607 s/step
# Meep progress: 7068.75/10000.0 = 70.7% done in 852.4s, 353.5s to go
# on time step 226260 (time=7070.62), 0.00344869 s/step
# Meep progress: 7105.46875/10000.0 = 71.1% done in 856.4s, 348.9s to go
# on time step 227439 (time=7107.47), 0.0033933 s/step
# Meep progress: 7141.875/10000.0 = 71.4% done in 860.4s, 344.3s to go
# on time step 228602 (time=7143.81), 0.00344021 s/step
# Meep progress: 7176.375/10000.0 = 71.8% done in 864.4s, 340.1s to go
# on time step 229705 (time=7178.28), 0.0036271 s/step
# Meep progress: 7212.125/10000.0 = 72.1% done in 868.4s, 335.7s to go
# on time step 230853 (time=7214.16), 0.00348513 s/step
# Meep progress: 7248.09375/10000.0 = 72.5% done in 872.4s, 331.2s to go
# on time step 232002 (time=7250.06), 0.00348356 s/step
# Meep progress: 7283.625/10000.0 = 72.8% done in 876.4s, 326.9s to go
# on time step 233141 (time=7285.66), 0.00351421 s/step
# Meep progress: 7319.75/10000.0 = 73.2% done in 880.4s, 322.4s to go
# on time step 234294 (time=7321.69), 0.00347128 s/step
# Meep progress: 7354.40625/10000.0 = 73.5% done in 884.4s, 318.1s to go
# on time step 235402 (time=7356.31), 0.00361147 s/step
# Meep progress: 7387.84375/10000.0 = 73.9% done in 888.4s, 314.1s to go
# on time step 236468 (time=7389.62), 0.00375365 s/step
# Meep progress: 7423.6875/10000.0 = 74.2% done in 892.4s, 309.7s to go
# on time step 237623 (time=7425.72), 0.00346455 s/step
# Meep progress: 7458.09375/10000.0 = 74.6% done in 896.4s, 305.5s to go
# on time step 238720 (time=7460), 0.00364744 s/step
# Meep progress: 7491.375/10000.0 = 74.9% done in 900.4s, 301.5s to go
# on time step 239785 (time=7493.28), 0.00375776 s/step
# Meep progress: 7526.375/10000.0 = 75.3% done in 904.4s, 297.2s to go
# on time step 240908 (time=7528.38), 0.00356389 s/step
# Meep progress: 7561.25/10000.0 = 75.6% done in 908.4s, 293.0s to go
# on time step 242022 (time=7563.19), 0.00359205 s/step
# Meep progress: 7595.5/10000.0 = 76.0% done in 912.4s, 288.8s to go
# on time step 243117 (time=7597.41), 0.00365466 s/step
# Meep progress: 7629.46875/10000.0 = 76.3% done in 916.4s, 284.7s to go
# on time step 244206 (time=7631.44), 0.00367335 s/step
# Meep progress: 7664.03125/10000.0 = 76.6% done in 920.4s, 280.5s to go
# on time step 245315 (time=7666.09), 0.00360991 s/step
# Meep progress: 7698.0/10000.0 = 77.0% done in 924.4s, 276.4s to go
# on time step 246404 (time=7700.12), 0.00367421 s/step
# Meep progress: 7732.3125/10000.0 = 77.3% done in 928.4s, 272.3s to go
# on time step 247492 (time=7734.12), 0.00367708 s/step
# Meep progress: 7766.34375/10000.0 = 77.7% done in 932.4s, 268.2s to go
# on time step 248586 (time=7768.31), 0.00365942 s/step
# Meep progress: 7800.6875/10000.0 = 78.0% done in 936.4s, 264.0s to go
# on time step 249690 (time=7802.81), 0.00362628 s/step
# Meep progress: 7834.71875/10000.0 = 78.3% done in 940.4s, 259.9s to go
# on time step 250776 (time=7836.75), 0.00368494 s/step
# Meep progress: 7869.71875/10000.0 = 78.7% done in 944.4s, 255.7s to go
# on time step 251899 (time=7871.84), 0.00356235 s/step
# Meep progress: 7905.375/10000.0 = 79.1% done in 948.4s, 251.3s to go
# on time step 253039 (time=7907.47), 0.00351192 s/step
# Meep progress: 7941.25/10000.0 = 79.4% done in 952.4s, 246.9s to go
# on time step 254193 (time=7943.53), 0.003468 s/step
# Meep progress: 7976.6875/10000.0 = 79.8% done in 956.4s, 242.6s to go
# on time step 255325 (time=7978.91), 0.00353621 s/step
# Meep progress: 8012.5/10000.0 = 80.1% done in 960.4s, 238.2s to go
# on time step 256474 (time=8014.81), 0.00348344 s/step
# Meep progress: 8048.625/10000.0 = 80.5% done in 964.4s, 233.8s to go
# on time step 257626 (time=8050.81), 0.00347324 s/step
# Meep progress: 8084.1875/10000.0 = 80.8% done in 968.4s, 229.5s to go
# on time step 258757 (time=8086.16), 0.00353837 s/step
# Meep progress: 8119.625/10000.0 = 81.2% done in 972.5s, 225.2s to go
# on time step 259893 (time=8121.66), 0.00352328 s/step
# Meep progress: 8155.0625/10000.0 = 81.6% done in 976.5s, 220.9s to go
# on time step 261031 (time=8157.22), 0.00351807 s/step
# Meep progress: 8190.65625/10000.0 = 81.9% done in 980.5s, 216.6s to go
# on time step 262173 (time=8192.91), 0.00350425 s/step
# Meep progress: 8226.4375/10000.0 = 82.3% done in 984.5s, 212.2s to go
# on time step 263315 (time=8228.59), 0.00350463 s/step
# Meep progress: 8261.40625/10000.0 = 82.6% done in 988.5s, 208.0s to go
# on time step 264436 (time=8263.62), 0.00357089 s/step
# Meep progress: 8296.46875/10000.0 = 83.0% done in 992.5s, 203.8s to go
# on time step 265563 (time=8298.84), 0.00355189 s/step
# Meep progress: 8331.5625/10000.0 = 83.3% done in 996.5s, 199.5s to go
# on time step 266683 (time=8333.84), 0.00357418 s/step
# Meep progress: 8367.9375/10000.0 = 83.7% done in 1000.5s, 195.1s to go
# on time step 267851 (time=8370.34), 0.00342698 s/step
# Meep progress: 8403.65625/10000.0 = 84.0% done in 1004.5s, 190.8s to go
# on time step 268988 (time=8405.88), 0.00351861 s/step
# Meep progress: 8439.5625/10000.0 = 84.4% done in 1008.5s, 186.5s to go
# on time step 270145 (time=8442.03), 0.00345742 s/step
# Meep progress: 8476.09375/10000.0 = 84.8% done in 1012.5s, 182.0s to go
# on time step 271312 (time=8478.5), 0.00342886 s/step
# Meep progress: 8512.09375/10000.0 = 85.1% done in 1016.5s, 177.7s to go
# on time step 272460 (time=8514.38), 0.003485 s/step
# Meep progress: 8547.9375/10000.0 = 85.5% done in 1020.5s, 173.4s to go
# on time step 273604 (time=8550.12), 0.00349881 s/step
# Meep progress: 8582.8125/10000.0 = 85.8% done in 1024.5s, 169.2s to go
# on time step 274715 (time=8584.84), 0.0036034 s/step
# Meep progress: 8613.5625/10000.0 = 86.1% done in 1028.5s, 165.5s to go
# on time step 275699 (time=8615.59), 0.00406603 s/step
# Meep progress: 8649.1875/10000.0 = 86.5% done in 1032.5s, 161.3s to go
# on time step 276843 (time=8651.34), 0.00350243 s/step
# Meep progress: 8684.53125/10000.0 = 86.8% done in 1036.5s, 157.0s to go
# on time step 277978 (time=8686.81), 0.00352507 s/step
# Meep progress: 8720.71875/10000.0 = 87.2% done in 1040.5s, 152.6s to go
# on time step 279147 (time=8723.34), 0.00342393 s/step
# Meep progress: 8756.625/10000.0 = 87.6% done in 1044.5s, 148.3s to go
# on time step 280287 (time=8758.97), 0.00351114 s/step
# Meep progress: 8792.0625/10000.0 = 87.9% done in 1048.5s, 144.1s to go
# on time step 281427 (time=8794.59), 0.00351288 s/step
# Meep progress: 8828.65625/10000.0 = 88.3% done in 1052.5s, 139.6s to go
# on time step 282597 (time=8831.16), 0.0034191 s/step
# Meep progress: 8865.21875/10000.0 = 88.7% done in 1056.5s, 135.2s to go
# on time step 283769 (time=8867.78), 0.00341497 s/step
# Meep progress: 8899.53125/10000.0 = 89.0% done in 1060.5s, 131.1s to go
# on time step 284865 (time=8902.03), 0.00365079 s/step
# Meep progress: 8933.46875/10000.0 = 89.3% done in 1064.5s, 127.1s to go
# on time step 285949 (time=8935.91), 0.00369184 s/step
# Meep progress: 8967.0625/10000.0 = 89.7% done in 1068.5s, 123.1s to go
# on time step 287022 (time=8969.44), 0.00372939 s/step
# Meep progress: 9000.625/10000.0 = 90.0% done in 1072.5s, 119.1s to go
# on time step 288100 (time=9003.12), 0.0037126 s/step
# Meep progress: 9035.21875/10000.0 = 90.4% done in 1076.5s, 114.9s to go
# on time step 289210 (time=9037.81), 0.00360623 s/step
# Meep progress: 9069.59375/10000.0 = 90.7% done in 1080.5s, 110.8s to go
# on time step 290305 (time=9072.03), 0.0036561 s/step
# Meep progress: 9103.65625/10000.0 = 91.0% done in 1084.5s, 106.8s to go
# on time step 291396 (time=9106.12), 0.0036678 s/step
# Meep progress: 9138.125/10000.0 = 91.4% done in 1088.5s, 102.7s to go
# on time step 292496 (time=9140.5), 0.00363775 s/step
# Meep progress: 9169.84375/10000.0 = 91.7% done in 1092.5s, 98.9s to go
# on time step 293507 (time=9172.09), 0.00395986 s/step
# Meep progress: 9202.59375/10000.0 = 92.0% done in 1096.5s, 95.0s to go
# on time step 294569 (time=9205.28), 0.00376927 s/step
# Meep progress: 9238.25/10000.0 = 92.4% done in 1100.5s, 90.7s to go
# on time step 295709 (time=9240.91), 0.00350995 s/step
# Meep progress: 9273.65625/10000.0 = 92.7% done in 1104.5s, 86.5s to go
# on time step 296847 (time=9276.47), 0.00351617 s/step
# Meep progress: 9310.21875/10000.0 = 93.1% done in 1108.5s, 82.1s to go
# on time step 298007 (time=9312.72), 0.00344866 s/step
# Meep progress: 9346.25/10000.0 = 93.5% done in 1112.5s, 77.8s to go
# on time step 299169 (time=9349.03), 0.00344492 s/step
# Meep progress: 9381.8125/10000.0 = 93.8% done in 1116.5s, 73.6s to go
# on time step 300290 (time=9384.06), 0.00356872 s/step
# Meep progress: 9415.03125/10000.0 = 94.2% done in 1120.5s, 69.6s to go
# on time step 301367 (time=9417.72), 0.00371534 s/step
# Meep progress: 9451.4375/10000.0 = 94.5% done in 1124.5s, 65.3s to go
# on time step 302522 (time=9453.81), 0.00346324 s/step
# Meep progress: 9487.40625/10000.0 = 94.9% done in 1128.5s, 61.0s to go
# on time step 303681 (time=9490.03), 0.0034531 s/step
# Meep progress: 9523.15625/10000.0 = 95.2% done in 1132.5s, 56.7s to go
# on time step 304833 (time=9526.03), 0.00347382 s/step
# Meep progress: 9559.46875/10000.0 = 95.6% done in 1136.5s, 52.4s to go
# on time step 305992 (time=9562.25), 0.00345326 s/step
# Meep progress: 9596.6875/10000.0 = 96.0% done in 1140.5s, 47.9s to go
# on time step 307177 (time=9599.28), 0.00337758 s/step
# Meep progress: 9632.75/10000.0 = 96.3% done in 1144.5s, 43.6s to go
# on time step 308333 (time=9635.41), 0.00346256 s/step
# Meep progress: 9669.28125/10000.0 = 96.7% done in 1148.5s, 39.3s to go
# on time step 309508 (time=9672.12), 0.0034066 s/step
# Meep progress: 9704.96875/10000.0 = 97.0% done in 1152.5s, 35.0s to go
# on time step 310645 (time=9707.66), 0.00351875 s/step
# Meep progress: 9740.59375/10000.0 = 97.4% done in 1156.5s, 30.8s to go
# on time step 311787 (time=9743.34), 0.00350558 s/step
# Meep progress: 9776.3125/10000.0 = 97.8% done in 1160.5s, 26.6s to go
# on time step 312928 (time=9779), 0.00350596 s/step
# Meep progress: 9812.375/10000.0 = 98.1% done in 1164.5s, 22.3s to go
# on time step 314079 (time=9814.97), 0.0034774 s/step
# Meep progress: 9847.96875/10000.0 = 98.5% done in 1168.5s, 18.0s to go
# on time step 315219 (time=9850.59), 0.00351071 s/step
# Meep progress: 9883.78125/10000.0 = 98.8% done in 1172.5s, 13.8s to go
# on time step 316366 (time=9886.44), 0.00348754 s/step
# Meep progress: 9919.96875/10000.0 = 99.2% done in 1176.5s, 9.5s to go
# on time step 317526 (time=9922.69), 0.00345166 s/step
# Meep progress: 9955.5/10000.0 = 99.6% done in 1180.5s, 5.3s to go
# on time step 318671 (time=9958.47), 0.00349544 s/step
# Meep progress: 9990.875/10000.0 = 99.9% done in 1184.6s, 1.1s to go
# on time step 319789 (time=9993.41), 0.00357935 s/step
# run 0 finished at t = 10000.0 (320000 timesteps)

# %%
plt.plot(freqs_wo,psd_out_wo)
plt.grid(True)

# %%
plt.plot(freqs_w,psd_out_w)
plt.grid(True)

# %%
plt.plot(np.array(freqs_w), np.array(psd_out_w)/np.array(psd_out_wo))
plt.xlabel("Frequency[c/a]")
plt.ylabel("Transmittance[c/a]")
plt.yscale('log')
plt.grid(True)
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
plt.plot(np.array(freqs_w), np.array(psd_out_w)/np.array(psd_out_wo))
plt.xlabel("Frequency[c/a]")
plt.ylabel("Transmittance[c/a]")
plt.yscale('log')
plt.grid(True)

# %%
a = 470
c_const = 299792458

freqs = a / np.array(freqs_w)
#freqs
plt.plot(freqs, np.array(psd_out_w)/np.array(psd_out_wo))
plt.scatter(freqs, np.array(psd_out_w)/np.array(psd_out_wo))
plt.xlabel("Frequency[c/a]")
plt.ylabel("Transmittance[c/a]")
#plt.xlim([0.28,0.30])
plt.yscale('log')
plt.grid(True)

# %%
freqs = a / np.array(freqs_w)
#freqs
plt.plot(freqs, np.array(psd_out_w)/np.array(psd_out_wo))
plt.scatter(freqs, np.array(psd_out_w)/np.array(psd_out_wo))
plt.xlabel("Frequency[c/a]")
plt.ylabel("Transmittance[c/a]")
plt.xlim([1450,1600])
plt.yscale('log')
plt.ylim([1e-4,1e-2])
plt.grid(True)

# %%
df = pd.DataFrame()
df["wavelength"] = freqs
df["transmittance"] = np.array(psd_out_w)/np.array(psd_out_wo)
df.to_csv("210122_resolution16_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d085_km01_cor.ipynb")

# %%
df
# Out:
#        wavelength  transmittance
# 0     2350.000000       0.075326
# 1     2349.530000       0.075350
# 2     2349.060188       0.075379
# 3     2348.590564       0.075425
# 4     2348.121127       0.075477
# ...           ...            ...
# 4995  1175.470282       0.093933
# 4996  1175.352676       0.094882
# 4997  1175.235094       0.095807
# 4998  1175.117535       0.096707
# 4999  1175.000000       0.097589
#
# [5000 rows x 2 columns]
