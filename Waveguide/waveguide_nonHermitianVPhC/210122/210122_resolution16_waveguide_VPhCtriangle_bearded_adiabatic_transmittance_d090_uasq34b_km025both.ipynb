# %% [markdown]
# https://github.com/NanoComp/meep/blob/master/python/examples/straight-waveguide.ipynb
#
# https://stackoverflow.com/questions/29454002/filenotfounderror-errno-2-no-such-file-or-directory-ffmpeg

# %%
import math
import meep as mp
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from matplotlib import rc
rc('text', usetex=False)
#plt.rcParams['font.family'] = 'Times New Roman'#使用するフォント
#plt.rcParams['mathtext.fontset'] = 'stix' # math fontの設定
plt.rcParams['font.family']= 'sans-serif'
plt.rcParams['font.sans-serif'] = ['Arial']
plt.rcParams["font.size"] = 15 # 全体のフォントサイズが変更されます。
plt.rcParams['xtick.direction'] = 'in'#x軸の目盛線が内向き('in')か外向き('out')か双方向か('inout')
plt.rcParams['ytick.direction'] = 'in'#y軸の目盛線が内向き('in')か外向き('out')か双方向か('inout')
# Out:
# Using MPI version 3.1, 1 processes

# %%
def eps_to_eps(eps_A_r,eps_A_i):
    eps_A = eps_A_r + 1.j*eps_A_i
    eps_Ainv = 1 / eps_A

    eps_Ainv_r = eps_Ainv.real
    eps_Ainv_i = -eps_Ainv.imag

    #print(eps_Ainv_r, eps_Ainv_i)

    eps_B_r = eps_A_r + 1/eps_Ainv_r * (eps_Ainv_i**2) / (eps_Ainv_r**2 + eps_Ainv_i**2)
    eps_B_i = 0

    eps_B = eps_B_r + 1.j*eps_B_i
    eps_Binv = 1 / eps_B

    eps_Binv_r = eps_Binv.real
    eps_Binv_i = -eps_Binv.imag

    #print(eps_Binv_r, eps_Binv_i)
    return eps_B_r, eps_B_i

# %%
def phc_trans(PhC = True, lengthPhC = 100, decay_check=0, T_decay=500):
    """
    <変数の説明>
    PhC...PhC(フォトニック決勝)を配置するかどうか。Falseで直線導波路
    lengthPhC...PhC導波方向の長さ
    widthPhC...PhC垂直方向の幅。PMLと被ってるので適当。
    ConnectionWaveguide...PhCに接続するSi導波路(棒の部分)の長さ
    wgi...導波路の幅を調整する。1で丸穴一個分空いてることを意味する。0.7とかにすると狭くなってバンドの形が変わる、っていうのはDaii君の研究とも絡む。
    r...穴の半径。ふつうはa/4くらい。meepだと格子定数は1で固定だから、格子定数との比を入力すればOK
    n_eff...屈折率。2次元だと2.5~2.7くらいにしておくと3次元のSi系(n_Si=3.48)と結果が近くなる。違う材料を使うときは要調整、通常はdefaultで大丈夫。
    fcen...入力光（ガウシアンビーム）の中心周波数。知りたいPhCバンドの周波数近くに設定する
    df...入力光（ガウシアンビーム）の半値幅（で合ってる？）
    nfreq...入力光（ガウシアンビーム）のきめ細かさ
    resolution...メッシュの細かさ。2^nにすると計算が軽くなるらしい。
    T_dacay...反復計算数。小さいと誤差が増え、大きいと時間がかかる。sim.run(until_after_sources=...)で計算時間を見積もってから変えるとよさそう
    decay_check...解の収束をどこで判定するか、位置を指定。defaultでOK

    <備考>
    ・meepでは格子定数aはパラメータに含まれないので設定不要
    　誘電体を使うときは入力するらしい（スケール依存性が出るから）
    ・THzやnmは使用せず、すべて規格化周波数で入力する (周波数はωa/2πcで直す)
    """
    ##### setting of parameters #####
    a = 1 # CADに移行しやすいように予め設定しておく
    widthPhC = 10
    ConnectionWaveguide = 5
    wgi = 1/2 #/np.sqrt(3)/2
    whetero = 1/np.sqrt(3)/4
    r = 1/4
    d_0 = 0.9*a
    yshift = -np.sqrt(3)/4*a #1/(np.sqrt(3)) #+ 1/6*np.sqrt(3)/2*d_0

    #n_eff = 2.6

    eps_A_r = 2.6**2
    eps_A_i = 0.25
    eps_B_r = eps_A_r
    eps_B_i = eps_A_i

    fcen = 0.29
    df = 0.2
    nfreq = 500 # number of frequencies at which to compute flux
    resolution = 16

    connect = 0
    #####
    length = lengthPhC + 2*ConnectionWaveguide
    width = widthPhC
    Nx = int(lengthPhC)
    Ny = int(widthPhC)

    # settings of imaginary part
    normalized_frequency = 0.3
    #extinction_coefficient = 0.2

    ##### settings of geometry #####
    # initialization
    cell = mp.Vector3(length,width*np.sqrt(3),0)

    # Si waveguide
    waveguide = mp.Block(mp.Vector3(mp.inf,wgi*np.sqrt(3),mp.inf),
                            center=mp.Vector3(),
                            material=mp.Medium(epsilon=eps_B_r))
    geometry = [waveguide]

    # PhC
    if PhC:
        # triangle
        tri_u = [
                mp.Vector3(-np.sqrt(3)/2,-1/2)*d_0/np.sqrt(3),
                mp.Vector3( np.sqrt(3)/2,-1/2)*d_0/np.sqrt(3),
                mp.Vector3(            0,   1)*d_0/np.sqrt(3),
                ]
        tri_d = [
                mp.Vector3(-np.sqrt(3)/2,-1/2)*d_0/np.sqrt(3)*(-1),
                mp.Vector3( np.sqrt(3)/2,-1/2)*d_0/np.sqrt(3)*(-1),
                mp.Vector3(            0,   1)*d_0/np.sqrt(3)*(-1),
                ]

        # slab
        blk_above = mp.Block(mp.Vector3(lengthPhC,widthPhC*np.sqrt(3),mp.inf),
                                center=mp.Vector3(0, widthPhC*np.sqrt(3)/2 - np.sqrt(3)/4 + 0*(yshift + 1/(2*np.sqrt(3))), 0),
                                material=mp.Medium(epsilon=eps_B_r, D_conductivity=0*2*np.pi*normalized_frequency*eps_B_i / eps_B_r))
        geometry.append(blk_above)
        blk_below = mp.Block(mp.Vector3(lengthPhC,widthPhC*np.sqrt(3),mp.inf),
                                center=mp.Vector3(0,-widthPhC*np.sqrt(3)/2 - np.sqrt(3)/4 + 0*(yshift + 1/(2*np.sqrt(3))), 0),
                                material=mp.Medium(epsilon=eps_A_r, D_conductivity=2*np.pi*normalized_frequency*eps_A_i / eps_A_r))
        geometry.append(blk_below)
        
        # arrange air-holes
        for j in range(Ny):
            for i in range(Nx+1):
                shift_y = np.sqrt(3)
                geometry.append(mp.Prism(tri_d, height = 1, center=mp.Vector3(i-(Nx+1)/2, yshift + 1/(np.sqrt(3)) + shift_y*(j+1/2))))                
                geometry.append(mp.Prism(tri_u, height = 1, center=mp.Vector3(i-(Nx+1)/2, yshift -(1/(np.sqrt(3)) + shift_y*(j+1/2)))))            
                geometry.append(mp.Prism(tri_d, height = 1, center=mp.Vector3(i-Nx/2, yshift +  1/(np.sqrt(3)) + shift_y*j )))

            if j == 0:
                for i in range(connect,Nx+1-connect):
                    geometry.append(mp.Prism(tri_u, height = 1, center=mp.Vector3(i-Nx/2, yshift - (1/(np.sqrt(3)) + shift_y*j))))
            else:
                for i in range(Nx+1):
                    geometry.append(mp.Prism(tri_u, height = 1, center=mp.Vector3(i-Nx/2, yshift - (1/(np.sqrt(3)) + shift_y*j))))
                    
        for i in range(1,Nx+1):
            geometry.append(mp.Prism(tri_u, height = 1, center=mp.Vector3(i-(Nx+1)/2, yshift - (1/(np.sqrt(3)) + shift_y*(-1/2)))))
        #geometry.append(mp.Prism(tri_d, height = 1, center=mp.Vector3(1, 0)))


                #geometry.append(mp.Cylinder(r, center=mp.Vector3(i-N/2,-wgi*np.sqrt(3)/2)))

    # Gaussian
    sources = [mp.Source(mp.GaussianSource(fcen, fwidth=df),
                            component=mp.Hz,
                            center=mp.Vector3(-length/2 +1,0),
                            size=mp.Vector3(0,wgi*np.sqrt(3)))
                ]

    # PML
    pml_layers = [mp.PML(1.0)]

    # z-symmetry (上下対称なら計算が軽くなる。対称性が無いなら消す)
    #sym = [mp.Mirror(mp.Y, phase=-1)]
    

    ####
    sim = mp.Simulation(cell_size=cell,
                        boundary_layers=pml_layers,
                        geometry=geometry,
                        sources=sources,
                        #symmetries=sym,
                        resolution=resolution)

    #tran_in = mp.FluxRegion(center=mp.Vector3(-lengthPhC/2-1,0),size=mp.Vector3(0, 2*wgi))
    tran_out = mp.FluxRegion(center=mp.Vector3(length/2-3/2,0),size=mp.Vector3(0, 2*wgi))
    #trans_in = sim.add_flux(fcen, df, nfreq, tran_in)
    trans_out = sim.add_flux(fcen, df, nfreq, tran_out)

    # show geometry
    # %matplotlib inline
    f = plt.figure(dpi=500, figsize=(8,16))
    sim.plot2D(ax=f.gca())
    plt.show()    

    #sim.run(until_after_sources=mp.stop_when_fields_decayed(50, mp.Hz, mp.Vector3(decay_check), 1e-3))
    sim.run(until=T_decay)

    freqs = mp.get_flux_freqs(trans_out)
    #psd_in = mp.get_fluxes(trans_in)
    psd_out = mp.get_fluxes(trans_out)

    return freqs, psd_out

# %%
freqs_wo, psd_out_wo = phc_trans(PhC = False, lengthPhC = 20, decay_check=10, T_decay=500)
freqs_w,  psd_out_w  = phc_trans(PhC = True, lengthPhC = 50, decay_check=20, T_decay=10000)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.001261 s
# Working in 2D dimensions.
# Computational cell is 30 x 17.3125 x 0 with resolution 16
#      block, center = (0,0,0)
#           size (1e+20,0.866025,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (6.76,6.76,6.76)
# time for set_epsilon = 0.261278 s
# -----------
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# FloatProgress(value=0.0, description='0% done ', max=500.0)
# Meep progress: 56.1875/500.0 = 11.2% done in 4.0s, 31.6s to go
# on time step 1799 (time=56.2188), 0.00222397 s/step
# Meep progress: 113.5/500.0 = 22.7% done in 8.0s, 27.3s to go
# on time step 3636 (time=113.625), 0.0021793 s/step
# Meep progress: 168.53125/500.0 = 33.7% done in 12.0s, 23.6s to go
# on time step 5396 (time=168.625), 0.0022729 s/step
# Meep progress: 211.71875/500.0 = 42.3% done in 16.0s, 21.8s to go
# on time step 6780 (time=211.875), 0.00289107 s/step
# Meep progress: 249.96875/500.0 = 50.0% done in 20.0s, 20.0s to go
# on time step 8003 (time=250.094), 0.00327171 s/step
# Meep progress: 303.25/500.0 = 60.6% done in 24.0s, 15.6s to go
# on time step 9708 (time=303.375), 0.00234637 s/step
# Meep progress: 348.375/500.0 = 69.7% done in 28.0s, 12.2s to go
# on time step 11154 (time=348.562), 0.00276664 s/step
# Meep progress: 367.75/500.0 = 73.5% done in 32.0s, 11.5s to go
# on time step 11769 (time=367.781), 0.00650526 s/step
# Meep progress: 385.0625/500.0 = 77.0% done in 36.0s, 10.8s to go
# on time step 12323 (time=385.094), 0.00722108 s/step
# Meep progress: 403.21875/500.0 = 80.6% done in 40.0s, 9.6s to go
# on time step 12904 (time=403.25), 0.00689166 s/step
# Meep progress: 416.71875/500.0 = 83.3% done in 44.0s, 8.8s to go
# on time step 13337 (time=416.781), 0.00924405 s/step
# Meep progress: 433.1875/500.0 = 86.6% done in 48.0s, 7.4s to go
# on time step 13865 (time=433.281), 0.0075801 s/step
# Meep progress: 463.6875/500.0 = 92.7% done in 52.0s, 4.1s to go
# on time step 14843 (time=463.844), 0.00409073 s/step
# Meep progress: 494.8125/500.0 = 99.0% done in 56.0s, 0.6s to go
# on time step 15838 (time=494.938), 0.00402499 s/step
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# run 0 finished at t = 500.0 (16000 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.13903 s
# Working in 2D dimensions.
# Computational cell is 60 x 17.3125 x 0 with resolution 16
#      block, center = (0,0,0)
#           size (1e+20,0.866025,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (6.76,6.76,6.76)
#      block, center = (0,8.22724,0)
#           size (50,17.3205,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (6.76,6.76,6.76)
#      block, center = (0,-9.09327,0)
#           size (50,17.3205,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (6.76,6.76,6.76)
#      prism, center = (-25.5,1.01036,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-25.05,1.27017,-0.5)
#           (-25.95,1.27017,-0.5)
#           (-25.5,0.490748,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      prism, center = (-25.5,-1.87639,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-25.95,-2.1362,-0.5)
#           (-25.05,-2.1362,-0.5)
#           (-25.5,-1.35677,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      prism, center = (-25,0.144338,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-24.55,0.404145,-0.5)
#           (-25.45,0.404145,-0.5)
#           (-25,-0.375278,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      prism, center = (-24.5,1.01036,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-24.05,1.27017,-0.5)
#           (-24.95,1.27017,-0.5)
#           (-24.5,0.490748,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      prism, center = (-24.5,-1.87639,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-24.95,-2.1362,-0.5)
#           (-24.05,-2.1362,-0.5)
#           (-24.5,-1.35677,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      prism, center = (-24,0.144338,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-23.55,0.404145,-0.5)
#           (-24.45,0.404145,-0.5)
#           (-24,-0.375278,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      prism, center = (-23.5,1.01036,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-23.05,1.27017,-0.5)
#           (-23.95,1.27017,-0.5)
#           (-23.5,0.490748,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      ...(+ 2083 objects not shown)...
# subpixel-averaging is 40.2316% done, 5.96697 s remaining
# subpixel-averaging is 87.5374% done, 0.571097 s remaining
# subpixel-averaging is 50.4001% done, 3.93975 s remaining
# subpixel-averaging is 55.7054% done, 3.20435 s remaining
# time for set_epsilon = 26.751 s
# time for set_conductivity = 0.381272 s
# time for set_conductivity = 0.399053 s
# time for set_conductivity = 0.355606 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=10000.0)
# ress: 6702.71875/10000.0 = 67.0% done in 1561.6s, 768.2s to go
# on time step 214621 (time=6706.91), 0.00742447 s/step
# Meep progress: 6721.875/10000.0 = 67.2% done in 1565.6s, 763.5s to go
# on time step 215226 (time=6725.81), 0.00661566 s/step
# Meep progress: 6738.71875/10000.0 = 67.4% done in 1569.6s, 759.6s to go
# on time step 215780 (time=6743.12), 0.00722215 s/step
# Meep progress: 6759.125/10000.0 = 67.6% done in 1573.6s, 754.5s to go
# on time step 216430 (time=6763.44), 0.0061618 s/step
# Meep progress: 6779.0625/10000.0 = 67.8% done in 1577.6s, 749.6s to go
# on time step 217077 (time=6783.66), 0.00618862 s/step
# Meep progress: 6799.4375/10000.0 = 68.0% done in 1581.6s, 744.5s to go
# on time step 217727 (time=6803.97), 0.00615516 s/step
# Meep progress: 6816.78125/10000.0 = 68.2% done in 1585.6s, 740.4s to go
# on time step 218275 (time=6821.09), 0.00730003 s/step
# Meep progress: 6834.3125/10000.0 = 68.3% done in 1589.6s, 736.3s to go
# on time step 218759 (time=6836.22), 0.0082677 s/step
# Meep progress: 6848.65625/10000.0 = 68.5% done in 1593.6s, 733.3s to go
# on time step 219276 (time=6852.38), 0.0077376 s/step
# Meep progress: 6866.4375/10000.0 = 68.7% done in 1597.6s, 729.1s to go
# on time step 219866 (time=6870.81), 0.00678476 s/step
# Meep progress: 6886.375/10000.0 = 68.9% done in 1601.6s, 724.2s to go
# on time step 220494 (time=6890.44), 0.00637063 s/step
# Meep progress: 6906.625/10000.0 = 69.1% done in 1605.6s, 719.1s to go
# on time step 221146 (time=6910.81), 0.00613542 s/step
# Meep progress: 6926.5625/10000.0 = 69.3% done in 1609.6s, 714.2s to go
# on time step 221786 (time=6930.81), 0.00625072 s/step
# Meep progress: 6946.0/10000.0 = 69.5% done in 1613.6s, 709.5s to go
# on time step 222378 (time=6949.31), 0.00675806 s/step
# Meep progress: 6964.40625/10000.0 = 69.6% done in 1617.6s, 705.1s to go
# on time step 223001 (time=6968.78), 0.00642605 s/step
# Meep progress: 6983.21875/10000.0 = 69.8% done in 1621.6s, 700.6s to go
# on time step 223597 (time=6987.41), 0.0067222 s/step
# Meep progress: 7002.53125/10000.0 = 70.0% done in 1625.6s, 695.9s to go
# on time step 224221 (time=7006.91), 0.00641028 s/step
# Meep progress: 7019.90625/10000.0 = 70.2% done in 1629.6s, 691.8s to go
# on time step 224704 (time=7022), 0.00828797 s/step
# Meep progress: 7031.75/10000.0 = 70.3% done in 1633.7s, 689.6s to go
# on time step 225114 (time=7034.81), 0.00975739 s/step
# Meep progress: 7046.28125/10000.0 = 70.5% done in 1637.7s, 686.5s to go
# on time step 225624 (time=7050.75), 0.00785466 s/step
# Meep progress: 7066.46875/10000.0 = 70.7% done in 1641.7s, 681.5s to go
# on time step 226256 (time=7070.5), 0.00633631 s/step
# Meep progress: 7081.125/10000.0 = 70.8% done in 1645.7s, 678.4s to go
# on time step 226676 (time=7083.62), 0.00954852 s/step
# Meep progress: 7094.34375/10000.0 = 70.9% done in 1649.7s, 675.7s to go
# on time step 227130 (time=7097.81), 0.00881196 s/step
# Meep progress: 7111.96875/10000.0 = 71.1% done in 1653.7s, 671.5s to go
# on time step 227708 (time=7115.88), 0.00693079 s/step
# Meep progress: 7131.625/10000.0 = 71.3% done in 1657.7s, 666.7s to go
# on time step 228342 (time=7135.69), 0.00631428 s/step
# Meep progress: 7151.625/10000.0 = 71.5% done in 1661.7s, 661.8s to go
# on time step 228998 (time=7156.19), 0.00610389 s/step
# Meep progress: 7172.21875/10000.0 = 71.7% done in 1665.7s, 656.7s to go
# on time step 229658 (time=7176.81), 0.00606802 s/step
# Meep progress: 7192.09375/10000.0 = 71.9% done in 1669.7s, 651.9s to go
# on time step 230277 (time=7196.16), 0.0064641 s/step
# Meep progress: 7211.375/10000.0 = 72.1% done in 1673.7s, 647.2s to go
# on time step 230912 (time=7216), 0.00630335 s/step
# Meep progress: 7229.96875/10000.0 = 72.3% done in 1677.7s, 642.8s to go
# on time step 231499 (time=7234.34), 0.00681955 s/step
# Meep progress: 7250.125/10000.0 = 72.5% done in 1681.7s, 637.8s to go
# on time step 232148 (time=7254.62), 0.00617092 s/step
# Meep progress: 7270.625/10000.0 = 72.7% done in 1685.7s, 632.8s to go
# on time step 232806 (time=7275.19), 0.00608561 s/step
# Meep progress: 7290.96875/10000.0 = 72.9% done in 1689.7s, 627.8s to go
# on time step 233460 (time=7295.62), 0.00611953 s/step
# Meep progress: 7311.75/10000.0 = 73.1% done in 1693.7s, 622.7s to go
# on time step 234120 (time=7316.25), 0.00606872 s/step
# Meep progress: 7332.4375/10000.0 = 73.3% done in 1697.7s, 617.6s to go
# on time step 234757 (time=7336.16), 0.0062825 s/step
# Meep progress: 7347.59375/10000.0 = 73.5% done in 1701.7s, 614.3s to go
# on time step 235237 (time=7351.16), 0.00835102 s/step
# Meep progress: 7364.5/10000.0 = 73.6% done in 1705.7s, 610.4s to go
# on time step 235795 (time=7368.59), 0.00717152 s/step
# Meep progress: 7383.125/10000.0 = 73.8% done in 1709.7s, 606.0s to go
# on time step 236367 (time=7386.47), 0.00699797 s/step
# Meep progress: 7399.71875/10000.0 = 74.0% done in 1713.7s, 602.2s to go
# on time step 236919 (time=7403.72), 0.00725757 s/step
# Meep progress: 7417.375/10000.0 = 74.2% done in 1717.7s, 598.1s to go
# on time step 237493 (time=7421.66), 0.00697849 s/step
# Meep progress: 7433.90625/10000.0 = 74.3% done in 1721.7s, 594.3s to go
# on time step 237942 (time=7435.69), 0.00893182 s/step
# Meep progress: 7441.34375/10000.0 = 74.4% done in 1725.7s, 593.4s to go
# on time step 238183 (time=7443.22), 0.0166336 s/step
# Meep progress: 7453.59375/10000.0 = 74.5% done in 1729.8s, 590.9s to go
# on time step 238610 (time=7456.56), 0.00938956 s/step
# Meep progress: 7462.21875/10000.0 = 74.6% done in 1733.8s, 589.6s to go
# on time step 238842 (time=7463.81), 0.0172652 s/step
# Meep progress: 7469.75/10000.0 = 74.7% done in 1737.8s, 588.6s to go
# on time step 239150 (time=7473.44), 0.0129975 s/step
# Meep progress: 7487.46875/10000.0 = 74.9% done in 1741.8s, 584.5s to go
# on time step 239718 (time=7491.19), 0.00705055 s/step
# Meep progress: 7502.96875/10000.0 = 75.0% done in 1745.8s, 581.0s to go
# on time step 240202 (time=7506.31), 0.0082705 s/step
# Meep progress: 7519.53125/10000.0 = 75.2% done in 1749.8s, 577.2s to go
# on time step 240766 (time=7523.94), 0.00710203 s/step
# Meep progress: 7537.0/10000.0 = 75.4% done in 1753.8s, 573.1s to go
# on time step 241305 (time=7540.78), 0.00742222 s/step
# Meep progress: 7554.0625/10000.0 = 75.5% done in 1757.8s, 569.2s to go
# on time step 241831 (time=7557.22), 0.00761995 s/step
# Meep progress: 7569.625/10000.0 = 75.7% done in 1761.8s, 565.7s to go
# on time step 242367 (time=7573.97), 0.00746651 s/step
# Meep progress: 7587.125/10000.0 = 75.9% done in 1765.8s, 561.6s to go
# on time step 242913 (time=7591.03), 0.00733528 s/step
# Meep progress: 7603.21875/10000.0 = 76.0% done in 1769.8s, 557.9s to go
# on time step 243394 (time=7606.06), 0.0083467 s/step
# Meep progress: 7616.65625/10000.0 = 76.2% done in 1773.8s, 555.0s to go
# on time step 243855 (time=7620.47), 0.00869592 s/step
# Meep progress: 7631.03125/10000.0 = 76.3% done in 1777.8s, 551.9s to go
# on time step 244306 (time=7634.56), 0.00887191 s/step
# Meep progress: 7645.71875/10000.0 = 76.5% done in 1781.8s, 548.7s to go
# on time step 244755 (time=7648.59), 0.00891729 s/step
# Meep progress: 7660.09375/10000.0 = 76.6% done in 1785.8s, 545.5s to go
# on time step 245269 (time=7664.66), 0.00778749 s/step
# Meep progress: 7680.28125/10000.0 = 76.8% done in 1789.8s, 540.6s to go
# on time step 245906 (time=7684.56), 0.00628874 s/step
# Meep progress: 7698.3125/10000.0 = 77.0% done in 1793.8s, 536.3s to go
# on time step 246430 (time=7700.94), 0.00764533 s/step
# Meep progress: 7714.03125/10000.0 = 77.1% done in 1797.8s, 532.8s to go
# on time step 246966 (time=7717.69), 0.00746885 s/step
# Meep progress: 7732.25/10000.0 = 77.3% done in 1801.8s, 528.5s to go
# on time step 247558 (time=7736.19), 0.00677029 s/step
# Meep progress: 7746.6875/10000.0 = 77.5% done in 1805.9s, 525.3s to go
# on time step 248019 (time=7750.59), 0.00868679 s/step
# Meep progress: 7763.875/10000.0 = 77.6% done in 1809.9s, 521.3s to go
# on time step 248565 (time=7767.66), 0.00732647 s/step
# Meep progress: 7780.59375/10000.0 = 77.8% done in 1813.9s, 517.4s to go
# on time step 249111 (time=7784.72), 0.00733701 s/step
# Meep progress: 7798.21875/10000.0 = 78.0% done in 1817.9s, 513.3s to go
# on time step 249689 (time=7802.78), 0.00692806 s/step
# Meep progress: 7813.6875/10000.0 = 78.1% done in 1821.9s, 509.8s to go
# on time step 250101 (time=7815.66), 0.00975659 s/step
# Meep progress: 7826.40625/10000.0 = 78.3% done in 1825.9s, 507.1s to go
# on time step 250553 (time=7829.78), 0.00885005 s/step
# Meep progress: 7844.21875/10000.0 = 78.4% done in 1829.9s, 502.9s to go
# on time step 251106 (time=7847.06), 0.00724314 s/step
# Meep progress: 7860.46875/10000.0 = 78.6% done in 1833.9s, 499.2s to go
# on time step 251669 (time=7864.66), 0.00710703 s/step
# Meep progress: 7875.4375/10000.0 = 78.8% done in 1837.9s, 495.8s to go
# on time step 252087 (time=7877.72), 0.00957944 s/step
# Meep progress: 7888.46875/10000.0 = 78.9% done in 1841.9s, 493.0s to go
# on time step 252558 (time=7892.44), 0.00849263 s/step
# Meep progress: 7905.4375/10000.0 = 79.1% done in 1845.9s, 489.1s to go
# on time step 253091 (time=7909.09), 0.00750604 s/step
# Meep progress: 7923.15625/10000.0 = 79.2% done in 1849.9s, 484.9s to go
# on time step 253672 (time=7927.25), 0.00689058 s/step
# Meep progress: 7941.03125/10000.0 = 79.4% done in 1853.9s, 480.7s to go
# on time step 254252 (time=7945.38), 0.00689991 s/step
# Meep progress: 7960.21875/10000.0 = 79.6% done in 1857.9s, 476.1s to go
# on time step 254881 (time=7965.03), 0.00636714 s/step
# Meep progress: 7979.9375/10000.0 = 79.8% done in 1861.9s, 471.3s to go
# on time step 255499 (time=7984.34), 0.00648214 s/step
# Meep progress: 7998.78125/10000.0 = 80.0% done in 1865.9s, 466.8s to go
# on time step 256114 (time=8003.56), 0.0065124 s/step
# Meep progress: 8018.53125/10000.0 = 80.2% done in 1869.9s, 462.1s to go
# on time step 256740 (time=8023.12), 0.00639422 s/step
# Meep progress: 8039.53125/10000.0 = 80.4% done in 1873.9s, 457.0s to go
# on time step 257423 (time=8044.47), 0.0058641 s/step
# Meep progress: 8057.875/10000.0 = 80.6% done in 1877.9s, 452.6s to go
# on time step 257984 (time=8062), 0.00715823 s/step
# Meep progress: 8073.8125/10000.0 = 80.7% done in 1881.9s, 449.0s to go
# on time step 258502 (time=8078.19), 0.00772386 s/step
# Meep progress: 8093.125/10000.0 = 80.9% done in 1885.9s, 444.4s to go
# on time step 259109 (time=8097.16), 0.00659246 s/step
# Meep progress: 8111.71875/10000.0 = 81.1% done in 1889.9s, 439.9s to go
# on time step 259710 (time=8115.94), 0.00665577 s/step
# Meep progress: 8131.09375/10000.0 = 81.3% done in 1893.9s, 435.3s to go
# on time step 260283 (time=8133.84), 0.00699502 s/step
# Meep progress: 8146.125/10000.0 = 81.5% done in 1897.9s, 431.9s to go
# on time step 260841 (time=8151.28), 0.00717 s/step
# Meep progress: 8166.40625/10000.0 = 81.7% done in 1901.9s, 427.0s to go
# on time step 261474 (time=8171.06), 0.00632376 s/step
# Meep progress: 8186.5625/10000.0 = 81.9% done in 1905.9s, 422.2s to go
# on time step 262138 (time=8191.81), 0.00602784 s/step
# Meep progress: 8208.34375/10000.0 = 82.1% done in 1909.9s, 416.9s to go
# on time step 262815 (time=8212.97), 0.00591212 s/step
# Meep progress: 8227.46875/10000.0 = 82.3% done in 1913.9s, 412.3s to go
# on time step 263412 (time=8231.62), 0.00670329 s/step
# Meep progress: 8243.5625/10000.0 = 82.4% done in 1917.9s, 408.7s to go
# on time step 263902 (time=8246.94), 0.00816774 s/step
# Meep progress: 8260.1875/10000.0 = 82.6% done in 1922.0s, 404.8s to go
# on time step 264459 (time=8264.34), 0.0072133 s/step
# Meep progress: 8275.8125/10000.0 = 82.8% done in 1926.0s, 401.3s to go
# on time step 264938 (time=8279.31), 0.00836575 s/step
# Meep progress: 8292.375/10000.0 = 82.9% done in 1930.0s, 397.4s to go
# on time step 265537 (time=8298.03), 0.00668593 s/step
# Meep progress: 8314.0/10000.0 = 83.1% done in 1934.0s, 392.2s to go
# on time step 266186 (time=8318.31), 0.00618591 s/step
# Meep progress: 8333.28125/10000.0 = 83.3% done in 1938.0s, 387.6s to go
# on time step 266839 (time=8338.72), 0.00612974 s/step
# Meep progress: 8355.09375/10000.0 = 83.6% done in 1942.0s, 382.3s to go
# on time step 267548 (time=8360.88), 0.00564984 s/step
# Meep progress: 8376.09375/10000.0 = 83.8% done in 1946.0s, 377.3s to go
# on time step 268206 (time=8381.44), 0.00608275 s/step
# Meep progress: 8396.84375/10000.0 = 84.0% done in 1950.0s, 372.3s to go
# on time step 268870 (time=8402.19), 0.00602572 s/step
# Meep progress: 8417.6875/10000.0 = 84.2% done in 1954.0s, 367.3s to go
# on time step 269529 (time=8422.78), 0.00607151 s/step
# Meep progress: 8437.0625/10000.0 = 84.4% done in 1958.0s, 362.7s to go
# on time step 270129 (time=8441.53), 0.00667217 s/step
# Meep progress: 8455.71875/10000.0 = 84.6% done in 1962.0s, 358.3s to go
# on time step 270757 (time=8461.16), 0.00637729 s/step
# Meep progress: 8476.625/10000.0 = 84.8% done in 1966.0s, 353.3s to go
# on time step 271420 (time=8481.88), 0.00603584 s/step
# Meep progress: 8497.5625/10000.0 = 85.0% done in 1970.0s, 348.3s to go
# on time step 272089 (time=8502.78), 0.00598236 s/step
# Meep progress: 8517.8125/10000.0 = 85.2% done in 1974.0s, 343.5s to go
# on time step 272695 (time=8521.72), 0.00661132 s/step
# Meep progress: 8534.6875/10000.0 = 85.3% done in 1978.0s, 339.6s to go
# on time step 273269 (time=8539.66), 0.00697666 s/step
# Meep progress: 8553.34375/10000.0 = 85.5% done in 1982.0s, 335.2s to go
# on time step 273869 (time=8558.41), 0.00667175 s/step
# Meep progress: 8572.9375/10000.0 = 85.7% done in 1986.0s, 330.6s to go
# on time step 274503 (time=8578.22), 0.00631701 s/step
# Meep progress: 8593.25/10000.0 = 85.9% done in 1990.0s, 325.8s to go
# on time step 275154 (time=8598.56), 0.00614599 s/step
# Meep progress: 8611.21875/10000.0 = 86.1% done in 1994.0s, 321.6s to go
# on time step 275669 (time=8614.66), 0.00777418 s/step
# Meep progress: 8629.65625/10000.0 = 86.3% done in 1998.0s, 317.3s to go
# on time step 276311 (time=8634.72), 0.00623882 s/step
# Meep progress: 8647.65625/10000.0 = 86.5% done in 2002.0s, 313.1s to go
# on time step 276886 (time=8652.69), 0.00696507 s/step
# Meep progress: 8666.96875/10000.0 = 86.7% done in 2006.0s, 308.5s to go
# on time step 277504 (time=8672), 0.00648084 s/step
# Meep progress: 8686.71875/10000.0 = 86.9% done in 2010.0s, 303.9s to go
# on time step 278146 (time=8692.06), 0.00623545 s/step
# Meep progress: 8706.8125/10000.0 = 87.1% done in 2014.0s, 299.1s to go
# on time step 278788 (time=8712.12), 0.00623091 s/step
# Meep progress: 8727.40625/10000.0 = 87.3% done in 2018.0s, 294.3s to go
# on time step 279452 (time=8732.88), 0.006036 s/step
# Meep progress: 8748.375/10000.0 = 87.5% done in 2022.0s, 289.3s to go
# on time step 280130 (time=8754.06), 0.00590252 s/step
# Meep progress: 8770.25/10000.0 = 87.7% done in 2026.0s, 284.1s to go
# on time step 280834 (time=8776.06), 0.00568488 s/step
# Meep progress: 8791.46875/10000.0 = 87.9% done in 2030.0s, 279.1s to go
# on time step 281503 (time=8796.97), 0.00598512 s/step
# Meep progress: 8812.75/10000.0 = 88.1% done in 2034.0s, 274.0s to go
# on time step 282168 (time=8817.75), 0.00603603 s/step
# Meep progress: 8830.0/10000.0 = 88.3% done in 2038.0s, 270.0s to go
# on time step 282694 (time=8834.19), 0.00762117 s/step
# Meep progress: 8842.75/10000.0 = 88.4% done in 2042.0s, 267.2s to go
# on time step 283110 (time=8847.19), 0.00962315 s/step
# Meep progress: 8858.75/10000.0 = 88.6% done in 2046.1s, 263.6s to go
# on time step 283651 (time=8864.09), 0.00739756 s/step
# Meep progress: 8877.875/10000.0 = 88.8% done in 2050.1s, 259.1s to go
# on time step 284282 (time=8883.81), 0.00634174 s/step
# Meep progress: 8898.84375/10000.0 = 89.0% done in 2054.1s, 254.2s to go
# on time step 284949 (time=8904.66), 0.00601431 s/step
# Meep progress: 8919.5625/10000.0 = 89.2% done in 2058.1s, 249.3s to go
# on time step 285606 (time=8925.19), 0.0060996 s/step
# Meep progress: 8939.34375/10000.0 = 89.4% done in 2062.1s, 244.7s to go
# on time step 286247 (time=8945.22), 0.0062471 s/step
# Meep progress: 8957.0/10000.0 = 89.6% done in 2066.1s, 240.6s to go
# on time step 286779 (time=8961.84), 0.00752934 s/step
# Meep progress: 8974.8125/10000.0 = 89.7% done in 2070.1s, 236.5s to go
# on time step 287359 (time=8979.97), 0.006904 s/step
# Meep progress: 8993.3125/10000.0 = 89.9% done in 2074.1s, 232.2s to go
# on time step 287966 (time=8998.94), 0.00659359 s/step
# Meep progress: 9012.15625/10000.0 = 90.1% done in 2078.1s, 227.8s to go
# on time step 288558 (time=9017.44), 0.00677269 s/step
# Meep progress: 9029.6875/10000.0 = 90.3% done in 2082.1s, 223.7s to go
# on time step 289121 (time=9035.03), 0.00711217 s/step
# Meep progress: 9048.96875/10000.0 = 90.5% done in 2086.1s, 219.2s to go
# on time step 289756 (time=9054.88), 0.00631886 s/step
# Meep progress: 9068.3125/10000.0 = 90.7% done in 2090.1s, 214.7s to go
# on time step 290319 (time=9072.47), 0.00710976 s/step
# Meep progress: 9083.90625/10000.0 = 90.8% done in 2094.1s, 211.2s to go
# on time step 290846 (time=9088.94), 0.00759166 s/step
# Meep progress: 9097.875/10000.0 = 91.0% done in 2098.1s, 208.0s to go
# on time step 291256 (time=9101.75), 0.00978859 s/step
# Meep progress: 9111.90625/10000.0 = 91.1% done in 2102.1s, 204.9s to go
# on time step 291721 (time=9116.28), 0.0086147 s/step
# Meep progress: 9125.71875/10000.0 = 91.3% done in 2106.1s, 201.8s to go
# on time step 292128 (time=9129), 0.00983117 s/step
# Meep progress: 9141.5625/10000.0 = 91.4% done in 2110.1s, 198.1s to go
# on time step 292708 (time=9147.12), 0.00690401 s/step
# Meep progress: 9165.3125/10000.0 = 91.7% done in 2114.1s, 192.5s to go
# on time step 293526 (time=9172.69), 0.00489243 s/step
# Meep progress: 9193.78125/10000.0 = 91.9% done in 2118.1s, 185.7s to go
# on time step 294489 (time=9202.78), 0.00415459 s/step
# Meep progress: 9226.5/10000.0 = 92.3% done in 2122.1s, 177.9s to go
# on time step 295606 (time=9237.69), 0.00358183 s/step
# Meep progress: 9264.3125/10000.0 = 92.6% done in 2126.1s, 168.8s to go
# on time step 296727 (time=9272.72), 0.00357054 s/step
# Meep progress: 9292.78125/10000.0 = 92.9% done in 2130.1s, 162.1s to go
# on time step 297730 (time=9304.06), 0.00398999 s/step
# Meep progress: 9331.28125/10000.0 = 93.3% done in 2134.1s, 152.9s to go
# on time step 298968 (time=9342.75), 0.00323149 s/step
# Meep progress: 9371.28125/10000.0 = 93.7% done in 2138.1s, 143.4s to go
# on time step 300274 (time=9383.56), 0.00306406 s/step
# Meep progress: 9412.4375/10000.0 = 94.1% done in 2142.1s, 133.7s to go
# on time step 301580 (time=9424.38), 0.00306469 s/step
# Meep progress: 9450.1875/10000.0 = 94.5% done in 2146.1s, 124.9s to go
# on time step 302763 (time=9461.34), 0.00338125 s/step
# Meep progress: 9490.09375/10000.0 = 94.9% done in 2150.1s, 115.5s to go
# on time step 304079 (time=9502.47), 0.00304132 s/step
# Meep progress: 9531.53125/10000.0 = 95.3% done in 2154.1s, 105.9s to go
# on time step 305402 (time=9543.81), 0.00302344 s/step
# Meep progress: 9572.9375/10000.0 = 95.7% done in 2158.1s, 96.3s to go
# on time step 306695 (time=9584.22), 0.00309363 s/step
# Meep progress: 9612.125/10000.0 = 96.1% done in 2162.1s, 87.2s to go
# on time step 307979 (time=9624.34), 0.00311571 s/step
# Meep progress: 9653.46875/10000.0 = 96.5% done in 2166.1s, 77.8s to go
# on time step 309294 (time=9665.44), 0.00304317 s/step
# Meep progress: 9694.96875/10000.0 = 96.9% done in 2170.1s, 68.3s to go
# on time step 310633 (time=9707.28), 0.00298894 s/step
# Meep progress: 9736.625/10000.0 = 97.4% done in 2174.1s, 58.8s to go
# on time step 311965 (time=9748.91), 0.00300466 s/step
# Meep progress: 9777.5/10000.0 = 97.8% done in 2178.1s, 49.6s to go
# on time step 313246 (time=9788.94), 0.00312278 s/step
# Meep progress: 9817.03125/10000.0 = 98.2% done in 2182.1s, 40.7s to go
# on time step 314452 (time=9826.62), 0.00331825 s/step
# Meep progress: 9852.09375/10000.0 = 98.5% done in 2186.1s, 32.8s to go
# on time step 315559 (time=9861.22), 0.00361361 s/step
# Meep progress: 9887.6875/10000.0 = 98.9% done in 2190.1s, 24.9s to go
# on time step 316792 (time=9899.75), 0.00324575 s/step
# Meep progress: 9928.875/10000.0 = 99.3% done in 2194.1s, 15.7s to go
# on time step 318116 (time=9941.12), 0.00302183 s/step
# Meep progress: 9970.15625/10000.0 = 99.7% done in 2198.1s, 6.6s to go
# on time step 319445 (time=9982.66), 0.00301159 s/step
# run 0 finished at t = 10000.0 (320000 timesteps)

# %%
plt.plot(freqs_wo,psd_out_wo)
plt.grid(True)

# %%
plt.plot(freqs_w,psd_out_w)
plt.grid(True)

# %%
plt.plot(np.array(freqs_w), np.array(psd_out_w)/np.array(psd_out_wo))
plt.xlabel("Frequency[c/a]")
plt.ylabel("Transmittance[c/a]")
plt.yscale('log')
plt.grid(True)
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
plt.plot(np.array(freqs_w), np.array(psd_out_w)/np.array(psd_out_wo))
plt.xlabel("Frequency[c/a]")
plt.ylabel("Transmittance[c/a]")
plt.yscale('log')
plt.grid(True)

# %%
a = 470
c_const = 299792458

freqs = a / np.array(freqs_w)
#freqs
plt.plot(freqs, np.array(psd_out_w)/np.array(psd_out_wo))
plt.scatter(freqs, np.array(psd_out_w)/np.array(psd_out_wo))
plt.xlabel("Frequency[c/a]")
plt.ylabel("Transmittance[c/a]")
#plt.xlim([0.28,0.30])
plt.yscale('log')
plt.grid(True)

# %%
freqs = a / np.array(freqs_w)
#freqs
plt.plot(freqs, np.array(psd_out_w)/np.array(psd_out_wo))
plt.scatter(freqs, np.array(psd_out_w)/np.array(psd_out_wo))
plt.xlabel("Frequency[c/a]")
plt.ylabel("Transmittance[c/a]")
plt.xlim([1400,1550])
plt.yscale('log')
plt.ylim([1e-7,1e-2])
plt.grid(True)

# %%
freqs = a / np.array(freqs_w)
#freqs
plt.plot(freqs, np.array(psd_out_w)/np.array(psd_out_wo))
plt.scatter(freqs, np.array(psd_out_w)/np.array(psd_out_wo))
plt.xlabel("Frequency[c/a]")
plt.ylabel("Transmittance[c/a]")
plt.xlim([1400,1550])
plt.yscale('log')
plt.ylim([1e-7,1e-5])
plt.grid(True)

# %%
df = pd.DataFrame()
df["wavelength"] = freqs
df["transmittance"] = np.array(psd_out_w)/np.array(psd_out_wo)
df.to_csv("210122_resolution16_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d090_uasq34b_km025both.ipynb")

# %%
df
# Out:
#        wavelength  transmittance
# 0     2350.000000       0.075326
# 1     2349.530000       0.075350
# 2     2349.060188       0.075379
# 3     2348.590564       0.075425
# 4     2348.121127       0.075477
# ...           ...            ...
# 4995  1175.470282       0.093933
# 4996  1175.352676       0.094882
# 4997  1175.235094       0.095807
# 4998  1175.117535       0.096707
# 4999  1175.000000       0.097589
#
# [5000 rows x 2 columns]
