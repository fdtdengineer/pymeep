# %% [markdown]
# https://github.com/NanoComp/meep/blob/master/python/examples/straight-waveguide.ipynb
#
# https://stackoverflow.com/questions/29454002/filenotfounderror-errno-2-no-such-file-or-directory-ffmpeg

# %%
import math
import meep as mp
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from matplotlib import rc
rc('text', usetex=False)
#plt.rcParams['font.family'] = 'Times New Roman'#使用するフォント
#plt.rcParams['mathtext.fontset'] = 'stix' # math fontの設定
plt.rcParams['font.family']= 'sans-serif'
plt.rcParams['font.sans-serif'] = ['Arial']
plt.rcParams["font.size"] = 15 # 全体のフォントサイズが変更されます。
plt.rcParams['xtick.direction'] = 'in'#x軸の目盛線が内向き('in')か外向き('out')か双方向か('inout')
plt.rcParams['ytick.direction'] = 'in'#y軸の目盛線が内向き('in')か外向き('out')か双方向か('inout')
# Out:
# Using MPI version 3.1, 1 processes

# %%
def eps_to_eps(eps_A_r,eps_A_i):
    eps_A = eps_A_r + 1.j*eps_A_i
    eps_Ainv = 1 / eps_A

    eps_Ainv_r = eps_Ainv.real
    eps_Ainv_i = -eps_Ainv.imag

    #print(eps_Ainv_r, eps_Ainv_i)

    eps_B_r = eps_A_r + 1/eps_Ainv_r * (eps_Ainv_i**2) / (eps_Ainv_r**2 + eps_Ainv_i**2)
    eps_B_i = 0

    eps_B = eps_B_r + 1.j*eps_B_i
    eps_Binv = 1 / eps_B

    eps_Binv_r = eps_Binv.real
    eps_Binv_i = -eps_Binv.imag

    #print(eps_Binv_r, eps_Binv_i)
    return eps_B_r, eps_B_i

# %%
def phc_trans(PhC = True, lengthPhC = 100, decay_check=0, T_decay=500):
    """
    <変数の説明>
    PhC...PhC(フォトニック決勝)を配置するかどうか。Falseで直線導波路
    lengthPhC...PhC導波方向の長さ
    widthPhC...PhC垂直方向の幅。PMLと被ってるので適当。
    ConnectionWaveguide...PhCに接続するSi導波路(棒の部分)の長さ
    wgi...導波路の幅を調整する。1で丸穴一個分空いてることを意味する。0.7とかにすると狭くなってバンドの形が変わる、っていうのはDaii君の研究とも絡む。
    r...穴の半径。ふつうはa/4くらい。meepだと格子定数は1で固定だから、格子定数との比を入力すればOK
    n_eff...屈折率。2次元だと2.5~2.7くらいにしておくと3次元のSi系(n_Si=3.48)と結果が近くなる。違う材料を使うときは要調整、通常はdefaultで大丈夫。
    fcen...入力光（ガウシアンビーム）の中心周波数。知りたいPhCバンドの周波数近くに設定する
    df...入力光（ガウシアンビーム）の半値幅（で合ってる？）
    nfreq...入力光（ガウシアンビーム）のきめ細かさ
    resolution...メッシュの細かさ。2^nにすると計算が軽くなるらしい。
    T_dacay...反復計算数。小さいと誤差が増え、大きいと時間がかかる。sim.run(until_after_sources=...)で計算時間を見積もってから変えるとよさそう
    decay_check...解の収束をどこで判定するか、位置を指定。defaultでOK

    <備考>
    ・meepでは格子定数aはパラメータに含まれないので設定不要
    　誘電体を使うときは入力するらしい（スケール依存性が出るから）
    ・THzやnmは使用せず、すべて規格化周波数で入力する (周波数はωa/2πcで直す)
    """
    ##### setting of parameters #####
    a = 1 # CADに移行しやすいように予め設定しておく
    widthPhC = 10
    ConnectionWaveguide = 5
    wgi = 1/2 #/np.sqrt(3)/2
    whetero = 1/np.sqrt(3)/4
    r = 1/4
    d_0 = 0.9*a
    yshift = -np.sqrt(3)/4*a #1/(np.sqrt(3)) #+ 1/6*np.sqrt(3)/2*d_0

    #n_eff = 2.6

    eps_A_r = 2.6**2
    eps_A_i = 0
    eps_B_r = eps_A_r
    eps_B_i = 0

    fcen = 0.29
    df = 0.2
    nfreq = 500 # number of frequencies at which to compute flux
    resolution = 16

    connect = 0
    #####
    length = lengthPhC + 2*ConnectionWaveguide
    width = widthPhC
    Nx = int(lengthPhC)
    Ny = int(widthPhC)

    # settings of imaginary part
    normalized_frequency = 0.3
    #extinction_coefficient = 0.2

    ##### settings of geometry #####
    # initialization
    cell = mp.Vector3(length,width*np.sqrt(3),0)

    # Si waveguide
    waveguide = mp.Block(mp.Vector3(mp.inf,wgi*np.sqrt(3),mp.inf),
                            center=mp.Vector3(),
                            material=mp.Medium(epsilon=eps_B_r))
    geometry = [waveguide]

    # PhC
    if PhC:
        # triangle
        tri_u = [
                mp.Vector3(-np.sqrt(3)/2,-1/2)*d_0/np.sqrt(3),
                mp.Vector3( np.sqrt(3)/2,-1/2)*d_0/np.sqrt(3),
                mp.Vector3(            0,   1)*d_0/np.sqrt(3),
                ]
        tri_d = [
                mp.Vector3(-np.sqrt(3)/2,-1/2)*d_0/np.sqrt(3)*(-1),
                mp.Vector3( np.sqrt(3)/2,-1/2)*d_0/np.sqrt(3)*(-1),
                mp.Vector3(            0,   1)*d_0/np.sqrt(3)*(-1),
                ]

        # slab
        blk_above = mp.Block(mp.Vector3(lengthPhC,widthPhC*np.sqrt(3),mp.inf),
                                center=mp.Vector3(0, widthPhC*np.sqrt(3)/2 - np.sqrt(3)/4 + 0*(yshift + 1/(2*np.sqrt(3))), 0),
                                material=mp.Medium(epsilon=eps_B_r, D_conductivity=0*2*np.pi*normalized_frequency*eps_B_i / eps_B_r))
        geometry.append(blk_above)
        blk_below = mp.Block(mp.Vector3(lengthPhC,widthPhC*np.sqrt(3),mp.inf),
                                center=mp.Vector3(0,-widthPhC*np.sqrt(3)/2 - np.sqrt(3)/4 + 0*(yshift + 1/(2*np.sqrt(3))), 0),
                                material=mp.Medium(epsilon=eps_A_r, D_conductivity=2*np.pi*normalized_frequency*eps_A_i / eps_A_r))
        geometry.append(blk_below)
        
        # arrange air-holes
        for j in range(Ny):
            for i in range(Nx+1):
                shift_y = np.sqrt(3)
                geometry.append(mp.Prism(tri_d, height = 1, center=mp.Vector3(i-(Nx+1)/2, yshift + 1/(np.sqrt(3)) + shift_y*(j+1/2))))                
                geometry.append(mp.Prism(tri_u, height = 1, center=mp.Vector3(i-(Nx+1)/2, yshift -(1/(np.sqrt(3)) + shift_y*(j+1/2)))))            
                geometry.append(mp.Prism(tri_d, height = 1, center=mp.Vector3(i-Nx/2, yshift +  1/(np.sqrt(3)) + shift_y*j )))

            if j == 0:
                for i in range(connect,Nx+1-connect):
                    geometry.append(mp.Prism(tri_u, height = 1, center=mp.Vector3(i-Nx/2, yshift - (1/(np.sqrt(3)) + shift_y*j))))
            else:
                for i in range(Nx+1):
                    geometry.append(mp.Prism(tri_u, height = 1, center=mp.Vector3(i-Nx/2, yshift - (1/(np.sqrt(3)) + shift_y*j))))
                    
        for i in range(1,Nx+1):
            geometry.append(mp.Prism(tri_u, height = 1, center=mp.Vector3(i-(Nx+1)/2, yshift - (1/(np.sqrt(3)) + shift_y*(-1/2)))))
        #geometry.append(mp.Prism(tri_d, height = 1, center=mp.Vector3(1, 0)))


                #geometry.append(mp.Cylinder(r, center=mp.Vector3(i-N/2,-wgi*np.sqrt(3)/2)))

    # Gaussian
    sources = [mp.Source(mp.GaussianSource(fcen, fwidth=df),
                            component=mp.Hz,
                            center=mp.Vector3(-length/2 +1,0),
                            size=mp.Vector3(0,wgi*np.sqrt(3)))
                ]

    # PML
    pml_layers = [mp.PML(1.0)]

    # z-symmetry (上下対称なら計算が軽くなる。対称性が無いなら消す)
    #sym = [mp.Mirror(mp.Y, phase=-1)]
    

    ####
    sim = mp.Simulation(cell_size=cell,
                        boundary_layers=pml_layers,
                        geometry=geometry,
                        sources=sources,
                        #symmetries=sym,
                        resolution=resolution)

    #tran_in = mp.FluxRegion(center=mp.Vector3(-lengthPhC/2-1,0),size=mp.Vector3(0, 2*wgi))
    tran_out = mp.FluxRegion(center=mp.Vector3(length/2-3/2,0),size=mp.Vector3(0, 2*wgi))
    #trans_in = sim.add_flux(fcen, df, nfreq, tran_in)
    trans_out = sim.add_flux(fcen, df, nfreq, tran_out)

    # show geometry
    # %matplotlib inline
    f = plt.figure(dpi=500, figsize=(8,16))
    sim.plot2D(ax=f.gca())
    plt.show()    

    #sim.run(until_after_sources=mp.stop_when_fields_decayed(50, mp.Hz, mp.Vector3(decay_check), 1e-3))
    sim.run(until=T_decay)

    freqs = mp.get_flux_freqs(trans_out)
    #psd_in = mp.get_fluxes(trans_in)
    psd_out = mp.get_fluxes(trans_out)

    return freqs, psd_out

# %%
freqs_wo, psd_out_wo = phc_trans(PhC = False, lengthPhC = 20, decay_check=10, T_decay=500)
freqs_w,  psd_out_w  = phc_trans(PhC = True, lengthPhC = 50, decay_check=20, T_decay=10000)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000270844 s
# Working in 2D dimensions.
# Computational cell is 30 x 17.3125 x 0 with resolution 16
#      block, center = (0,0,0)
#           size (1e+20,0.866025,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (6.76,6.76,6.76)
# time for set_epsilon = 0.254593 s
# -----------
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# FloatProgress(value=0.0, description='0% done ', max=500.0)
# Meep progress: 49.9375/500.0 = 10.0% done in 4.0s, 36.1s to go
# on time step 1612 (time=50.375), 0.002483 s/step
# Meep progress: 108.34375/500.0 = 21.7% done in 8.0s, 28.9s to go
# on time step 3483 (time=108.844), 0.00213849 s/step
# Meep progress: 170.15625/500.0 = 34.0% done in 12.0s, 23.3s to go
# on time step 5461 (time=170.656), 0.00202251 s/step
# Meep progress: 224.1875/500.0 = 44.8% done in 16.0s, 19.7s to go
# on time step 7186 (time=224.562), 0.00231985 s/step
# Meep progress: 261.625/500.0 = 52.3% done in 20.0s, 18.2s to go
# on time step 8386 (time=262.062), 0.00333604 s/step
# Meep progress: 303.25/500.0 = 60.6% done in 24.0s, 15.6s to go
# on time step 9723 (time=303.844), 0.00299267 s/step
# Meep progress: 359.125/500.0 = 71.8% done in 28.0s, 11.0s to go
# on time step 11514 (time=359.812), 0.00223384 s/step
# Meep progress: 418.15625/500.0 = 83.6% done in 32.0s, 6.3s to go
# on time step 13399 (time=418.719), 0.00212234 s/step
# Meep progress: 477.875/500.0 = 95.6% done in 36.0s, 1.7s to go
# on time step 15313 (time=478.531), 0.00208995 s/step
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# run 0 finished at t = 500.0 (16000 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.110004 s
# Working in 2D dimensions.
# Computational cell is 60 x 17.3125 x 0 with resolution 16
#      block, center = (0,0,0)
#           size (1e+20,0.866025,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (6.76,6.76,6.76)
#      block, center = (0,8.22724,0)
#           size (50,17.3205,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (6.76,6.76,6.76)
#      block, center = (0,-9.09327,0)
#           size (50,17.3205,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (6.76,6.76,6.76)
#      prism, center = (-25.5,1.01036,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-25.05,1.27017,-0.5)
#           (-25.95,1.27017,-0.5)
#           (-25.5,0.490748,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      prism, center = (-25.5,-1.87639,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-25.95,-2.1362,-0.5)
#           (-25.05,-2.1362,-0.5)
#           (-25.5,-1.35677,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      prism, center = (-25,0.144338,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-24.55,0.404145,-0.5)
#           (-25.45,0.404145,-0.5)
#           (-25,-0.375278,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      prism, center = (-24.5,1.01036,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-24.05,1.27017,-0.5)
#           (-24.95,1.27017,-0.5)
#           (-24.5,0.490748,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      prism, center = (-24.5,-1.87639,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-24.95,-2.1362,-0.5)
#           (-24.05,-2.1362,-0.5)
#           (-24.5,-1.35677,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      prism, center = (-24,0.144338,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-23.55,0.404145,-0.5)
#           (-24.45,0.404145,-0.5)
#           (-24,-0.375278,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      prism, center = (-23.5,1.01036,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-23.05,1.27017,-0.5)
#           (-23.95,1.27017,-0.5)
#           (-23.5,0.490748,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      ...(+ 2083 objects not shown)...
# subpixel-averaging is 60.1265% done, 2.66749 s remaining
# subpixel-averaging is 70.2951% done, 1.69732 s remaining
# subpixel-averaging is 73.3898% done, 1.45733 s remaining
# time for set_epsilon = 19.7724 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=10000.0)
#  s/step
# Meep progress: 6922.625/10000.0 = 69.2% done in 1337.1s, 594.4s to go
# on time step 221604 (time=6925.12), 0.0081062 s/step
# Meep progress: 6938.0/10000.0 = 69.4% done in 1341.1s, 591.9s to go
# on time step 222128 (time=6941.5), 0.00764088 s/step
# Meep progress: 6955.84375/10000.0 = 69.6% done in 1345.1s, 588.7s to go
# on time step 222652 (time=6957.88), 0.00765114 s/step
# Meep progress: 6965.3125/10000.0 = 69.7% done in 1349.7s, 588.0s to go
# on time step 222903 (time=6965.72), 0.0159517 s/step
# Meep progress: 6970.9375/10000.0 = 69.7% done in 1353.7s, 588.2s to go
# on time step 223083 (time=6971.34), 0.0222726 s/step
# Meep progress: 6985.46875/10000.0 = 69.9% done in 1357.7s, 585.9s to go
# on time step 223550 (time=6985.94), 0.00856636 s/step
# Meep progress: 7003.46875/10000.0 = 70.0% done in 1361.7s, 582.6s to go
# on time step 224126 (time=7003.94), 0.00694757 s/step
# Meep progress: 7019.03125/10000.0 = 70.2% done in 1365.7s, 580.0s to go
# on time step 224624 (time=7019.5), 0.00804805 s/step
# Meep progress: 7033.375/10000.0 = 70.3% done in 1369.7s, 577.7s to go
# on time step 225091 (time=7034.09), 0.00857492 s/step
# Meep progress: 7053.28125/10000.0 = 70.5% done in 1373.7s, 573.9s to go
# on time step 225724 (time=7053.88), 0.0063214 s/step
# Meep progress: 7069.6875/10000.0 = 70.7% done in 1377.7s, 571.1s to go
# on time step 226244 (time=7070.12), 0.00770044 s/step
# Meep progress: 7089.5625/10000.0 = 70.9% done in 1381.7s, 567.2s to go
# on time step 226887 (time=7090.22), 0.00622097 s/step
# Meep progress: 7108.375/10000.0 = 71.1% done in 1385.7s, 563.7s to go
# on time step 227487 (time=7108.97), 0.00666755 s/step
# Meep progress: 7126.40625/10000.0 = 71.3% done in 1389.7s, 560.4s to go
# on time step 228059 (time=7126.84), 0.00700032 s/step
# Meep progress: 7146.1875/10000.0 = 71.5% done in 1393.7s, 556.6s to go
# on time step 228696 (time=7146.75), 0.00628188 s/step
# Meep progress: 7167.84375/10000.0 = 71.7% done in 1397.7s, 552.3s to go
# on time step 229395 (time=7168.59), 0.00572865 s/step
# Meep progress: 7188.375/10000.0 = 71.9% done in 1401.7s, 548.3s to go
# on time step 230048 (time=7189), 0.00612767 s/step
# Meep progress: 7206.6875/10000.0 = 72.1% done in 1405.7s, 544.9s to go
# on time step 230633 (time=7207.28), 0.00684219 s/step
# Meep progress: 7226.34375/10000.0 = 72.3% done in 1409.8s, 541.1s to go
# on time step 231263 (time=7226.97), 0.00634975 s/step
# Meep progress: 7244.40625/10000.0 = 72.4% done in 1413.8s, 537.8s to go
# on time step 231841 (time=7245.03), 0.00692888 s/step
# Meep progress: 7264.15625/10000.0 = 72.6% done in 1417.8s, 534.0s to go
# on time step 232474 (time=7264.81), 0.00632186 s/step
# Meep progress: 7285.53125/10000.0 = 72.9% done in 1421.8s, 529.7s to go
# on time step 233161 (time=7286.28), 0.00582865 s/step
# Meep progress: 7304.59375/10000.0 = 73.0% done in 1425.8s, 526.1s to go
# on time step 233760 (time=7305), 0.00670096 s/step
# Meep progress: 7323.375/10000.0 = 73.2% done in 1429.8s, 522.6s to go
# on time step 234369 (time=7324.03), 0.00657459 s/step
# Meep progress: 7342.59375/10000.0 = 73.4% done in 1433.8s, 518.9s to go
# on time step 234988 (time=7343.38), 0.00646365 s/step
# Meep progress: 7362.96875/10000.0 = 73.6% done in 1437.8s, 514.9s to go
# on time step 235628 (time=7363.38), 0.006252 s/step
# Meep progress: 7381.875/10000.0 = 73.8% done in 1441.8s, 511.4s to go
# on time step 236244 (time=7382.62), 0.00650237 s/step
# Meep progress: 7402.71875/10000.0 = 74.0% done in 1445.8s, 507.3s to go
# on time step 236906 (time=7403.31), 0.00605437 s/step
# Meep progress: 7423.6875/10000.0 = 74.2% done in 1449.8s, 503.1s to go
# on time step 237583 (time=7424.47), 0.00590986 s/step
# Meep progress: 7444.75/10000.0 = 74.4% done in 1453.8s, 499.0s to go
# on time step 238257 (time=7445.53), 0.00594122 s/step
# Meep progress: 7463.53125/10000.0 = 74.6% done in 1457.8s, 495.4s to go
# on time step 238860 (time=7464.38), 0.00663431 s/step
# Meep progress: 7483.34375/10000.0 = 74.8% done in 1461.8s, 491.6s to go
# on time step 239491 (time=7484.09), 0.00634203 s/step
# Meep progress: 7504.71875/10000.0 = 75.0% done in 1465.8s, 487.4s to go
# on time step 240174 (time=7505.44), 0.00585831 s/step
# Meep progress: 7525.53125/10000.0 = 75.3% done in 1469.8s, 483.3s to go
# on time step 240839 (time=7526.22), 0.00602231 s/step
# Meep progress: 7540.4375/10000.0 = 75.4% done in 1473.8s, 480.7s to go
# on time step 241318 (time=7541.19), 0.00835467 s/step
# Meep progress: 7560.28125/10000.0 = 75.6% done in 1477.8s, 476.9s to go
# on time step 241957 (time=7561.16), 0.00626084 s/step
# Meep progress: 7583.15625/10000.0 = 75.8% done in 1481.8s, 472.3s to go
# on time step 242688 (time=7584), 0.0054776 s/step
# Meep progress: 7606.375/10000.0 = 76.1% done in 1485.8s, 467.6s to go
# on time step 243432 (time=7607.25), 0.00538076 s/step
# Meep progress: 7630.3125/10000.0 = 76.3% done in 1489.8s, 462.7s to go
# on time step 244199 (time=7631.22), 0.00522011 s/step
# Meep progress: 7651.125/10000.0 = 76.5% done in 1493.8s, 458.6s to go
# on time step 244862 (time=7651.94), 0.00603911 s/step
# Meep progress: 7671.09375/10000.0 = 76.7% done in 1497.8s, 454.7s to go
# on time step 245503 (time=7671.97), 0.0062429 s/step
# Meep progress: 7693.28125/10000.0 = 76.9% done in 1501.8s, 450.3s to go
# on time step 246213 (time=7694.16), 0.00563541 s/step
# Meep progress: 7714.34375/10000.0 = 77.1% done in 1505.8s, 446.2s to go
# on time step 246879 (time=7714.97), 0.00601465 s/step
# Meep progress: 7735.625/10000.0 = 77.4% done in 1509.8s, 442.0s to go
# on time step 247569 (time=7736.53), 0.00580031 s/step
# Meep progress: 7758.90625/10000.0 = 77.6% done in 1513.8s, 437.3s to go
# on time step 248309 (time=7759.66), 0.00540964 s/step
# Meep progress: 7774.375/10000.0 = 77.7% done in 1517.8s, 434.5s to go
# on time step 248802 (time=7775.06), 0.0081178 s/step
# Meep progress: 7789.84375/10000.0 = 77.9% done in 1521.9s, 431.8s to go
# on time step 249290 (time=7790.31), 0.00819867 s/step
# Meep progress: 7801.375/10000.0 = 78.0% done in 1525.9s, 430.0s to go
# on time step 249658 (time=7801.81), 0.0109054 s/step
# Meep progress: 7813.59375/10000.0 = 78.1% done in 1529.9s, 428.1s to go
# on time step 250050 (time=7814.06), 0.0102209 s/step
# Meep progress: 7829.3125/10000.0 = 78.3% done in 1533.9s, 425.3s to go
# on time step 250564 (time=7830.12), 0.00778648 s/step
# Meep progress: 7848.6875/10000.0 = 78.5% done in 1537.9s, 421.5s to go
# on time step 251181 (time=7849.41), 0.00648316 s/step
# Meep progress: 7866.875/10000.0 = 78.7% done in 1541.9s, 418.1s to go
# on time step 251762 (time=7867.56), 0.00689402 s/step
# Meep progress: 7880.71875/10000.0 = 78.8% done in 1545.9s, 415.7s to go
# on time step 252205 (time=7881.41), 0.00902983 s/step
# Meep progress: 7900.4375/10000.0 = 79.0% done in 1549.9s, 411.9s to go
# on time step 252833 (time=7901.03), 0.0063697 s/step
# Meep progress: 7924.09375/10000.0 = 79.2% done in 1553.9s, 407.1s to go
# on time step 253597 (time=7924.91), 0.00524005 s/step
# Meep progress: 7943.90625/10000.0 = 79.4% done in 1557.9s, 403.2s to go
# on time step 254230 (time=7944.69), 0.00632019 s/step
# Meep progress: 7965.5/10000.0 = 79.7% done in 1561.9s, 398.9s to go
# on time step 254924 (time=7966.38), 0.0057699 s/step
# Meep progress: 7983.4375/10000.0 = 79.8% done in 1565.9s, 395.5s to go
# on time step 255484 (time=7983.88), 0.0071592 s/step
# Meep progress: 8004.84375/10000.0 = 80.0% done in 1569.9s, 391.3s to go
# on time step 256183 (time=8005.72), 0.00572592 s/step
# Meep progress: 8026.34375/10000.0 = 80.3% done in 1573.9s, 387.0s to go
# on time step 256874 (time=8027.31), 0.00579566 s/step
# Meep progress: 8048.34375/10000.0 = 80.5% done in 1577.9s, 382.6s to go
# on time step 257574 (time=8049.19), 0.00571863 s/step
# Meep progress: 8068.03125/10000.0 = 80.7% done in 1581.9s, 378.8s to go
# on time step 258207 (time=8068.97), 0.00632626 s/step
# Meep progress: 8086.28125/10000.0 = 80.9% done in 1585.9s, 375.3s to go
# on time step 258791 (time=8087.22), 0.00686161 s/step
# Meep progress: 8106.15625/10000.0 = 81.1% done in 1589.9s, 371.5s to go
# on time step 259403 (time=8106.34), 0.00654463 s/step
# Meep progress: 8122.96875/10000.0 = 81.2% done in 1593.9s, 368.3s to go
# on time step 259957 (time=8123.66), 0.00722166 s/step
# Meep progress: 8144.5/10000.0 = 81.4% done in 1597.9s, 364.0s to go
# on time step 260650 (time=8145.31), 0.00577382 s/step
# Meep progress: 8160.75/10000.0 = 81.6% done in 1602.0s, 361.0s to go
# on time step 261165 (time=8161.41), 0.00777906 s/step
# Meep progress: 8177.03125/10000.0 = 81.8% done in 1606.0s, 358.0s to go
# on time step 261685 (time=8177.66), 0.0077003 s/step
# Meep progress: 8198.625/10000.0 = 82.0% done in 1610.0s, 353.7s to go
# on time step 262381 (time=8199.41), 0.00575486 s/step
# Meep progress: 8220.40625/10000.0 = 82.2% done in 1614.0s, 349.4s to go
# on time step 263080 (time=8221.25), 0.00573174 s/step
# Meep progress: 8242.78125/10000.0 = 82.4% done in 1618.0s, 344.9s to go
# on time step 263800 (time=8243.75), 0.00555773 s/step
# Meep progress: 8264.6875/10000.0 = 82.6% done in 1622.0s, 340.6s to go
# on time step 264493 (time=8265.41), 0.00577644 s/step
# Meep progress: 8284.6875/10000.0 = 82.8% done in 1626.0s, 336.7s to go
# on time step 265136 (time=8285.5), 0.00622809 s/step
# Meep progress: 8302.0625/10000.0 = 83.0% done in 1630.0s, 333.4s to go
# on time step 265699 (time=8303.09), 0.0071093 s/step
# Meep progress: 8322.75/10000.0 = 83.2% done in 1634.0s, 329.3s to go
# on time step 266352 (time=8323.5), 0.00613445 s/step
# Meep progress: 8343.125/10000.0 = 83.4% done in 1638.0s, 325.3s to go
# on time step 267009 (time=8344.03), 0.006095 s/step
# Meep progress: 8363.1875/10000.0 = 83.6% done in 1642.0s, 321.4s to go
# on time step 267645 (time=8363.91), 0.00629864 s/step
# Meep progress: 8381.96875/10000.0 = 83.8% done in 1646.0s, 317.7s to go
# on time step 268250 (time=8382.81), 0.00661807 s/step
# Meep progress: 8402.125/10000.0 = 84.0% done in 1650.0s, 313.8s to go
# on time step 268895 (time=8402.97), 0.00620745 s/step
# Meep progress: 8421.8125/10000.0 = 84.2% done in 1654.0s, 309.9s to go
# on time step 269528 (time=8422.75), 0.00632471 s/step
# Meep progress: 8442.8125/10000.0 = 84.4% done in 1658.0s, 305.8s to go
# on time step 270186 (time=8443.31), 0.00609138 s/step
# Meep progress: 8461.65625/10000.0 = 84.6% done in 1662.0s, 302.2s to go
# on time step 270792 (time=8462.25), 0.00660431 s/step
# Meep progress: 8482.3125/10000.0 = 84.8% done in 1666.0s, 298.1s to go
# on time step 271446 (time=8482.69), 0.00612197 s/step
# Meep progress: 8502.71875/10000.0 = 85.0% done in 1670.0s, 294.1s to go
# on time step 272116 (time=8503.62), 0.00597256 s/step
# Meep progress: 8522.59375/10000.0 = 85.2% done in 1674.0s, 290.2s to go
# on time step 272744 (time=8523.25), 0.00637314 s/step
# Meep progress: 8539.9375/10000.0 = 85.4% done in 1678.0s, 286.9s to go
# on time step 273305 (time=8540.78), 0.00713916 s/step
# Meep progress: 8559.5625/10000.0 = 85.6% done in 1682.0s, 283.1s to go
# on time step 273916 (time=8559.88), 0.00655561 s/step
# Meep progress: 8581.125/10000.0 = 85.8% done in 1686.1s, 278.8s to go
# on time step 274626 (time=8582.06), 0.00563586 s/step
# Meep progress: 8605.15625/10000.0 = 86.1% done in 1690.1s, 273.9s to go
# on time step 275396 (time=8606.12), 0.00519652 s/step
# Meep progress: 8625.875/10000.0 = 86.3% done in 1694.1s, 269.9s to go
# on time step 276041 (time=8626.28), 0.00620993 s/step
# Meep progress: 8642.78125/10000.0 = 86.4% done in 1698.1s, 266.7s to go
# on time step 276588 (time=8643.38), 0.00731397 s/step
# Meep progress: 8660.625/10000.0 = 86.6% done in 1702.1s, 263.2s to go
# on time step 277172 (time=8661.62), 0.00685365 s/step
# Meep progress: 8684.71875/10000.0 = 86.8% done in 1706.1s, 258.4s to go
# on time step 277940 (time=8685.62), 0.00521103 s/step
# Meep progress: 8706.875/10000.0 = 87.1% done in 1710.1s, 254.0s to go
# on time step 278649 (time=8707.78), 0.00565234 s/step
# Meep progress: 8726.125/10000.0 = 87.3% done in 1714.1s, 250.2s to go
# on time step 279266 (time=8727.06), 0.00648904 s/step
# Meep progress: 8745.375/10000.0 = 87.5% done in 1718.1s, 246.5s to go
# on time step 279880 (time=8746.25), 0.00651675 s/step
# Meep progress: 8763.6875/10000.0 = 87.6% done in 1722.1s, 242.9s to go
# on time step 280472 (time=8764.75), 0.00676573 s/step
# Meep progress: 8785.5625/10000.0 = 87.9% done in 1726.1s, 238.6s to go
# on time step 281170 (time=8786.56), 0.00573176 s/step
# Meep progress: 8804.65625/10000.0 = 88.0% done in 1730.1s, 234.9s to go
# on time step 281775 (time=8805.47), 0.00661682 s/step
# Meep progress: 8825.65625/10000.0 = 88.3% done in 1734.1s, 230.7s to go
# on time step 282454 (time=8826.69), 0.00589823 s/step
# Meep progress: 8847.8125/10000.0 = 88.5% done in 1738.1s, 226.3s to go
# on time step 283163 (time=8848.84), 0.0056474 s/step
# Meep progress: 8867.1875/10000.0 = 88.7% done in 1742.1s, 222.6s to go
# on time step 283786 (time=8868.31), 0.00642264 s/step
# Meep progress: 8887.40625/10000.0 = 88.9% done in 1746.1s, 218.6s to go
# on time step 284433 (time=8888.53), 0.00618655 s/step
# Meep progress: 8906.09375/10000.0 = 89.1% done in 1750.1s, 215.0s to go
# on time step 285026 (time=8907.06), 0.00674573 s/step
# Meep progress: 8927.75/10000.0 = 89.3% done in 1754.1s, 210.7s to go
# on time step 285725 (time=8928.91), 0.00572859 s/step
# Meep progress: 8947.84375/10000.0 = 89.5% done in 1758.1s, 206.7s to go
# on time step 286363 (time=8948.84), 0.00627127 s/step
# Meep progress: 8966.625/10000.0 = 89.7% done in 1762.1s, 203.1s to go
# on time step 286962 (time=8967.56), 0.00669308 s/step
# Meep progress: 8987.96875/10000.0 = 89.9% done in 1766.1s, 198.9s to go
# on time step 287648 (time=8989), 0.00583741 s/step
# Meep progress: 9009.5/10000.0 = 90.1% done in 1770.1s, 194.6s to go
# on time step 288336 (time=9010.5), 0.00582026 s/step
# Meep progress: 9032.90625/10000.0 = 90.3% done in 1774.1s, 189.9s to go
# on time step 289091 (time=9034.09), 0.00530235 s/step
# Meep progress: 9055.875/10000.0 = 90.6% done in 1778.1s, 185.4s to go
# on time step 289827 (time=9057.09), 0.00544097 s/step
# Meep progress: 9079.78125/10000.0 = 90.8% done in 1782.1s, 180.6s to go
# on time step 290594 (time=9081.06), 0.00521795 s/step
# Meep progress: 9102.78125/10000.0 = 91.0% done in 1786.1s, 176.1s to go
# on time step 291326 (time=9103.94), 0.00546764 s/step
# Meep progress: 9126.6875/10000.0 = 91.3% done in 1790.1s, 171.3s to go
# on time step 292094 (time=9127.94), 0.00521054 s/step
# Meep progress: 9146.8125/10000.0 = 91.5% done in 1794.1s, 167.4s to go
# on time step 292719 (time=9147.47), 0.00640082 s/step
# Meep progress: 9162.96875/10000.0 = 91.6% done in 1798.2s, 164.3s to go
# on time step 293247 (time=9163.97), 0.00757859 s/step
# Meep progress: 9182.1875/10000.0 = 91.8% done in 1802.2s, 160.5s to go
# on time step 293864 (time=9183.25), 0.00649052 s/step
# Meep progress: 9203.34375/10000.0 = 92.0% done in 1806.2s, 156.3s to go
# on time step 294541 (time=9204.41), 0.00591081 s/step
# Meep progress: 9224.59375/10000.0 = 92.2% done in 1810.2s, 152.2s to go
# on time step 295216 (time=9225.5), 0.005931 s/step
# Meep progress: 9244.71875/10000.0 = 92.4% done in 1814.2s, 148.2s to go
# on time step 295868 (time=9245.88), 0.00614079 s/step
# Meep progress: 9267.9375/10000.0 = 92.7% done in 1818.2s, 143.6s to go
# on time step 296611 (time=9269.09), 0.00538793 s/step
# Meep progress: 9290.46875/10000.0 = 92.9% done in 1822.2s, 139.2s to go
# on time step 297331 (time=9291.59), 0.00556123 s/step
# Meep progress: 9314.0625/10000.0 = 93.1% done in 1826.2s, 134.5s to go
# on time step 298087 (time=9315.22), 0.0052914 s/step
# Meep progress: 9336.15625/10000.0 = 93.4% done in 1830.2s, 130.1s to go
# on time step 298797 (time=9337.41), 0.00563687 s/step
# Meep progress: 9359.15625/10000.0 = 93.6% done in 1834.2s, 125.6s to go
# on time step 299511 (time=9359.72), 0.00561029 s/step
# Meep progress: 9373.5625/10000.0 = 93.7% done in 1838.2s, 122.8s to go
# on time step 299985 (time=9374.53), 0.00845712 s/step
# Meep progress: 9389.84375/10000.0 = 93.9% done in 1842.2s, 119.7s to go
# on time step 300514 (time=9391.06), 0.00756367 s/step
# Meep progress: 9411.5/10000.0 = 94.1% done in 1846.2s, 115.4s to go
# on time step 301206 (time=9412.69), 0.00578379 s/step
# Meep progress: 9430.96875/10000.0 = 94.3% done in 1850.2s, 111.6s to go
# on time step 301824 (time=9432), 0.00647972 s/step
# Meep progress: 9447.4375/10000.0 = 94.5% done in 1854.2s, 108.4s to go
# on time step 302356 (time=9448.62), 0.00751912 s/step
# Meep progress: 9469.34375/10000.0 = 94.7% done in 1858.2s, 104.1s to go
# on time step 303053 (time=9470.41), 0.00574506 s/step
# Meep progress: 9486.375/10000.0 = 94.9% done in 1862.2s, 100.8s to go
# on time step 303585 (time=9487.03), 0.00752189 s/step
# Meep progress: 9502.6875/10000.0 = 95.0% done in 1866.2s, 97.7s to go
# on time step 304113 (time=9503.53), 0.00759603 s/step
# Meep progress: 9521.46875/10000.0 = 95.2% done in 1870.2s, 94.0s to go
# on time step 304729 (time=9522.78), 0.00649918 s/step
# Meep progress: 9541.5/10000.0 = 95.4% done in 1874.2s, 90.1s to go
# on time step 305359 (time=9542.47), 0.00635916 s/step
# Meep progress: 9559.28125/10000.0 = 95.6% done in 1878.2s, 86.6s to go
# on time step 305929 (time=9560.28), 0.0070264 s/step
# Meep progress: 9578.90625/10000.0 = 95.8% done in 1882.2s, 82.7s to go
# on time step 306561 (time=9580.03), 0.00633841 s/step
# Meep progress: 9598.25/10000.0 = 96.0% done in 1886.2s, 79.0s to go
# on time step 307185 (time=9599.53), 0.00641696 s/step
# Meep progress: 9617.90625/10000.0 = 96.2% done in 1890.2s, 75.1s to go
# on time step 307814 (time=9619.19), 0.00636535 s/step
# Meep progress: 9637.625/10000.0 = 96.4% done in 1894.2s, 71.2s to go
# on time step 308430 (time=9638.44), 0.0065024 s/step
# Meep progress: 9655.34375/10000.0 = 96.6% done in 1898.2s, 67.8s to go
# on time step 309014 (time=9656.69), 0.00685705 s/step
# Meep progress: 9674.5625/10000.0 = 96.7% done in 1902.2s, 64.0s to go
# on time step 309624 (time=9675.75), 0.00655739 s/step
# Meep progress: 9693.96875/10000.0 = 96.9% done in 1906.2s, 60.2s to go
# on time step 310240 (time=9695), 0.00650251 s/step
# Meep progress: 9711.15625/10000.0 = 97.1% done in 1910.2s, 56.8s to go
# on time step 310805 (time=9712.66), 0.00708427 s/step
# Meep progress: 9731.84375/10000.0 = 97.3% done in 1914.2s, 52.7s to go
# on time step 311467 (time=9733.34), 0.00604679 s/step
# Meep progress: 9753.5625/10000.0 = 97.5% done in 1918.2s, 48.5s to go
# on time step 312155 (time=9754.84), 0.00582819 s/step
# Meep progress: 9773.6875/10000.0 = 97.7% done in 1922.2s, 44.5s to go
# on time step 312808 (time=9775.25), 0.00612565 s/step
# Meep progress: 9789.4375/10000.0 = 97.9% done in 1926.2s, 41.4s to go
# on time step 313293 (time=9790.41), 0.00826619 s/step
# Meep progress: 9798.4375/10000.0 = 98.0% done in 1930.2s, 39.7s to go
# on time step 313580 (time=9799.38), 0.013964 s/step
# Meep progress: 9808.8125/10000.0 = 98.1% done in 1934.2s, 37.7s to go
# on time step 313927 (time=9810.22), 0.0115463 s/step
# Meep progress: 9826.78125/10000.0 = 98.3% done in 1938.2s, 34.2s to go
# on time step 314509 (time=9828.41), 0.0068829 s/step
# Meep progress: 9846.59375/10000.0 = 98.5% done in 1942.2s, 30.3s to go
# on time step 315144 (time=9848.25), 0.0063098 s/step
# Meep progress: 9865.15625/10000.0 = 98.7% done in 1946.2s, 26.6s to go
# on time step 315741 (time=9866.91), 0.00670419 s/step
# Meep progress: 9883.40625/10000.0 = 98.8% done in 1950.2s, 23.0s to go
# on time step 316323 (time=9885.09), 0.00688148 s/step
# Meep progress: 9903.34375/10000.0 = 99.0% done in 1954.3s, 19.1s to go
# on time step 316963 (time=9905.09), 0.00625549 s/step
# Meep progress: 9921.53125/10000.0 = 99.2% done in 1958.3s, 15.5s to go
# on time step 317545 (time=9923.28), 0.00687977 s/step
# Meep progress: 9939.125/10000.0 = 99.4% done in 1962.3s, 12.0s to go
# on time step 318107 (time=9940.84), 0.00712304 s/step
# Meep progress: 9955.40625/10000.0 = 99.6% done in 1966.3s, 8.8s to go
# on time step 318631 (time=9957.22), 0.0076368 s/step
# Meep progress: 9975.625/10000.0 = 99.8% done in 1970.3s, 4.8s to go
# on time step 319270 (time=9977.19), 0.00626612 s/step
# Meep progress: 9995.78125/10000.0 = 100.0% done in 1974.3s, 0.8s to go
# on time step 319921 (time=9997.53), 0.00615067 s/step
# run 0 finished at t = 10000.0 (320000 timesteps)

# %%
plt.plot(freqs_wo,psd_out_wo)
plt.grid(True)

# %%
plt.plot(freqs_w,psd_out_w)
plt.grid(True)

# %%
plt.plot(np.array(freqs_w), np.array(psd_out_w)/np.array(psd_out_wo))
plt.xlabel("Frequency[c/a]")
plt.ylabel("Transmittance[c/a]")
plt.yscale('log')
plt.grid(True)
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
plt.plot(np.array(freqs_w), np.array(psd_out_w)/np.array(psd_out_wo))
plt.xlabel("Frequency[c/a]")
plt.ylabel("Transmittance[c/a]")
plt.yscale('log')
plt.grid(True)

# %%
a = 470
c_const = 299792458

freqs = a / np.array(freqs_w)
#freqs
plt.plot(freqs, np.array(psd_out_w)/np.array(psd_out_wo))
plt.scatter(freqs, np.array(psd_out_w)/np.array(psd_out_wo))
plt.xlabel("Frequency[c/a]")
plt.ylabel("Transmittance[c/a]")
#plt.xlim([0.28,0.30])
plt.yscale('log')
plt.grid(True)

# %%
freqs = a / np.array(freqs_w)
#freqs
plt.plot(freqs, np.array(psd_out_w)/np.array(psd_out_wo))
plt.scatter(freqs, np.array(psd_out_w)/np.array(psd_out_wo))
plt.xlabel("Frequency[c/a]")
plt.ylabel("Transmittance[c/a]")
plt.xlim([1400,1550])
plt.yscale('log')
plt.ylim([1e-7,1e-0])
plt.grid(True)

# %%
freqs = a / np.array(freqs_w)
#freqs
plt.plot(freqs, np.array(psd_out_w)/np.array(psd_out_wo))
plt.scatter(freqs, np.array(psd_out_w)/np.array(psd_out_wo))
plt.xlabel("Frequency[c/a]")
plt.ylabel("Transmittance[c/a]")
plt.xlim([1400,1550])
plt.yscale('log')
plt.ylim([1e-7,1e-5])
plt.grid(True)

# %%
df = pd.DataFrame()
df["wavelength"] = freqs
df["transmittance"] = np.array(psd_out_w)/np.array(psd_out_wo)
df.to_csv("210122_resolution16_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d090_uasq34b_km05.ipynb")

# %%
df
# Out:
#        wavelength  transmittance
# 0     2350.000000       0.075326
# 1     2349.530000       0.075350
# 2     2349.060188       0.075379
# 3     2348.590564       0.075425
# 4     2348.121127       0.075477
# ...           ...            ...
# 4995  1175.470282       0.093933
# 4996  1175.352676       0.094882
# 4997  1175.235094       0.095807
# 4998  1175.117535       0.096707
# 4999  1175.000000       0.097589
#
# [5000 rows x 2 columns]
