# %% [markdown]
# https://github.com/NanoComp/meep/blob/master/python/examples/straight-waveguide.ipynb
#
# https://stackoverflow.com/questions/29454002/filenotfounderror-errno-2-no-such-file-or-directory-ffmpeg

# %%
import math
import meep as mp
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from matplotlib import rc
rc('text', usetex=False)
#plt.rcParams['font.family'] = 'Times New Roman'#使用するフォント
#plt.rcParams['mathtext.fontset'] = 'stix' # math fontの設定
plt.rcParams['font.family']= 'sans-serif'
plt.rcParams['font.sans-serif'] = ['Arial']
plt.rcParams["font.size"] = 15 # 全体のフォントサイズが変更されます。
plt.rcParams['xtick.direction'] = 'in'#x軸の目盛線が内向き('in')か外向き('out')か双方向か('inout')
plt.rcParams['ytick.direction'] = 'in'#y軸の目盛線が内向き('in')か外向き('out')か双方向か('inout')
# Out:
# Using MPI version 3.1, 1 processes

# %%
def eps_to_eps(eps_A_r,eps_A_i):
    eps_A = eps_A_r + 1.j*eps_A_i
    eps_Ainv = 1 / eps_A

    eps_Ainv_r = eps_Ainv.real
    eps_Ainv_i = -eps_Ainv.imag

    #print(eps_Ainv_r, eps_Ainv_i)

    eps_B_r = eps_A_r + 1/eps_Ainv_r * (eps_Ainv_i**2) / (eps_Ainv_r**2 + eps_Ainv_i**2)
    eps_B_i = 0

    eps_B = eps_B_r + 1.j*eps_B_i
    eps_Binv = 1 / eps_B

    eps_Binv_r = eps_Binv.real
    eps_Binv_i = -eps_Binv.imag

    #print(eps_Binv_r, eps_Binv_i)
    return eps_B_r, eps_B_i

# %%
def phc_trans(PhC = True, lengthPhC = 100, decay_check=0, T_decay=500):
    """
    <変数の説明>
    PhC...PhC(フォトニック決勝)を配置するかどうか。Falseで直線導波路
    lengthPhC...PhC導波方向の長さ
    widthPhC...PhC垂直方向の幅。PMLと被ってるので適当。
    ConnectionWaveguide...PhCに接続するSi導波路(棒の部分)の長さ
    wgi...導波路の幅を調整する。1で丸穴一個分空いてることを意味する。0.7とかにすると狭くなってバンドの形が変わる、っていうのはDaii君の研究とも絡む。
    r...穴の半径。ふつうはa/4くらい。meepだと格子定数は1で固定だから、格子定数との比を入力すればOK
    n_eff...屈折率。2次元だと2.5~2.7くらいにしておくと3次元のSi系(n_Si=3.48)と結果が近くなる。違う材料を使うときは要調整、通常はdefaultで大丈夫。
    fcen...入力光（ガウシアンビーム）の中心周波数。知りたいPhCバンドの周波数近くに設定する
    df...入力光（ガウシアンビーム）の半値幅（で合ってる？）
    nfreq...入力光（ガウシアンビーム）のきめ細かさ
    resolution...メッシュの細かさ。2^nにすると計算が軽くなるらしい。
    T_dacay...反復計算数。小さいと誤差が増え、大きいと時間がかかる。sim.run(until_after_sources=...)で計算時間を見積もってから変えるとよさそう
    decay_check...解の収束をどこで判定するか、位置を指定。defaultでOK

    <備考>
    ・meepでは格子定数aはパラメータに含まれないので設定不要
    　誘電体を使うときは入力するらしい（スケール依存性が出るから）
    ・THzやnmは使用せず、すべて規格化周波数で入力する (周波数はωa/2πcで直す)
    """
    ##### setting of parameters #####
    a = 1 # CADに移行しやすいように予め設定しておく
    widthPhC = 10
    ConnectionWaveguide = 5
    wgi = 1/2 #/np.sqrt(3)/2
    whetero = 1/np.sqrt(3)/4
    r = 1/4
    d_0 = 0.85*a
    yshift = -np.sqrt(3)/4*a #1/(np.sqrt(3)) #+ 1/6*np.sqrt(3)/2*d_0

    #n_eff = 2.6

    eps_A_r = 2.6**2
    eps_A_i = 0.5
    eps_B_r = eps_A_r
    eps_B_i = 0

    fcen = 0.29
    df = 0.2
    nfreq = 500 # number of frequencies at which to compute flux
    resolution = 32

    connect = 0
    #####
    length = lengthPhC + 2*ConnectionWaveguide
    width = widthPhC
    Nx = int(lengthPhC)
    Ny = int(widthPhC)

    # settings of imaginary part
    normalized_frequency = 0.3
    #extinction_coefficient = 0.2

    ##### settings of geometry #####
    # initialization
    cell = mp.Vector3(length,width*np.sqrt(3),0)

    # Si waveguide
    waveguide = mp.Block(mp.Vector3(mp.inf,wgi*np.sqrt(3),mp.inf),
                            center=mp.Vector3(),
                            material=mp.Medium(epsilon=eps_B_r))
    geometry = [waveguide]

    # PhC
    if PhC:
        # triangle
        tri_u = [
                mp.Vector3(-np.sqrt(3)/2,-1/2)*d_0/np.sqrt(3),
                mp.Vector3( np.sqrt(3)/2,-1/2)*d_0/np.sqrt(3),
                mp.Vector3(            0,   1)*d_0/np.sqrt(3),
                ]
        tri_d = [
                mp.Vector3(-np.sqrt(3)/2,-1/2)*d_0/np.sqrt(3)*(-1),
                mp.Vector3( np.sqrt(3)/2,-1/2)*d_0/np.sqrt(3)*(-1),
                mp.Vector3(            0,   1)*d_0/np.sqrt(3)*(-1),
                ]

        # slab
        blk_above = mp.Block(mp.Vector3(lengthPhC,widthPhC*np.sqrt(3),mp.inf),
                                center=mp.Vector3(0, widthPhC*np.sqrt(3)/2 - np.sqrt(3)/4 + 0*(yshift + 1/(2*np.sqrt(3))), 0),
                                material=mp.Medium(epsilon=eps_B_r, D_conductivity=2*np.pi*normalized_frequency*eps_B_i / eps_B_r))
        geometry.append(blk_above)
        blk_below = mp.Block(mp.Vector3(lengthPhC,widthPhC*np.sqrt(3),mp.inf),
                                center=mp.Vector3(0,-widthPhC*np.sqrt(3)/2 - np.sqrt(3)/4 + 0*(yshift + 1/(2*np.sqrt(3))), 0),
                                material=mp.Medium(epsilon=eps_A_r, D_conductivity=2*np.pi*normalized_frequency*eps_A_i / eps_A_r))
        geometry.append(blk_below)
        
        # arrange air-holes
        for j in range(Ny):
            for i in range(Nx+1):
                shift_y = np.sqrt(3)
                geometry.append(mp.Prism(tri_d, height = 1, center=mp.Vector3(i-(Nx+1)/2, yshift + 1/(np.sqrt(3)) + shift_y*(j+1/2))))                
                geometry.append(mp.Prism(tri_u, height = 1, center=mp.Vector3(i-(Nx+1)/2, yshift -(1/(np.sqrt(3)) + shift_y*(j+1/2)))))            
                geometry.append(mp.Prism(tri_d, height = 1, center=mp.Vector3(i-Nx/2, yshift +  1/(np.sqrt(3)) + shift_y*j )))

            if j == 0:
                for i in range(connect,Nx+1-connect):
                    geometry.append(mp.Prism(tri_u, height = 1, center=mp.Vector3(i-Nx/2, yshift - (1/(np.sqrt(3)) + shift_y*j))))
            else:
                for i in range(Nx+1):
                    geometry.append(mp.Prism(tri_u, height = 1, center=mp.Vector3(i-Nx/2, yshift - (1/(np.sqrt(3)) + shift_y*j))))
                    
        for i in range(1,Nx+1):
            geometry.append(mp.Prism(tri_u, height = 1, center=mp.Vector3(i-(Nx+1)/2, yshift - (1/(np.sqrt(3)) + shift_y*(-1/2)))))
        #geometry.append(mp.Prism(tri_d, height = 1, center=mp.Vector3(1, 0)))


                #geometry.append(mp.Cylinder(r, center=mp.Vector3(i-N/2,-wgi*np.sqrt(3)/2)))

    # Gaussian
    sources = [mp.Source(mp.GaussianSource(fcen, fwidth=df),
                            component=mp.Hz,
                            center=mp.Vector3(-length/2 +1,0),
                            size=mp.Vector3(0,wgi*np.sqrt(3)))
                ]

    # PML
    pml_layers = [mp.PML(1.0)]

    # z-symmetry (上下対称なら計算が軽くなる。対称性が無いなら消す)
    #sym = [mp.Mirror(mp.Y, phase=-1)]
    

    ####
    sim = mp.Simulation(cell_size=cell,
                        boundary_layers=pml_layers,
                        geometry=geometry,
                        sources=sources,
                        #symmetries=sym,
                        resolution=resolution)

    #tran_in = mp.FluxRegion(center=mp.Vector3(-lengthPhC/2-1,0),size=mp.Vector3(0, 2*wgi))
    tran_out = mp.FluxRegion(center=mp.Vector3(length/2-3/2,0),size=mp.Vector3(0, 2*wgi))
    #trans_in = sim.add_flux(fcen, df, nfreq, tran_in)
    trans_out = sim.add_flux(fcen, df, nfreq, tran_out)

    # show geometry
    # %matplotlib inline
    f = plt.figure(dpi=500, figsize=(8,16))
    sim.plot2D(ax=f.gca())
    plt.show()    

    #sim.run(until_after_sources=mp.stop_when_fields_decayed(50, mp.Hz, mp.Vector3(decay_check), 1e-3))
    sim.run(until=T_decay)

    freqs = mp.get_flux_freqs(trans_out)
    #psd_in = mp.get_fluxes(trans_in)
    psd_out = mp.get_fluxes(trans_out)

    return freqs, psd_out

# %%
freqs_wo, psd_out_wo = phc_trans(PhC = False, lengthPhC = 20, decay_check=10, T_decay=500)
freqs_w,  psd_out_w  = phc_trans(PhC = True, lengthPhC = 50, decay_check=20, T_decay=10000)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00101185 s
# Working in 2D dimensions.
# Computational cell is 30 x 17.3125 x 0 with resolution 32
#      block, center = (0,0,0)
#           size (1e+20,0.866025,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (6.76,6.76,6.76)
# time for set_epsilon = 0.796734 s
# -----------
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# FloatProgress(value=0.0, description='0% done ', max=500.0)
# Meep progress: 2.984375/500.0 = 0.6% done in 4.0s, 667.0s to go
# on time step 192 (time=3), 0.0208849 s/step
# Meep progress: 6.234375/500.0 = 1.2% done in 8.0s, 634.0s to go
# on time step 400 (time=6.25), 0.0192411 s/step
# Meep progress: 9.5625/500.0 = 1.9% done in 12.0s, 615.8s to go
# on time step 613 (time=9.57812), 0.0187801 s/step
# Meep progress: 12.859375/500.0 = 2.6% done in 16.0s, 607.0s to go
# on time step 824 (time=12.875), 0.0190224 s/step
# Meep progress: 16.0625/500.0 = 3.2% done in 20.0s, 603.9s to go
# on time step 1029 (time=16.0781), 0.0196038 s/step
# Meep progress: 19.140625/500.0 = 3.8% done in 24.1s, 604.4s to go
# on time step 1226 (time=19.1562), 0.0203392 s/step
# Meep progress: 22.4375/500.0 = 4.5% done in 28.1s, 597.3s to go
# on time step 1437 (time=22.4531), 0.0189712 s/step
# Meep progress: 25.765625/500.0 = 5.2% done in 32.1s, 590.5s to go
# on time step 1650 (time=25.7812), 0.0188524 s/step
# Meep progress: 29.078125/500.0 = 5.8% done in 36.1s, 584.5s to go
# on time step 1862 (time=29.0938), 0.0189146 s/step
# Meep progress: 32.375/500.0 = 6.5% done in 40.1s, 579.3s to go
# on time step 2073 (time=32.3906), 0.0190292 s/step
# Meep progress: 35.65625/500.0 = 7.1% done in 44.1s, 574.5s to go
# on time step 2283 (time=35.6719), 0.0190703 s/step
# Meep progress: 38.6875/500.0 = 7.7% done in 48.1s, 573.8s to go
# on time step 2477 (time=38.7031), 0.0206804 s/step
# Meep progress: 41.921875/500.0 = 8.4% done in 52.1s, 569.8s to go
# on time step 2684 (time=41.9375), 0.0195253 s/step
# Meep progress: 46.109375/500.0 = 9.2% done in 56.1s, 552.7s to go
# on time step 2955 (time=46.1719), 0.0147765 s/step
# Meep progress: 50.296875/500.0 = 10.1% done in 60.2s, 537.9s to go
# on time step 3223 (time=50.3594), 0.0149672 s/step
# Meep progress: 54.6875/500.0 = 10.9% done in 64.2s, 522.6s to go
# on time step 3502 (time=54.7188), 0.0144073 s/step
# Meep progress: 57.8125/500.0 = 11.6% done in 68.2s, 521.6s to go
# on time step 3702 (time=57.8438), 0.0201477 s/step
# Meep progress: 61.453125/500.0 = 12.3% done in 72.2s, 515.3s to go
# on time step 3938 (time=61.5312), 0.0169822 s/step
# Meep progress: 64.5/500.0 = 12.9% done in 76.2s, 514.7s to go
# on time step 4131 (time=64.5469), 0.0208097 s/step
# Meep progress: 68.53125/500.0 = 13.7% done in 80.2s, 505.1s to go
# on time step 4391 (time=68.6094), 0.015418 s/step
# Meep progress: 72.71875/500.0 = 14.5% done in 84.2s, 494.9s to go
# on time step 4660 (time=72.8125), 0.0149189 s/step
# Meep progress: 75.625/500.0 = 15.1% done in 88.2s, 495.2s to go
# on time step 4845 (time=75.7031), 0.021717 s/step
# Meep progress: 78.828125/500.0 = 15.8% done in 92.2s, 492.8s to go
# on time step 5051 (time=78.9219), 0.019496 s/step
# Meep progress: 82.953125/500.0 = 16.6% done in 96.2s, 483.8s to go
# on time step 5317 (time=83.0781), 0.0150438 s/step
# Meep progress: 87.5625/500.0 = 17.5% done in 100.2s, 472.2s to go
# on time step 5613 (time=87.7031), 0.0135564 s/step
# Meep progress: 92.28125/500.0 = 18.5% done in 104.3s, 460.6s to go
# on time step 5915 (time=92.4219), 0.0132712 s/step
# Meep progress: 96.96875/500.0 = 19.4% done in 108.3s, 450.0s to go
# on time step 6215 (time=97.1094), 0.0133427 s/step
# Meep progress: 101.671875/500.0 = 20.3% done in 112.3s, 439.8s to go
# on time step 6517 (time=101.828), 0.0132837 s/step
# Meep progress: 106.359375/500.0 = 21.3% done in 116.3s, 430.3s to go
# on time step 6817 (time=106.516), 0.0133458 s/step
# Meep progress: 111.0625/500.0 = 22.2% done in 120.3s, 421.2s to go
# on time step 7118 (time=111.219), 0.013329 s/step
# Meep progress: 115.765625/500.0 = 23.2% done in 124.3s, 412.5s to go
# on time step 7419 (time=115.922), 0.0132934 s/step
# Meep progress: 120.4375/500.0 = 24.1% done in 128.3s, 404.3s to go
# on time step 7718 (time=120.594), 0.0133915 s/step
# Meep progress: 125.171875/500.0 = 25.0% done in 132.3s, 396.2s to go
# on time step 8021 (time=125.328), 0.0132321 s/step
# Meep progress: 129.890625/500.0 = 26.0% done in 136.3s, 388.4s to go
# on time step 8323 (time=130.047), 0.0132527 s/step
# Meep progress: 134.59375/500.0 = 26.9% done in 140.3s, 381.0s to go
# on time step 8623 (time=134.734), 0.013346 s/step
# Meep progress: 139.296875/500.0 = 27.9% done in 144.3s, 373.7s to go
# on time step 8924 (time=139.438), 0.0132995 s/step
# Meep progress: 144.0/500.0 = 28.8% done in 148.3s, 366.7s to go
# on time step 9225 (time=144.141), 0.0133299 s/step
# Meep progress: 148.703125/500.0 = 29.7% done in 152.3s, 359.9s to go
# on time step 9527 (time=148.859), 0.013279 s/step
# Meep progress: 153.421875/500.0 = 30.7% done in 156.4s, 353.2s to go
# on time step 9829 (time=153.578), 0.0132726 s/step
# Meep progress: 158.125/500.0 = 31.6% done in 160.4s, 346.7s to go
# on time step 10130 (time=158.281), 0.0133069 s/step
# Meep progress: 162.828125/500.0 = 32.6% done in 164.4s, 340.3s to go
# on time step 10432 (time=163), 0.0132701 s/step
# Meep progress: 167.53125/500.0 = 33.5% done in 168.4s, 334.1s to go
# on time step 10733 (time=167.703), 0.0133326 s/step
# Meep progress: 172.203125/500.0 = 34.4% done in 172.4s, 328.1s to go
# on time step 11033 (time=172.391), 0.0133717 s/step
# Meep progress: 176.90625/500.0 = 35.4% done in 176.4s, 322.1s to go
# on time step 11334 (time=177.094), 0.0133086 s/step
# Meep progress: 181.5625/500.0 = 36.3% done in 180.4s, 316.4s to go
# on time step 11632 (time=181.75), 0.0134523 s/step
# Meep progress: 186.265625/500.0 = 37.3% done in 184.4s, 310.6s to go
# on time step 11934 (time=186.469), 0.013279 s/step
# Meep progress: 190.953125/500.0 = 38.2% done in 188.4s, 304.9s to go
# on time step 12234 (time=191.156), 0.0133355 s/step
# Meep progress: 195.671875/500.0 = 39.1% done in 192.4s, 299.2s to go
# on time step 12536 (time=195.875), 0.0132647 s/step
# Meep progress: 200.375/500.0 = 40.1% done in 196.4s, 293.7s to go
# on time step 12836 (time=200.562), 0.013337 s/step
# Meep progress: 205.109375/500.0 = 41.0% done in 200.4s, 288.1s to go
# on time step 13139 (time=205.297), 0.0132338 s/step
# Meep progress: 209.796875/500.0 = 42.0% done in 204.4s, 282.8s to go
# on time step 13440 (time=210), 0.0133213 s/step
# Meep progress: 214.515625/500.0 = 42.9% done in 208.4s, 277.4s to go
# on time step 13742 (time=214.719), 0.0132727 s/step
# Meep progress: 219.203125/500.0 = 43.8% done in 212.4s, 272.1s to go
# on time step 14042 (time=219.406), 0.0133472 s/step
# Meep progress: 223.90625/500.0 = 44.8% done in 216.4s, 266.9s to go
# on time step 14343 (time=224.109), 0.0133127 s/step
# Meep progress: 228.625/500.0 = 45.7% done in 220.4s, 261.7s to go
# on time step 14645 (time=228.828), 0.0132619 s/step
# Meep progress: 233.328125/500.0 = 46.7% done in 224.5s, 256.5s to go
# on time step 14946 (time=233.531), 0.0133253 s/step
# Meep progress: 238.046875/500.0 = 47.6% done in 228.5s, 251.4s to go
# on time step 15248 (time=238.25), 0.0132738 s/step
# Meep progress: 242.78125/500.0 = 48.6% done in 232.5s, 246.3s to go
# on time step 15551 (time=242.984), 0.0132239 s/step
# Meep progress: 247.484375/500.0 = 49.5% done in 236.5s, 241.3s to go
# on time step 15852 (time=247.688), 0.0132909 s/step
# Meep progress: 252.109375/500.0 = 50.4% done in 240.5s, 236.5s to go
# on time step 16148 (time=252.312), 0.0135208 s/step
# Meep progress: 256.8125/500.0 = 51.4% done in 244.5s, 231.5s to go
# on time step 16449 (time=257.016), 0.0132943 s/step
# Meep progress: 261.484375/500.0 = 52.3% done in 248.5s, 226.7s to go
# on time step 16748 (time=261.688), 0.0133855 s/step
# Meep progress: 266.203125/500.0 = 53.2% done in 252.5s, 221.8s to go
# on time step 17050 (time=266.406), 0.0132706 s/step
# Meep progress: 270.90625/500.0 = 54.2% done in 256.5s, 216.9s to go
# on time step 17352 (time=271.125), 0.0132708 s/step
# Meep progress: 275.609375/500.0 = 55.1% done in 260.5s, 212.1s to go
# on time step 17653 (time=275.828), 0.0132991 s/step
# Meep progress: 280.296875/500.0 = 56.1% done in 264.5s, 207.3s to go
# on time step 17953 (time=280.516), 0.0133576 s/step
# Meep progress: 284.96875/500.0 = 57.0% done in 268.5s, 202.6s to go
# on time step 18252 (time=285.188), 0.0133787 s/step
# Meep progress: 289.671875/500.0 = 57.9% done in 272.5s, 197.9s to go
# on time step 18552 (time=289.875), 0.0133348 s/step
# Meep progress: 294.359375/500.0 = 58.9% done in 276.5s, 193.2s to go
# on time step 18852 (time=294.562), 0.0133683 s/step
# Meep progress: 299.078125/500.0 = 59.8% done in 280.5s, 188.5s to go
# on time step 19154 (time=299.281), 0.0132622 s/step
# Meep progress: 303.78125/500.0 = 60.8% done in 284.5s, 183.8s to go
# on time step 19455 (time=303.984), 0.013309 s/step
# Meep progress: 308.484375/500.0 = 61.7% done in 288.6s, 179.1s to go
# on time step 19755 (time=308.672), 0.0133374 s/step
# Meep progress: 313.203125/500.0 = 62.6% done in 292.6s, 174.5s to go
# on time step 20057 (time=313.391), 0.0132641 s/step
# Meep progress: 317.859375/500.0 = 63.6% done in 296.6s, 169.9s to go
# on time step 20355 (time=318.047), 0.0134482 s/step
# Meep progress: 322.578125/500.0 = 64.5% done in 300.6s, 165.3s to go
# on time step 20657 (time=322.766), 0.0132584 s/step
# Meep progress: 327.25/500.0 = 65.5% done in 304.6s, 160.8s to go
# on time step 20956 (time=327.438), 0.0133804 s/step
# Meep progress: 331.90625/500.0 = 66.4% done in 308.6s, 156.3s to go
# on time step 21254 (time=332.094), 0.0134244 s/step
# Meep progress: 336.625/500.0 = 67.3% done in 312.6s, 151.7s to go
# on time step 21556 (time=336.812), 0.0132682 s/step
# Meep progress: 341.328125/500.0 = 68.3% done in 316.6s, 147.2s to go
# on time step 21857 (time=341.516), 0.0133199 s/step
# Meep progress: 346.03125/500.0 = 69.2% done in 320.6s, 142.7s to go
# on time step 22158 (time=346.219), 0.0133197 s/step
# Meep progress: 350.71875/500.0 = 70.1% done in 324.6s, 138.2s to go
# on time step 22459 (time=350.922), 0.0133178 s/step
# Meep progress: 355.40625/500.0 = 71.1% done in 328.6s, 133.7s to go
# on time step 22759 (time=355.609), 0.0133625 s/step
# Meep progress: 359.71875/500.0 = 71.9% done in 332.6s, 129.7s to go
# on time step 23034 (time=359.906), 0.0145519 s/step
# Meep progress: 363.96875/500.0 = 72.8% done in 336.6s, 125.8s to go
# on time step 23307 (time=364.172), 0.0146837 s/step
# Meep progress: 368.46875/500.0 = 73.7% done in 340.6s, 121.6s to go
# on time step 23595 (time=368.672), 0.0139032 s/step
# Meep progress: 373.015625/500.0 = 74.6% done in 344.6s, 117.3s to go
# on time step 23886 (time=373.219), 0.013775 s/step
# Meep progress: 377.71875/500.0 = 75.5% done in 348.7s, 112.9s to go
# on time step 24187 (time=377.922), 0.0133022 s/step
# Meep progress: 382.40625/500.0 = 76.5% done in 352.7s, 108.4s to go
# on time step 24487 (time=382.609), 0.013342 s/step
# Meep progress: 387.125/500.0 = 77.4% done in 356.7s, 104.0s to go
# on time step 24789 (time=387.328), 0.0132689 s/step
# Meep progress: 391.828125/500.0 = 78.4% done in 360.7s, 99.6s to go
# on time step 25090 (time=392.031), 0.0133038 s/step
# Meep progress: 396.3125/500.0 = 79.3% done in 364.7s, 95.4s to go
# on time step 25376 (time=396.5), 0.0140221 s/step
# Meep progress: 400.625/500.0 = 80.1% done in 368.7s, 91.5s to go
# on time step 25653 (time=400.828), 0.0144417 s/step
# Meep progress: 405.328125/500.0 = 81.1% done in 372.7s, 87.0s to go
# on time step 25954 (time=405.531), 0.0133029 s/step
# Meep progress: 410.0625/500.0 = 82.0% done in 376.7s, 82.6s to go
# on time step 26257 (time=410.266), 0.0132361 s/step
# Meep progress: 414.78125/500.0 = 83.0% done in 380.7s, 78.2s to go
# on time step 26559 (time=414.984), 0.0132492 s/step
# Meep progress: 419.484375/500.0 = 83.9% done in 384.7s, 73.8s to go
# on time step 26859 (time=419.672), 0.0133514 s/step
# Meep progress: 424.1875/500.0 = 84.8% done in 388.7s, 69.5s to go
# on time step 27160 (time=424.375), 0.0132937 s/step
# Meep progress: 428.90625/500.0 = 85.8% done in 392.7s, 65.1s to go
# on time step 27462 (time=429.094), 0.0132585 s/step
# Meep progress: 433.578125/500.0 = 86.7% done in 396.7s, 60.8s to go
# on time step 27761 (time=433.766), 0.0134079 s/step
# Meep progress: 438.265625/500.0 = 87.7% done in 400.8s, 56.5s to go
# on time step 28061 (time=438.453), 0.0133635 s/step
# Meep progress: 442.96875/500.0 = 88.6% done in 404.8s, 52.1s to go
# on time step 28363 (time=443.172), 0.0132881 s/step
# Meep progress: 447.65625/500.0 = 89.5% done in 408.8s, 47.8s to go
# on time step 28664 (time=447.875), 0.0133318 s/step
# Meep progress: 452.34375/500.0 = 90.5% done in 412.8s, 43.5s to go
# on time step 28965 (time=452.578), 0.013331 s/step
# Meep progress: 457.03125/500.0 = 91.4% done in 416.8s, 39.2s to go
# on time step 29266 (time=457.281), 0.0133288 s/step
# Meep progress: 461.71875/500.0 = 92.3% done in 420.8s, 34.9s to go
# on time step 29565 (time=461.953), 0.0133863 s/step
# Meep progress: 466.4375/500.0 = 93.3% done in 424.8s, 30.6s to go
# on time step 29867 (time=466.672), 0.0132644 s/step
# Meep progress: 471.140625/500.0 = 94.2% done in 428.8s, 26.3s to go
# on time step 30168 (time=471.375), 0.0133181 s/step
# Meep progress: 475.84375/500.0 = 95.2% done in 432.8s, 22.0s to go
# on time step 30469 (time=476.078), 0.0132977 s/step
# Meep progress: 480.546875/500.0 = 96.1% done in 436.8s, 17.7s to go
# on time step 30770 (time=480.781), 0.0133126 s/step
# Meep progress: 488.234375/500.0 = 97.6% done in 440.8s, 10.6s to go
# on time step 31273 (time=488.641), 0.0079559 s/step
# Meep progress: 496.9375/500.0 = 99.4% done in 444.8s, 2.7s to go
# on time step 31834 (time=497.406), 0.00713217 s/step
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# run 0 finished at t = 500.0 (32000 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.0997708 s
# Working in 2D dimensions.
# Computational cell is 60 x 17.3125 x 0 with resolution 32
#      block, center = (0,0,0)
#           size (1e+20,0.866025,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (6.76,6.76,6.76)
#      block, center = (0,8.22724,0)
#           size (50,17.3205,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (6.76,6.76,6.76)
#      block, center = (0,-9.09327,0)
#           size (50,17.3205,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (6.76,6.76,6.76)
#      prism, center = (-25.5,1.01036,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-25.075,1.25574,-0.5)
#           (-25.925,1.25574,-0.5)
#           (-25.5,0.519615,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      prism, center = (-25.5,-1.87639,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-25.925,-2.12176,-0.5)
#           (-25.075,-2.12176,-0.5)
#           (-25.5,-1.38564,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      prism, center = (-25,0.144338,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-24.575,0.389711,-0.5)
#           (-25.425,0.389711,-0.5)
#           (-25,-0.34641,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      prism, center = (-24.5,1.01036,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-24.075,1.25574,-0.5)
#           (-24.925,1.25574,-0.5)
#           (-24.5,0.519615,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      prism, center = (-24.5,-1.87639,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-24.925,-2.12176,-0.5)
#           (-24.075,-2.12176,-0.5)
#           (-24.5,-1.38564,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      prism, center = (-24,0.144338,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-23.575,0.389711,-0.5)
#           (-24.425,0.389711,-0.5)
#           (-24,-0.34641,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      prism, center = (-23.5,1.01036,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-23.075,1.25574,-0.5)
#           (-23.925,1.25574,-0.5)
#           (-23.5,0.519615,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      ...(+ 2083 objects not shown)...
# subpixel-averaging is 42.3328% done, 5.45079 s remaining
# subpixel-averaging is 79.4844% done, 1.03342 s remaining
# subpixel-averaging is 43.6557% done, 5.16412 s remaining
# subpixel-averaging is 81.0278% done, 0.937107 s remaining
# subpixel-averaging is 43.8762% done, 5.1318 s remaining
# subpixel-averaging is 82.2404% done, 0.867632 s remaining
# time for set_epsilon = 32.7492 s
# time for set_conductivity = 0.691758 s
# time for set_conductivity = 0.551654 s
# time for set_conductivity = 0.549119 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=10000.0)
# .69), 0.0327409 s/step
# Meep progress: 9696.796875/10000.0 = 97.0% done in 20599.7s, 644.1s to go
# on time step 620711 (time=9698.61), 0.0326571 s/step
# Meep progress: 9698.71875/10000.0 = 97.0% done in 20603.7s, 640.0s to go
# on time step 620836 (time=9700.56), 0.0321591 s/step
# Meep progress: 9700.65625/10000.0 = 97.0% done in 20607.7s, 635.9s to go
# on time step 620958 (time=9702.47), 0.0328907 s/step
# Meep progress: 9702.578125/10000.0 = 97.0% done in 20611.8s, 631.8s to go
# on time step 621081 (time=9704.39), 0.0325654 s/step
# Meep progress: 9704.5/10000.0 = 97.0% done in 20615.8s, 627.7s to go
# on time step 621205 (time=9706.33), 0.0323303 s/step
# Meep progress: 9706.4375/10000.0 = 97.1% done in 20619.8s, 623.6s to go
# on time step 621327 (time=9708.23), 0.0328682 s/step
# Meep progress: 9708.34375/10000.0 = 97.1% done in 20623.8s, 619.6s to go
# on time step 621450 (time=9710.16), 0.0326628 s/step
# Meep progress: 9710.265625/10000.0 = 97.1% done in 20627.8s, 615.5s to go
# on time step 621574 (time=9712.09), 0.0323553 s/step
# Meep progress: 9712.203125/10000.0 = 97.1% done in 20631.8s, 611.4s to go
# on time step 621696 (time=9714), 0.0327913 s/step
# Meep progress: 9714.109375/10000.0 = 97.1% done in 20635.8s, 607.3s to go
# on time step 621818 (time=9715.91), 0.0328969 s/step
# Meep progress: 9716.015625/10000.0 = 97.2% done in 20639.8s, 603.3s to go
# on time step 621942 (time=9717.84), 0.0325064 s/step
# Meep progress: 9717.9375/10000.0 = 97.2% done in 20643.8s, 599.2s to go
# on time step 622064 (time=9719.75), 0.0328603 s/step
# Meep progress: 9719.859375/10000.0 = 97.2% done in 20647.9s, 595.1s to go
# on time step 622187 (time=9721.67), 0.0325505 s/step
# Meep progress: 9721.78125/10000.0 = 97.2% done in 20651.9s, 591.0s to go
# on time step 622310 (time=9723.59), 0.0326074 s/step
# Meep progress: 9723.703125/10000.0 = 97.2% done in 20655.9s, 586.9s to go
# on time step 622433 (time=9725.52), 0.0327043 s/step
# Meep progress: 9725.640625/10000.0 = 97.3% done in 20659.9s, 582.8s to go
# on time step 622549 (time=9727.33), 0.0345736 s/step
# Meep progress: 9727.4375/10000.0 = 97.3% done in 20664.0s, 579.0s to go
# on time step 622667 (time=9729.17), 0.0340261 s/step
# Meep progress: 9729.296875/10000.0 = 97.3% done in 20668.0s, 575.1s to go
# on time step 622790 (time=9731.09), 0.032712 s/step
# Meep progress: 9731.21875/10000.0 = 97.3% done in 20672.0s, 571.0s to go
# on time step 622913 (time=9733.02), 0.0328404 s/step
# Meep progress: 9733.125/10000.0 = 97.3% done in 20676.0s, 566.9s to go
# on time step 623036 (time=9734.94), 0.0325302 s/step
# Meep progress: 9735.046875/10000.0 = 97.4% done in 20680.0s, 562.8s to go
# on time step 623158 (time=9736.84), 0.0328447 s/step
# Meep progress: 9736.96875/10000.0 = 97.4% done in 20684.0s, 558.8s to go
# on time step 623281 (time=9738.77), 0.0327076 s/step
# Meep progress: 9738.890625/10000.0 = 97.4% done in 20688.1s, 554.7s to go
# on time step 623404 (time=9740.69), 0.0325283 s/step
# Meep progress: 9740.8125/10000.0 = 97.4% done in 20692.1s, 550.6s to go
# on time step 623527 (time=9742.61), 0.0327359 s/step
# Meep progress: 9742.734375/10000.0 = 97.4% done in 20696.1s, 546.5s to go
# on time step 623650 (time=9744.53), 0.0326101 s/step
# Meep progress: 9744.65625/10000.0 = 97.4% done in 20700.1s, 542.4s to go
# on time step 623774 (time=9746.47), 0.0324171 s/step
# Meep progress: 9746.59375/10000.0 = 97.5% done in 20704.2s, 538.3s to go
# on time step 623897 (time=9748.39), 0.032572 s/step
# Meep progress: 9748.53125/10000.0 = 97.5% done in 20708.2s, 534.2s to go
# on time step 624020 (time=9750.31), 0.0326611 s/step
# Meep progress: 9750.453125/10000.0 = 97.5% done in 20712.2s, 530.1s to go
# on time step 624144 (time=9752.25), 0.0324631 s/step
# Meep progress: 9752.375/10000.0 = 97.5% done in 20716.2s, 526.0s to go
# on time step 624267 (time=9754.17), 0.0326721 s/step
# Meep progress: 9754.296875/10000.0 = 97.5% done in 20720.2s, 521.9s to go
# on time step 624390 (time=9756.09), 0.0326488 s/step
# Meep progress: 9756.21875/10000.0 = 97.6% done in 20724.2s, 517.8s to go
# on time step 624514 (time=9758.03), 0.0324803 s/step
# Meep progress: 9758.15625/10000.0 = 97.6% done in 20728.3s, 513.7s to go
# on time step 624637 (time=9759.95), 0.0326652 s/step
# Meep progress: 9760.09375/10000.0 = 97.6% done in 20732.3s, 509.6s to go
# on time step 624760 (time=9761.88), 0.0326954 s/step
# Meep progress: 9762.015625/10000.0 = 97.6% done in 20736.3s, 505.5s to go
# on time step 624884 (time=9763.81), 0.0323954 s/step
# Meep progress: 9763.9375/10000.0 = 97.6% done in 20740.3s, 501.4s to go
# on time step 625007 (time=9765.73), 0.0325796 s/step
# Meep progress: 9765.875/10000.0 = 97.7% done in 20744.4s, 497.3s to go
# on time step 625130 (time=9767.66), 0.0326237 s/step
# Meep progress: 9767.796875/10000.0 = 97.7% done in 20748.4s, 493.2s to go
# on time step 625253 (time=9769.58), 0.0325755 s/step
# Meep progress: 9769.71875/10000.0 = 97.7% done in 20752.4s, 489.2s to go
# on time step 625375 (time=9771.48), 0.0328435 s/step
# Meep progress: 9771.640625/10000.0 = 97.7% done in 20756.4s, 485.1s to go
# on time step 625497 (time=9773.39), 0.0328732 s/step
# Meep progress: 9773.546875/10000.0 = 97.7% done in 20760.4s, 481.0s to go
# on time step 625621 (time=9775.33), 0.0324311 s/step
# Meep progress: 9775.46875/10000.0 = 97.8% done in 20764.4s, 476.9s to go
# on time step 625744 (time=9777.25), 0.0327067 s/step
# Meep progress: 9777.40625/10000.0 = 97.8% done in 20768.5s, 472.8s to go
# on time step 625866 (time=9779.16), 0.0330101 s/step
# Meep progress: 9779.296875/10000.0 = 97.8% done in 20772.5s, 468.8s to go
# on time step 625985 (time=9781.02), 0.0337668 s/step
# Meep progress: 9781.140625/10000.0 = 97.8% done in 20776.5s, 464.9s to go
# on time step 626101 (time=9782.83), 0.0345521 s/step
# Meep progress: 9782.96875/10000.0 = 97.8% done in 20780.5s, 461.0s to go
# on time step 626217 (time=9784.64), 0.0345407 s/step
# Meep progress: 9784.78125/10000.0 = 97.8% done in 20784.5s, 457.2s to go
# on time step 626337 (time=9786.52), 0.0335655 s/step
# Meep progress: 9786.65625/10000.0 = 97.9% done in 20788.5s, 453.2s to go
# on time step 626459 (time=9788.42), 0.0328277 s/step
# Meep progress: 9788.5625/10000.0 = 97.9% done in 20792.6s, 449.1s to go
# on time step 626582 (time=9790.34), 0.0327575 s/step
# Meep progress: 9790.484375/10000.0 = 97.9% done in 20796.6s, 445.0s to go
# on time step 626705 (time=9792.27), 0.0326029 s/step
# Meep progress: 9792.390625/10000.0 = 97.9% done in 20800.6s, 441.0s to go
# on time step 626827 (time=9794.17), 0.0329553 s/step
# Meep progress: 9794.3125/10000.0 = 97.9% done in 20804.6s, 436.9s to go
# on time step 626949 (time=9796.08), 0.0329365 s/step
# Meep progress: 9796.203125/10000.0 = 98.0% done in 20808.6s, 432.9s to go
# on time step 627068 (time=9797.94), 0.0336453 s/step
# Meep progress: 9798.0625/10000.0 = 98.0% done in 20812.7s, 428.9s to go
# on time step 627188 (time=9799.81), 0.0335169 s/step
# Meep progress: 9799.953125/10000.0 = 98.0% done in 20816.7s, 424.9s to go
# on time step 627308 (time=9801.69), 0.0334395 s/step
# Meep progress: 9801.828125/10000.0 = 98.0% done in 20820.7s, 421.0s to go
# on time step 627428 (time=9803.56), 0.0334663 s/step
# Meep progress: 9803.6875/10000.0 = 98.0% done in 20824.7s, 417.0s to go
# on time step 627549 (time=9805.45), 0.0331664 s/step
# Meep progress: 9805.59375/10000.0 = 98.1% done in 20828.7s, 413.0s to go
# on time step 627671 (time=9807.36), 0.032905 s/step
# Meep progress: 9807.5/10000.0 = 98.1% done in 20832.7s, 408.9s to go
# on time step 627795 (time=9809.3), 0.0323154 s/step
# Meep progress: 9809.4375/10000.0 = 98.1% done in 20836.8s, 404.8s to go
# on time step 627918 (time=9811.22), 0.032697 s/step
# Meep progress: 9811.359375/10000.0 = 98.1% done in 20840.8s, 400.7s to go
# on time step 628041 (time=9813.14), 0.0325598 s/step
# Meep progress: 9813.28125/10000.0 = 98.1% done in 20844.8s, 396.6s to go
# on time step 628165 (time=9815.08), 0.0324551 s/step
# Meep progress: 9815.21875/10000.0 = 98.2% done in 20848.8s, 392.5s to go
# on time step 628287 (time=9816.98), 0.0327951 s/step
# Meep progress: 9817.140625/10000.0 = 98.2% done in 20852.8s, 388.4s to go
# on time step 628411 (time=9818.92), 0.0324726 s/step
# Meep progress: 9819.078125/10000.0 = 98.2% done in 20856.9s, 384.3s to go
# on time step 628535 (time=9820.86), 0.0324282 s/step
# Meep progress: 9821.0/10000.0 = 98.2% done in 20860.9s, 380.2s to go
# on time step 628658 (time=9822.78), 0.0326783 s/step
# Meep progress: 9822.9375/10000.0 = 98.2% done in 20864.9s, 376.1s to go
# on time step 628781 (time=9824.7), 0.0326041 s/step
# Meep progress: 9824.859375/10000.0 = 98.2% done in 20868.9s, 372.0s to go
# on time step 628905 (time=9826.64), 0.0323865 s/step
# Meep progress: 9826.78125/10000.0 = 98.3% done in 20872.9s, 367.9s to go
# on time step 629028 (time=9828.56), 0.0325713 s/step
# Meep progress: 9828.71875/10000.0 = 98.3% done in 20876.9s, 363.8s to go
# on time step 629152 (time=9830.5), 0.0325257 s/step
# Meep progress: 9830.65625/10000.0 = 98.3% done in 20881.0s, 359.7s to go
# on time step 629277 (time=9832.45), 0.0322445 s/step
# Meep progress: 9832.59375/10000.0 = 98.3% done in 20885.0s, 355.6s to go
# on time step 629399 (time=9834.36), 0.032865 s/step
# Meep progress: 9834.515625/10000.0 = 98.3% done in 20889.0s, 351.5s to go
# on time step 629521 (time=9836.27), 0.0330305 s/step
# Meep progress: 9836.40625/10000.0 = 98.4% done in 20893.0s, 347.5s to go
# on time step 629644 (time=9838.19), 0.032787 s/step
# Meep progress: 9838.328125/10000.0 = 98.4% done in 20897.0s, 343.4s to go
# on time step 629768 (time=9840.12), 0.0324276 s/step
# Meep progress: 9840.25/10000.0 = 98.4% done in 20901.1s, 339.3s to go
# on time step 629891 (time=9842.05), 0.0326711 s/step
# Meep progress: 9842.1875/10000.0 = 98.4% done in 20905.1s, 335.2s to go
# on time step 630015 (time=9843.98), 0.0323619 s/step
# Meep progress: 9844.109375/10000.0 = 98.4% done in 20909.1s, 331.1s to go
# on time step 630138 (time=9845.91), 0.0327342 s/step
# Meep progress: 9846.03125/10000.0 = 98.5% done in 20913.1s, 327.0s to go
# on time step 630258 (time=9847.78), 0.0335867 s/step
# Meep progress: 9847.90625/10000.0 = 98.5% done in 20917.1s, 323.0s to go
# on time step 630380 (time=9849.69), 0.0330572 s/step
# Meep progress: 9849.796875/10000.0 = 98.5% done in 20921.1s, 319.0s to go
# on time step 630503 (time=9851.61), 0.0327659 s/step
# Meep progress: 9851.71875/10000.0 = 98.5% done in 20925.1s, 315.0s to go
# on time step 630626 (time=9853.53), 0.0327493 s/step
# Meep progress: 9853.625/10000.0 = 98.5% done in 20929.2s, 310.9s to go
# on time step 630750 (time=9855.47), 0.0324947 s/step
# Meep progress: 9855.5625/10000.0 = 98.6% done in 20933.2s, 306.8s to go
# on time step 630865 (time=9857.27), 0.0348533 s/step
# Meep progress: 9857.359375/10000.0 = 98.6% done in 20937.2s, 303.0s to go
# on time step 630988 (time=9859.19), 0.0327727 s/step
# Meep progress: 9859.265625/10000.0 = 98.6% done in 20941.2s, 298.9s to go
# on time step 631111 (time=9861.11), 0.0327196 s/step
# Meep progress: 9861.203125/10000.0 = 98.6% done in 20945.2s, 294.8s to go
# on time step 631234 (time=9863.03), 0.0326412 s/step
# Meep progress: 9863.125/10000.0 = 98.6% done in 20949.3s, 290.7s to go
# on time step 631355 (time=9864.92), 0.0332375 s/step
# Meep progress: 9865.015625/10000.0 = 98.7% done in 20953.3s, 286.7s to go
# on time step 631477 (time=9866.83), 0.0329672 s/step
# Meep progress: 9866.921875/10000.0 = 98.7% done in 20957.3s, 282.7s to go
# on time step 631601 (time=9868.77), 0.0324549 s/step
# Meep progress: 9868.84375/10000.0 = 98.7% done in 20961.3s, 278.6s to go
# on time step 631725 (time=9870.7), 0.0324506 s/step
# Meep progress: 9870.78125/10000.0 = 98.7% done in 20965.3s, 274.5s to go
# on time step 631848 (time=9872.62), 0.0325575 s/step
# Meep progress: 9872.71875/10000.0 = 98.7% done in 20969.4s, 270.3s to go
# on time step 631972 (time=9874.56), 0.03245 s/step
# Meep progress: 9874.65625/10000.0 = 98.7% done in 20973.4s, 266.2s to go
# on time step 632096 (time=9876.5), 0.0322938 s/step
# Meep progress: 9876.578125/10000.0 = 98.8% done in 20977.4s, 262.1s to go
# on time step 632219 (time=9878.42), 0.0325327 s/step
# Meep progress: 9878.515625/10000.0 = 98.8% done in 20981.4s, 258.0s to go
# on time step 632340 (time=9880.31), 0.0331774 s/step
# Meep progress: 9880.40625/10000.0 = 98.8% done in 20985.4s, 254.0s to go
# on time step 632464 (time=9882.25), 0.0323319 s/step
# Meep progress: 9882.34375/10000.0 = 98.8% done in 20989.4s, 249.9s to go
# on time step 632587 (time=9884.17), 0.0325891 s/step
# Meep progress: 9884.28125/10000.0 = 98.8% done in 20993.5s, 245.8s to go
# on time step 632710 (time=9886.09), 0.0325934 s/step
# Meep progress: 9886.203125/10000.0 = 98.9% done in 20997.5s, 241.7s to go
# on time step 632831 (time=9887.98), 0.0332088 s/step
# Meep progress: 9888.09375/10000.0 = 98.9% done in 21001.5s, 237.7s to go
# on time step 632955 (time=9889.92), 0.0324774 s/step
# Meep progress: 9890.03125/10000.0 = 98.9% done in 21005.5s, 233.6s to go
# on time step 633079 (time=9891.86), 0.0324637 s/step
# Meep progress: 9891.953125/10000.0 = 98.9% done in 21009.5s, 229.5s to go
# on time step 633202 (time=9893.78), 0.0326224 s/step
# Meep progress: 9893.875/10000.0 = 98.9% done in 21013.5s, 225.4s to go
# on time step 633325 (time=9895.7), 0.0326372 s/step
# Meep progress: 9895.796875/10000.0 = 99.0% done in 21017.6s, 221.3s to go
# on time step 633448 (time=9897.62), 0.0325713 s/step
# Meep progress: 9897.734375/10000.0 = 99.0% done in 21021.6s, 217.2s to go
# on time step 633570 (time=9899.53), 0.0329459 s/step
# Meep progress: 9899.640625/10000.0 = 99.0% done in 21025.6s, 213.2s to go
# on time step 633694 (time=9901.47), 0.0324005 s/step
# Meep progress: 9901.5625/10000.0 = 99.0% done in 21029.6s, 209.1s to go
# on time step 633816 (time=9903.38), 0.0328092 s/step
# Meep progress: 9903.484375/10000.0 = 99.0% done in 21033.6s, 205.0s to go
# on time step 633935 (time=9905.23), 0.0337987 s/step
# Meep progress: 9905.34375/10000.0 = 99.1% done in 21037.6s, 201.0s to go
# on time step 634057 (time=9907.14), 0.0328649 s/step
# Meep progress: 9907.25/10000.0 = 99.1% done in 21041.7s, 197.0s to go
# on time step 634182 (time=9909.09), 0.0322144 s/step
# Meep progress: 9909.1875/10000.0 = 99.1% done in 21045.7s, 192.9s to go
# on time step 634306 (time=9911.03), 0.0324496 s/step
# Meep progress: 9911.125/10000.0 = 99.1% done in 21049.7s, 188.8s to go
# on time step 634429 (time=9912.95), 0.0325595 s/step
# Meep progress: 9913.0625/10000.0 = 99.1% done in 21053.7s, 184.6s to go
# on time step 634553 (time=9914.89), 0.0325003 s/step
# Meep progress: 9914.96875/10000.0 = 99.1% done in 21057.7s, 180.6s to go
# on time step 634676 (time=9916.81), 0.0325431 s/step
# Meep progress: 9916.90625/10000.0 = 99.2% done in 21061.7s, 176.5s to go
# on time step 634799 (time=9918.73), 0.0326821 s/step
# Meep progress: 9918.828125/10000.0 = 99.2% done in 21065.8s, 172.4s to go
# on time step 634922 (time=9920.66), 0.0326148 s/step
# Meep progress: 9920.75/10000.0 = 99.2% done in 21069.8s, 168.3s to go
# on time step 635046 (time=9922.59), 0.0325858 s/step
# Meep progress: 9922.6875/10000.0 = 99.2% done in 21073.8s, 164.2s to go
# on time step 635168 (time=9924.5), 0.032807 s/step
# Meep progress: 9924.609375/10000.0 = 99.2% done in 21077.8s, 160.1s to go
# on time step 635292 (time=9926.44), 0.03235 s/step
# Meep progress: 9926.53125/10000.0 = 99.3% done in 21081.8s, 156.0s to go
# on time step 635416 (time=9928.38), 0.0324334 s/step
# Meep progress: 9928.46875/10000.0 = 99.3% done in 21085.8s, 151.9s to go
# on time step 635540 (time=9930.31), 0.0324662 s/step
# Meep progress: 9930.40625/10000.0 = 99.3% done in 21089.9s, 147.8s to go
# on time step 635664 (time=9932.25), 0.0324225 s/step
# Meep progress: 9932.328125/10000.0 = 99.3% done in 21093.9s, 143.7s to go
# on time step 635787 (time=9934.17), 0.032727 s/step
# Meep progress: 9934.265625/10000.0 = 99.3% done in 21097.9s, 139.6s to go
# on time step 635910 (time=9936.09), 0.0326021 s/step
# Meep progress: 9936.1875/10000.0 = 99.4% done in 21101.9s, 135.5s to go
# on time step 636033 (time=9938.02), 0.0326434 s/step
# Meep progress: 9938.109375/10000.0 = 99.4% done in 21105.9s, 131.4s to go
# on time step 636156 (time=9939.94), 0.0327602 s/step
# Meep progress: 9940.03125/10000.0 = 99.4% done in 21110.0s, 127.4s to go
# on time step 636279 (time=9941.86), 0.0326261 s/step
# Meep progress: 9941.953125/10000.0 = 99.4% done in 21114.0s, 123.3s to go
# on time step 636402 (time=9943.78), 0.0326287 s/step
# Meep progress: 9943.875/10000.0 = 99.4% done in 21118.0s, 119.2s to go
# on time step 636525 (time=9945.7), 0.0327423 s/step
# Meep progress: 9945.796875/10000.0 = 99.5% done in 21122.0s, 115.1s to go
# on time step 636649 (time=9947.64), 0.032491 s/step
# Meep progress: 9947.71875/10000.0 = 99.5% done in 21126.0s, 111.0s to go
# on time step 636773 (time=9949.58), 0.0324267 s/step
# Meep progress: 9949.65625/10000.0 = 99.5% done in 21130.1s, 106.9s to go
# on time step 636895 (time=9951.48), 0.0328443 s/step
# Meep progress: 9951.578125/10000.0 = 99.5% done in 21134.1s, 102.8s to go
# on time step 637018 (time=9953.41), 0.0327702 s/step
# Meep progress: 9953.484375/10000.0 = 99.5% done in 21138.1s, 98.8s to go
# on time step 637140 (time=9955.31), 0.0328135 s/step
# Meep progress: 9955.390625/10000.0 = 99.6% done in 21142.1s, 94.7s to go
# on time step 637263 (time=9957.23), 0.0326253 s/step
# Meep progress: 9957.3125/10000.0 = 99.6% done in 21146.1s, 90.7s to go
# on time step 637386 (time=9959.16), 0.0325822 s/step
# Meep progress: 9959.234375/10000.0 = 99.6% done in 21150.1s, 86.6s to go
# on time step 637509 (time=9961.08), 0.0325521 s/step
# Meep progress: 9961.15625/10000.0 = 99.6% done in 21154.1s, 82.5s to go
# on time step 637632 (time=9963), 0.0326759 s/step
# Meep progress: 9963.078125/10000.0 = 99.6% done in 21158.1s, 78.4s to go
# on time step 637756 (time=9964.94), 0.0324663 s/step
# Meep progress: 9965.0/10000.0 = 99.7% done in 21162.2s, 74.3s to go
# on time step 637878 (time=9966.84), 0.0327897 s/step
# Meep progress: 9966.921875/10000.0 = 99.7% done in 21166.2s, 70.2s to go
# on time step 638000 (time=9968.75), 0.032854 s/step
# Meep progress: 9968.84375/10000.0 = 99.7% done in 21170.2s, 66.2s to go
# on time step 638124 (time=9970.69), 0.0325017 s/step
# Meep progress: 9970.75/10000.0 = 99.7% done in 21174.2s, 62.1s to go
# on time step 638246 (time=9972.59), 0.0328464 s/step
# Meep progress: 9972.671875/10000.0 = 99.7% done in 21178.2s, 58.0s to go
# on time step 638369 (time=9974.52), 0.0327418 s/step
# Meep progress: 9974.59375/10000.0 = 99.7% done in 21182.2s, 54.0s to go
# on time step 638493 (time=9976.45), 0.0324988 s/step
# Meep progress: 9976.515625/10000.0 = 99.8% done in 21186.2s, 49.9s to go
# on time step 638617 (time=9978.39), 0.0324091 s/step
# Meep progress: 9978.453125/10000.0 = 99.8% done in 21190.3s, 45.8s to go
# on time step 638740 (time=9980.31), 0.0325605 s/step
# Meep progress: 9980.390625/10000.0 = 99.8% done in 21194.3s, 41.6s to go
# on time step 638863 (time=9982.23), 0.0325579 s/step
# Meep progress: 9982.328125/10000.0 = 99.8% done in 21198.3s, 37.5s to go
# on time step 638986 (time=9984.16), 0.0325886 s/step
# Meep progress: 9984.25/10000.0 = 99.8% done in 21202.4s, 33.4s to go
# on time step 639109 (time=9986.08), 0.0326292 s/step
# Meep progress: 9986.1875/10000.0 = 99.9% done in 21206.4s, 29.3s to go
# on time step 639233 (time=9988.02), 0.0324886 s/step
# Meep progress: 9988.109375/10000.0 = 99.9% done in 21210.4s, 25.3s to go
# on time step 639357 (time=9989.95), 0.0324066 s/step
# Meep progress: 9990.046875/10000.0 = 99.9% done in 21214.4s, 21.1s to go
# on time step 639479 (time=9991.86), 0.0328793 s/step
# Meep progress: 9991.96875/10000.0 = 99.9% done in 21218.5s, 17.1s to go
# on time step 639602 (time=9993.78), 0.0326402 s/step
# Meep progress: 9993.890625/10000.0 = 99.9% done in 21222.5s, 13.0s to go
# on time step 639725 (time=9995.7), 0.0325984 s/step
# Meep progress: 9995.796875/10000.0 = 100.0% done in 21226.5s, 8.9s to go
# on time step 639847 (time=9997.61), 0.0328066 s/step
# Meep progress: 9997.71875/10000.0 = 100.0% done in 21230.5s, 4.8s to go
# on time step 639971 (time=9999.55), 0.032483 s/step
# Meep progress: 9999.65625/10000.0 = 100.0% done in 21234.5s, 0.7s to go
# run 0 finished at t = 10000.0 (640000 timesteps)

# %%
plt.plot(freqs_wo,psd_out_wo)
plt.grid(True)

# %%
plt.plot(freqs_w,psd_out_w)
plt.grid(True)

# %%
plt.plot(np.array(freqs_w), np.array(psd_out_w)/np.array(psd_out_wo))
plt.xlabel("Frequency[c/a]")
plt.ylabel("Transmittance")
plt.yscale('log')
plt.grid(True)
plt.savefig("usaq34b_km05.png")

# %%
ls
# Out:
# 201029_waveguide_VPhCtriangle_zigzag.ipynb_transmittance.csv*
# 210111_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d085_km005_T1e5.csv*
# 210111_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d085_km0_resolution32.csv*
# 210111_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d085_kpm005.csv*
# 210111_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d085_kpm005_T1e5.csv*
# 210122_resolution15_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d085_km02.ipynb*
# 210122_resolution16_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d085_km05.ipynb*
# 210122_resolution16_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d085_km05_cor.ipynb*
# 210122_resolution32_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d085_km02.ipynb*
# 210122_resolution32_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d085_km05_cor.ipynb*
# 210122_resolution32_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d085_uasq34b_km025both.ipynb*
# 210122_resolution32_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d085_uasq34b_km05.ipynb*
# 210122_resolution32_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d090_uasq34b_km025both.ipynb*
# 210122_resolution32_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d090_uasq34b_km05.ipynb*
# Code.VisualElementsManifest.xml*
# Code.exe*
# bin/
# chrome_100_percent.pak*
# chrome_200_percent.pak*
# d3dcompiler_47.dll*
# ffmpeg.dll*
# icudtl.dat*
# libEGL.dll*
# libGLESv2.dll*
# locales/
# resources/
# resources.pak*
# snapshot_blob.bin*
# swiftshader/
# tools/
# unins000.dat*
# unins000.exe*
# unins000.msg*
# usaq34b_km05.png*
# v8_context_snapshot.bin*
# vk_swiftshader.dll*
# vk_swiftshader_icd.json*
# vulkan-1.dll*

# %%
cd c/users/uemura_tokyotech/desktop
# Out:
# /mnt/c/users/uemura_tokyotech/desktop

# %%
# %cd
# Out:
# /home/unix

# %%
plt.plot(np.array(freqs_w), np.array(psd_out_w)/np.array(psd_out_wo))
plt.xlabel("Frequency[c/a]")
plt.ylabel("Transmittance[c/a]")
plt.yscale('log')
plt.grid(True)

# %%
a = 470
c_const = 299792458

freqs = a / np.array(freqs_w)
#freqs
plt.plot(freqs, np.array(psd_out_w)/np.array(psd_out_wo))
plt.scatter(freqs, np.array(psd_out_w)/np.array(psd_out_wo))
plt.xlabel("Frequency[c/a]")
plt.ylabel("Transmittance[c/a]")
#plt.xlim([0.28,0.30])
plt.yscale('log')
plt.grid(True)

# %%
freqs = a / np.array(freqs_w)
#freqs
plt.plot(freqs, np.array(psd_out_w)/np.array(psd_out_wo))
plt.scatter(freqs, np.array(psd_out_w)/np.array(psd_out_wo))
plt.xlabel("Frequency")
plt.ylabel("Transmittance[c/a]")
plt.xlim([1350,1550])
plt.yscale('log')
plt.ylim([1e-6,1e-3])
plt.grid(True)
plt.savefig("usaq34b_km05_detail.png")

# %%
freqs = a / np.array(freqs_w)
#freqs
plt.plot(freqs, np.array(psd_out_w)/np.array(psd_out_wo))
plt.scatter(freqs, np.array(psd_out_w)/np.array(psd_out_wo))
plt.xlabel("Frequency[c/a]")
plt.ylabel("Transmittance[c/a]")
plt.xlim([1400,1550])
plt.yscale('log')
plt.ylim([1e-7,1e-2])
plt.grid(True)

# %%
df = pd.DataFrame()
df["wavelength"] = freqs
df["transmittance"] = np.array(psd_out_w)/np.array(psd_out_wo)
df.to_csv("210122_resolution32_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d085_uasq34b_km05.ipynb")

# %%
df
# Out:
#        wavelength  transmittance
# 0     2350.000000       0.075326
# 1     2349.530000       0.075350
# 2     2349.060188       0.075379
# 3     2348.590564       0.075425
# 4     2348.121127       0.075477
# ...           ...            ...
# 4995  1175.470282       0.093933
# 4996  1175.352676       0.094882
# 4997  1175.235094       0.095807
# 4998  1175.117535       0.096707
# 4999  1175.000000       0.097589
#
# [5000 rows x 2 columns]

# %%
ls
# Out:
# 201029_waveguide_VPhCtriangle_zigzag.ipynb_transmittance.csv*
# 210111_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d085_km005_T1e5.csv*
# 210111_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d085_km0_resolution32.csv*
# 210111_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d085_kpm005.csv*
# 210111_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d085_kpm005_T1e5.csv*
# 210122_resolution15_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d085_km02.ipynb*
# 210122_resolution16_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d085_km05.ipynb*
# 210122_resolution16_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d085_km05_cor.ipynb*
# 210122_resolution32_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d085_km02.ipynb*
# 210122_resolution32_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d085_km05_cor.ipynb*
# 210122_resolution32_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d085_uasq34b_km025both.ipynb*
# 210122_resolution32_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d085_uasq34b_km05.ipynb*
# 210122_resolution32_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d090_uasq34b_km025both.ipynb*
# 210122_resolution32_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d090_uasq34b_km05.ipynb*
# Code.VisualElementsManifest.xml*
# Code.exe*
# bin/
# chrome_100_percent.pak*
# chrome_200_percent.pak*
# d3dcompiler_47.dll*
# ffmpeg.dll*
# icudtl.dat*
# km025both.png*
# km025both_detail.png*
# libEGL.dll*
# libGLESv2.dll*
# locales/
# resources/
# resources.pak*
# snapshot_blob.bin*
# swiftshader/
# tools/
# unins000.dat*
# unins000.exe*
# unins000.msg*
# usaq34b_km05.png*
# v8_context_snapshot.bin*
# vk_swiftshader.dll*
# vk_swiftshader_icd.json*
# vulkan-1.dll*

# %%
cd ..
# Out:
# /mnt/c/Users/uemura_tokyotech/AppData/Local/Programs
