# %% [markdown]
# https://github.com/NanoComp/meep/blob/master/python/examples/straight-waveguide.ipynb
#
# https://stackoverflow.com/questions/29454002/filenotfounderror-errno-2-no-such-file-or-directory-ffmpeg

# %%
import math
import meep as mp
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# Using MPI version 3.1, 1 processes

# %%
def phc_trans(PhC = True, lengthPhC = 100, decay_check=0, T_decay=500):
    """
    <変数の説明>
    PhC...PhC(フォトニック決勝)を配置するかどうか。Falseで直線導波路
    lengthPhC...PhC導波方向の長さ
    widthPhC...PhC垂直方向の幅。PMLと被ってるので適当。
    ConnectionWaveguide...PhCに接続するSi導波路(棒の部分)の長さ
    wgi...導波路の幅を調整する。1で丸穴一個分空いてることを意味する。0.7とかにすると狭くなってバンドの形が変わる、っていうのはDaii君の研究とも絡む。
    r...穴の半径。ふつうはa/4くらい。meepだと格子定数は1で固定だから、格子定数との比を入力すればOK
    n_eff...屈折率。2次元だと2.5~2.7くらいにしておくと3次元のSi系(n_Si=3.48)と結果が近くなる。違う材料を使うときは要調整、通常はdefaultで大丈夫。
    fcen...入力光（ガウシアンビーム）の中心周波数。知りたいPhCバンドの周波数近くに設定する
    df...入力光（ガウシアンビーム）の半値幅（で合ってる？）
    nfreq...入力光（ガウシアンビーム）のきめ細かさ
    resolution...メッシュの細かさ。2^nにすると計算が軽くなるらしい。
    T_dacay...反復計算数。小さいと誤差が増え、大きいと時間がかかる。sim.run(until_after_sources=...)で計算時間を見積もってから変えるとよさそう
    decay_check...解の収束をどこで判定するか、位置を指定。defaultでOK

    <備考>
    ・meepでは格子定数aはパラメータに含まれないので設定不要
    　誘電体を使うときは入力するらしい（スケール依存性が出るから）
    ・THzやnmは使用せず、すべて規格化周波数で入力する (周波数はωa/2πcで直す)
    """
    ##### setting of parameters #####
    a = 1 # CADに移行しやすいように予め設定しておく
    widthPhC = 10
    ConnectionWaveguide = 5
    wgi = 1/2 #/np.sqrt(3)/2
    whetero = 1/np.sqrt(3)/4
    r = 1/4
    d_0 = 0.85*a
    yshift = -np.sqrt(3)/4*a #1/(np.sqrt(3)) #+ 1/6*np.sqrt(3)/2*d_0
    n_eff = 2.6
    fcen = 0.3 
    df = 0.2
    nfreq = 500 # number of frequencies at which to compute flux
    resolution = 16

    connect = 0
    #####
    length = lengthPhC + 2*ConnectionWaveguide
    width = widthPhC
    Nx = int(lengthPhC)
    Ny = int(widthPhC)
    eps = n_eff**2

    # settings of imaginary part
    normalized_frequency = 0.3
    extinction_coefficient = 0.05

    ##### settings of geometry #####
    # initialization
    cell = mp.Vector3(length,width*np.sqrt(3),0)

    # Si waveguide
    waveguide = mp.Block(mp.Vector3(mp.inf,wgi*np.sqrt(3),mp.inf),
                            center=mp.Vector3(),
                            material=mp.Medium(epsilon=eps))
    geometry = [waveguide]

    # PhC
    if PhC:
        # triangle
        tri_u = [
                mp.Vector3(-np.sqrt(3)/2,-1/2)*d_0/np.sqrt(3),
                mp.Vector3( np.sqrt(3)/2,-1/2)*d_0/np.sqrt(3),
                mp.Vector3(            0,   1)*d_0/np.sqrt(3),
                ]
        tri_d = [
                mp.Vector3(-np.sqrt(3)/2,-1/2)*d_0/np.sqrt(3)*(-1),
                mp.Vector3( np.sqrt(3)/2,-1/2)*d_0/np.sqrt(3)*(-1),
                mp.Vector3(            0,   1)*d_0/np.sqrt(3)*(-1),
                ]

        # slab
        blk_above = mp.Block(mp.Vector3(lengthPhC,widthPhC*np.sqrt(3),mp.inf),
                                center=mp.Vector3(0, widthPhC*np.sqrt(3)/2 + 0*(yshift + 1/(2*np.sqrt(3))), 0),
                                material=mp.Medium(epsilon=eps, D_conductivity=2*np.pi*normalized_frequency*extinction_coefficient / eps))
        geometry.append(blk_above)
        blk_below = mp.Block(mp.Vector3(lengthPhC,widthPhC*np.sqrt(3),mp.inf),
                                center=mp.Vector3(0,-widthPhC*np.sqrt(3)/2 + 0*(yshift + 1/(2*np.sqrt(3))), 0),
                                material=mp.Medium(epsilon=eps, D_conductivity=2*np.pi*normalized_frequency*extinction_coefficient / eps))
        geometry.append(blk_below)
        
        # arrange air-holes
        for j in range(Ny):
            for i in range(Nx+1):
                shift_y = np.sqrt(3)
                geometry.append(mp.Prism(tri_d, height = 1, center=mp.Vector3(i-(Nx+1)/2, yshift + 1/(np.sqrt(3)) + shift_y*(j+1/2))))                
                geometry.append(mp.Prism(tri_u, height = 1, center=mp.Vector3(i-(Nx+1)/2, yshift -(1/(np.sqrt(3)) + shift_y*(j+1/2)))))            
                geometry.append(mp.Prism(tri_d, height = 1, center=mp.Vector3(i-Nx/2, yshift +  1/(np.sqrt(3)) + shift_y*j )))

            if j == 0:
                for i in range(connect,Nx+1-connect):
                    geometry.append(mp.Prism(tri_u, height = 1, center=mp.Vector3(i-Nx/2, yshift - (1/(np.sqrt(3)) + shift_y*j))))
            else:
                for i in range(Nx+1):
                    geometry.append(mp.Prism(tri_u, height = 1, center=mp.Vector3(i-Nx/2, yshift - (1/(np.sqrt(3)) + shift_y*j))))
                    
        for i in range(1,Nx+1):
            geometry.append(mp.Prism(tri_u, height = 1, center=mp.Vector3(i-(Nx+1)/2, yshift - (1/(np.sqrt(3)) + shift_y*(-1/2)))))
        #geometry.append(mp.Prism(tri_d, height = 1, center=mp.Vector3(1, 0)))


                #geometry.append(mp.Cylinder(r, center=mp.Vector3(i-N/2,-wgi*np.sqrt(3)/2)))

    # Gaussian
    sources = [mp.Source(mp.GaussianSource(fcen, fwidth=df),
                            component=mp.Hz,
                            center=mp.Vector3(-length/2 +1,0),
                            size=mp.Vector3(0,wgi*np.sqrt(3)))
                ]

    # PML
    pml_layers = [mp.PML(1.0)]

    # z-symmetry (上下対称なら計算が軽くなる。対称性が無いなら消す)
    #sym = [mp.Mirror(mp.Y, phase=-1)]
    

    ####
    sim = mp.Simulation(cell_size=cell,
                        boundary_layers=pml_layers,
                        geometry=geometry,
                        sources=sources,
                        #symmetries=sym,
                        resolution=resolution)

    #tran_in = mp.FluxRegion(center=mp.Vector3(-lengthPhC/2-1,0),size=mp.Vector3(0, 2*wgi))
    tran_out = mp.FluxRegion(center=mp.Vector3(length/2-3/2,0),size=mp.Vector3(0, 2*wgi))
    #trans_in = sim.add_flux(fcen, df, nfreq, tran_in)
    trans_out = sim.add_flux(fcen, df, nfreq, tran_out)

    # show geometry
    # %matplotlib inline
    f = plt.figure(dpi=500, figsize=(8,16))
    sim.plot2D(ax=f.gca())
    plt.show()    

    #sim.run(until_after_sources=mp.stop_when_fields_decayed(50, mp.Hz, mp.Vector3(decay_check), 1e-3))
    sim.run(until=T_decay)

    freqs = mp.get_flux_freqs(trans_out)
    #psd_in = mp.get_fluxes(trans_in)
    psd_out = mp.get_fluxes(trans_out)

    return freqs, psd_out

# %%
freqs_wo, psd_out_wo = phc_trans(PhC = False, lengthPhC = 20, decay_check=10, T_decay=500)
freqs_w,  psd_out_w  = phc_trans(PhC = True, lengthPhC = 50, decay_check=20, T_decay=10000)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000816107 s
# Working in 2D dimensions.
# Computational cell is 30 x 17.3125 x 0 with resolution 16
#      block, center = (0,0,0)
#           size (1e+20,0.866025,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (6.76,6.76,6.76)
# time for set_epsilon = 0.253895 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=500.0)
# Meep progress: 94.84375/500.0 = 19.0% done in 4.0s, 17.1s to go
# on time step 3041 (time=95.0312), 0.0013155 s/step
# Meep progress: 201.21875/500.0 = 40.2% done in 8.0s, 11.9s to go
# on time step 6445 (time=201.406), 0.00117519 s/step
# Meep progress: 286.25/500.0 = 57.2% done in 12.0s, 9.0s to go
# on time step 9163 (time=286.344), 0.00147183 s/step
# Meep progress: 360.21875/500.0 = 72.0% done in 16.0s, 6.2s to go
# on time step 11529 (time=360.281), 0.00169188 s/step
# Meep progress: 449.59375/500.0 = 89.9% done in 20.0s, 2.2s to go
# on time step 14395 (time=449.844), 0.00139569 s/step
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# run 0 finished at t = 500.0 (16000 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.087661 s
# Working in 2D dimensions.
# Computational cell is 60 x 17.3125 x 0 with resolution 16
#      block, center = (0,0,0)
#           size (1e+20,0.866025,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (6.76,6.76,6.76)
#      block, center = (0,8.66025,0)
#           size (50,17.3205,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (6.76,6.76,6.76)
#      block, center = (0,-8.66025,0)
#           size (50,17.3205,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (6.76,6.76,6.76)
#      prism, center = (-25.5,1.01036,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-25.075,1.25574,-0.5)
#           (-25.925,1.25574,-0.5)
#           (-25.5,0.519615,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      prism, center = (-25.5,-1.87639,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-25.925,-2.12176,-0.5)
#           (-25.075,-2.12176,-0.5)
#           (-25.5,-1.38564,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      prism, center = (-25,0.144338,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-24.575,0.389711,-0.5)
#           (-25.425,0.389711,-0.5)
#           (-25,-0.34641,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      prism, center = (-24.5,1.01036,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-24.075,1.25574,-0.5)
#           (-24.925,1.25574,-0.5)
#           (-24.5,0.519615,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      prism, center = (-24.5,-1.87639,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-24.925,-2.12176,-0.5)
#           (-24.075,-2.12176,-0.5)
#           (-24.5,-1.38564,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      prism, center = (-24,0.144338,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-23.575,0.389711,-0.5)
#           (-24.425,0.389711,-0.5)
#           (-24,-0.34641,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      prism, center = (-23.5,1.01036,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-23.075,1.25574,-0.5)
#           (-23.925,1.25574,-0.5)
#           (-23.5,0.519615,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      ...(+ 2083 objects not shown)...
# subpixel-averaging is 81.7899% done, 0.89064 s remaining
# subpixel-averaging is 89.7479% done, 0.456945 s remaining
# time for set_epsilon = 14.7183 s
# time for set_conductivity = 0.176137 s
# time for set_conductivity = 0.178713 s
# time for set_conductivity = 0.171787 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=10000.0)
# 4.44), 0.00688579 s/step
# Meep progress: 7049.5625/10000.0 = 70.5% done in 1140.9s, 477.5s to go
# on time step 225627 (time=7050.84), 0.00762735 s/step
# Meep progress: 7068.125/10000.0 = 70.7% done in 1144.9s, 474.9s to go
# on time step 226222 (time=7069.44), 0.00672972 s/step
# Meep progress: 7084.625/10000.0 = 70.8% done in 1148.9s, 472.8s to go
# on time step 226729 (time=7085.28), 0.00789899 s/step
# Meep progress: 7093.9375/10000.0 = 70.9% done in 1152.9s, 472.3s to go
# on time step 227048 (time=7095.25), 0.0125419 s/step
# Meep progress: 7113.125/10000.0 = 71.1% done in 1156.9s, 469.5s to go
# on time step 227657 (time=7114.28), 0.0065749 s/step
# Meep progress: 7131.6875/10000.0 = 71.3% done in 1160.9s, 466.9s to go
# on time step 228257 (time=7133.03), 0.00667543 s/step
# Meep progress: 7150.5625/10000.0 = 71.5% done in 1164.9s, 464.2s to go
# on time step 228861 (time=7151.91), 0.00662653 s/step
# Meep progress: 7168.40625/10000.0 = 71.7% done in 1168.9s, 461.7s to go
# on time step 229433 (time=7169.78), 0.0069937 s/step
# Meep progress: 7187.8125/10000.0 = 71.9% done in 1172.9s, 458.9s to go
# on time step 230053 (time=7189.16), 0.00646176 s/step
# Meep progress: 7206.96875/10000.0 = 72.1% done in 1176.9s, 456.1s to go
# on time step 230664 (time=7208.25), 0.00655086 s/step
# Meep progress: 7225.5625/10000.0 = 72.3% done in 1180.9s, 453.4s to go
# on time step 231262 (time=7226.94), 0.00669654 s/step
# Meep progress: 7244.4375/10000.0 = 72.4% done in 1184.9s, 450.7s to go
# on time step 231866 (time=7245.81), 0.00662853 s/step
# Meep progress: 7262.03125/10000.0 = 72.6% done in 1188.9s, 448.2s to go
# on time step 232422 (time=7263.19), 0.00719912 s/step
# Meep progress: 7280.03125/10000.0 = 72.8% done in 1192.9s, 445.7s to go
# on time step 233002 (time=7281.31), 0.00691861 s/step
# Meep progress: 7297.34375/10000.0 = 73.0% done in 1196.9s, 443.3s to go
# on time step 233556 (time=7298.62), 0.00723278 s/step
# Meep progress: 7314.0/10000.0 = 73.1% done in 1200.9s, 441.0s to go
# on time step 234091 (time=7315.34), 0.00748279 s/step
# Meep progress: 7333.25/10000.0 = 73.3% done in 1204.9s, 438.2s to go
# on time step 234704 (time=7334.5), 0.00653102 s/step
# Meep progress: 7348.90625/10000.0 = 73.5% done in 1208.9s, 436.1s to go
# on time step 235203 (time=7350.09), 0.00802879 s/step
# Meep progress: 7365.28125/10000.0 = 73.7% done in 1212.9s, 433.9s to go
# on time step 235736 (time=7366.75), 0.00750596 s/step
# Meep progress: 7384.4375/10000.0 = 73.8% done in 1216.9s, 431.0s to go
# on time step 236351 (time=7385.97), 0.00651326 s/step
# Meep progress: 7403.65625/10000.0 = 74.0% done in 1220.9s, 428.2s to go
# on time step 236966 (time=7405.19), 0.00651056 s/step
# Meep progress: 7422.40625/10000.0 = 74.2% done in 1224.9s, 425.4s to go
# on time step 237565 (time=7423.91), 0.00669018 s/step
# Meep progress: 7439.65625/10000.0 = 74.4% done in 1228.9s, 422.9s to go
# on time step 238121 (time=7441.28), 0.00720221 s/step
# Meep progress: 7459.40625/10000.0 = 74.6% done in 1232.9s, 419.9s to go
# on time step 238754 (time=7461.06), 0.00632627 s/step
# Meep progress: 7479.0/10000.0 = 74.8% done in 1236.9s, 416.9s to go
# on time step 239380 (time=7480.62), 0.00639513 s/step
# Meep progress: 7498.5625/10000.0 = 75.0% done in 1240.9s, 414.0s to go
# on time step 240006 (time=7500.19), 0.00639677 s/step
# Meep progress: 7517.4375/10000.0 = 75.2% done in 1244.9s, 411.1s to go
# on time step 240610 (time=7519.06), 0.00663238 s/step
# Meep progress: 7536.75/10000.0 = 75.4% done in 1248.9s, 408.2s to go
# on time step 241227 (time=7538.34), 0.00649001 s/step
# Meep progress: 7555.84375/10000.0 = 75.6% done in 1253.0s, 405.3s to go
# on time step 241836 (time=7557.38), 0.00657392 s/step
# Meep progress: 7575.34375/10000.0 = 75.8% done in 1257.0s, 402.3s to go
# on time step 242464 (time=7577), 0.00637508 s/step
# Meep progress: 7594.84375/10000.0 = 75.9% done in 1261.0s, 399.3s to go
# on time step 243085 (time=7596.41), 0.00644763 s/step
# Meep progress: 7614.0/10000.0 = 76.1% done in 1265.0s, 396.4s to go
# on time step 243694 (time=7615.44), 0.00657335 s/step
# Meep progress: 7630.5/10000.0 = 76.3% done in 1269.0s, 394.1s to go
# on time step 244216 (time=7631.75), 0.00767401 s/step
# Meep progress: 7644.65625/10000.0 = 76.4% done in 1273.0s, 392.2s to go
# on time step 244666 (time=7645.81), 0.00889412 s/step
# Meep progress: 7659.125/10000.0 = 76.6% done in 1277.0s, 390.3s to go
# on time step 245128 (time=7660.25), 0.00866281 s/step
# Meep progress: 7677.4375/10000.0 = 76.8% done in 1281.0s, 387.5s to go
# on time step 245731 (time=7679.09), 0.00664943 s/step
# Meep progress: 7696.71875/10000.0 = 77.0% done in 1285.0s, 384.5s to go
# on time step 246349 (time=7698.41), 0.00647984 s/step
# Meep progress: 7716.21875/10000.0 = 77.2% done in 1289.0s, 381.5s to go
# on time step 246972 (time=7717.88), 0.00642255 s/step
# Meep progress: 7735.8125/10000.0 = 77.4% done in 1293.0s, 378.4s to go
# on time step 247601 (time=7737.53), 0.00636307 s/step
# Meep progress: 7754.0/10000.0 = 77.5% done in 1297.0s, 375.7s to go
# on time step 248177 (time=7755.53), 0.00695202 s/step
# Meep progress: 7769.625/10000.0 = 77.7% done in 1301.0s, 373.5s to go
# on time step 248681 (time=7771.28), 0.00793797 s/step
# Meep progress: 7787.4375/10000.0 = 77.9% done in 1305.0s, 370.8s to go
# on time step 249244 (time=7788.88), 0.00711172 s/step
# Meep progress: 7804.78125/10000.0 = 78.0% done in 1309.0s, 368.2s to go
# on time step 249802 (time=7806.31), 0.00718205 s/step
# Meep progress: 7823.53125/10000.0 = 78.2% done in 1313.0s, 365.3s to go
# on time step 250408 (time=7825.25), 0.00660882 s/step
# Meep progress: 7842.96875/10000.0 = 78.4% done in 1317.0s, 362.2s to go
# on time step 251031 (time=7844.72), 0.00642605 s/step
# Meep progress: 7862.40625/10000.0 = 78.6% done in 1321.0s, 359.2s to go
# on time step 251652 (time=7864.12), 0.00644948 s/step
# Meep progress: 7881.5/10000.0 = 78.8% done in 1325.0s, 356.2s to go
# on time step 252266 (time=7883.31), 0.00651901 s/step
# Meep progress: 7901.375/10000.0 = 79.0% done in 1329.0s, 353.0s to go
# on time step 252899 (time=7903.09), 0.00632072 s/step
# Meep progress: 7918.71875/10000.0 = 79.2% done in 1333.0s, 350.4s to go
# on time step 253430 (time=7919.69), 0.0075382 s/step
# Meep progress: 7932.875/10000.0 = 79.3% done in 1337.0s, 348.4s to go
# on time step 253903 (time=7934.47), 0.00846914 s/step
# Meep progress: 7947.65625/10000.0 = 79.5% done in 1341.0s, 346.3s to go
# on time step 254384 (time=7949.5), 0.00832708 s/step
# Meep progress: 7966.1875/10000.0 = 79.7% done in 1345.0s, 343.4s to go
# on time step 254980 (time=7968.12), 0.00671646 s/step
# Meep progress: 7986.75/10000.0 = 79.9% done in 1349.1s, 340.1s to go
# on time step 255637 (time=7988.66), 0.00609574 s/step
# Meep progress: 8006.09375/10000.0 = 80.1% done in 1353.1s, 337.0s to go
# on time step 256235 (time=8007.34), 0.00669089 s/step
# Meep progress: 8024.9375/10000.0 = 80.2% done in 1357.1s, 334.0s to go
# on time step 256849 (time=8026.53), 0.00651514 s/step
# Meep progress: 8044.375/10000.0 = 80.4% done in 1361.1s, 330.9s to go
# on time step 257479 (time=8046.22), 0.00635703 s/step
# Meep progress: 8063.78125/10000.0 = 80.6% done in 1365.1s, 327.8s to go
# on time step 258105 (time=8065.78), 0.00639223 s/step
# Meep progress: 8085.25/10000.0 = 80.9% done in 1369.1s, 324.2s to go
# on time step 258786 (time=8087.06), 0.00587821 s/step
# Meep progress: 8103.5/10000.0 = 81.0% done in 1373.1s, 321.3s to go
# on time step 259369 (time=8105.28), 0.00686118 s/step
# Meep progress: 8122.125/10000.0 = 81.2% done in 1377.1s, 318.4s to go
# on time step 259955 (time=8123.59), 0.00683163 s/step
# Meep progress: 8142.125/10000.0 = 81.4% done in 1381.1s, 315.1s to go
# on time step 260610 (time=8144.06), 0.00612313 s/step
# Meep progress: 8162.125/10000.0 = 81.6% done in 1385.1s, 311.9s to go
# on time step 261243 (time=8163.84), 0.00632149 s/step
# Meep progress: 8179.875/10000.0 = 81.8% done in 1389.1s, 309.1s to go
# on time step 261821 (time=8181.91), 0.00693142 s/step
# Meep progress: 8199.34375/10000.0 = 82.0% done in 1393.1s, 305.9s to go
# on time step 262434 (time=8201.06), 0.00653721 s/step
# Meep progress: 8217.8125/10000.0 = 82.2% done in 1397.1s, 303.0s to go
# on time step 263034 (time=8219.81), 0.00667827 s/step
# Meep progress: 8236.53125/10000.0 = 82.4% done in 1401.1s, 300.0s to go
# on time step 263625 (time=8238.28), 0.00677339 s/step
# Meep progress: 8257.78125/10000.0 = 82.6% done in 1405.1s, 296.4s to go
# on time step 264300 (time=8259.38), 0.00593303 s/step
# Meep progress: 8276.625/10000.0 = 82.8% done in 1409.1s, 293.4s to go
# on time step 264924 (time=8278.88), 0.00641572 s/step
# Meep progress: 8296.28125/10000.0 = 83.0% done in 1413.1s, 290.2s to go
# on time step 265552 (time=8298.5), 0.00637659 s/step
# Meep progress: 8317.5/10000.0 = 83.2% done in 1417.1s, 286.7s to go
# on time step 266231 (time=8319.72), 0.00589536 s/step
# Meep progress: 8337.78125/10000.0 = 83.4% done in 1421.1s, 283.3s to go
# on time step 266861 (time=8339.41), 0.00634944 s/step
# Meep progress: 8354.75/10000.0 = 83.5% done in 1425.1s, 280.6s to go
# on time step 267408 (time=8356.5), 0.00731782 s/step
# Meep progress: 8375.25/10000.0 = 83.8% done in 1429.1s, 277.2s to go
# on time step 268060 (time=8376.88), 0.00613737 s/step
# Meep progress: 8394.96875/10000.0 = 83.9% done in 1433.1s, 274.0s to go
# on time step 268691 (time=8396.59), 0.0063488 s/step
# Meep progress: 8415.59375/10000.0 = 84.2% done in 1437.1s, 270.6s to go
# on time step 269353 (time=8417.28), 0.00605996 s/step
# Meep progress: 8430.9375/10000.0 = 84.3% done in 1441.1s, 268.2s to go
# on time step 269832 (time=8432.25), 0.00837059 s/step
# Meep progress: 8450.25/10000.0 = 84.5% done in 1445.1s, 265.0s to go
# on time step 270473 (time=8452.28), 0.00624815 s/step
# Meep progress: 8468.59375/10000.0 = 84.7% done in 1449.1s, 262.1s to go
# on time step 271052 (time=8470.38), 0.00694003 s/step
# Meep progress: 8487.28125/10000.0 = 84.9% done in 1453.1s, 259.0s to go
# on time step 271658 (time=8489.31), 0.00660997 s/step
# Meep progress: 8506.65625/10000.0 = 85.1% done in 1457.1s, 255.8s to go
# on time step 272287 (time=8508.97), 0.00636191 s/step
# Meep progress: 8528.625/10000.0 = 85.3% done in 1461.2s, 252.1s to go
# on time step 272984 (time=8530.75), 0.00574019 s/step
# Meep progress: 8547.9375/10000.0 = 85.5% done in 1465.2s, 248.9s to go
# on time step 273601 (time=8550.03), 0.00648308 s/step
# Meep progress: 8568.46875/10000.0 = 85.7% done in 1469.2s, 245.5s to go
# on time step 274263 (time=8570.72), 0.00604857 s/step
# Meep progress: 8587.53125/10000.0 = 85.9% done in 1473.2s, 242.3s to go
# on time step 274878 (time=8589.94), 0.00651156 s/step
# Meep progress: 8608.59375/10000.0 = 86.1% done in 1477.2s, 238.8s to go
# on time step 275548 (time=8610.88), 0.00597518 s/step
# Meep progress: 8627.90625/10000.0 = 86.3% done in 1481.2s, 235.5s to go
# on time step 276168 (time=8630.25), 0.00645708 s/step
# Meep progress: 8647.9375/10000.0 = 86.5% done in 1485.2s, 232.2s to go
# on time step 276799 (time=8649.97), 0.00634935 s/step
# Meep progress: 8667.40625/10000.0 = 86.7% done in 1489.2s, 229.0s to go
# on time step 277424 (time=8669.5), 0.00640978 s/step
# Meep progress: 8687.875/10000.0 = 86.9% done in 1493.2s, 225.5s to go
# on time step 278082 (time=8690.06), 0.00608095 s/step
# Meep progress: 8705.40625/10000.0 = 87.1% done in 1497.2s, 222.6s to go
# on time step 278645 (time=8707.66), 0.00711587 s/step
# Meep progress: 8726.40625/10000.0 = 87.3% done in 1501.2s, 219.1s to go
# on time step 279323 (time=8728.84), 0.00590097 s/step
# Meep progress: 8744.59375/10000.0 = 87.4% done in 1505.2s, 216.1s to go
# on time step 279880 (time=8746.25), 0.00718268 s/step
# Meep progress: 8762.84375/10000.0 = 87.6% done in 1509.2s, 213.1s to go
# on time step 280464 (time=8764.5), 0.00686277 s/step
# Meep progress: 8781.1875/10000.0 = 87.8% done in 1513.2s, 210.0s to go
# on time step 281055 (time=8782.97), 0.00678971 s/step
# Meep progress: 8799.5625/10000.0 = 88.0% done in 1517.2s, 207.0s to go
# on time step 281666 (time=8802.06), 0.00655723 s/step
# Meep progress: 8819.9375/10000.0 = 88.2% done in 1521.2s, 203.5s to go
# on time step 282315 (time=8822.34), 0.0061701 s/step
# Meep progress: 8840.25/10000.0 = 88.4% done in 1525.2s, 200.1s to go
# on time step 282967 (time=8842.72), 0.00613928 s/step
# Meep progress: 8860.53125/10000.0 = 88.6% done in 1529.2s, 196.7s to go
# on time step 283612 (time=8862.88), 0.00620182 s/step
# Meep progress: 8880.71875/10000.0 = 88.8% done in 1533.2s, 193.2s to go
# on time step 284261 (time=8883.16), 0.00617139 s/step
# Meep progress: 8896.78125/10000.0 = 89.0% done in 1537.2s, 190.6s to go
# on time step 284764 (time=8898.88), 0.00796292 s/step
# Meep progress: 8914.0625/10000.0 = 89.1% done in 1541.2s, 187.8s to go
# on time step 285323 (time=8916.34), 0.00716311 s/step
# Meep progress: 8932.71875/10000.0 = 89.3% done in 1545.2s, 184.6s to go
# on time step 285913 (time=8934.78), 0.0067799 s/step
# Meep progress: 8951.34375/10000.0 = 89.5% done in 1549.2s, 181.5s to go
# on time step 286522 (time=8953.81), 0.00657277 s/step
# Meep progress: 8968.1875/10000.0 = 89.7% done in 1553.2s, 178.7s to go
# on time step 287035 (time=8969.84), 0.00780679 s/step
# Meep progress: 8985.3125/10000.0 = 89.9% done in 1557.2s, 175.9s to go
# on time step 287607 (time=8987.72), 0.00700018 s/step
# Meep progress: 9004.78125/10000.0 = 90.0% done in 1561.2s, 172.5s to go
# on time step 288236 (time=9007.38), 0.00636729 s/step
# Meep progress: 9024.75/10000.0 = 90.2% done in 1565.2s, 169.1s to go
# on time step 288871 (time=9027.22), 0.0063068 s/step
# Meep progress: 9043.78125/10000.0 = 90.4% done in 1569.2s, 165.9s to go
# on time step 289463 (time=9045.72), 0.00676952 s/step
# Meep progress: 9057.34375/10000.0 = 90.6% done in 1573.2s, 163.7s to go
# on time step 289897 (time=9059.28), 0.00922384 s/step
# Meep progress: 9074.09375/10000.0 = 90.7% done in 1577.2s, 160.9s to go
# on time step 290454 (time=9076.69), 0.00719426 s/step
# Meep progress: 9090.875/10000.0 = 90.9% done in 1581.3s, 158.1s to go
# on time step 290984 (time=9093.25), 0.00754972 s/step
# Meep progress: 9109.03125/10000.0 = 91.1% done in 1585.3s, 155.1s to go
# on time step 291558 (time=9111.19), 0.0069758 s/step
# Meep progress: 9127.625/10000.0 = 91.3% done in 1589.3s, 151.9s to go
# on time step 292169 (time=9130.28), 0.00655056 s/step
# Meep progress: 9148.125/10000.0 = 91.5% done in 1593.3s, 148.4s to go
# on time step 292822 (time=9150.69), 0.00612913 s/step
# Meep progress: 9168.84375/10000.0 = 91.7% done in 1597.3s, 144.8s to go
# on time step 293490 (time=9171.56), 0.00598884 s/step
# Meep progress: 9189.90625/10000.0 = 91.9% done in 1601.3s, 141.2s to go
# on time step 294164 (time=9192.62), 0.00594123 s/step
# Meep progress: 9208.5/10000.0 = 92.1% done in 1605.3s, 138.0s to go
# on time step 294733 (time=9210.41), 0.00704402 s/step
# Meep progress: 9221.65625/10000.0 = 92.2% done in 1609.3s, 135.8s to go
# on time step 295137 (time=9223.03), 0.00992468 s/step
# Meep progress: 9235.25/10000.0 = 92.4% done in 1613.3s, 133.6s to go
# on time step 295590 (time=9237.19), 0.00883682 s/step
# Meep progress: 9251.0/10000.0 = 92.5% done in 1617.3s, 130.9s to go
# on time step 296114 (time=9253.56), 0.00763534 s/step
# Meep progress: 9271.6875/10000.0 = 92.7% done in 1621.3s, 127.4s to go
# on time step 296780 (time=9274.38), 0.00601258 s/step
# Meep progress: 9292.46875/10000.0 = 92.9% done in 1625.3s, 123.8s to go
# on time step 297445 (time=9295.16), 0.00601827 s/step
# Meep progress: 9313.375/10000.0 = 93.1% done in 1629.3s, 120.1s to go
# on time step 298113 (time=9316.03), 0.0059903 s/step
# Meep progress: 9334.1875/10000.0 = 93.3% done in 1633.3s, 116.5s to go
# on time step 298775 (time=9336.72), 0.00604553 s/step
# Meep progress: 9353.34375/10000.0 = 93.5% done in 1637.3s, 113.2s to go
# on time step 299370 (time=9355.31), 0.0067337 s/step
# Meep progress: 9369.375/10000.0 = 93.7% done in 1641.3s, 110.5s to go
# on time step 299895 (time=9371.72), 0.00763021 s/step
# Meep progress: 9386.59375/10000.0 = 93.9% done in 1645.3s, 107.5s to go
# on time step 300451 (time=9389.09), 0.00719902 s/step
# Meep progress: 9403.78125/10000.0 = 94.0% done in 1649.3s, 104.6s to go
# on time step 300993 (time=9406.03), 0.007385 s/step
# Meep progress: 9422.34375/10000.0 = 94.2% done in 1653.3s, 101.4s to go
# on time step 301600 (time=9425), 0.00659334 s/step
# Meep progress: 9440.71875/10000.0 = 94.4% done in 1657.3s, 98.2s to go
# on time step 302171 (time=9442.84), 0.0070169 s/step
# Meep progress: 9458.03125/10000.0 = 94.6% done in 1661.3s, 95.2s to go
# on time step 302752 (time=9461), 0.00689131 s/step
# Meep progress: 9477.09375/10000.0 = 94.8% done in 1665.3s, 91.9s to go
# on time step 303335 (time=9479.22), 0.00686804 s/step
# Meep progress: 9491.4375/10000.0 = 94.9% done in 1669.3s, 89.4s to go
# on time step 303809 (time=9494.03), 0.00844017 s/step
# Meep progress: 9510.5/10000.0 = 95.1% done in 1673.3s, 86.1s to go
# on time step 304423 (time=9513.22), 0.00652047 s/step
# Meep progress: 9530.375/10000.0 = 95.3% done in 1677.3s, 82.7s to go
# on time step 305060 (time=9533.12), 0.00628552 s/step
# Meep progress: 9549.1875/10000.0 = 95.5% done in 1681.4s, 79.4s to go
# on time step 305659 (time=9551.84), 0.00667837 s/step
# Meep progress: 9569.78125/10000.0 = 95.7% done in 1685.4s, 75.8s to go
# on time step 306317 (time=9572.41), 0.0060872 s/step
# Meep progress: 9589.6875/10000.0 = 95.9% done in 1689.4s, 72.3s to go
# on time step 306948 (time=9592.12), 0.00634107 s/step
# Meep progress: 9608.0625/10000.0 = 96.1% done in 1693.4s, 69.1s to go
# on time step 307544 (time=9610.75), 0.00671807 s/step
# Meep progress: 9627.53125/10000.0 = 96.3% done in 1697.4s, 65.7s to go
# on time step 308168 (time=9630.25), 0.00641905 s/step
# Meep progress: 9644.46875/10000.0 = 96.4% done in 1701.4s, 62.7s to go
# on time step 308716 (time=9647.38), 0.00730851 s/step
# Meep progress: 9663.84375/10000.0 = 96.6% done in 1705.4s, 59.3s to go
# on time step 309335 (time=9666.72), 0.00646951 s/step
# Meep progress: 9683.59375/10000.0 = 96.8% done in 1709.4s, 55.9s to go
# on time step 309951 (time=9685.97), 0.00649687 s/step
# Meep progress: 9701.625/10000.0 = 97.0% done in 1713.4s, 52.7s to go
# on time step 310546 (time=9704.56), 0.0067317 s/step
# Meep progress: 9722.59375/10000.0 = 97.2% done in 1717.4s, 49.0s to go
# on time step 311209 (time=9725.28), 0.00603371 s/step
# Meep progress: 9743.46875/10000.0 = 97.4% done in 1721.4s, 45.3s to go
# on time step 311886 (time=9746.44), 0.00591619 s/step
# Meep progress: 9764.59375/10000.0 = 97.6% done in 1725.4s, 41.6s to go
# on time step 312565 (time=9767.66), 0.00589181 s/step
# Meep progress: 9785.9375/10000.0 = 97.9% done in 1729.4s, 37.8s to go
# on time step 313244 (time=9788.88), 0.00589805 s/step
# Meep progress: 9807.0/10000.0 = 98.1% done in 1733.4s, 34.1s to go
# on time step 313916 (time=9809.88), 0.00595248 s/step
# Meep progress: 9827.84375/10000.0 = 98.3% done in 1737.4s, 30.4s to go
# on time step 314567 (time=9830.22), 0.00614477 s/step
# Meep progress: 9843.9375/10000.0 = 98.4% done in 1741.4s, 27.6s to go
# on time step 315054 (time=9845.44), 0.00823374 s/step
# Meep progress: 9858.1875/10000.0 = 98.6% done in 1745.4s, 25.1s to go
# on time step 315537 (time=9860.53), 0.00828691 s/step
# Meep progress: 9873.96875/10000.0 = 98.7% done in 1749.4s, 22.3s to go
# on time step 316052 (time=9876.62), 0.00777617 s/step
# Meep progress: 9892.46875/10000.0 = 98.9% done in 1753.4s, 19.1s to go
# on time step 316639 (time=9894.97), 0.00681614 s/step
# Meep progress: 9909.40625/10000.0 = 99.1% done in 1757.4s, 16.1s to go
# on time step 317185 (time=9912.03), 0.00732954 s/step
# Meep progress: 9927.625/10000.0 = 99.3% done in 1761.4s, 12.8s to go
# on time step 317767 (time=9930.22), 0.00688042 s/step
# Meep progress: 9944.3125/10000.0 = 99.4% done in 1765.4s, 9.9s to go
# on time step 318295 (time=9946.72), 0.00758186 s/step
# Meep progress: 9961.5625/10000.0 = 99.6% done in 1769.4s, 6.8s to go
# on time step 318855 (time=9964.22), 0.00714609 s/step
# Meep progress: 9980.5/10000.0 = 99.8% done in 1773.4s, 3.5s to go
# on time step 319463 (time=9983.22), 0.0065874 s/step
# Meep progress: 9996.0/10000.0 = 100.0% done in 1777.4s, 0.7s to go
# on time step 319938 (time=9998.06), 0.00843066 s/step
# run 0 finished at t = 10000.0 (320000 timesteps)

# %%
plt.plot(freqs_wo,psd_out_wo)
plt.grid(True)

# %%
plt.plot(freqs_w,psd_out_w)
plt.grid(True)

# %%
plt.plot(np.array(freqs_w), np.array(psd_out_w)/np.array(psd_out_wo))
plt.xlabel("Frequency[c/a]")
plt.ylabel("Transmittance[c/a]")
plt.yscale('log')
plt.grid(True)

# %%
plt.plot(np.array(freqs_w), np.array(psd_out_w)/np.array(psd_out_wo))
plt.xlabel("Frequency[c/a]")
plt.ylabel("Transmittance[c/a]")
plt.yscale('log')
plt.grid(True)

# %%
a = 470
c_const = 299792458

freqs = a / np.array(freqs_w)
#freqs
plt.plot(freqs, np.array(psd_out_w)/np.array(psd_out_wo))
plt.scatter(freqs, np.array(psd_out_w)/np.array(psd_out_wo))
plt.xlabel("Frequency[c/a]")
plt.ylabel("Transmittance[c/a]")
#plt.xlim([0.28,0.30])
plt.yscale('log')
plt.grid(True)

# %%
freqs = a / np.array(freqs_w)
#freqs
plt.plot(freqs, np.array(psd_out_w)/np.array(psd_out_wo))
plt.scatter(freqs, np.array(psd_out_w)/np.array(psd_out_wo))
plt.xlabel("Frequency[c/a]")
plt.ylabel("Transmittance[c/a]")
plt.xlim([1450,1550])
plt.yscale('log')
plt.grid(True)

# %%
df = pd.DataFrame()
df["wavelength"] = freqs
df["transmittance"] = np.array(psd_out_w)/np.array(psd_out_wo)
df.to_csv("210111_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d085_kpm005.csv")

# %%
df
# Out:
#       wavelength  transmittance
# 0    2350.000000       0.025658
# 1    2345.300000       0.024603
# 2    2340.618762       0.023389
# 3    2335.956175       0.022002
# 4    2331.312127       0.020514
# ..           ...            ...
# 495  1179.728370       0.017603
# 496  1178.542714       0.018226
# 497  1177.359438       0.019059
# 498  1176.178536       0.019781
# 499  1175.000000       0.020042
#
# [500 rows x 2 columns]

# %%
ls
# Out:
# 201029_waveguide_VPhCtriangle_zigzag.ipynb_transmittance.csv*
# 210111_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d085_kpm005.csv*
# Code.VisualElementsManifest.xml*
# Code.exe*
# bin/
# chrome_100_percent.pak*
# chrome_200_percent.pak*
# d3dcompiler_47.dll*
# ffmpeg.dll*
# icudtl.dat*
# libEGL.dll*
# libGLESv2.dll*
# locales/
# resources/
# resources.pak*
# result.csv*
# snapshot_blob.bin*
# swiftshader/
# tools/
# unins000.dat*
# unins000.exe*
# unins000.msg*
# v8_context_snapshot.bin*
# vk_swiftshader.dll*
# vk_swiftshader_icd.json*
# vulkan-1.dll*
