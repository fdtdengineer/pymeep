# %% [markdown]
# https://github.com/NanoComp/meep/blob/master/python/examples/straight-waveguide.ipynb
#
# https://stackoverflow.com/questions/29454002/filenotfounderror-errno-2-no-such-file-or-directory-ffmpeg

# %%
import math
import meep as mp
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# Using MPI version 3.1, 1 processes

# %%
def phc_trans(PhC = True, lengthPhC = 100, decay_check=0, T_decay=500):
    """
    <変数の説明>
    PhC...PhC(フォトニック決勝)を配置するかどうか。Falseで直線導波路
    lengthPhC...PhC導波方向の長さ
    widthPhC...PhC垂直方向の幅。PMLと被ってるので適当。
    ConnectionWaveguide...PhCに接続するSi導波路(棒の部分)の長さ
    wgi...導波路の幅を調整する。1で丸穴一個分空いてることを意味する。0.7とかにすると狭くなってバンドの形が変わる、っていうのはDaii君の研究とも絡む。
    r...穴の半径。ふつうはa/4くらい。meepだと格子定数は1で固定だから、格子定数との比を入力すればOK
    n_eff...屈折率。2次元だと2.5~2.7くらいにしておくと3次元のSi系(n_Si=3.48)と結果が近くなる。違う材料を使うときは要調整、通常はdefaultで大丈夫。
    fcen...入力光（ガウシアンビーム）の中心周波数。知りたいPhCバンドの周波数近くに設定する
    df...入力光（ガウシアンビーム）の半値幅（で合ってる？）
    nfreq...入力光（ガウシアンビーム）のきめ細かさ
    resolution...メッシュの細かさ。2^nにすると計算が軽くなるらしい。
    T_dacay...反復計算数。小さいと誤差が増え、大きいと時間がかかる。sim.run(until_after_sources=...)で計算時間を見積もってから変えるとよさそう
    decay_check...解の収束をどこで判定するか、位置を指定。defaultでOK

    <備考>
    ・meepでは格子定数aはパラメータに含まれないので設定不要
    　誘電体を使うときは入力するらしい（スケール依存性が出るから）
    ・THzやnmは使用せず、すべて規格化周波数で入力する (周波数はωa/2πcで直す)
    """
    ##### setting of parameters #####
    a = 1 # CADに移行しやすいように予め設定しておく
    widthPhC = 10
    ConnectionWaveguide = 5
    wgi = 1/2 #/np.sqrt(3)/2
    whetero = 1/np.sqrt(3)/4
    r = 1/4
    d_0 = 0.85*a
    yshift = -np.sqrt(3)/4*a #1/(np.sqrt(3)) #+ 1/6*np.sqrt(3)/2*d_0
    n_eff = 2.6
    fcen = 0.3 
    df = 0.2
    nfreq = 5000 # number of frequencies at which to compute flux
    resolution = 16

    connect = 0
    #####
    length = lengthPhC + 2*ConnectionWaveguide
    width = widthPhC
    Nx = int(lengthPhC)
    Ny = int(widthPhC)
    eps = n_eff**2

    # settings of imaginary part
    normalized_frequency = 0.3
    extinction_coefficient = 0.5

    ##### settings of geometry #####
    # initialization
    cell = mp.Vector3(length,width*np.sqrt(3),0)

    # Si waveguide
    waveguide = mp.Block(mp.Vector3(mp.inf,wgi*np.sqrt(3),mp.inf),
                            center=mp.Vector3(),
                            material=mp.Medium(epsilon=eps))
    geometry = [waveguide]

    # PhC
    if PhC:
        # triangle
        tri_u = [
                mp.Vector3(-np.sqrt(3)/2,-1/2)*d_0/np.sqrt(3),
                mp.Vector3( np.sqrt(3)/2,-1/2)*d_0/np.sqrt(3),
                mp.Vector3(            0,   1)*d_0/np.sqrt(3),
                ]
        tri_d = [
                mp.Vector3(-np.sqrt(3)/2,-1/2)*d_0/np.sqrt(3)*(-1),
                mp.Vector3( np.sqrt(3)/2,-1/2)*d_0/np.sqrt(3)*(-1),
                mp.Vector3(            0,   1)*d_0/np.sqrt(3)*(-1),
                ]

        # slab
        blk_above = mp.Block(mp.Vector3(lengthPhC,widthPhC*np.sqrt(3),mp.inf),
                                center=mp.Vector3(0, widthPhC*np.sqrt(3)/2 + 0*(yshift + 1/(2*np.sqrt(3))), 0),
                                material=mp.Medium(epsilon=eps, D_conductivity=0*2*np.pi*normalized_frequency*extinction_coefficient / eps))
        geometry.append(blk_above)
        blk_below = mp.Block(mp.Vector3(lengthPhC,widthPhC*np.sqrt(3),mp.inf),
                                center=mp.Vector3(0,-widthPhC*np.sqrt(3)/2 + 0*(yshift + 1/(2*np.sqrt(3))), 0),
                                material=mp.Medium(epsilon=eps, D_conductivity=2*np.pi*normalized_frequency*extinction_coefficient / eps))
        geometry.append(blk_below)
        
        # arrange air-holes
        # zigzag に 三角穴を足して bearded にしている
        for j in range(Ny):
            for i in range(Nx+1):
                shift_y = np.sqrt(3)
                geometry.append(mp.Prism(tri_d, height = 1, center=mp.Vector3(i-(Nx+1)/2, yshift + 1/(np.sqrt(3)) + shift_y*(j+1/2))))                
                geometry.append(mp.Prism(tri_u, height = 1, center=mp.Vector3(i-(Nx+1)/2, yshift -(1/(np.sqrt(3)) + shift_y*(j+1/2)))))            
                geometry.append(mp.Prism(tri_d, height = 1, center=mp.Vector3(i-Nx/2, yshift +  1/(np.sqrt(3)) + shift_y*j )))

            if j == 0:
                for i in range(connect,Nx+1-connect):
                    geometry.append(mp.Prism(tri_u, height = 1, center=mp.Vector3(i-Nx/2, yshift - (1/(np.sqrt(3)) + shift_y*j))))
            else:
                for i in range(Nx+1):
                    geometry.append(mp.Prism(tri_u, height = 1, center=mp.Vector3(i-Nx/2, yshift - (1/(np.sqrt(3)) + shift_y*j))))
                    
        for i in range(1,Nx+1):
            geometry.append(mp.Prism(tri_u, height = 1, center=mp.Vector3(i-(Nx+1)/2, yshift - (1/(np.sqrt(3)) + shift_y*(-1/2)))))
        #geometry.append(mp.Prism(tri_d, height = 1, center=mp.Vector3(1, 0)))


                #geometry.append(mp.Cylinder(r, center=mp.Vector3(i-N/2,-wgi*np.sqrt(3)/2)))

    # Gaussian
    sources = [mp.Source(mp.GaussianSource(fcen, fwidth=df),
                            component=mp.Hz,
                            center=mp.Vector3(-length/2 +1,0),
                            size=mp.Vector3(0,wgi*np.sqrt(3)))
                ]

    # PML
    pml_layers = [mp.PML(1.0)]

    # z-symmetry (上下対称なら計算が軽くなる。対称性が無いなら消す)
    #sym = [mp.Mirror(mp.Y, phase=-1)]
    

    ####
    sim = mp.Simulation(cell_size=cell,
                        boundary_layers=pml_layers,
                        geometry=geometry,
                        sources=sources,
                        #symmetries=sym,
                        resolution=resolution)

    #tran_in = mp.FluxRegion(center=mp.Vector3(-lengthPhC/2-1,0),size=mp.Vector3(0, 2*wgi))
    tran_out = mp.FluxRegion(center=mp.Vector3(length/2-3/2,0),size=mp.Vector3(0, 2*wgi))
    #trans_in = sim.add_flux(fcen, df, nfreq, tran_in)
    trans_out = sim.add_flux(fcen, df, nfreq, tran_out)

    # show geometry
    # %matplotlib inline
    f = plt.figure(dpi=500, figsize=(8,16))
    sim.plot2D(ax=f.gca())
    plt.show()    

    #sim.run(until_after_sources=mp.stop_when_fields_decayed(50, mp.Hz, mp.Vector3(decay_check), 1e-3))
    sim.run(until=T_decay)

    freqs = mp.get_flux_freqs(trans_out)
    #psd_in = mp.get_fluxes(trans_in)
    psd_out = mp.get_fluxes(trans_out)

    return freqs, psd_out

# %%
freqs_wo, psd_out_wo = phc_trans(PhC = False, lengthPhC = 20, decay_check=10, T_decay=500)
freqs_w,  psd_out_w  = phc_trans(PhC = True, lengthPhC = 50, decay_check=20, T_decay=10000)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.001091 s
# Working in 2D dimensions.
# Computational cell is 30 x 17.3125 x 0 with resolution 16
#      block, center = (0,0,0)
#           size (1e+20,0.866025,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (6.76,6.76,6.76)
# time for set_epsilon = 0.715481 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=500.0)
# Meep progress: 34.75/500.0 = 7.0% done in 4.0s, 53.6s to go
# on time step 1123 (time=35.0938), 0.00356245 s/step
# Meep progress: 76.09375/500.0 = 15.2% done in 8.0s, 44.6s to go
# on time step 2441 (time=76.2812), 0.00303651 s/step
# Meep progress: 116.78125/500.0 = 23.4% done in 12.0s, 39.4s to go
# on time step 3741 (time=116.906), 0.00307799 s/step
# Meep progress: 157.6875/500.0 = 31.5% done in 16.0s, 34.7s to go
# on time step 5058 (time=158.062), 0.00303873 s/step
# Meep progress: 195.3125/500.0 = 39.1% done in 20.0s, 31.2s to go
# on time step 6260 (time=195.625), 0.00332839 s/step
# Meep progress: 238.5625/500.0 = 47.7% done in 24.0s, 26.3s to go
# on time step 7646 (time=238.938), 0.00288651 s/step
# Meep progress: 279.71875/500.0 = 55.9% done in 28.0s, 22.1s to go
# on time step 8960 (time=280), 0.00304501 s/step
# Meep progress: 317.625/500.0 = 63.5% done in 32.0s, 18.4s to go
# on time step 10180 (time=318.125), 0.00327948 s/step
# Meep progress: 361.53125/500.0 = 72.3% done in 36.0s, 13.8s to go
# on time step 11576 (time=361.75), 0.00286533 s/step
# Meep progress: 398.8125/500.0 = 79.8% done in 40.0s, 10.2s to go
# on time step 12778 (time=399.312), 0.00332871 s/step
# Meep progress: 435.59375/500.0 = 87.1% done in 44.0s, 6.5s to go
# on time step 13946 (time=435.812), 0.00342606 s/step
# Meep progress: 473.96875/500.0 = 94.8% done in 48.0s, 2.6s to go
# on time step 15183 (time=474.469), 0.00323363 s/step
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# run 0 finished at t = 500.0 (16000 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.193913 s
# Working in 2D dimensions.
# Computational cell is 60 x 17.3125 x 0 with resolution 16
#      block, center = (0,0,0)
#           size (1e+20,0.866025,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (6.76,6.76,6.76)
#      block, center = (0,8.66025,0)
#           size (50,17.3205,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (6.76,6.76,6.76)
#      block, center = (0,-8.66025,0)
#           size (50,17.3205,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (6.76,6.76,6.76)
#      prism, center = (-25.5,1.01036,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-25.075,1.25574,-0.5)
#           (-25.925,1.25574,-0.5)
#           (-25.5,0.519615,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      prism, center = (-25.5,-1.87639,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-25.925,-2.12176,-0.5)
#           (-25.075,-2.12176,-0.5)
#           (-25.5,-1.38564,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      prism, center = (-25,0.144338,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-24.575,0.389711,-0.5)
#           (-25.425,0.389711,-0.5)
#           (-25,-0.34641,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      prism, center = (-24.5,1.01036,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-24.075,1.25574,-0.5)
#           (-24.925,1.25574,-0.5)
#           (-24.5,0.519615,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      prism, center = (-24.5,-1.87639,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-24.925,-2.12176,-0.5)
#           (-24.075,-2.12176,-0.5)
#           (-24.5,-1.38564,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      prism, center = (-24,0.144338,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-23.575,0.389711,-0.5)
#           (-24.425,0.389711,-0.5)
#           (-24,-0.34641,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      prism, center = (-23.5,1.01036,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-23.075,1.25574,-0.5)
#           (-23.925,1.25574,-0.5)
#           (-23.5,0.519615,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      ...(+ 2083 objects not shown)...
# subpixel-averaging is 42.4421% done, 5.47916 s remaining
# subpixel-averaging is 91.0742% done, 0.39515 s remaining
# subpixel-averaging is 58.3581% done, 2.86438 s remaining
# subpixel-averaging is 47.3053% done, 4.4675 s remaining
# subpixel-averaging is 87.9795% done, 0.547757 s remaining
# time for set_epsilon = 28.3959 s
# time for set_conductivity = 0.4093 s
# time for set_conductivity = 0.478282 s
# time for set_conductivity = 0.336439 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=10000.0)
#  time step 219312 (time=6853.5), 0.00755076 s/step
# Meep progress: 6869.46875/10000.0 = 68.7% done in 1602.2s, 730.1s to go
# on time step 219903 (time=6871.97), 0.00677768 s/step
# Meep progress: 6890.3125/10000.0 = 68.9% done in 1606.2s, 724.9s to go
# on time step 220591 (time=6893.47), 0.00582045 s/step
# Meep progress: 6912.65625/10000.0 = 69.1% done in 1610.2s, 719.1s to go
# on time step 221295 (time=6915.47), 0.00568773 s/step
# Meep progress: 6931.625/10000.0 = 69.3% done in 1614.2s, 714.5s to go
# on time step 221877 (time=6933.66), 0.00687563 s/step
# Meep progress: 6953.21875/10000.0 = 69.5% done in 1618.2s, 709.1s to go
# on time step 222587 (time=6955.84), 0.00564781 s/step
# Meep progress: 6971.84375/10000.0 = 69.7% done in 1622.2s, 704.6s to go
# on time step 223168 (time=6974), 0.00688828 s/step
# Meep progress: 6988.375/10000.0 = 69.9% done in 1626.2s, 700.8s to go
# on time step 223706 (time=6990.81), 0.00744523 s/step
# Meep progress: 7003.65625/10000.0 = 70.0% done in 1630.2s, 697.4s to go
# on time step 224203 (time=7006.34), 0.00805166 s/step
# Meep progress: 7021.78125/10000.0 = 70.2% done in 1634.2s, 693.1s to go
# on time step 224785 (time=7024.53), 0.00687765 s/step
# Meep progress: 7039.78125/10000.0 = 70.4% done in 1638.2s, 688.9s to go
# on time step 225373 (time=7042.91), 0.00681406 s/step
# Meep progress: 7059.875/10000.0 = 70.6% done in 1642.2s, 683.9s to go
# on time step 226014 (time=7062.94), 0.00624293 s/step
# Meep progress: 7078.25/10000.0 = 70.8% done in 1646.2s, 679.5s to go
# on time step 226594 (time=7081.06), 0.00689823 s/step
# Meep progress: 7095.40625/10000.0 = 71.0% done in 1650.2s, 675.5s to go
# on time step 227122 (time=7097.56), 0.0075807 s/step
# Meep progress: 7112.46875/10000.0 = 71.1% done in 1654.2s, 671.6s to go
# on time step 227673 (time=7114.78), 0.00726151 s/step
# Meep progress: 7128.21875/10000.0 = 71.3% done in 1658.2s, 668.1s to go
# on time step 228160 (time=7130), 0.00821503 s/step
# Meep progress: 7145.21875/10000.0 = 71.5% done in 1662.2s, 664.1s to go
# on time step 228726 (time=7147.69), 0.00706921 s/step
# Meep progress: 7162.875/10000.0 = 71.6% done in 1666.2s, 660.0s to go
# on time step 229293 (time=7165.41), 0.0070599 s/step
# Meep progress: 7181.90625/10000.0 = 71.8% done in 1670.2s, 655.4s to go
# on time step 229902 (time=7184.44), 0.00657214 s/step
# Meep progress: 7196.0625/10000.0 = 72.0% done in 1674.2s, 652.4s to go
# on time step 230354 (time=7198.56), 0.00885012 s/step
# Meep progress: 7214.28125/10000.0 = 72.1% done in 1678.2s, 648.0s to go
# on time step 230940 (time=7216.88), 0.00682753 s/step
# Meep progress: 7232.0625/10000.0 = 72.3% done in 1682.2s, 643.8s to go
# on time step 231492 (time=7234.12), 0.00725023 s/step
# Meep progress: 7249.125/10000.0 = 72.5% done in 1686.3s, 639.9s to go
# on time step 232060 (time=7251.88), 0.00704297 s/step
# Meep progress: 7268.03125/10000.0 = 72.7% done in 1690.3s, 635.3s to go
# on time step 232616 (time=7269.25), 0.00719695 s/step
# Meep progress: 7284.0/10000.0 = 72.8% done in 1694.3s, 631.7s to go
# on time step 233168 (time=7286.5), 0.00725827 s/step
# Meep progress: 7302.46875/10000.0 = 73.0% done in 1698.3s, 627.3s to go
# on time step 233774 (time=7305.44), 0.00660746 s/step
# Meep progress: 7322.46875/10000.0 = 73.2% done in 1702.3s, 622.5s to go
# on time step 234392 (time=7324.75), 0.00647597 s/step
# Meep progress: 7335.46875/10000.0 = 73.4% done in 1706.3s, 619.8s to go
# on time step 234809 (time=7337.78), 0.00960301 s/step
# Meep progress: 7348.0/10000.0 = 73.5% done in 1710.3s, 617.3s to go
# on time step 235208 (time=7350.25), 0.0100312 s/step
# Meep progress: 7362.875/10000.0 = 73.6% done in 1714.3s, 614.0s to go
# on time step 235667 (time=7364.59), 0.00873155 s/step
# Meep progress: 7381.0/10000.0 = 73.8% done in 1718.3s, 609.7s to go
# on time step 236279 (time=7383.72), 0.00654449 s/step
# Meep progress: 7397.9375/10000.0 = 74.0% done in 1722.3s, 605.8s to go
# on time step 236794 (time=7399.81), 0.00778473 s/step
# Meep progress: 7412.84375/10000.0 = 74.1% done in 1726.3s, 602.5s to go
# on time step 237308 (time=7415.88), 0.00778249 s/step
# Meep progress: 7433.03125/10000.0 = 74.3% done in 1730.3s, 597.6s to go
# on time step 237929 (time=7435.28), 0.00644828 s/step
# Meep progress: 7447.0625/10000.0 = 74.5% done in 1734.3s, 594.5s to go
# on time step 238374 (time=7449.19), 0.00899949 s/step
# Meep progress: 7466.4375/10000.0 = 74.7% done in 1738.3s, 589.9s to go
# on time step 239023 (time=7469.47), 0.0061697 s/step
# Meep progress: 7484.84375/10000.0 = 74.8% done in 1742.3s, 585.5s to go
# on time step 239605 (time=7487.66), 0.00688448 s/step
# Meep progress: 7502.59375/10000.0 = 75.0% done in 1746.3s, 581.3s to go
# on time step 240159 (time=7504.97), 0.00722418 s/step
# Meep progress: 7522.0625/10000.0 = 75.2% done in 1750.3s, 576.6s to go
# on time step 240796 (time=7524.88), 0.00628152 s/step
# Meep progress: 7540.71875/10000.0 = 75.4% done in 1754.3s, 572.1s to go
# on time step 241382 (time=7543.19), 0.00683171 s/step
# Meep progress: 7557.90625/10000.0 = 75.6% done in 1758.3s, 568.2s to go
# on time step 241919 (time=7559.97), 0.00745425 s/step
# Meep progress: 7574.34375/10000.0 = 75.7% done in 1762.3s, 564.4s to go
# on time step 242466 (time=7577.06), 0.00731269 s/step
# Meep progress: 7593.90625/10000.0 = 75.9% done in 1766.4s, 559.7s to go
# on time step 243082 (time=7596.31), 0.00649432 s/step
# Meep progress: 7607.75/10000.0 = 76.1% done in 1770.4s, 556.7s to go
# on time step 243524 (time=7610.12), 0.0090523 s/step
# Meep progress: 7626.1875/10000.0 = 76.3% done in 1774.4s, 552.3s to go
# on time step 244130 (time=7629.06), 0.00660247 s/step
# Meep progress: 7643.28125/10000.0 = 76.4% done in 1778.4s, 548.3s to go
# on time step 244654 (time=7645.44), 0.0076439 s/step
# Meep progress: 7659.53125/10000.0 = 76.6% done in 1782.4s, 544.6s to go
# on time step 245196 (time=7662.38), 0.00738327 s/step
# Meep progress: 7673.21875/10000.0 = 76.7% done in 1786.4s, 541.7s to go
# on time step 245584 (time=7674.5), 0.0103295 s/step
# Meep progress: 7687.15625/10000.0 = 76.9% done in 1790.4s, 538.7s to go
# on time step 246078 (time=7689.94), 0.00810445 s/step
# Meep progress: 7702.15625/10000.0 = 77.0% done in 1794.4s, 535.3s to go
# on time step 246547 (time=7704.59), 0.00852892 s/step
# Meep progress: 7719.0625/10000.0 = 77.2% done in 1798.4s, 531.4s to go
# on time step 247058 (time=7720.56), 0.00783562 s/step
# Meep progress: 7731.40625/10000.0 = 77.3% done in 1802.4s, 528.9s to go
# on time step 247478 (time=7733.69), 0.00953589 s/step
# Meep progress: 7746.96875/10000.0 = 77.5% done in 1806.4s, 525.4s to go
# on time step 247969 (time=7749.03), 0.00816408 s/step
# Meep progress: 7765.59375/10000.0 = 77.7% done in 1810.4s, 520.9s to go
# on time step 248599 (time=7768.72), 0.00635145 s/step
# Meep progress: 7785.15625/10000.0 = 77.9% done in 1814.4s, 516.2s to go
# on time step 249215 (time=7787.97), 0.00649758 s/step
# Meep progress: 7804.53125/10000.0 = 78.0% done in 1818.4s, 511.5s to go
# on time step 249821 (time=7806.91), 0.00660596 s/step
# Meep progress: 7824.53125/10000.0 = 78.2% done in 1822.4s, 506.7s to go
# on time step 250474 (time=7827.31), 0.00613433 s/step
# Meep progress: 7842.625/10000.0 = 78.4% done in 1826.4s, 502.4s to go
# on time step 251032 (time=7844.75), 0.00717143 s/step
# Meep progress: 7861.78125/10000.0 = 78.6% done in 1830.4s, 497.8s to go
# on time step 251671 (time=7864.72), 0.00626699 s/step
# Meep progress: 7884.1875/10000.0 = 78.8% done in 1834.4s, 492.3s to go
# on time step 252391 (time=7887.22), 0.00555709 s/step
# Meep progress: 7907.84375/10000.0 = 79.1% done in 1838.4s, 486.4s to go
# on time step 253152 (time=7911), 0.00525718 s/step
# Meep progress: 7932.4375/10000.0 = 79.3% done in 1842.4s, 480.2s to go
# on time step 253942 (time=7935.69), 0.0050635 s/step
# Meep progress: 7956.5/10000.0 = 79.6% done in 1846.5s, 474.2s to go
# on time step 254693 (time=7959.16), 0.00532896 s/step
# Meep progress: 7977.0625/10000.0 = 79.8% done in 1850.5s, 469.3s to go
# on time step 255356 (time=7979.88), 0.00603595 s/step
# Meep progress: 8000.0625/10000.0 = 80.0% done in 1854.5s, 463.6s to go
# on time step 256098 (time=8003.06), 0.00539146 s/step
# Meep progress: 8021.34375/10000.0 = 80.2% done in 1858.5s, 458.4s to go
# on time step 256796 (time=8024.88), 0.00573464 s/step
# Meep progress: 8042.84375/10000.0 = 80.4% done in 1862.5s, 453.2s to go
# on time step 257463 (time=8045.72), 0.00600354 s/step
# Meep progress: 8065.0625/10000.0 = 80.7% done in 1866.5s, 447.8s to go
# on time step 258155 (time=8067.34), 0.00578293 s/step
# Meep progress: 8087.75/10000.0 = 80.9% done in 1870.5s, 442.3s to go
# on time step 258903 (time=8090.72), 0.00534974 s/step
# Meep progress: 8112.1875/10000.0 = 81.1% done in 1874.5s, 436.2s to go
# on time step 259692 (time=8115.38), 0.00507317 s/step
# Meep progress: 8135.90625/10000.0 = 81.4% done in 1878.5s, 430.4s to go
# on time step 260462 (time=8139.44), 0.00519647 s/step
# Meep progress: 8158.09375/10000.0 = 81.6% done in 1882.5s, 425.0s to go
# on time step 261176 (time=8161.75), 0.00560227 s/step
# Meep progress: 8183.96875/10000.0 = 81.8% done in 1886.5s, 418.6s to go
# on time step 262001 (time=8187.53), 0.00484903 s/step
# Meep progress: 8207.96875/10000.0 = 82.1% done in 1890.5s, 412.7s to go
# on time step 262758 (time=8211.19), 0.00528805 s/step
# Meep progress: 8231.78125/10000.0 = 82.3% done in 1894.5s, 406.9s to go
# on time step 263534 (time=8235.44), 0.00515798 s/step
# Meep progress: 8256.46875/10000.0 = 82.6% done in 1898.5s, 400.9s to go
# on time step 264311 (time=8259.72), 0.00515081 s/step
# Meep progress: 8279.28125/10000.0 = 82.8% done in 1902.5s, 395.4s to go
# on time step 265051 (time=8282.84), 0.00540564 s/step
# Meep progress: 8303.59375/10000.0 = 83.0% done in 1906.5s, 389.5s to go
# on time step 265818 (time=8306.81), 0.00522275 s/step
# Meep progress: 8325.34375/10000.0 = 83.3% done in 1910.5s, 384.3s to go
# on time step 266520 (time=8328.75), 0.00569986 s/step
# Meep progress: 8349.8125/10000.0 = 83.5% done in 1914.5s, 378.4s to go
# on time step 267308 (time=8353.38), 0.00507729 s/step
# Meep progress: 8373.6875/10000.0 = 83.7% done in 1918.5s, 372.6s to go
# on time step 268062 (time=8376.94), 0.00530629 s/step
# Meep progress: 8397.5/10000.0 = 84.0% done in 1922.5s, 366.9s to go
# on time step 268832 (time=8401), 0.00519545 s/step
# Meep progress: 8421.96875/10000.0 = 84.2% done in 1926.5s, 361.0s to go
# on time step 269603 (time=8425.09), 0.00519133 s/step
# Meep progress: 8445.5/10000.0 = 84.5% done in 1930.5s, 355.3s to go
# on time step 270364 (time=8448.88), 0.00525774 s/step
# Meep progress: 8469.03125/10000.0 = 84.7% done in 1934.5s, 349.7s to go
# on time step 271120 (time=8472.5), 0.00529257 s/step
# Meep progress: 8492.34375/10000.0 = 84.9% done in 1938.5s, 344.1s to go
# on time step 271835 (time=8494.84), 0.00559673 s/step
# Meep progress: 8514.9375/10000.0 = 85.1% done in 1942.5s, 338.8s to go
# on time step 272578 (time=8518.06), 0.00538398 s/step
# Meep progress: 8537.3125/10000.0 = 85.4% done in 1946.5s, 333.5s to go
# on time step 273294 (time=8540.44), 0.0055912 s/step
# Meep progress: 8561.375/10000.0 = 85.6% done in 1950.5s, 327.8s to go
# on time step 274073 (time=8564.78), 0.00513597 s/step
# Meep progress: 8584.6875/10000.0 = 85.8% done in 1954.5s, 322.2s to go
# on time step 274821 (time=8588.16), 0.00535528 s/step
# Meep progress: 8608.6875/10000.0 = 86.1% done in 1958.5s, 316.5s to go
# on time step 275583 (time=8611.97), 0.00525364 s/step
# Meep progress: 8633.9375/10000.0 = 86.3% done in 1962.5s, 310.5s to go
# on time step 276393 (time=8637.28), 0.0049419 s/step
# Meep progress: 8657.9375/10000.0 = 86.6% done in 1966.6s, 304.8s to go
# on time step 277160 (time=8661.25), 0.00521526 s/step
# Meep progress: 8682.25/10000.0 = 86.8% done in 1970.6s, 299.1s to go
# on time step 277934 (time=8685.44), 0.00517003 s/step
# Meep progress: 8705.78125/10000.0 = 87.1% done in 1974.6s, 293.5s to go
# on time step 278700 (time=8709.38), 0.00522569 s/step
# Meep progress: 8730.4375/10000.0 = 87.3% done in 1978.6s, 287.7s to go
# on time step 279478 (time=8733.69), 0.00514601 s/step
# Meep progress: 8754.0625/10000.0 = 87.5% done in 1982.6s, 282.2s to go
# on time step 280238 (time=8757.44), 0.00526477 s/step
# Meep progress: 8779.09375/10000.0 = 87.8% done in 1986.6s, 276.3s to go
# on time step 281022 (time=8781.94), 0.00510219 s/step
# Meep progress: 8803.6875/10000.0 = 88.0% done in 1990.6s, 270.5s to go
# on time step 281830 (time=8807.19), 0.00495362 s/step
# Meep progress: 8828.59375/10000.0 = 88.3% done in 1994.6s, 264.6s to go
# on time step 282626 (time=8832.06), 0.00502976 s/step
# Meep progress: 8853.03125/10000.0 = 88.5% done in 1998.6s, 258.9s to go
# on time step 283406 (time=8856.44), 0.00513363 s/step
# Meep progress: 8878.03125/10000.0 = 88.8% done in 2002.6s, 253.1s to go
# on time step 284210 (time=8881.56), 0.00497777 s/step
# Meep progress: 8901.84375/10000.0 = 89.0% done in 2006.6s, 247.5s to go
# on time step 284977 (time=8905.53), 0.00521817 s/step
# Meep progress: 8925.84375/10000.0 = 89.3% done in 2010.6s, 242.0s to go
# on time step 285724 (time=8928.88), 0.00535878 s/step
# Meep progress: 8949.90625/10000.0 = 89.5% done in 2014.6s, 236.4s to go
# on time step 286508 (time=8953.38), 0.00510612 s/step
# Meep progress: 8974.875/10000.0 = 89.7% done in 2018.6s, 230.6s to go
# on time step 287309 (time=8978.41), 0.00499579 s/step
# Meep progress: 8992.4375/10000.0 = 89.9% done in 2022.6s, 226.6s to go
# on time step 287823 (time=8994.47), 0.00778674 s/step
# Meep progress: 9011.03125/10000.0 = 90.1% done in 2026.6s, 222.4s to go
# on time step 288413 (time=9012.91), 0.00679281 s/step
# Meep progress: 9032.78125/10000.0 = 90.3% done in 2030.6s, 217.4s to go
# on time step 289152 (time=9036), 0.00542031 s/step
# Meep progress: 9052.5/10000.0 = 90.5% done in 2034.6s, 213.0s to go
# on time step 289781 (time=9055.66), 0.0063593 s/step
# Meep progress: 9073.3125/10000.0 = 90.7% done in 2038.6s, 208.2s to go
# on time step 290412 (time=9075.38), 0.0063461 s/step
# Meep progress: 9090.8125/10000.0 = 90.9% done in 2042.6s, 204.3s to go
# on time step 290967 (time=9092.72), 0.00720984 s/step
# Meep progress: 9107.75/10000.0 = 91.1% done in 2046.6s, 200.5s to go
# on time step 291551 (time=9110.97), 0.00684946 s/step
# Meep progress: 9129.25/10000.0 = 91.3% done in 2050.6s, 195.6s to go
# on time step 292224 (time=9132), 0.00595453 s/step
# Meep progress: 9150.375/10000.0 = 91.5% done in 2054.6s, 190.8s to go
# on time step 292910 (time=9153.44), 0.00583264 s/step
# Meep progress: 9171.8125/10000.0 = 91.7% done in 2058.6s, 185.9s to go
# on time step 293584 (time=9174.5), 0.00593551 s/step
# Meep progress: 9193.09375/10000.0 = 91.9% done in 2062.6s, 181.0s to go
# on time step 294267 (time=9195.84), 0.00585869 s/step
# Meep progress: 9215.28125/10000.0 = 92.2% done in 2066.6s, 176.0s to go
# on time step 294991 (time=9218.47), 0.00553181 s/step
# Meep progress: 9233.40625/10000.0 = 92.3% done in 2070.6s, 171.9s to go
# on time step 295551 (time=9235.97), 0.00714519 s/step
# Meep progress: 9253.5625/10000.0 = 92.5% done in 2074.6s, 167.3s to go
# on time step 296184 (time=9255.75), 0.00632567 s/step
# Meep progress: 9275.34375/10000.0 = 92.8% done in 2078.6s, 162.4s to go
# on time step 296916 (time=9278.62), 0.00546991 s/step
# Meep progress: 9295.40625/10000.0 = 93.0% done in 2082.6s, 157.9s to go
# on time step 297546 (time=9298.31), 0.00635509 s/step
# Meep progress: 9314.5/10000.0 = 93.1% done in 2086.6s, 153.6s to go
# on time step 298148 (time=9317.12), 0.00666064 s/step
# Meep progress: 9333.9375/10000.0 = 93.3% done in 2090.6s, 149.2s to go
# on time step 298772 (time=9336.62), 0.00641175 s/step
# Meep progress: 9357.03125/10000.0 = 93.6% done in 2094.6s, 143.9s to go
# on time step 299539 (time=9360.59), 0.00522385 s/step
# Meep progress: 9376.25/10000.0 = 93.8% done in 2098.7s, 139.6s to go
# on time step 300125 (time=9378.91), 0.00683207 s/step
# Meep progress: 9395.0/10000.0 = 94.0% done in 2102.7s, 135.4s to go
# on time step 300756 (time=9398.62), 0.00634563 s/step
# Meep progress: 9415.25/10000.0 = 94.2% done in 2106.7s, 130.8s to go
# on time step 301399 (time=9418.72), 0.00622287 s/step
# Meep progress: 9437.15625/10000.0 = 94.4% done in 2110.7s, 125.9s to go
# on time step 302071 (time=9439.72), 0.00596084 s/step
# Meep progress: 9456.875/10000.0 = 94.6% done in 2114.7s, 121.4s to go
# on time step 302732 (time=9460.38), 0.00605307 s/step
# Meep progress: 9476.34375/10000.0 = 94.8% done in 2118.7s, 117.1s to go
# on time step 303355 (time=9479.84), 0.00642844 s/step
# Meep progress: 9496.375/10000.0 = 95.0% done in 2122.7s, 112.6s to go
# on time step 303966 (time=9498.94), 0.00655367 s/step
# Meep progress: 9514.9375/10000.0 = 95.1% done in 2126.7s, 108.4s to go
# on time step 304558 (time=9517.44), 0.00676532 s/step
# Meep progress: 9528.8125/10000.0 = 95.3% done in 2130.7s, 105.4s to go
# on time step 304976 (time=9530.5), 0.00960284 s/step
# Meep progress: 9544.59375/10000.0 = 95.4% done in 2134.7s, 101.9s to go
# on time step 305490 (time=9546.56), 0.0077893 s/step
# Meep progress: 9562.4375/10000.0 = 95.6% done in 2138.7s, 97.9s to go
# on time step 306089 (time=9565.28), 0.00668817 s/step
# Meep progress: 9582.625/10000.0 = 95.8% done in 2142.7s, 93.3s to go
# on time step 306747 (time=9585.84), 0.00607907 s/step
# Meep progress: 9599.40625/10000.0 = 96.0% done in 2146.7s, 89.6s to go
# on time step 307271 (time=9602.22), 0.00763604 s/step
# Meep progress: 9614.65625/10000.0 = 96.1% done in 2150.7s, 86.2s to go
# on time step 307738 (time=9616.81), 0.00856552 s/step
# Meep progress: 9632.9375/10000.0 = 96.3% done in 2154.7s, 82.1s to go
# on time step 308352 (time=9636), 0.00651857 s/step
# Meep progress: 9650.40625/10000.0 = 96.5% done in 2158.7s, 78.2s to go
# on time step 308908 (time=9653.38), 0.00719866 s/step
# Meep progress: 9667.78125/10000.0 = 96.7% done in 2162.7s, 74.3s to go
# on time step 309483 (time=9671.34), 0.00696221 s/step
# Meep progress: 9685.6875/10000.0 = 96.9% done in 2166.7s, 70.3s to go
# on time step 310038 (time=9688.69), 0.00720911 s/step
# Meep progress: 9705.34375/10000.0 = 97.1% done in 2170.7s, 65.9s to go
# on time step 310674 (time=9708.56), 0.0062976 s/step
# Meep progress: 9724.53125/10000.0 = 97.2% done in 2174.7s, 61.6s to go
# on time step 311273 (time=9727.28), 0.00668001 s/step
# Meep progress: 9740.90625/10000.0 = 97.4% done in 2178.7s, 58.0s to go
# on time step 311793 (time=9743.53), 0.00769875 s/step
# Meep progress: 9755.59375/10000.0 = 97.6% done in 2182.7s, 54.7s to go
# on time step 312303 (time=9759.47), 0.00784835 s/step
# Meep progress: 9774.59375/10000.0 = 97.7% done in 2186.7s, 50.4s to go
# on time step 312881 (time=9777.53), 0.00692267 s/step
# Meep progress: 9794.0/10000.0 = 97.9% done in 2190.7s, 46.1s to go
# on time step 313497 (time=9796.78), 0.0065066 s/step
# Meep progress: 9811.59375/10000.0 = 98.1% done in 2194.8s, 42.1s to go
# on time step 314063 (time=9814.47), 0.00707837 s/step
# Meep progress: 9825.15625/10000.0 = 98.3% done in 2198.8s, 39.1s to go
# on time step 314490 (time=9827.81), 0.00937265 s/step
# Meep progress: 9842.15625/10000.0 = 98.4% done in 2202.8s, 35.3s to go
# on time step 315037 (time=9844.91), 0.00732366 s/step
# Meep progress: 9860.625/10000.0 = 98.6% done in 2206.8s, 31.2s to go
# on time step 315635 (time=9863.59), 0.00669234 s/step
# Meep progress: 9878.09375/10000.0 = 98.8% done in 2210.8s, 27.3s to go
# on time step 316184 (time=9880.75), 0.00729171 s/step
# Meep progress: 9895.21875/10000.0 = 99.0% done in 2214.8s, 23.5s to go
# on time step 316740 (time=9898.12), 0.00719463 s/step
# Meep progress: 9912.03125/10000.0 = 99.1% done in 2218.8s, 19.7s to go
# on time step 317272 (time=9914.75), 0.00752738 s/step
# Meep progress: 9929.4375/10000.0 = 99.3% done in 2222.8s, 15.8s to go
# on time step 317826 (time=9932.06), 0.00723427 s/step
# Meep progress: 9944.84375/10000.0 = 99.4% done in 2226.8s, 12.4s to go
# on time step 318337 (time=9948.03), 0.00783062 s/step
# Meep progress: 9963.0/10000.0 = 99.6% done in 2230.8s, 8.3s to go
# on time step 318926 (time=9966.44), 0.00680034 s/step
# Meep progress: 9981.40625/10000.0 = 99.8% done in 2234.8s, 4.2s to go
# on time step 319504 (time=9984.5), 0.00692921 s/step
# Meep progress: 9998.875/10000.0 = 100.0% done in 2238.8s, 0.3s to go
# run 0 finished at t = 10000.0 (320000 timesteps)

# %%
plt.plot(freqs_wo,psd_out_wo)
plt.grid(True)

# %%
plt.plot(freqs_w,psd_out_w)
plt.grid(True)

# %%
plt.plot(np.array(freqs_w), np.array(psd_out_w)/np.array(psd_out_wo))
plt.xlabel("Frequency[c/a]")
plt.ylabel("Transmittance[c/a]")
plt.yscale('log')
plt.grid(True)

# %%
plt.plot(np.array(freqs_w), np.array(psd_out_w)/np.array(psd_out_wo))
plt.xlabel("Frequency[c/a]")
plt.ylabel("Transmittance[c/a]")
plt.yscale('log')
plt.grid(True)

# %%
a = 470
c_const = 299792458

freqs = a / np.array(freqs_w)
#freqs
plt.plot(freqs, np.array(psd_out_w)/np.array(psd_out_wo))
plt.scatter(freqs, np.array(psd_out_w)/np.array(psd_out_wo))
plt.xlabel("Frequency[c/a]")
plt.ylabel("Transmittance[c/a]")
#plt.xlim([0.28,0.30])
plt.yscale('log')
plt.grid(True)

# %%
freqs = a / np.array(freqs_w)
#freqs
plt.plot(freqs, np.array(psd_out_w)/np.array(psd_out_wo))
plt.scatter(freqs, np.array(psd_out_w)/np.array(psd_out_wo))
plt.xlabel("Frequency[c/a]")
plt.ylabel("Transmittance[c/a]")
plt.xlim([1450,1550])
plt.yscale('log')
plt.ylim([1e-8,1e-5])
plt.grid(True)

# %%
df = pd.DataFrame()
df["wavelength"] = freqs
df["transmittance"] = np.array(psd_out_w)/np.array(psd_out_wo)
df.to_csv("210111_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d085_km005.csv")

# %%
df
# Out:
#       wavelength  transmittance
# 0    2350.000000       0.035522
# 1    2345.300000       0.033173
# 2    2340.618762       0.030877
# 3    2335.956175       0.028562
# 4    2331.312127       0.026239
# ..           ...            ...
# 495  1179.728370       0.019919
# 496  1178.542714       0.020704
# 497  1177.359438       0.021691
# 498  1176.178536       0.023108
# 499  1175.000000       0.025021
#
# [500 rows x 2 columns]
