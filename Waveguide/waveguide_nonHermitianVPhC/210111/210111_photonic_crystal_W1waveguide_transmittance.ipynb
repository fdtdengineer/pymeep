# %% [markdown]
# https://github.com/NanoComp/meep/blob/master/python/examples/straight-waveguide.ipynb
#
# https://stackoverflow.com/questions/29454002/filenotfounderror-errno-2-no-such-file-or-directory-ffmpeg

# %%
import math
import meep as mp
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# Out:
# Using MPI version 3.1, 1 processes

# %%
def phc_trans(PhC = True, lengthPhC = 100, decay_check=0, T_decay=500):
    """
    <変数の説明>
    PhC...PhC(フォトニック決勝)を配置するかどうか。Falseで直線導波路
    lengthPhC...PhC導波方向の長さ
    widthPhC...PhC垂直方向の幅。PMLと被ってるので適当。
    ConnectionWaveguide...PhCに接続するSi導波路(棒の部分)の長さ
    wgi...導波路の幅を調整する。1で丸穴一個分空いてることを意味する。0.7とかにすると狭くなってバンドの形が変わる、っていうのはDaii君の研究とも絡む。
    r...穴の半径。ふつうはa/4くらい。meepだと格子定数は1で固定だから、格子定数との比を入力すればOK
    n_eff...屈折率。2次元だと2.5~2.7くらいにしておくと3次元のSi系(n_Si=3.48)と結果が近くなる。違う材料を使うときは要調整、通常はdefaultで大丈夫。
    fcen...入力光（ガウシアンビーム）の中心周波数。知りたいPhCバンドの周波数近くに設定する
    df...入力光（ガウシアンビーム）の半値幅（で合ってる？）
    nfreq...入力光（ガウシアンビーム）のきめ細かさ
    resolution...メッシュの細かさ。2^nにすると計算が軽くなるらしい。
    T_dacay...反復計算数。小さいと誤差が増え、大きいと時間がかかる。sim.run(until_after_sources=...)で計算時間を見積もってから変えるとよさそう
    decay_check...解の収束をどこで判定するか、位置を指定。defaultでOK

    <備考>
    ・meepでは格子定数aはパラメータに含まれないので設定不要
    　誘電体を使うときは入力するらしい（スケール依存性が出るから）
    ・THzやnmは使用せず、すべて規格化周波数で入力する (周波数はωa/2πcで直す)
    """
    ##### setting of parameters #####
    widthPhC = 10
    ConnectionWaveguide = 5
    wgi = 1
    r = 1/4
    n_eff = 2.6
    fcen = 0.3 
    df = 0.1
    nfreq = 500 # number of frequencies at which to compute flux
    resolution = 16
    
    #####
    length = lengthPhC + 2*ConnectionWaveguide
    width = widthPhC
    Nx = int(lengthPhC)
    Ny = int(widthPhC)
    eps = n_eff**2

    # settings of imaginary part
    normalized_frequency = 0.3
    extinction_coefficient = 0.0

    ##### settings of geometry #####
    # initialization
    cell = mp.Vector3(length,width*np.sqrt(3),0)

    # Si waveguide
    waveguide = mp.Block(mp.Vector3(mp.inf,wgi*np.sqrt(3),mp.inf),
                         center=mp.Vector3(),
                         material=mp.Medium(epsilon=eps))
    geometry = [waveguide]

    # PhC
    if PhC:
        # slab
        """
        blk = mp.Block(mp.Vector3(lengthPhC,widthPhC*np.sqrt(3),mp.inf),
                             center=mp.Vector3(),
                             material=mp.Medium(epsilon=eps))
        """
        blk = mp.Block(mp.Vector3(lengthPhC,widthPhC*np.sqrt(3),mp.inf),
                             center=mp.Vector3(),
                             material=mp.Medium(epsilon=eps, D_conductivity=2*np.pi*normalized_frequency*extinction_coefficient / eps))

        geometry.append(blk)
        
        # arrange air-holes
        for j in range(Ny):
            for i in range(Nx+1):
                shift_y = np.sqrt(3)
                geometry.append(mp.Cylinder(r, center=mp.Vector3(i-Nx/2, wgi*np.sqrt(3)/2 + shift_y*j)))
                geometry.append(mp.Cylinder(r, center=mp.Vector3(i-Nx/2, -(wgi*np.sqrt(3)/2 + shift_y*j))))

                geometry.append(mp.Cylinder(r, center=mp.Vector3(i-(Nx+1)/2, wgi*np.sqrt(3)/2 + shift_y*(j+1/2))))
                geometry.append(mp.Cylinder(r, center=mp.Vector3(i-(Nx+1)/2, -(wgi*np.sqrt(3)/2 + shift_y*(j+1/2)))))
                #geometry.append(mp.Cylinder(r, center=mp.Vector3(i-N/2,-wgi*np.sqrt(3)/2)))
    
    # Gaussian
    sources = [mp.Source(mp.GaussianSource(fcen, fwidth=df),
                         component=mp.Hz,
                         center=mp.Vector3(-length/2 +1,0),
                         size=mp.Vector3(0,wgi*np.sqrt(3)))
              ]

    # PML
    pml_layers = [mp.PML(1.0)]

    # z-symmetry (上下対称なら計算が軽くなる。対称性が無いなら消す)
    sym = [mp.Mirror(mp.Y, phase=-1)]
    

    ####
    sim = mp.Simulation(cell_size=cell,
                        boundary_layers=pml_layers,
                        geometry=geometry,
                        sources=sources,
                        symmetries=sym,
                        resolution=resolution)

    #tran_in = mp.FluxRegion(center=mp.Vector3(-lengthPhC/2-1,0),size=mp.Vector3(0, 2*wgi))
    tran_out = mp.FluxRegion(center=mp.Vector3(length/2-3/2,0),size=mp.Vector3(0, 2*wgi))
    #trans_in = sim.add_flux(fcen, df, nfreq, tran_in)
    trans_out = sim.add_flux(fcen, df, nfreq, tran_out)

    # show geometry
    # %matplotlib inline
    f = plt.figure(dpi=150)
    sim.plot2D(ax=f.gca())
    plt.show()    

    #sim.run(until_after_sources=mp.stop_when_fields_decayed(50, mp.Hz, mp.Vector3(decay_check), 1e-3))
    sim.run(until=T_decay)

    freqs = mp.get_flux_freqs(trans_out)
    #psd_in = mp.get_fluxes(trans_in)
    psd_out = mp.get_fluxes(trans_out)

    return freqs, psd_out

# %%
freqs_wo, psd_out_wo = phc_trans(PhC = False, lengthPhC = 20, decay_check=10, T_decay=500)
freqs_w,  psd_out_w  = phc_trans(PhC = True, lengthPhC = 40, decay_check=20, T_decay=1000)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.00203896 s
# Working in 2D dimensions.
# Computational cell is 30 x 17.3125 x 0 with resolution 16
#      block, center = (0,0,0)
#           size (1e+20,1.73205,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (6.76,6.76,6.76)
# time for set_epsilon = 0.125539 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=500.0)
# Meep progress: 133.625/500.0 = 26.7% done in 4.0s, 11.0s to go
# on time step 4281 (time=133.781), 0.000934434 s/step
# Meep progress: 255.125/500.0 = 51.0% done in 8.0s, 7.7s to go
# on time step 8169 (time=255.281), 0.00102944 s/step
# Meep progress: 372.78125/500.0 = 74.6% done in 12.0s, 4.1s to go
# on time step 11941 (time=373.156), 0.00106052 s/step
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# run 0 finished at t = 500.0 (16000 timesteps)
# -----------
# Initializing structure...
# Padding y to even number of grid points.
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.0268011 s
# Working in 2D dimensions.
# Computational cell is 50 x 17.3125 x 0 with resolution 16
#      block, center = (0,0,0)
#           size (1e+20,1.73205,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (6.76,6.76,6.76)
#      block, center = (0,0,0)
#           size (40,17.3205,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (6.76,6.76,6.76)
#      cylinder, center = (-20,0.866025,0)
#           radius 0.25, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-20,-0.866025,0)
#           radius 0.25, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-20.5,1.73205,0)
#           radius 0.25, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-20.5,-1.73205,0)
#           radius 0.25, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-19,0.866025,0)
#           radius 0.25, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-19,-0.866025,0)
#           radius 0.25, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-19.5,1.73205,0)
#           radius 0.25, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      cylinder, center = (-19.5,-1.73205,0)
#           radius 0.25, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1,1,1)
#      ...(+ 1632 objects not shown)...
# time for set_epsilon = 2.52573 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=1000.0)
# Meep progress: 51.34375/1000.0 = 5.1% done in 4.0s, 73.9s to go
# on time step 1647 (time=51.4688), 0.00242962 s/step
# Meep progress: 110.34375/1000.0 = 11.0% done in 8.0s, 64.5s to go
# on time step 3536 (time=110.5), 0.0021181 s/step
# Meep progress: 169.0/1000.0 = 16.9% done in 12.0s, 59.0s to go
# on time step 5414 (time=169.188), 0.00213089 s/step
# Meep progress: 227.1875/1000.0 = 22.7% done in 16.0s, 54.4s to go
# on time step 7277 (time=227.406), 0.00214797 s/step
# Meep progress: 286.03125/1000.0 = 28.6% done in 20.0s, 49.9s to go
# on time step 9160 (time=286.25), 0.00212564 s/step
# Meep progress: 344.46875/1000.0 = 34.4% done in 24.0s, 45.7s to go
# on time step 11031 (time=344.719), 0.00213831 s/step
# Meep progress: 402.9375/1000.0 = 40.3% done in 28.0s, 41.5s to go
# on time step 12901 (time=403.156), 0.00213947 s/step
# Meep progress: 460.59375/1000.0 = 46.1% done in 32.0s, 37.5s to go
# on time step 14747 (time=460.844), 0.00216755 s/step
# Meep progress: 519.34375/1000.0 = 51.9% done in 36.0s, 33.3s to go
# on time step 16628 (time=519.625), 0.00212683 s/step
# Meep progress: 578.09375/1000.0 = 57.8% done in 40.0s, 29.2s to go
# on time step 18509 (time=578.406), 0.00212711 s/step
# Meep progress: 636.90625/1000.0 = 63.7% done in 44.0s, 25.1s to go
# on time step 20390 (time=637.188), 0.00212675 s/step
# Meep progress: 694.71875/1000.0 = 69.5% done in 48.0s, 21.1s to go
# on time step 22242 (time=695.062), 0.00215999 s/step
# Meep progress: 752.625/1000.0 = 75.3% done in 52.0s, 17.1s to go
# on time step 24094 (time=752.938), 0.00215988 s/step
# Meep progress: 811.09375/1000.0 = 81.1% done in 56.0s, 13.0s to go
# on time step 25965 (time=811.406), 0.0021391 s/step
# Meep progress: 869.3125/1000.0 = 86.9% done in 60.0s, 9.0s to go
# on time step 27832 (time=869.75), 0.00214265 s/step
# Meep progress: 927.96875/1000.0 = 92.8% done in 64.0s, 5.0s to go
# on time step 29708 (time=928.375), 0.0021331 s/step
# Meep progress: 986.46875/1000.0 = 98.6% done in 68.0s, 0.9s to go
# on time step 31581 (time=986.906), 0.00213655 s/step
# run 0 finished at t = 1000.0 (32000 timesteps)

# %%
plt.plot(freqs_wo,psd_out_wo)
plt.grid(True)

# %%
plt.plot(freqs_w,psd_out_w)
plt.grid(True)

# %%
plt.plot(np.array(freqs_w), np.array(psd_out_w)/np.array(psd_out_wo))
plt.xlabel("Frequency[c/a]")
plt.ylabel("Transmittance[c/a]")
plt.yscale('log')
plt.grid(True)

# %%
plt.plot(np.array(freqs_w), np.array(psd_out_w)/np.array(psd_out_wo))
plt.xlabel("Frequency[c/a]")
plt.ylabel("Transmittance[c/a]")
plt.yscale('log')
plt.grid(True)

# %%
a = 400
c_const = 299792458

freqs = a / np.array(freqs_w)
#freqs
plt.plot(freqs, np.array(psd_out_w)/np.array(psd_out_wo))
plt.scatter(freqs, np.array(psd_out_w)/np.array(psd_out_wo))
plt.xlabel("Frequency[c/a]")
plt.ylabel("Transmittance[c/a]")
#plt.xlim([0.28,0.30])
plt.yscale('log')
plt.grid(True)

# %%
a = 400
c_const = 299792458

freqs = a / np.array(freqs_w)
#freqs
plt.plot(freqs, np.array(psd_out_w)/np.array(psd_out_wo))
plt.scatter(freqs, np.array(psd_out_w)/np.array(psd_out_wo))
plt.xlabel("Frequency[c/a]")
plt.ylabel("Transmittance[c/a]")
plt.xlim([1450,1550])
plt.yscale('log')
plt.grid(True)

# %%
df = pd.DataFrame()
df["wavelength"] = freqs
df["transmittance"] = np.array(psd_out_w)/np.array(psd_out_wo)
df.to_csv("result.csv")
