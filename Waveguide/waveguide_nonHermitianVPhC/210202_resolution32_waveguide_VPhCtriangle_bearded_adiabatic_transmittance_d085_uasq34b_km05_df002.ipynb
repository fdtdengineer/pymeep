# %% [markdown]
# https://github.com/NanoComp/meep/blob/master/python/examples/straight-waveguide.ipynb
#
# https://stackoverflow.com/questions/29454002/filenotfounderror-errno-2-no-such-file-or-directory-ffmpeg

# %%
import math
import meep as mp
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from matplotlib import rc
rc('text', usetex=False)
#plt.rcParams['font.family'] = 'Times New Roman'#使用するフォント
#plt.rcParams['mathtext.fontset'] = 'stix' # math fontの設定
plt.rcParams['font.family']= 'sans-serif'
plt.rcParams['font.sans-serif'] = ['Arial']
plt.rcParams["font.size"] = 15 # 全体のフォントサイズが変更されます。
plt.rcParams['xtick.direction'] = 'in'#x軸の目盛線が内向き('in')か外向き('out')か双方向か('inout')
plt.rcParams['ytick.direction'] = 'in'#y軸の目盛線が内向き('in')か外向き('out')か双方向か('inout')

# %%
def eps_to_eps(eps_A_r,eps_A_i):
    eps_A = eps_A_r + 1.j*eps_A_i
    eps_Ainv = 1 / eps_A

    eps_Ainv_r = eps_Ainv.real
    eps_Ainv_i = -eps_Ainv.imag

    #print(eps_Ainv_r, eps_Ainv_i)

    eps_B_r = eps_A_r + 1/eps_Ainv_r * (eps_Ainv_i**2) / (eps_Ainv_r**2 + eps_Ainv_i**2)
    eps_B_i = 0

    eps_B = eps_B_r + 1.j*eps_B_i
    eps_Binv = 1 / eps_B

    eps_Binv_r = eps_Binv.real
    eps_Binv_i = -eps_Binv.imag

    #print(eps_Binv_r, eps_Binv_i)
    return eps_B_r, eps_B_i

# %%
def phc_trans(PhC = True, lengthPhC = 100, decay_check=0, T_decay=500):
    """
    <変数の説明>
    PhC...PhC(フォトニック決勝)を配置するかどうか。Falseで直線導波路
    lengthPhC...PhC導波方向の長さ
    widthPhC...PhC垂直方向の幅。PMLと被ってるので適当。
    ConnectionWaveguide...PhCに接続するSi導波路(棒の部分)の長さ
    wgi...導波路の幅を調整する。1で丸穴一個分空いてることを意味する。0.7とかにすると狭くなってバンドの形が変わる、っていうのはDaii君の研究とも絡む。
    r...穴の半径。ふつうはa/4くらい。meepだと格子定数は1で固定だから、格子定数との比を入力すればOK
    n_eff...屈折率。2次元だと2.5~2.7くらいにしておくと3次元のSi系(n_Si=3.48)と結果が近くなる。違う材料を使うときは要調整、通常はdefaultで大丈夫。
    fcen...入力光（ガウシアンビーム）の中心周波数。知りたいPhCバンドの周波数近くに設定する
    df...入力光（ガウシアンビーム）の半値幅（で合ってる？）
    nfreq...入力光（ガウシアンビーム）のきめ細かさ
    resolution...メッシュの細かさ。2^nにすると計算が軽くなるらしい。
    T_dacay...反復計算数。小さいと誤差が増え、大きいと時間がかかる。sim.run(until_after_sources=...)で計算時間を見積もってから変えるとよさそう
    decay_check...解の収束をどこで判定するか、位置を指定。defaultでOK

    <備考>
    ・meepでは格子定数aはパラメータに含まれないので設定不要
    　誘電体を使うときは入力するらしい（スケール依存性が出るから）
    ・THzやnmは使用せず、すべて規格化周波数で入力する (周波数はωa/2πcで直す)
    """
    ##### setting of parameters #####
    a = 1 # CADに移行しやすいように予め設定しておく
    widthPhC = 10
    ConnectionWaveguide = 5
    wgi = 1/2 #/np.sqrt(3)/2
    whetero = 1/np.sqrt(3)/4
    r = 1/4
    d_0 = 0.85*a
    yshift = -np.sqrt(3)/4*a #1/(np.sqrt(3)) #+ 1/6*np.sqrt(3)/2*d_0

    #n_eff = 2.6

    eps_A_r = 2.6**2
    eps_A_i = 0.5
    eps_B_r = eps_A_r
    eps_B_i = 0

    fcen = 0.31
    df = 0.02
    nfreq = 500 # number of frequencies at which to compute flux
    resolution = 32

    connect = 0
    #####
    length = lengthPhC + 2*ConnectionWaveguide
    width = widthPhC
    Nx = int(lengthPhC)
    Ny = int(widthPhC)

    # settings of imaginary part
    normalized_frequency = 0.3
    #extinction_coefficient = 0.2

    ##### settings of geometry #####
    # initialization
    cell = mp.Vector3(length,width*np.sqrt(3),0)

    # Si waveguide
    waveguide = mp.Block(mp.Vector3(mp.inf,wgi*np.sqrt(3),mp.inf),
                            center=mp.Vector3(),
                            material=mp.Medium(epsilon=eps_B_r))
    geometry = [waveguide]

    # PhC
    if PhC:
        # triangle
        tri_u = [
                mp.Vector3(-np.sqrt(3)/2,-1/2)*d_0/np.sqrt(3),
                mp.Vector3( np.sqrt(3)/2,-1/2)*d_0/np.sqrt(3),
                mp.Vector3(            0,   1)*d_0/np.sqrt(3),
                ]
        tri_d = [
                mp.Vector3(-np.sqrt(3)/2,-1/2)*d_0/np.sqrt(3)*(-1),
                mp.Vector3( np.sqrt(3)/2,-1/2)*d_0/np.sqrt(3)*(-1),
                mp.Vector3(            0,   1)*d_0/np.sqrt(3)*(-1),
                ]

        # slab
        blk_above = mp.Block(mp.Vector3(lengthPhC,widthPhC*np.sqrt(3),mp.inf),
                                center=mp.Vector3(0, widthPhC*np.sqrt(3)/2 - np.sqrt(3)/4 + 0*(yshift + 1/(2*np.sqrt(3))), 0),
                                material=mp.Medium(epsilon=eps_B_r, D_conductivity=2*np.pi*normalized_frequency*eps_B_i / eps_B_r))
        geometry.append(blk_above)
        blk_below = mp.Block(mp.Vector3(lengthPhC,widthPhC*np.sqrt(3),mp.inf),
                                center=mp.Vector3(0,-widthPhC*np.sqrt(3)/2 - np.sqrt(3)/4 + 0*(yshift + 1/(2*np.sqrt(3))), 0),
                                material=mp.Medium(epsilon=eps_A_r, D_conductivity=2*np.pi*normalized_frequency*eps_A_i / eps_A_r))
        geometry.append(blk_below)
        
        # arrange air-holes
        for j in range(Ny):
            for i in range(Nx+1):
                shift_y = np.sqrt(3)
                geometry.append(mp.Prism(tri_d, height = 1, center=mp.Vector3(i-(Nx+1)/2, yshift + 1/(np.sqrt(3)) + shift_y*(j+1/2))))                
                geometry.append(mp.Prism(tri_u, height = 1, center=mp.Vector3(i-(Nx+1)/2, yshift -(1/(np.sqrt(3)) + shift_y*(j+1/2)))))            
                geometry.append(mp.Prism(tri_d, height = 1, center=mp.Vector3(i-Nx/2, yshift +  1/(np.sqrt(3)) + shift_y*j )))

            if j == 0:
                for i in range(connect,Nx+1-connect):
                    geometry.append(mp.Prism(tri_u, height = 1, center=mp.Vector3(i-Nx/2, yshift - (1/(np.sqrt(3)) + shift_y*j))))
            else:
                for i in range(Nx+1):
                    geometry.append(mp.Prism(tri_u, height = 1, center=mp.Vector3(i-Nx/2, yshift - (1/(np.sqrt(3)) + shift_y*j))))
                    
        for i in range(1,Nx+1):
            geometry.append(mp.Prism(tri_u, height = 1, center=mp.Vector3(i-(Nx+1)/2, yshift - (1/(np.sqrt(3)) + shift_y*(-1/2)))))
        #geometry.append(mp.Prism(tri_d, height = 1, center=mp.Vector3(1, 0)))


                #geometry.append(mp.Cylinder(r, center=mp.Vector3(i-N/2,-wgi*np.sqrt(3)/2)))

    # Gaussian
    sources = [mp.Source(mp.GaussianSource(fcen, fwidth=df),
                            component=mp.Hz,
                            center=mp.Vector3(-length/2 +1,0),
                            size=mp.Vector3(0,wgi*np.sqrt(3)))
                ]

    # PML
    pml_layers = [mp.PML(1.0)]

    # z-symmetry (上下対称なら計算が軽くなる。対称性が無いなら消す)
    #sym = [mp.Mirror(mp.Y, phase=-1)]
    

    ####
    sim = mp.Simulation(cell_size=cell,
                        boundary_layers=pml_layers,
                        geometry=geometry,
                        sources=sources,
                        #symmetries=sym,
                        resolution=resolution)

    #tran_in = mp.FluxRegion(center=mp.Vector3(-lengthPhC/2-1,0),size=mp.Vector3(0, 2*wgi))
    tran_out = mp.FluxRegion(center=mp.Vector3(length/2-3/2,0),size=mp.Vector3(0, 2*wgi))
    #trans_in = sim.add_flux(fcen, df, nfreq, tran_in)
    trans_out = sim.add_flux(fcen, df, nfreq, tran_out)

    # show geometry
    # %matplotlib inline
    f = plt.figure(dpi=500, figsize=(8,16))
    sim.plot2D(ax=f.gca())
    plt.show()    

    #sim.run(until_after_sources=mp.stop_when_fields_decayed(50, mp.Hz, mp.Vector3(decay_check), 1e-3))
    sim.run(until=T_decay)

    freqs = mp.get_flux_freqs(trans_out)
    #psd_in = mp.get_fluxes(trans_in)
    psd_out = mp.get_fluxes(trans_out)

    return freqs, psd_out

# %%
freqs_wo, psd_out_wo = phc_trans(PhC = False, lengthPhC = 20, decay_check=10, T_decay=500)
freqs_w,  psd_out_w  = phc_trans(PhC = True, lengthPhC = 50, decay_check=20, T_decay=10000)
# Out:
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.094244 s
# Working in 2D dimensions.
# Computational cell is 30 x 17.3125 x 0 with resolution 32
#      block, center = (0,0,0)
#           size (1e+20,0.866025,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (6.76,6.76,6.76)
# time for set_epsilon = 0.721109 s
# -----------
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# FloatProgress(value=0.0, description='0% done ', max=500.0)
#  time step 3731 (time=58.2969), 0.0210701 s/step
# Meep progress: 61.40625/500.0 = 12.3% done in 52.1s, 372.1s to go
# on time step 3938 (time=61.5312), 0.0193899 s/step
# Meep progress: 64.515625/500.0 = 12.9% done in 56.1s, 378.7s to go
# on time step 4137 (time=64.6406), 0.0201477 s/step
# Meep progress: 68.046875/500.0 = 13.6% done in 60.1s, 381.6s to go
# on time step 4365 (time=68.2031), 0.0175787 s/step
# Meep progress: 71.46875/500.0 = 14.3% done in 64.1s, 384.4s to go
# on time step 4582 (time=71.5938), 0.0185074 s/step
# Meep progress: 74.734375/500.0 = 14.9% done in 68.1s, 387.7s to go
# on time step 4791 (time=74.8594), 0.0192116 s/step
# Meep progress: 77.921875/500.0 = 15.6% done in 72.1s, 390.7s to go
# on time step 4995 (time=78.0469), 0.0196597 s/step
# Meep progress: 81.125/500.0 = 16.2% done in 76.1s, 393.1s to go
# on time step 5201 (time=81.2656), 0.0195035 s/step
# Meep progress: 84.328125/500.0 = 16.9% done in 80.1s, 395.0s to go
# on time step 5406 (time=84.4688), 0.0195253 s/step
# Meep progress: 87.515625/500.0 = 17.5% done in 84.2s, 396.6s to go
# on time step 5610 (time=87.6562), 0.0196591 s/step
# Meep progress: 90.6875/500.0 = 18.1% done in 88.2s, 397.9s to go
# on time step 5814 (time=90.8438), 0.0196922 s/step
# Meep progress: 93.875/500.0 = 18.8% done in 92.2s, 398.7s to go
# on time step 6018 (time=94.0312), 0.0196298 s/step
# Meep progress: 96.984375/500.0 = 19.4% done in 96.2s, 399.6s to go
# on time step 6216 (time=97.125), 0.0202475 s/step
# Meep progress: 99.78125/500.0 = 20.0% done in 100.2s, 401.9s to go
# on time step 6394 (time=99.9062), 0.022523 s/step
# Meep progress: 102.5/500.0 = 20.5% done in 104.2s, 404.1s to go
# on time step 6569 (time=102.641), 0.0229914 s/step
# Meep progress: 105.375/500.0 = 21.1% done in 108.2s, 405.2s to go
# on time step 6755 (time=105.547), 0.021572 s/step
# Meep progress: 108.421875/500.0 = 21.7% done in 112.2s, 405.3s to go
# on time step 6949 (time=108.578), 0.020657 s/step
# Meep progress: 111.40625/500.0 = 22.3% done in 116.2s, 405.4s to go
# on time step 7141 (time=111.578), 0.0209744 s/step
# Meep progress: 114.421875/500.0 = 22.9% done in 120.2s, 405.2s to go
# on time step 7334 (time=114.594), 0.0207716 s/step
# Meep progress: 117.453125/500.0 = 23.5% done in 124.3s, 404.7s to go
# on time step 7528 (time=117.625), 0.0207048 s/step
# Meep progress: 120.578125/500.0 = 24.1% done in 128.3s, 403.6s to go
# on time step 7728 (time=120.75), 0.0200106 s/step
# Meep progress: 123.71875/500.0 = 24.7% done in 132.3s, 402.4s to go
# on time step 7929 (time=123.891), 0.0199612 s/step
# Meep progress: 126.890625/500.0 = 25.4% done in 136.3s, 400.8s to go
# on time step 8132 (time=127.062), 0.0197551 s/step
# Meep progress: 130.109375/500.0 = 26.0% done in 140.3s, 398.9s to go
# on time step 8338 (time=130.281), 0.0194909 s/step
# Meep progress: 133.28125/500.0 = 26.7% done in 144.3s, 397.1s to go
# on time step 8542 (time=133.469), 0.0196618 s/step
# Meep progress: 136.515625/500.0 = 27.3% done in 148.3s, 394.9s to go
# on time step 8749 (time=136.703), 0.0194034 s/step
# Meep progress: 139.6875/500.0 = 27.9% done in 152.3s, 393.0s to go
# on time step 8952 (time=139.875), 0.0197439 s/step
# Meep progress: 142.765625/500.0 = 28.6% done in 156.3s, 391.2s to go
# on time step 9149 (time=142.953), 0.0203627 s/step
# Meep progress: 145.90625/500.0 = 29.2% done in 160.4s, 389.2s to go
# on time step 9350 (time=146.094), 0.0199184 s/step
# Meep progress: 149.03125/500.0 = 29.8% done in 164.4s, 387.1s to go
# on time step 9550 (time=149.219), 0.0201248 s/step
# Meep progress: 152.0/500.0 = 30.4% done in 168.4s, 385.5s to go
# on time step 9739 (time=152.172), 0.0211823 s/step
# Meep progress: 154.921875/500.0 = 31.0% done in 172.4s, 384.0s to go
# on time step 9927 (time=155.109), 0.0212928 s/step
# Meep progress: 157.90625/500.0 = 31.6% done in 176.4s, 382.1s to go
# on time step 10118 (time=158.094), 0.0210113 s/step
# Meep progress: 160.90625/500.0 = 32.2% done in 180.4s, 380.2s to go
# on time step 10311 (time=161.109), 0.0208264 s/step
# Meep progress: 163.859375/500.0 = 32.8% done in 184.4s, 378.3s to go
# on time step 10500 (time=164.062), 0.0212015 s/step
# Meep progress: 166.796875/500.0 = 33.4% done in 188.4s, 376.4s to go
# on time step 10687 (time=166.984), 0.0214755 s/step
# Meep progress: 169.765625/500.0 = 34.0% done in 192.4s, 374.3s to go
# on time step 10878 (time=169.969), 0.0209795 s/step
# Meep progress: 172.765625/500.0 = 34.6% done in 196.5s, 372.1s to go
# on time step 11071 (time=172.984), 0.0208557 s/step
# Meep progress: 175.78125/500.0 = 35.2% done in 200.5s, 369.8s to go
# on time step 11263 (time=175.984), 0.0209141 s/step
# Meep progress: 178.8125/500.0 = 35.8% done in 204.5s, 367.3s to go
# on time step 11459 (time=179.047), 0.0204642 s/step
# Meep progress: 182.046875/500.0 = 36.4% done in 208.5s, 364.1s to go
# on time step 11666 (time=182.281), 0.0193824 s/step
# Meep progress: 185.28125/500.0 = 37.1% done in 212.5s, 361.0s to go
# on time step 11873 (time=185.516), 0.0194265 s/step
# Meep progress: 188.453125/500.0 = 37.7% done in 216.5s, 357.9s to go
# on time step 12076 (time=188.688), 0.0197589 s/step
# Meep progress: 191.65625/500.0 = 38.3% done in 220.5s, 354.8s to go
# on time step 12282 (time=191.906), 0.0195112 s/step
# Meep progress: 194.84375/500.0 = 39.0% done in 224.5s, 351.7s to go
# on time step 12486 (time=195.094), 0.0196217 s/step
# Meep progress: 197.984375/500.0 = 39.6% done in 228.6s, 348.7s to go
# on time step 12685 (time=198.203), 0.0201612 s/step
# Meep progress: 201.1875/500.0 = 40.2% done in 232.6s, 345.4s to go
# on time step 12891 (time=201.422), 0.0194295 s/step
# Meep progress: 204.375/500.0 = 40.9% done in 236.6s, 342.2s to go
# on time step 13096 (time=204.625), 0.0196085 s/step
# Meep progress: 207.578125/500.0 = 41.5% done in 240.6s, 338.9s to go
# on time step 13302 (time=207.844), 0.0194811 s/step
# Meep progress: 210.765625/500.0 = 42.2% done in 244.6s, 335.7s to go
# on time step 13505 (time=211.016), 0.019758 s/step
# Meep progress: 213.9375/500.0 = 42.8% done in 248.6s, 332.4s to go
# on time step 13709 (time=214.203), 0.0196666 s/step
# Meep progress: 217.125/500.0 = 43.4% done in 252.6s, 329.1s to go
# on time step 13912 (time=217.375), 0.0197677 s/step
# Meep progress: 220.3125/500.0 = 44.1% done in 256.6s, 325.8s to go
# on time step 14116 (time=220.562), 0.0196694 s/step
# Meep progress: 223.484375/500.0 = 44.7% done in 260.6s, 322.5s to go
# on time step 14320 (time=223.75), 0.0197052 s/step
# Meep progress: 226.6875/500.0 = 45.3% done in 264.7s, 319.1s to go
# on time step 14524 (time=226.938), 0.0196119 s/step
# Meep progress: 229.875/500.0 = 46.0% done in 268.7s, 315.7s to go
# on time step 14728 (time=230.125), 0.0196887 s/step
# Meep progress: 233.046875/500.0 = 46.6% done in 272.7s, 312.4s to go
# on time step 14931 (time=233.297), 0.0197933 s/step
# Meep progress: 236.265625/500.0 = 47.3% done in 276.7s, 308.9s to go
# on time step 15137 (time=236.516), 0.0194413 s/step
# Meep progress: 239.46875/500.0 = 47.9% done in 280.7s, 305.4s to go
# on time step 15341 (time=239.703), 0.0196367 s/step
# Meep progress: 242.65625/500.0 = 48.5% done in 284.7s, 302.0s to go
# on time step 15545 (time=242.891), 0.019633 s/step
# Meep progress: 245.6875/500.0 = 49.1% done in 288.7s, 298.9s to go
# on time step 15739 (time=245.922), 0.0206776 s/step
# Meep progress: 248.796875/500.0 = 49.8% done in 292.7s, 295.6s to go
# on time step 15940 (time=249.062), 0.0199559 s/step
# Meep progress: 251.953125/500.0 = 50.4% done in 296.8s, 292.2s to go
# on time step 16141 (time=252.203), 0.0199167 s/step
# Meep progress: 255.078125/500.0 = 51.0% done in 300.8s, 288.8s to go
# on time step 16341 (time=255.328), 0.0201007 s/step
# Meep progress: 257.84375/500.0 = 51.6% done in 304.8s, 286.2s to go
# on time step 16515 (time=258.047), 0.0230828 s/step
# Meep progress: 260.34375/500.0 = 52.1% done in 308.8s, 284.3s to go
# on time step 16677 (time=260.578), 0.0247804 s/step
# Meep progress: 263.234375/500.0 = 52.6% done in 312.8s, 281.4s to go
# on time step 16864 (time=263.5), 0.0214186 s/step
# Meep progress: 266.390625/500.0 = 53.3% done in 316.8s, 277.8s to go
# on time step 17066 (time=266.656), 0.0198829 s/step
# Meep progress: 269.578125/500.0 = 53.9% done in 320.8s, 274.2s to go
# on time step 17270 (time=269.844), 0.0196142 s/step
# Meep progress: 272.734375/500.0 = 54.5% done in 324.8s, 270.7s to go
# on time step 17472 (time=273), 0.0198088 s/step
# Meep progress: 275.953125/500.0 = 55.2% done in 328.8s, 267.0s to go
# on time step 17678 (time=276.219), 0.0195028 s/step
# Meep progress: 279.109375/500.0 = 55.8% done in 332.9s, 263.4s to go
# on time step 17880 (time=279.375), 0.0198262 s/step
# Meep progress: 282.328125/500.0 = 56.5% done in 336.9s, 259.7s to go
# on time step 18086 (time=282.594), 0.0194434 s/step
# Meep progress: 285.5/500.0 = 57.1% done in 340.9s, 256.1s to go
# on time step 18290 (time=285.781), 0.0197105 s/step
# Meep progress: 288.703125/500.0 = 57.7% done in 344.9s, 252.4s to go
# on time step 18495 (time=288.984), 0.0195967 s/step
# Meep progress: 291.859375/500.0 = 58.4% done in 348.9s, 248.8s to go
# on time step 18695 (time=292.109), 0.0200596 s/step
# Meep progress: 295.03125/500.0 = 59.0% done in 352.9s, 245.2s to go
# on time step 18900 (time=295.312), 0.01957 s/step
# Meep progress: 298.171875/500.0 = 59.6% done in 356.9s, 241.6s to go
# on time step 19102 (time=298.469), 0.019821 s/step
# Meep progress: 301.390625/500.0 = 60.3% done in 360.9s, 237.8s to go
# on time step 19308 (time=301.688), 0.0195123 s/step
# Meep progress: 304.578125/500.0 = 60.9% done in 364.9s, 234.1s to go
# on time step 19513 (time=304.891), 0.019636 s/step
# Meep progress: 307.78125/500.0 = 61.6% done in 368.9s, 230.4s to go
# on time step 19718 (time=308.094), 0.0195613 s/step
# Meep progress: 310.90625/500.0 = 62.2% done in 372.9s, 226.8s to go
# on time step 19919 (time=311.234), 0.0199587 s/step
# Meep progress: 314.09375/500.0 = 62.8% done in 376.9s, 223.1s to go
# on time step 20123 (time=314.422), 0.0196528 s/step
# Meep progress: 317.28125/500.0 = 63.5% done in 381.0s, 219.4s to go
# on time step 20326 (time=317.594), 0.019729 s/step
# Meep progress: 320.421875/500.0 = 64.1% done in 385.0s, 215.8s to go
# on time step 20528 (time=320.75), 0.0198538 s/step
# Meep progress: 323.609375/500.0 = 64.7% done in 389.0s, 212.0s to go
# on time step 20733 (time=323.953), 0.0195757 s/step
# Meep progress: 326.8125/500.0 = 65.4% done in 393.0s, 208.3s to go
# on time step 20938 (time=327.156), 0.0195946 s/step
# Meep progress: 330.03125/500.0 = 66.0% done in 397.0s, 204.5s to go
# on time step 21144 (time=330.375), 0.0194407 s/step
# Meep progress: 333.234375/500.0 = 66.6% done in 401.0s, 200.7s to go
# on time step 21349 (time=333.578), 0.0195161 s/step
# Meep progress: 336.203125/500.0 = 67.2% done in 405.0s, 197.3s to go
# on time step 21538 (time=336.531), 0.0212259 s/step
# Meep progress: 339.109375/500.0 = 67.8% done in 409.0s, 194.1s to go
# on time step 21725 (time=339.453), 0.0214925 s/step
# Meep progress: 342.28125/500.0 = 68.5% done in 413.0s, 190.3s to go
# on time step 21929 (time=342.641), 0.0196139 s/step
# Meep progress: 345.484375/500.0 = 69.1% done in 417.0s, 186.5s to go
# on time step 22134 (time=345.844), 0.0195284 s/step
# Meep progress: 348.671875/500.0 = 69.7% done in 421.0s, 182.7s to go
# on time step 22337 (time=349.016), 0.0197264 s/step
# Meep progress: 351.875/500.0 = 70.4% done in 425.1s, 178.9s to go
# on time step 22541 (time=352.203), 0.0197799 s/step
# Meep progress: 355.046875/500.0 = 71.0% done in 429.1s, 175.2s to go
# on time step 22747 (time=355.422), 0.0194966 s/step
# Meep progress: 358.265625/500.0 = 71.7% done in 433.1s, 171.3s to go
# on time step 22953 (time=358.641), 0.0194346 s/step
# Meep progress: 361.453125/500.0 = 72.3% done in 437.1s, 167.5s to go
# on time step 23158 (time=361.844), 0.0195479 s/step
# Meep progress: 364.640625/500.0 = 72.9% done in 441.1s, 163.7s to go
# on time step 23361 (time=365.016), 0.019912 s/step
# Meep progress: 367.765625/500.0 = 73.6% done in 445.1s, 160.0s to go
# on time step 23563 (time=368.172), 0.0198549 s/step
# Meep progress: 370.9375/500.0 = 74.2% done in 449.1s, 156.3s to go
# on time step 23766 (time=371.344), 0.0197264 s/step
# Meep progress: 374.109375/500.0 = 74.8% done in 453.1s, 152.5s to go
# on time step 23970 (time=374.531), 0.0196749 s/step
# Meep progress: 377.3125/500.0 = 75.5% done in 457.1s, 148.6s to go
# on time step 24173 (time=377.703), 0.0197797 s/step
# Meep progress: 380.4375/500.0 = 76.1% done in 461.1s, 144.9s to go
# on time step 24376 (time=380.875), 0.0197404 s/step
# Meep progress: 383.609375/500.0 = 76.7% done in 465.1s, 141.1s to go
# on time step 24579 (time=384.047), 0.0197976 s/step
# Meep progress: 386.71875/500.0 = 77.3% done in 469.1s, 137.4s to go
# on time step 24774 (time=387.094), 0.020565 s/step
# Meep progress: 389.703125/500.0 = 77.9% done in 473.2s, 133.9s to go
# on time step 24968 (time=390.125), 0.0206539 s/step
# Meep progress: 392.859375/500.0 = 78.6% done in 477.2s, 130.1s to go
# on time step 25169 (time=393.266), 0.0199075 s/step
# Meep progress: 396.046875/500.0 = 79.2% done in 481.2s, 126.3s to go
# on time step 25375 (time=396.484), 0.0195076 s/step
# Meep progress: 399.234375/500.0 = 79.8% done in 485.2s, 122.5s to go
# on time step 25577 (time=399.641), 0.0198501 s/step
# Meep progress: 402.421875/500.0 = 80.5% done in 489.2s, 118.6s to go
# on time step 25781 (time=402.828), 0.0196602 s/step
# Meep progress: 405.625/500.0 = 81.1% done in 493.2s, 114.8s to go
# on time step 25986 (time=406.031), 0.0196364 s/step
# Meep progress: 408.78125/500.0 = 81.8% done in 497.2s, 111.0s to go
# on time step 26188 (time=409.188), 0.0198264 s/step
# Meep progress: 411.953125/500.0 = 82.4% done in 501.2s, 107.1s to go
# on time step 26392 (time=412.375), 0.0196425 s/step
# Meep progress: 415.109375/500.0 = 83.0% done in 505.3s, 103.3s to go
# on time step 26595 (time=415.547), 0.0197655 s/step
# Meep progress: 418.296875/500.0 = 83.7% done in 509.3s, 99.5s to go
# on time step 26798 (time=418.719), 0.019775 s/step
# Meep progress: 421.4375/500.0 = 84.3% done in 513.3s, 95.7s to go
# on time step 27000 (time=421.875), 0.0199485 s/step
# Meep progress: 424.59375/500.0 = 84.9% done in 517.3s, 91.9s to go
# on time step 27203 (time=425.047), 0.0197948 s/step
# Meep progress: 427.765625/500.0 = 85.6% done in 521.3s, 88.0s to go
# on time step 27407 (time=428.234), 0.0196199 s/step
# Meep progress: 430.96875/500.0 = 86.2% done in 525.3s, 84.1s to go
# on time step 27611 (time=431.422), 0.0197191 s/step
# Meep progress: 434.09375/500.0 = 86.8% done in 529.3s, 80.4s to go
# on time step 27813 (time=434.578), 0.0198773 s/step
# Meep progress: 437.25/500.0 = 87.5% done in 533.3s, 76.5s to go
# on time step 28016 (time=437.75), 0.0197527 s/step
# Meep progress: 440.4375/500.0 = 88.1% done in 537.3s, 72.7s to go
# on time step 28220 (time=440.938), 0.0197002 s/step
# Meep progress: 443.59375/500.0 = 88.7% done in 541.3s, 68.8s to go
# on time step 28422 (time=444.094), 0.0198566 s/step
# Meep progress: 446.78125/500.0 = 89.4% done in 545.3s, 65.0s to go
# on time step 28627 (time=447.297), 0.019538 s/step
# Meep progress: 449.9375/500.0 = 90.0% done in 549.3s, 61.1s to go
# on time step 28829 (time=450.453), 0.0198538 s/step
# Meep progress: 453.125/500.0 = 90.6% done in 553.4s, 57.2s to go
# on time step 29033 (time=453.641), 0.0196861 s/step
# Meep progress: 456.3125/500.0 = 91.3% done in 557.4s, 53.4s to go
# on time step 29237 (time=456.828), 0.0196606 s/step
# Meep progress: 459.484375/500.0 = 91.9% done in 561.4s, 49.5s to go
# on time step 29440 (time=460), 0.0198386 s/step
# Meep progress: 462.6875/500.0 = 92.5% done in 565.4s, 45.6s to go
# on time step 29644 (time=463.188), 0.0196461 s/step
# Meep progress: 465.8125/500.0 = 93.2% done in 569.4s, 41.8s to go
# on time step 29846 (time=466.344), 0.0198175 s/step
# Meep progress: 468.96875/500.0 = 93.8% done in 573.4s, 37.9s to go
# on time step 30049 (time=469.516), 0.0197438 s/step
# Meep progress: 472.140625/500.0 = 94.4% done in 577.4s, 34.1s to go
# on time step 30248 (time=472.625), 0.0201356 s/step
# Meep progress: 475.28125/500.0 = 95.1% done in 581.4s, 30.2s to go
# on time step 30452 (time=475.812), 0.0196658 s/step
# Meep progress: 478.46875/500.0 = 95.7% done in 585.4s, 26.3s to go
# on time step 30656 (time=479), 0.0196102 s/step
# Meep progress: 481.359375/500.0 = 96.3% done in 589.4s, 22.8s to go
# on time step 30838 (time=481.844), 0.0219899 s/step
# Meep progress: 484.421875/500.0 = 96.9% done in 593.5s, 19.1s to go
# on time step 31037 (time=484.953), 0.0201619 s/step
# Meep progress: 487.5/500.0 = 97.5% done in 597.5s, 15.3s to go
# on time step 31233 (time=488.016), 0.020446 s/step
# Meep progress: 490.671875/500.0 = 98.1% done in 601.5s, 11.4s to go
# on time step 31436 (time=491.188), 0.0197323 s/step
# Meep progress: 493.796875/500.0 = 98.8% done in 605.5s, 7.6s to go
# on time step 31637 (time=494.328), 0.0199536 s/step
# Meep progress: 496.96875/500.0 = 99.4% done in 609.5s, 3.7s to go
# on time step 31840 (time=497.5), 0.0197448 s/step
# Warning: grid volume is not an integer number of pixels; cell size will be rounded to nearest pixel.
# run 0 finished at t = 500.0 (32000 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.166716 s
# Working in 2D dimensions.
# Computational cell is 60 x 17.3125 x 0 with resolution 32
#      block, center = (0,0,0)
#           size (1e+20,0.866025,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (6.76,6.76,6.76)
#      block, center = (0,8.22724,0)
#           size (50,17.3205,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (6.76,6.76,6.76)
#      block, center = (0,-9.09327,0)
#           size (50,17.3205,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (6.76,6.76,6.76)
#      prism, center = (-25.5,1.01036,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-25.075,1.25574,-0.5)
#           (-25.925,1.25574,-0.5)
#           (-25.5,0.519615,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      prism, center = (-25.5,-1.87639,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-25.925,-2.12176,-0.5)
#           (-25.075,-2.12176,-0.5)
#           (-25.5,-1.38564,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      prism, center = (-25,0.144338,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-24.575,0.389711,-0.5)
#           (-25.425,0.389711,-0.5)
#           (-25,-0.34641,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      prism, center = (-24.5,1.01036,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-24.075,1.25574,-0.5)
#           (-24.925,1.25574,-0.5)
#           (-24.5,0.519615,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      prism, center = (-24.5,-1.87639,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-24.925,-2.12176,-0.5)
#           (-24.075,-2.12176,-0.5)
#           (-24.5,-1.38564,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      prism, center = (-24,0.144338,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-23.575,0.389711,-0.5)
#           (-24.425,0.389711,-0.5)
#           (-24,-0.34641,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      prism, center = (-23.5,1.01036,0)
#           height 1, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-23.075,1.25574,-0.5)
#           (-23.925,1.25574,-0.5)
#           (-23.5,0.519615,-0.5)
#           dielectric constant epsilon diagonal = (1,1,1)
#      ...(+ 2083 objects not shown)...
# subpixel-averaging is 33.4032% done, 7.98794 s remaining
# subpixel-averaging is 63.4993% done, 2.30491 s remaining
# subpixel-averaging is 36.6002% done, 6.93947 s remaining
# subpixel-averaging is 68.7909% done, 1.81738 s remaining
# subpixel-averaging is 34.8364% done, 7.51347 s remaining
# subpixel-averaging is 66.9168% done, 1.97874 s remaining
# time for set_epsilon = 40.1662 s
# time for set_conductivity = 0.731395 s
# time for set_conductivity = 0.676181 s
# time for set_conductivity = 0.724759 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=10000.0)
# 29869 s/step
# Meep progress: 9692.40625/10000.0 = 96.9% done in 21705.5s, 688.8s to go
# on time step 620375 (time=9693.36), 0.0330172 s/step
# Meep progress: 9694.3125/10000.0 = 96.9% done in 21709.5s, 684.6s to go
# on time step 620497 (time=9695.27), 0.0328976 s/step
# Meep progress: 9696.203125/10000.0 = 97.0% done in 21713.6s, 680.3s to go
# on time step 620619 (time=9697.17), 0.0330204 s/step
# Meep progress: 9698.109375/10000.0 = 97.0% done in 21717.6s, 676.0s to go
# on time step 620741 (time=9699.08), 0.0329128 s/step
# Meep progress: 9699.96875/10000.0 = 97.0% done in 21721.6s, 671.9s to go
# on time step 620860 (time=9700.94), 0.0336992 s/step
# Meep progress: 9701.875/10000.0 = 97.0% done in 21725.6s, 667.6s to go
# on time step 620982 (time=9702.84), 0.0329405 s/step
# Meep progress: 9703.78125/10000.0 = 97.0% done in 21729.6s, 663.3s to go
# on time step 621103 (time=9704.73), 0.0330675 s/step
# Meep progress: 9705.6875/10000.0 = 97.1% done in 21733.6s, 659.0s to go
# on time step 621225 (time=9706.64), 0.0328211 s/step
# Meep progress: 9707.578125/10000.0 = 97.1% done in 21737.6s, 654.8s to go
# on time step 621347 (time=9708.55), 0.0330099 s/step
# Meep progress: 9709.46875/10000.0 = 97.1% done in 21741.6s, 650.6s to go
# on time step 621468 (time=9710.44), 0.0331221 s/step
# Meep progress: 9711.375/10000.0 = 97.1% done in 21745.6s, 646.3s to go
# on time step 621590 (time=9712.34), 0.0328179 s/step
# Meep progress: 9713.265625/10000.0 = 97.1% done in 21749.7s, 642.0s to go
# on time step 621711 (time=9714.23), 0.0330701 s/step
# Meep progress: 9715.171875/10000.0 = 97.2% done in 21753.7s, 637.8s to go
# on time step 621833 (time=9716.14), 0.033004 s/step
# Meep progress: 9717.078125/10000.0 = 97.2% done in 21757.7s, 633.5s to go
# on time step 621955 (time=9718.05), 0.0330234 s/step
# Meep progress: 9718.96875/10000.0 = 97.2% done in 21761.7s, 629.3s to go
# on time step 622074 (time=9719.91), 0.0338202 s/step
# Meep progress: 9720.828125/10000.0 = 97.2% done in 21765.7s, 625.1s to go
# on time step 622194 (time=9721.78), 0.0333822 s/step
# Meep progress: 9722.71875/10000.0 = 97.2% done in 21769.8s, 620.8s to go
# on time step 622316 (time=9723.69), 0.0329761 s/step
# Meep progress: 9724.609375/10000.0 = 97.2% done in 21773.8s, 616.6s to go
# on time step 622437 (time=9725.58), 0.0331613 s/step
# Meep progress: 9726.515625/10000.0 = 97.3% done in 21777.8s, 612.3s to go
# on time step 622559 (time=9727.48), 0.0329289 s/step
# Meep progress: 9728.328125/10000.0 = 97.3% done in 21781.8s, 608.3s to go
# on time step 622676 (time=9729.31), 0.0343725 s/step
# Meep progress: 9730.234375/10000.0 = 97.3% done in 21785.8s, 604.0s to go
# on time step 622798 (time=9731.22), 0.032911 s/step
# Meep progress: 9732.140625/10000.0 = 97.3% done in 21789.8s, 599.7s to go
# on time step 622920 (time=9733.12), 0.0329246 s/step
# Meep progress: 9734.046875/10000.0 = 97.3% done in 21793.8s, 595.4s to go
# on time step 623042 (time=9735.03), 0.0329443 s/step
# Meep progress: 9735.9375/10000.0 = 97.4% done in 21797.8s, 591.2s to go
# on time step 623163 (time=9736.92), 0.0332703 s/step
# Meep progress: 9737.78125/10000.0 = 97.4% done in 21801.9s, 587.1s to go
# on time step 623282 (time=9738.78), 0.0338262 s/step
# Meep progress: 9739.671875/10000.0 = 97.4% done in 21805.9s, 582.8s to go
# on time step 623403 (time=9740.67), 0.0330836 s/step
# Meep progress: 9741.5625/10000.0 = 97.4% done in 21809.9s, 578.6s to go
# on time step 623524 (time=9742.56), 0.0330722 s/step
# Meep progress: 9743.46875/10000.0 = 97.4% done in 21813.9s, 574.3s to go
# on time step 623645 (time=9744.45), 0.0333083 s/step
# Meep progress: 9745.359375/10000.0 = 97.5% done in 21817.9s, 570.1s to go
# on time step 623768 (time=9746.38), 0.0326825 s/step
# Meep progress: 9747.21875/10000.0 = 97.5% done in 21821.9s, 565.9s to go
# on time step 623887 (time=9748.23), 0.033858 s/step
# Meep progress: 9749.109375/10000.0 = 97.5% done in 21825.9s, 561.7s to go
# on time step 624009 (time=9750.14), 0.0329983 s/step
# Meep progress: 9751.0/10000.0 = 97.5% done in 21829.9s, 557.4s to go
# on time step 624130 (time=9752.03), 0.0332445 s/step
# Meep progress: 9752.875/10000.0 = 97.5% done in 21833.9s, 553.2s to go
# on time step 624252 (time=9753.94), 0.0330148 s/step
# Meep progress: 9754.78125/10000.0 = 97.5% done in 21837.9s, 549.0s to go
# on time step 624373 (time=9755.83), 0.0331032 s/step
# Meep progress: 9756.6875/10000.0 = 97.6% done in 21841.9s, 544.7s to go
# on time step 624496 (time=9757.75), 0.0326635 s/step
# Meep progress: 9758.59375/10000.0 = 97.6% done in 21846.0s, 540.4s to go
# on time step 624617 (time=9759.64), 0.0331507 s/step
# Meep progress: 9760.5/10000.0 = 97.6% done in 21850.0s, 536.1s to go
# on time step 624739 (time=9761.55), 0.0330349 s/step
# Meep progress: 9762.40625/10000.0 = 97.6% done in 21854.0s, 531.9s to go
# on time step 624862 (time=9763.47), 0.032775 s/step
# Meep progress: 9764.328125/10000.0 = 97.6% done in 21858.0s, 527.6s to go
# on time step 624984 (time=9765.38), 0.0328607 s/step
# Meep progress: 9766.234375/10000.0 = 97.7% done in 21862.1s, 523.3s to go
# on time step 625106 (time=9767.28), 0.0329379 s/step
# Meep progress: 9768.140625/10000.0 = 97.7% done in 21866.1s, 519.0s to go
# on time step 625228 (time=9769.19), 0.0328901 s/step
# Meep progress: 9770.03125/10000.0 = 97.7% done in 21870.1s, 514.8s to go
# on time step 625349 (time=9771.08), 0.0330875 s/step
# Meep progress: 9771.953125/10000.0 = 97.7% done in 21874.1s, 510.5s to go
# on time step 625472 (time=9773), 0.0327121 s/step
# Meep progress: 9773.859375/10000.0 = 97.7% done in 21878.1s, 506.2s to go
# on time step 625594 (time=9774.91), 0.0328346 s/step
# Meep progress: 9775.765625/10000.0 = 97.8% done in 21882.1s, 501.9s to go
# on time step 625716 (time=9776.81), 0.0329613 s/step
# Meep progress: 9777.671875/10000.0 = 97.8% done in 21886.1s, 497.7s to go
# on time step 625833 (time=9778.64), 0.0341951 s/step
# Meep progress: 9779.5/10000.0 = 97.8% done in 21890.2s, 493.6s to go
# on time step 625955 (time=9780.55), 0.0328391 s/step
# Meep progress: 9781.40625/10000.0 = 97.8% done in 21894.2s, 489.3s to go
# on time step 626076 (time=9782.44), 0.0331128 s/step
# Meep progress: 9783.3125/10000.0 = 97.8% done in 21898.2s, 485.0s to go
# on time step 626198 (time=9784.34), 0.0331299 s/step
# Meep progress: 9785.203125/10000.0 = 97.9% done in 21902.2s, 480.8s to go
# on time step 626320 (time=9786.25), 0.0330411 s/step
# Meep progress: 9787.09375/10000.0 = 97.9% done in 21906.2s, 476.5s to go
# on time step 626442 (time=9788.16), 0.0330596 s/step
# Meep progress: 9789.0/10000.0 = 97.9% done in 21910.2s, 472.3s to go
# on time step 626564 (time=9790.06), 0.0329766 s/step
# Meep progress: 9790.90625/10000.0 = 97.9% done in 21914.2s, 468.0s to go
# on time step 626683 (time=9791.92), 0.0336242 s/step
# Meep progress: 9792.671875/10000.0 = 97.9% done in 21918.3s, 464.0s to go
# on time step 626797 (time=9793.7), 0.035258 s/step
# Meep progress: 9794.546875/10000.0 = 97.9% done in 21922.3s, 459.8s to go
# on time step 626919 (time=9795.61), 0.0328278 s/step
# Meep progress: 9796.46875/10000.0 = 98.0% done in 21926.3s, 455.5s to go
# on time step 627041 (time=9797.52), 0.0328563 s/step
# Meep progress: 9798.359375/10000.0 = 98.0% done in 21930.3s, 451.3s to go
# on time step 627162 (time=9799.41), 0.0330718 s/step
# Meep progress: 9800.28125/10000.0 = 98.0% done in 21934.3s, 447.0s to go
# on time step 627284 (time=9801.31), 0.0330327 s/step
# Meep progress: 9802.171875/10000.0 = 98.0% done in 21938.3s, 442.8s to go
# on time step 627407 (time=9803.23), 0.0326865 s/step
# Meep progress: 9804.078125/10000.0 = 98.0% done in 21942.4s, 438.5s to go
# on time step 627528 (time=9805.12), 0.0332146 s/step
# Meep progress: 9805.984375/10000.0 = 98.1% done in 21946.4s, 434.2s to go
# on time step 627650 (time=9807.03), 0.0327936 s/step
# Meep progress: 9807.890625/10000.0 = 98.1% done in 21950.4s, 429.9s to go
# on time step 627772 (time=9808.94), 0.032843 s/step
# Meep progress: 9809.796875/10000.0 = 98.1% done in 21954.4s, 425.7s to go
# on time step 627894 (time=9810.84), 0.0329085 s/step
# Meep progress: 9811.71875/10000.0 = 98.1% done in 21958.4s, 421.4s to go
# on time step 628016 (time=9812.75), 0.0327937 s/step
# Meep progress: 9813.625/10000.0 = 98.1% done in 21962.5s, 417.1s to go
# on time step 628138 (time=9814.66), 0.0328486 s/step
# Meep progress: 9815.53125/10000.0 = 98.2% done in 21966.5s, 412.8s to go
# on time step 628260 (time=9816.56), 0.0328959 s/step
# Meep progress: 9817.4375/10000.0 = 98.2% done in 21970.5s, 408.6s to go
# on time step 628381 (time=9818.45), 0.033072 s/step
# Meep progress: 9819.34375/10000.0 = 98.2% done in 21974.5s, 404.3s to go
# on time step 628503 (time=9820.36), 0.0328796 s/step
# Meep progress: 9821.234375/10000.0 = 98.2% done in 21978.5s, 400.1s to go
# on time step 628625 (time=9822.27), 0.0329937 s/step
# Meep progress: 9823.140625/10000.0 = 98.2% done in 21982.5s, 395.8s to go
# on time step 628747 (time=9824.17), 0.0328678 s/step
# Meep progress: 9825.0625/10000.0 = 98.3% done in 21986.5s, 391.5s to go
# on time step 628869 (time=9826.08), 0.0328382 s/step
# Meep progress: 9826.9375/10000.0 = 98.3% done in 21990.6s, 387.3s to go
# on time step 628991 (time=9827.98), 0.0330179 s/step
# Meep progress: 9828.796875/10000.0 = 98.3% done in 21994.6s, 383.1s to go
# on time step 629108 (time=9829.81), 0.0342615 s/step
# Meep progress: 9830.6875/10000.0 = 98.3% done in 21998.6s, 378.9s to go
# on time step 629230 (time=9831.72), 0.0328673 s/step
# Meep progress: 9832.609375/10000.0 = 98.3% done in 22002.6s, 374.6s to go
# on time step 629352 (time=9833.62), 0.0330399 s/step
# Meep progress: 9834.515625/10000.0 = 98.3% done in 22006.7s, 370.3s to go
# on time step 629474 (time=9835.53), 0.0328349 s/step
# Meep progress: 9836.421875/10000.0 = 98.4% done in 22010.7s, 366.0s to go
# on time step 629595 (time=9837.42), 0.0330687 s/step
# Meep progress: 9838.328125/10000.0 = 98.4% done in 22014.7s, 361.8s to go
# on time step 629716 (time=9839.31), 0.0330605 s/step
# Meep progress: 9840.234375/10000.0 = 98.4% done in 22018.7s, 357.5s to go
# on time step 629838 (time=9841.22), 0.0329838 s/step
# Meep progress: 9842.125/10000.0 = 98.4% done in 22022.7s, 353.3s to go
# on time step 629960 (time=9843.12), 0.0330153 s/step
# Meep progress: 9844.03125/10000.0 = 98.4% done in 22026.8s, 349.0s to go
# on time step 630083 (time=9845.05), 0.0327025 s/step
# Meep progress: 9845.953125/10000.0 = 98.5% done in 22030.8s, 344.7s to go
# on time step 630205 (time=9846.95), 0.0328985 s/step
# Meep progress: 9847.875/10000.0 = 98.5% done in 22034.8s, 340.4s to go
# on time step 630328 (time=9848.88), 0.0327625 s/step
# Meep progress: 9849.78125/10000.0 = 98.5% done in 22038.8s, 336.1s to go
# on time step 630450 (time=9850.78), 0.0329251 s/step
# Meep progress: 9851.6875/10000.0 = 98.5% done in 22042.8s, 331.8s to go
# on time step 630572 (time=9852.69), 0.0330067 s/step
# Meep progress: 9853.59375/10000.0 = 98.5% done in 22046.9s, 327.6s to go
# on time step 630695 (time=9854.61), 0.032628 s/step
# Meep progress: 9855.515625/10000.0 = 98.6% done in 22050.9s, 323.3s to go
# on time step 630817 (time=9856.52), 0.032998 s/step
# Meep progress: 9857.421875/10000.0 = 98.6% done in 22054.9s, 319.0s to go
# on time step 630939 (time=9858.42), 0.0329053 s/step
# Meep progress: 9859.328125/10000.0 = 98.6% done in 22058.9s, 314.7s to go
# on time step 631061 (time=9860.33), 0.032882 s/step
# Meep progress: 9861.21875/10000.0 = 98.6% done in 22063.0s, 310.5s to go
# on time step 631180 (time=9862.19), 0.033801 s/step
# Meep progress: 9863.09375/10000.0 = 98.6% done in 22067.0s, 306.3s to go
# on time step 631303 (time=9864.11), 0.0327646 s/step
# Meep progress: 9865.015625/10000.0 = 98.7% done in 22071.0s, 302.0s to go
# on time step 631424 (time=9866), 0.0331259 s/step
# Meep progress: 9866.921875/10000.0 = 98.7% done in 22075.0s, 297.7s to go
# on time step 631546 (time=9867.91), 0.0329874 s/step
# Meep progress: 9868.8125/10000.0 = 98.7% done in 22079.0s, 293.5s to go
# on time step 631668 (time=9869.81), 0.0329141 s/step
# Meep progress: 9870.71875/10000.0 = 98.7% done in 22083.0s, 289.2s to go
# on time step 631791 (time=9871.73), 0.0327402 s/step
# Meep progress: 9872.609375/10000.0 = 98.7% done in 22087.1s, 285.0s to go
# on time step 631912 (time=9873.62), 0.0332839 s/step
# Meep progress: 9874.515625/10000.0 = 98.7% done in 22091.1s, 280.7s to go
# on time step 632034 (time=9875.53), 0.0329345 s/step
# Meep progress: 9876.421875/10000.0 = 98.8% done in 22095.1s, 276.5s to go
# on time step 632157 (time=9877.45), 0.0327043 s/step
# Meep progress: 9878.328125/10000.0 = 98.8% done in 22099.1s, 272.2s to go
# on time step 632278 (time=9879.34), 0.0332909 s/step
# Meep progress: 9880.21875/10000.0 = 98.8% done in 22103.1s, 268.0s to go
# on time step 632401 (time=9881.27), 0.0327534 s/step
# Meep progress: 9882.125/10000.0 = 98.8% done in 22107.1s, 263.7s to go
# on time step 632523 (time=9883.17), 0.0329818 s/step
# Meep progress: 9884.046875/10000.0 = 98.8% done in 22111.2s, 259.4s to go
# on time step 632646 (time=9885.09), 0.0326865 s/step
# Meep progress: 9885.953125/10000.0 = 98.9% done in 22115.2s, 255.1s to go
# on time step 632768 (time=9887), 0.0329092 s/step
# Meep progress: 9887.875/10000.0 = 98.9% done in 22119.2s, 250.8s to go
# on time step 632888 (time=9888.88), 0.033449 s/step
# Meep progress: 9889.734375/10000.0 = 98.9% done in 22123.2s, 246.7s to go
# on time step 633009 (time=9890.77), 0.0331829 s/step
# Meep progress: 9891.625/10000.0 = 98.9% done in 22127.2s, 242.4s to go
# on time step 633131 (time=9892.67), 0.0328474 s/step
# Meep progress: 9893.53125/10000.0 = 98.9% done in 22131.2s, 238.2s to go
# on time step 633252 (time=9894.56), 0.0332396 s/step
# Meep progress: 9895.421875/10000.0 = 99.0% done in 22135.2s, 233.9s to go
# on time step 633374 (time=9896.47), 0.0330037 s/step
# Meep progress: 9897.328125/10000.0 = 99.0% done in 22139.3s, 229.7s to go
# on time step 633496 (time=9898.38), 0.0328463 s/step
# Meep progress: 9899.234375/10000.0 = 99.0% done in 22143.3s, 225.4s to go
# on time step 633618 (time=9900.28), 0.0329414 s/step
# Meep progress: 9901.140625/10000.0 = 99.0% done in 22147.3s, 221.1s to go
# on time step 633740 (time=9902.19), 0.032969 s/step
# Meep progress: 9903.046875/10000.0 = 99.0% done in 22151.3s, 216.9s to go
# on time step 633862 (time=9904.09), 0.0328489 s/step
# Meep progress: 9904.953125/10000.0 = 99.0% done in 22155.3s, 212.6s to go
# on time step 633984 (time=9906), 0.0329663 s/step
# Meep progress: 9906.875/10000.0 = 99.1% done in 22159.4s, 208.3s to go
# on time step 634106 (time=9907.91), 0.0328592 s/step
# Meep progress: 9908.78125/10000.0 = 99.1% done in 22163.4s, 204.0s to go
# on time step 634229 (time=9909.83), 0.0327287 s/step
# Meep progress: 9910.6875/10000.0 = 99.1% done in 22167.4s, 199.8s to go
# on time step 634351 (time=9911.73), 0.032935 s/step
# Meep progress: 9912.59375/10000.0 = 99.1% done in 22171.4s, 195.5s to go
# on time step 634473 (time=9913.64), 0.0330358 s/step
# Meep progress: 9914.484375/10000.0 = 99.1% done in 22175.4s, 191.3s to go
# on time step 634594 (time=9915.53), 0.033091 s/step
# Meep progress: 9916.375/10000.0 = 99.2% done in 22179.4s, 187.0s to go
# on time step 634715 (time=9917.42), 0.0330788 s/step
# Meep progress: 9918.265625/10000.0 = 99.2% done in 22183.4s, 182.8s to go
# on time step 634837 (time=9919.33), 0.0329993 s/step
# Meep progress: 9920.171875/10000.0 = 99.2% done in 22187.5s, 178.5s to go
# on time step 634959 (time=9921.23), 0.0328396 s/step
# Meep progress: 9922.078125/10000.0 = 99.2% done in 22191.5s, 174.3s to go
# on time step 635081 (time=9923.14), 0.0329867 s/step
# Meep progress: 9923.984375/10000.0 = 99.2% done in 22195.5s, 170.0s to go
# on time step 635203 (time=9925.05), 0.0328013 s/step
# Meep progress: 9925.890625/10000.0 = 99.3% done in 22199.5s, 165.7s to go
# on time step 635326 (time=9926.97), 0.0327292 s/step
# Meep progress: 9927.78125/10000.0 = 99.3% done in 22203.5s, 161.5s to go
# on time step 635447 (time=9928.86), 0.0330981 s/step
# Meep progress: 9929.6875/10000.0 = 99.3% done in 22207.5s, 157.3s to go
# on time step 635568 (time=9930.75), 0.0330581 s/step
# Meep progress: 9931.5625/10000.0 = 99.3% done in 22211.5s, 153.1s to go
# on time step 635690 (time=9932.66), 0.0330236 s/step
# Meep progress: 9933.46875/10000.0 = 99.3% done in 22215.5s, 148.8s to go
# on time step 635812 (time=9934.56), 0.0329543 s/step
# Meep progress: 9935.375/10000.0 = 99.4% done in 22219.5s, 144.5s to go
# on time step 635934 (time=9936.47), 0.0329705 s/step
# Meep progress: 9937.28125/10000.0 = 99.4% done in 22223.5s, 140.3s to go
# on time step 636056 (time=9938.38), 0.0328783 s/step
# Meep progress: 9939.171875/10000.0 = 99.4% done in 22227.5s, 136.0s to go
# on time step 636177 (time=9940.27), 0.0331115 s/step
# Meep progress: 9941.078125/10000.0 = 99.4% done in 22231.5s, 131.8s to go
# on time step 636299 (time=9942.17), 0.0328179 s/step
# Meep progress: 9942.984375/10000.0 = 99.4% done in 22235.5s, 127.5s to go
# on time step 636421 (time=9944.08), 0.0329063 s/step
# Meep progress: 9944.890625/10000.0 = 99.4% done in 22239.6s, 123.2s to go
# on time step 636543 (time=9945.98), 0.0329321 s/step
# Meep progress: 9946.796875/10000.0 = 99.5% done in 22243.6s, 119.0s to go
# on time step 636664 (time=9947.88), 0.0330656 s/step
# Meep progress: 9948.6875/10000.0 = 99.5% done in 22247.6s, 114.7s to go
# on time step 636787 (time=9949.8), 0.0326833 s/step
# Meep progress: 9950.59375/10000.0 = 99.5% done in 22251.6s, 110.5s to go
# on time step 636908 (time=9951.69), 0.0331204 s/step
# Meep progress: 9952.5/10000.0 = 99.5% done in 22255.6s, 106.2s to go
# on time step 637030 (time=9953.59), 0.0330205 s/step
# Meep progress: 9954.40625/10000.0 = 99.5% done in 22259.6s, 102.0s to go
# on time step 637153 (time=9955.52), 0.0326499 s/step
# Meep progress: 9956.3125/10000.0 = 99.6% done in 22263.7s, 97.7s to go
# on time step 637274 (time=9957.41), 0.033172 s/step
# Meep progress: 9958.21875/10000.0 = 99.6% done in 22267.7s, 93.4s to go
# on time step 637396 (time=9959.31), 0.0328622 s/step
# Meep progress: 9960.125/10000.0 = 99.6% done in 22271.7s, 89.2s to go
# on time step 637518 (time=9961.22), 0.032991 s/step
# Meep progress: 9962.015625/10000.0 = 99.6% done in 22275.7s, 84.9s to go
# on time step 637639 (time=9963.11), 0.0331201 s/step
# Meep progress: 9963.921875/10000.0 = 99.6% done in 22279.7s, 80.7s to go
# on time step 637761 (time=9965.02), 0.0328811 s/step
# Meep progress: 9965.828125/10000.0 = 99.7% done in 22283.7s, 76.4s to go
# on time step 637883 (time=9966.92), 0.0328953 s/step
# Meep progress: 9967.734375/10000.0 = 99.7% done in 22287.8s, 72.1s to go
# on time step 638005 (time=9968.83), 0.0330002 s/step
# Meep progress: 9969.640625/10000.0 = 99.7% done in 22291.8s, 67.9s to go
# on time step 638127 (time=9970.73), 0.0329791 s/step
# Meep progress: 9971.53125/10000.0 = 99.7% done in 22295.8s, 63.7s to go
# on time step 638249 (time=9972.64), 0.0328492 s/step
# Meep progress: 9973.4375/10000.0 = 99.7% done in 22299.8s, 59.4s to go
# on time step 638370 (time=9974.53), 0.0330927 s/step
# Meep progress: 9975.328125/10000.0 = 99.8% done in 22303.8s, 55.2s to go
# on time step 638491 (time=9976.42), 0.0332719 s/step
# Meep progress: 9977.21875/10000.0 = 99.8% done in 22307.8s, 50.9s to go
# on time step 638614 (time=9978.34), 0.032737 s/step
# Meep progress: 9979.125/10000.0 = 99.8% done in 22311.8s, 46.7s to go
# on time step 638735 (time=9980.23), 0.0330647 s/step
# Meep progress: 9981.03125/10000.0 = 99.8% done in 22315.8s, 42.4s to go
# on time step 638857 (time=9982.14), 0.0329738 s/step
# Meep progress: 9982.9375/10000.0 = 99.8% done in 22319.9s, 38.1s to go
# on time step 638976 (time=9984), 0.0338574 s/step
# Meep progress: 9984.796875/10000.0 = 99.8% done in 22323.9s, 34.0s to go
# on time step 639099 (time=9985.92), 0.0326993 s/step
# Meep progress: 9987.171875/10000.0 = 99.9% done in 22327.9s, 28.7s to go
# on time step 639319 (time=9989.36), 0.0181906 s/step
# Meep progress: 9990.765625/10000.0 = 99.9% done in 22331.9s, 20.6s to go
# on time step 639548 (time=9992.94), 0.0174919 s/step
# Meep progress: 9994.484375/10000.0 = 99.9% done in 22335.9s, 12.3s to go
# on time step 639786 (time=9996.66), 0.0168192 s/step
# Meep progress: 9998.1875/10000.0 = 100.0% done in 22339.9s, 4.0s to go
# run 0 finished at t = 10000.0 (640000 timesteps)

# %%
plt.plot(freqs_wo,psd_out_wo)
plt.grid(True)

# %%
plt.plot(freqs_w,psd_out_w)
plt.grid(True)

# %%
plt.plot(np.array(freqs_w), np.array(psd_out_w)/np.array(psd_out_wo))
plt.xlabel("Frequency[c/a]")
plt.ylabel("Transmittance")
plt.yscale('log')
plt.grid(True)
plt.savefig("aaaaaaaaaaaa.png")
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
ls
# Out:
# 201029_waveguide_VPhCtriangle_zigzag.ipynb_transmittance.csv*
# 210111_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d085_km005_T1e5.csv*
# 210111_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d085_km0_resolution32.csv*
# 210111_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d085_kpm005.csv*
# 210111_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d085_kpm005_T1e5.csv*
# 210122_resolution15_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d085_km02.ipynb*
# 210122_resolution16_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d085_km05.ipynb*
# 210122_resolution16_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d085_km05_cor.ipynb*
# 210122_resolution32_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d085_km02.ipynb*
# 210122_resolution32_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d085_km05_cor.ipynb*
# 210122_resolution32_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d085_uasq34b_km025both.ipynb*
# 210122_resolution32_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d085_uasq34b_km05.ipynb*
# 210122_resolution32_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d090_uasq34b_km025both.ipynb*
# 210122_resolution32_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d090_uasq34b_km05.ipynb*
# Code.VisualElementsManifest.xml*
# Code.exe*
# bin/
# chrome_100_percent.pak*
# chrome_200_percent.pak*
# d3dcompiler_47.dll*
# ffmpeg.dll*
# icudtl.dat*
# libEGL.dll*
# libGLESv2.dll*
# locales/
# resources/
# resources.pak*
# snapshot_blob.bin*
# swiftshader/
# tools/
# unins000.dat*
# unins000.exe*
# unins000.msg*
# usaq34b_km05.png*
# v8_context_snapshot.bin*
# vk_swiftshader.dll*
# vk_swiftshader_icd.json*
# vulkan-1.dll*

# %%
cd c/users/uemura_tokyotech/desktop
# Out:
# /mnt/c/users/uemura_tokyotech/desktop

# %%
# %cd
# Out:
# /home/unix

# %%
plt.plot(np.array(freqs_w), np.array(psd_out_w)/np.array(psd_out_wo))
plt.xlabel("Frequency[c/a]")
plt.ylabel("Transmittance[c/a]")
plt.yscale('log')
plt.grid(True)

# %%
a = 470
c_const = 299792458

freqs = a / np.array(freqs_w)
#freqs
plt.plot(freqs, np.array(psd_out_w)/np.array(psd_out_wo))
plt.scatter(freqs, np.array(psd_out_w)/np.array(psd_out_wo))
plt.xlabel("Frequency[c/a]")
plt.ylabel("Transmittance[c/a]")
#plt.xlim([0.28,0.30])
plt.yscale('log')
plt.grid(True)

# %%
freqs = a / np.array(freqs_w)
#freqs
plt.plot(freqs, np.array(psd_out_w)/np.array(psd_out_wo))
plt.scatter(freqs, np.array(psd_out_w)/np.array(psd_out_wo))
plt.xlabel("Frequency")
plt.ylabel("Transmittance[c/a]")
plt.xlim([1350,1550])
plt.yscale('log')
plt.ylim([1e-6,1e-3])
plt.grid(True)
plt.savefig("usaq34b_km05_detail.png")

# %%
freqs = a / np.array(freqs_w)
#freqs
plt.plot(freqs, np.array(psd_out_w)/np.array(psd_out_wo))
plt.scatter(freqs, np.array(psd_out_w)/np.array(psd_out_wo))
plt.xlabel("Frequency[c/a]")
plt.ylabel("Transmittance[c/a]")
plt.xlim([1400,1550])
plt.yscale('log')
plt.ylim([1e-7,1e-2])
plt.grid(True)

# %%
df = pd.DataFrame()
df["wavelength"] = freqs
df["transmittance"] = np.array(psd_out_w)/np.array(psd_out_wo)
df.to_csv("210122_resolution32_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d085_uasq34b_km05.ipynb")

# %%
df
# Out:
#        wavelength  transmittance
# 0     2350.000000       0.075326
# 1     2349.530000       0.075350
# 2     2349.060188       0.075379
# 3     2348.590564       0.075425
# 4     2348.121127       0.075477
# ...           ...            ...
# 4995  1175.470282       0.093933
# 4996  1175.352676       0.094882
# 4997  1175.235094       0.095807
# 4998  1175.117535       0.096707
# 4999  1175.000000       0.097589
#
# [5000 rows x 2 columns]

# %%
ls
# Out:
# 201029_waveguide_VPhCtriangle_zigzag.ipynb_transmittance.csv*
# 210111_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d085_km005_T1e5.csv*
# 210111_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d085_km0_resolution32.csv*
# 210111_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d085_kpm005.csv*
# 210111_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d085_kpm005_T1e5.csv*
# 210122_resolution15_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d085_km02.ipynb*
# 210122_resolution16_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d085_km05.ipynb*
# 210122_resolution16_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d085_km05_cor.ipynb*
# 210122_resolution32_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d085_km02.ipynb*
# 210122_resolution32_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d085_km05_cor.ipynb*
# 210122_resolution32_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d085_uasq34b_km025both.ipynb*
# 210122_resolution32_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d085_uasq34b_km05.ipynb*
# 210122_resolution32_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d090_uasq34b_km025both.ipynb*
# 210122_resolution32_waveguide_VPhCtriangle_bearded_adiabatic_transmittance_d090_uasq34b_km05.ipynb*
# Code.VisualElementsManifest.xml*
# Code.exe*
# bin/
# chrome_100_percent.pak*
# chrome_200_percent.pak*
# d3dcompiler_47.dll*
# ffmpeg.dll*
# icudtl.dat*
# km025both.png*
# km025both_detail.png*
# libEGL.dll*
# libGLESv2.dll*
# locales/
# resources/
# resources.pak*
# snapshot_blob.bin*
# swiftshader/
# tools/
# unins000.dat*
# unins000.exe*
# unins000.msg*
# usaq34b_km05.png*
# v8_context_snapshot.bin*
# vk_swiftshader.dll*
# vk_swiftshader_icd.json*
# vulkan-1.dll*

# %%
cd ..
# Out:
# /mnt/c/Users/uemura_tokyotech/AppData/Local/Programs
