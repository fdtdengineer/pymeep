# %% [markdown]
# 参考
# https://mpb.readthedocs.io/en/latest/Python_Data_Analysis_Tutorial/

# %%
import math
import meep as mp
from meep import mpb

import numpy as np
import matplotlib.pyplot as plt

# %%
#屈折率
n_Air = 1
n_Si = 2.6

#計算する固有周波数の数
num_bands = 4

#メッシュの細かさ
resolution = 32

#単位格子
geometry_lattice = mp.Lattice(size=mp.Vector3(1, 1),
                              basis1=mp.Vector3(1./2, np.sqrt(3)/2),
                              basis2=mp.Vector3(1./2, -np.sqrt(3)/2))

#構造
#default_material = mp.Medium(epsilon=n_Si**2)
geometry = [
    mp.Block(material=mp.Medium(epsilon=n_Si**2),
             size=mp.Vector3(mp.inf, mp.inf)),
    mp.Cylinder(0.25, material=mp.Medium(epsilon=n_Air**2))
]

#ブリルアンゾーン
k_points = [
    mp.Vector3(),               # Gamma
    mp.Vector3(1./2, 0),          # M
    mp.Vector3(1./3, 1./3),    # K
    mp.Vector3(),               # Gamma
]
k_points = mp.interpolate(4, k_points)

# %%
#計算
ms = mpb.ModeSolver(
    geometry=geometry,
    geometry_lattice=geometry_lattice,
    k_points=k_points,
    resolution=resolution,
    num_bands=num_bands
)

ms.run_tm(mpb.output_at_kpoint(mp.Vector3(1./3, 1./3),
                               mpb.fix_efield_phase,
                               mpb.output_efield_z))
tm_freqs = ms.all_freqs
tm_gaps = ms.gap_list
ms.run_te(mpb.output_at_kpoint(mp.Vector3(1./3, 1./3),
                               mpb.fix_efield_phase,
                               mpb.output_efield_z))
te_freqs = ms.all_freqs
te_gaps = ms.gap_list
# Out:
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.5, 0.866025, 0)
#      (0.5, -0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, 0.57735, -0)
#      (1, -0.57735, 0)
#      (-0, 0, 1)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1e+20,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      cylinder, center = (0,0,0)
#           radius 0.25, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 10 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.1, 0.0, 0.0>
#   Vector3<0.2, 0.0, 0.0>
#   Vector3<0.30000000000000004, 0.0, 0.0>
#   Vector3<0.4, 0.0, 0.0>
#   Vector3<0.5, 0.0, 0.0>
#   Vector3<0.4666666666666667, 0.06666666666666667, 0.0>
#   Vector3<0.43333333333333335, 0.13333333333333333, 0.0>
#   Vector3<0.39999999999999997, 0.2, 0.0>
#   Vector3<0.36666666666666664, 0.26666666666666666, 0.0>
#   Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<0.26666666666666666, 0.26666666666666666, 0.0>
#   Vector3<0.19999999999999998, 0.19999999999999998, 0.0>
#   Vector3<0.1333333333333333, 0.1333333333333333, 0.0>
#   Vector3<0.06666666666666665, 0.06666666666666665, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.0350954532623291
# solve_kpoint (0,0,0):
# Solving for bands 2 to 4...
# Finished solving for bands 2 to 4 after 16 iterations.
# tmfreqs:, 1, 0, 0, 0, 0, 0, 0.445451, 0.452498, 0.452542
# elapsed time for k point: 0.027290821075439453
# solve_kpoint (0.1,0,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 13 iterations.
# tmfreqs:, 2, 0.1, 0, 0, 0.11547, 0.0494066, 0.414634, 0.445106, 0.471516
# elapsed time for k point: 0.02720952033996582
# solve_kpoint (0.2,0,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 7 iterations.
# tmfreqs:, 3, 0.2, 0, 0, 0.23094, 0.0985794, 0.376519, 0.432077, 0.468137
# elapsed time for k point: 0.019377946853637695
# solve_kpoint (0.3,0,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 6 iterations.
# tmfreqs:, 4, 0.3, 0, 0, 0.34641, 0.147199, 0.335374, 0.420849, 0.457512
# elapsed time for k point: 0.01915764808654785
# solve_kpoint (0.4,0,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 5 iterations.
# tmfreqs:, 5, 0.4, 0, 0, 0.46188, 0.194486, 0.292355, 0.413604, 0.449567
# elapsed time for k point: 0.08052372932434082
# solve_kpoint (0.5,0,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 5 iterations.
# tmfreqs:, 6, 0.5, 0, 0, 0.57735, 0.229585, 0.258637, 0.411116, 0.446738
# elapsed time for k point: 0.015283346176147461
# solve_kpoint (0.466667,0.0666667,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 5 iterations.
# tmfreqs:, 7, 0.466667, 0.0666667, 0, 0.581187, 0.231101, 0.259954, 0.397578, 0.46036
# elapsed time for k point: 0.015682697296142578
# solve_kpoint (0.433333,0.133333,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 5 iterations.
# tmfreqs:, 8, 0.433333, 0.133333, 0, 0.592546, 0.23559, 0.26362, 0.374813, 0.483538
# elapsed time for k point: 0.018134355545043945
# solve_kpoint (0.4,0.2,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 5 iterations.
# tmfreqs:, 9, 0.4, 0.2, 0, 0.61101, 0.242883, 0.268519, 0.351959, 0.50784
# elapsed time for k point: 0.01513051986694336
# solve_kpoint (0.366667,0.266667,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 6 iterations.
# tmfreqs:, 10, 0.366667, 0.266667, 0, 0.635959, 0.252728, 0.271353, 0.333184, 0.531349
# elapsed time for k point: 0.017392635345458984
# solve_kpoint (0.333333,0.333333,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 17 iterations.
# tmfreqs:, 11, 0.333333, 0.333333, 0, 0.666667, 0.264822, 0.26486, 0.325682, 0.55003
# elapsed time for k point: 0.025657176971435547
# Fixing e-field (band 1) phase by -1 + -1.46821e-08i; max ampl. = 0.707049
# Outputting fields to e.k11.b01.z.tm.h5...
# Fixing e-field (band 2) phase by -1 + -1.46821e-08i; max ampl. = 0.612444
# Outputting fields to e.k11.b02.z.tm.h5...
# Fixing e-field (band 3) phase by 1 + 1.43101e-08i; max ampl. = 0.666892
# Outputting fields to e.k11.b03.z.tm.h5...
# Fixing e-field (band 4) phase by 1 + 1.46911e-08i; max ampl. = 0.774075
# Outputting fields to e.k11.b04.z.tm.h5...
# solve_kpoint (0.266667,0.266667,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 16 iterations.
# tmfreqs:, 12, 0.266667, 0.266667, 0, 0.533333, 0.22272, 0.294618, 0.3443, 0.526504
# elapsed time for k point: 0.02427840232849121
# solve_kpoint (0.2,0.2,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 6 iterations.
# tmfreqs:, 13, 0.2, 0.2, 0, 0.4, 0.169438, 0.329911, 0.377442, 0.506679
# elapsed time for k point: 0.018279314041137695
# solve_kpoint (0.133333,0.133333,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 7 iterations.
# tmfreqs:, 14, 0.133333, 0.133333, 0, 0.266667, 0.113702, 0.368833, 0.412329, 0.490821
# elapsed time for k point: 0.01531982421875
# solve_kpoint (0.0666667,0.0666667,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 8 iterations.
# tmfreqs:, 15, 0.0666667, 0.0666667, 0, 0.133333, 0.0570354, 0.409543, 0.440912, 0.47615
# elapsed time for k point: 0.018622159957885742
# solve_kpoint (0,0,0):
# Solving for bands 2 to 4...
# Finished solving for bands 2 to 4 after 9 iterations.
# tmfreqs:, 16, 0, 0, 0, 0, 0, 0.445451, 0.452498, 0.452542
# elapsed time for k point: 0.016398191452026367
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.26482170708910446 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.2586373334655435 at Vector3<0.5, 0.0, 0.0> to 0.4454512824941494 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.3256824709756509 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0> to 0.452498289116314 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.4467380851617561 at Vector3<0.5, 0.0, 0.0> to 0.5500301564452093 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
# total elapsed time for run: 0.4395909309387207
# done
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.5, 0.866025, 0)
#      (0.5, -0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, 0.57735, -0)
#      (1, -0.57735, 0)
#      (-0, 0, 1)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1e+20,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      cylinder, center = (0,0,0)
#           radius 0.25, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 10 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.1, 0.0, 0.0>
#   Vector3<0.2, 0.0, 0.0>
#   Vector3<0.30000000000000004, 0.0, 0.0>
#   Vector3<0.4, 0.0, 0.0>
#   Vector3<0.5, 0.0, 0.0>
#   Vector3<0.4666666666666667, 0.06666666666666667, 0.0>
#   Vector3<0.43333333333333335, 0.13333333333333333, 0.0>
#   Vector3<0.39999999999999997, 0.2, 0.0>
#   Vector3<0.36666666666666664, 0.26666666666666666, 0.0>
#   Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<0.26666666666666666, 0.26666666666666666, 0.0>
#   Vector3<0.19999999999999998, 0.19999999999999998, 0.0>
#   Vector3<0.1333333333333333, 0.1333333333333333, 0.0>
#   Vector3<0.06666666666666665, 0.06666666666666665, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.03551340103149414
# solve_kpoint (0,0,0):
# Solving for bands 2 to 4...
# Finished solving for bands 2 to 4 after 19 iterations.
# tefreqs:, 1, 0, 0, 0, 0, 0, 0.459588, 0.496461, 0.496631
# elapsed time for k point: 0.03163909912109375
# solve_kpoint (0.1,0,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 45 iterations.
# tefreqs:, 2, 0.1, 0, 0, 0.11547, 0.0525916, 0.44357, 0.485631, 0.494276
# elapsed time for k point: 0.05441689491271973
# solve_kpoint (0.2,0,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 9 iterations.
# tefreqs:, 3, 0.2, 0, 0, 0.23094, 0.104842, 0.412121, 0.458653, 0.488985
# elapsed time for k point: 0.02461075782775879
# solve_kpoint (0.3,0,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 7 iterations.
# tefreqs:, 4, 0.3, 0, 0, 0.34641, 0.156103, 0.371184, 0.439292, 0.48328
# elapsed time for k point: 0.018779516220092773
# solve_kpoint (0.4,0,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 7 iterations.
# tefreqs:, 5, 0.4, 0, 0, 0.46188, 0.204084, 0.327462, 0.42855, 0.479157
# elapsed time for k point: 0.019146203994750977
# solve_kpoint (0.5,0,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 6 iterations.
# tefreqs:, 6, 0.5, 0, 0, 0.57735, 0.232386, 0.300328, 0.425084, 0.477675
# elapsed time for k point: 0.018598556518554688
# solve_kpoint (0.466667,0.0666667,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 7 iterations.
# tefreqs:, 7, 0.466667, 0.0666667, 0, 0.581187, 0.234428, 0.301439, 0.413781, 0.48862
# elapsed time for k point: 0.018682003021240234
# solve_kpoint (0.433333,0.133333,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 7 iterations.
# tefreqs:, 8, 0.433333, 0.133333, 0, 0.592546, 0.240321, 0.304743, 0.391564, 0.50973
# elapsed time for k point: 0.017537832260131836
# solve_kpoint (0.4,0.2,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 8 iterations.
# tefreqs:, 9, 0.4, 0.2, 0, 0.61101, 0.249275, 0.310157, 0.367109, 0.532126
# elapsed time for k point: 0.017359256744384766
# solve_kpoint (0.366667,0.266667,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 9 iterations.
# tefreqs:, 10, 0.366667, 0.266667, 0, 0.635959, 0.259393, 0.317555, 0.343708, 0.551428
# elapsed time for k point: 0.020807266235351562
# solve_kpoint (0.333333,0.333333,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 9 iterations.
# tefreqs:, 11, 0.333333, 0.333333, 0, 0.666667, 0.26521, 0.326748, 0.326845, 0.559458
# elapsed time for k point: 0.02097320556640625
# Fixing e-field (band 1) phase by -1 + 2.15862e-08i; max ampl. = 0.505301
# Outputting fields to e.k11.b01.z.te.h5...
# Fixing e-field (band 2) phase by 1 + -2.15862e-08i; max ampl. = 0.86706
# Outputting fields to e.k11.b02.z.te.h5...
# Fixing e-field (band 3) phase by -1 + 2.15862e-08i; max ampl. = 0.851697
# Outputting fields to e.k11.b03.z.te.h5...
# Fixing e-field (band 4) phase by -2.15862e-08 + -1i; max ampl. = 0.565617
# Outputting fields to e.k11.b04.z.te.h5...
# solve_kpoint (0.266667,0.266667,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 9 iterations.
# tefreqs:, 12, 0.266667, 0.266667, 0, 0.533333, 0.234664, 0.340406, 0.349973, 0.544917
# elapsed time for k point: 0.022429466247558594
# solve_kpoint (0.2,0.2,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 8 iterations.
# tefreqs:, 13, 0.2, 0.2, 0, 0.4, 0.179804, 0.377946, 0.382909, 0.525719
# elapsed time for k point: 0.01974034309387207
# solve_kpoint (0.133333,0.133333,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 7 iterations.
# tefreqs:, 14, 0.133333, 0.133333, 0, 0.266667, 0.120911, 0.40889, 0.430946, 0.510592
# elapsed time for k point: 0.01873636245727539
# solve_kpoint (0.0666667,0.0666667,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 9 iterations.
# tefreqs:, 15, 0.0666667, 0.0666667, 0, 0.133333, 0.060704, 0.440022, 0.476598, 0.501254
# elapsed time for k point: 0.024860620498657227
# solve_kpoint (0,0,0):
# Solving for bands 2 to 4...
# Finished solving for bands 2 to 4 after 11 iterations.
# tefreqs:, 16, 0, 0, 0, 0, 0, 0.459588, 0.496461, 0.50238
# elapsed time for k point: 0.01981663703918457
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.2652101974612378 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.3003283862476728 at Vector3<0.5, 0.0, 0.0> to 0.4595876019978609 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.32684546235575845 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0> to 0.49646074880552993 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.4776750257890585 at Vector3<0.5, 0.0, 0.0> to 0.559457766028443 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
# Gap from band 1 (0.2652101974612378) to band 2 (0.3003283862476728), 12.419378552785254%
# total elapsed time for run: 0.43706846237182617
# done

# %%
md = mpb.MPBData(rectify=True, periods=3, resolution=64)
eps = ms.get_epsilon()
converted_eps = md.convert(eps)
converted_eps.shape
# Out:
# epsilon: 1-6.76, mean 5.45406, harm. mean 3.06613, 80.957% > 1, 77.3275% "fill"
# (192, 166)

# %%
import csv
with open('epsilon_distribution.csv', 'wt') as f:
    writer = csv.writer(f)
    writer.writerows(converted_eps)

# %%
plt.imshow(converted_eps, interpolation='spline36', cmap="binary")
plt.axis('off')
plt.show()

# %%
tm_freqs.max()
# Out:
# 0.5500301564452093

# %%
fig, ax = plt.subplots()

x = range(len(tm_freqs))

# Plot bands
# Scatter plot for multiple y values, see https://stackoverflow.com/a/34280815/2261298
for xz, tmz, tez in zip(x, tm_freqs, te_freqs):
    ax.scatter([xz]*len(tmz), tmz, color='blue')
    ax.scatter([xz]*len(tez), tez, color='red', facecolors='none')
ax.plot(tm_freqs, color='blue')
ax.plot(te_freqs, color='red')
ax.set_ylim([tm_freqs.min(), tm_freqs.max()])
ax.set_xlim([x[0], x[-1]])

# Plot gaps
for gap in tm_gaps:
    if gap[0] > 1:
        ax.fill_between(x, gap[1], gap[2], color='blue', alpha=0.2)

for gap in te_gaps:
    if gap[0] > 1:
        ax.fill_between(x, gap[1], gap[2], color='red', alpha=0.2)


# Plot labels
ax.text(12, 0.04, 'TM bands', color='blue', size=15)
ax.text(13.05, 0.235, 'TE bands', color='red', size=15)

points_in_between = (len(tm_freqs) - 4) / 3
tick_locs = [i*points_in_between+i for i in range(4)]
tick_labs = ['Γ', 'K', 'M', 'Γ']
ax.set_xticks(tick_locs)
ax.set_xticklabels(tick_labs, size=16)
ax.set_ylabel('frequency (c/a)', size=16)
ax.grid(True)

plt.show()

# %%
efields = []

def get_efields(ms, band):
    efields.append(ms.get_efield(band, bloch_phase=True))

ms.run_te(mpb.output_at_kpoint(mp.Vector3(1/3, 1/3), mpb.fix_efield_phase,
          get_efields))

# Create an MPBData instance to transform the efields
md = mpb.MPBData(rectify=True, resolution=64, periods=3)

converted = []
for f in efields:
    # Get just the z component of the efields
    f = f[..., 0, 2]
    converted.append(md.convert(f))

for i, f in enumerate(converted):
    plt.subplot(331 + i)
    plt.contour(converted_eps.T, cmap='binary')
    plt.imshow(np.real(f).T, interpolation='spline36', cmap='bwr', alpha=0.9)
    plt.axis('off')

plt.show()
# Out:
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.5, 0.866025, 0)
#      (0.5, -0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, 0.57735, -0)
#      (1, -0.57735, 0)
#      (-0, 0, 1)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1e+20,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      cylinder, center = (0,0,0)
#           radius 0.25, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 10 object nodes (vs. 2 actual objects)
# Initializing epsilon function...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.1, 0.0, 0.0>
#   Vector3<0.2, 0.0, 0.0>
#   Vector3<0.30000000000000004, 0.0, 0.0>
#   Vector3<0.4, 0.0, 0.0>
#   Vector3<0.5, 0.0, 0.0>
#   Vector3<0.4666666666666667, 0.06666666666666667, 0.0>
#   Vector3<0.43333333333333335, 0.13333333333333333, 0.0>
#   Vector3<0.39999999999999997, 0.2, 0.0>
#   Vector3<0.36666666666666664, 0.26666666666666666, 0.0>
#   Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<0.26666666666666666, 0.26666666666666666, 0.0>
#   Vector3<0.19999999999999998, 0.19999999999999998, 0.0>
#   Vector3<0.1333333333333333, 0.1333333333333333, 0.0>
#   Vector3<0.06666666666666665, 0.06666666666666665, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.031905174255371094
# solve_kpoint (0,0,0):
# Solving for bands 2 to 4...
# Finished solving for bands 2 to 4 after 28 iterations.
# tefreqs:, 1, 0, 0, 0, 0, 0, 0.459588, 0.496461, 0.496631
# elapsed time for k point: 0.03809499740600586
# solve_kpoint (0.1,0,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 45 iterations.
# tefreqs:, 2, 0.1, 0, 0, 0.11547, 0.0525916, 0.44357, 0.485631, 0.494276
# elapsed time for k point: 0.05502510070800781
# solve_kpoint (0.2,0,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 9 iterations.
# tefreqs:, 3, 0.2, 0, 0, 0.23094, 0.104842, 0.412121, 0.458653, 0.488985
# elapsed time for k point: 0.023890018463134766
# solve_kpoint (0.3,0,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 7 iterations.
# tefreqs:, 4, 0.3, 0, 0, 0.34641, 0.156103, 0.371184, 0.439292, 0.48328
# elapsed time for k point: 0.015368223190307617
# solve_kpoint (0.4,0,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 7 iterations.
# tefreqs:, 5, 0.4, 0, 0, 0.46188, 0.204084, 0.327462, 0.42855, 0.479157
# elapsed time for k point: 0.016901016235351562
# solve_kpoint (0.5,0,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 6 iterations.
# tefreqs:, 6, 0.5, 0, 0, 0.57735, 0.232386, 0.300328, 0.425084, 0.477675
# elapsed time for k point: 0.0195009708404541
# solve_kpoint (0.466667,0.0666667,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 7 iterations.
# tefreqs:, 7, 0.466667, 0.0666667, 0, 0.581187, 0.234428, 0.301439, 0.413781, 0.48862
# elapsed time for k point: 0.01714158058166504
# solve_kpoint (0.433333,0.133333,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 7 iterations.
# tefreqs:, 8, 0.433333, 0.133333, 0, 0.592546, 0.240321, 0.304743, 0.391564, 0.50973
# elapsed time for k point: 0.016405820846557617
# solve_kpoint (0.4,0.2,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 8 iterations.
# tefreqs:, 9, 0.4, 0.2, 0, 0.61101, 0.249275, 0.310157, 0.367109, 0.532126
# elapsed time for k point: 0.019481658935546875
# solve_kpoint (0.366667,0.266667,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 9 iterations.
# tefreqs:, 10, 0.366667, 0.266667, 0, 0.635959, 0.259393, 0.317555, 0.343708, 0.551428
# elapsed time for k point: 0.019678592681884766
# solve_kpoint (0.333333,0.333333,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 9 iterations.
# tefreqs:, 11, 0.333333, 0.333333, 0, 0.666667, 0.26521, 0.326748, 0.326845, 0.559458
# elapsed time for k point: 0.01853346824645996
# Fixing e-field (band 1) phase by -1 + 1.8316e-08i; max ampl. = 0.505301
# Fixing e-field (band 2) phase by 1 + -1.8316e-08i; max ampl. = 0.86706
# Fixing e-field (band 3) phase by 1 + -1.8316e-08i; max ampl. = 0.851697
# Fixing e-field (band 4) phase by -1.8316e-08 + -1i; max ampl. = 0.565617
# solve_kpoint (0.266667,0.266667,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 9 iterations.
# tefreqs:, 12, 0.266667, 0.266667, 0, 0.533333, 0.234664, 0.340406, 0.349973, 0.544917
# elapsed time for k point: 0.018689393997192383
# solve_kpoint (0.2,0.2,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 8 iterations.
# tefreqs:, 13, 0.2, 0.2, 0, 0.4, 0.179804, 0.377946, 0.382909, 0.525719
# elapsed time for k point: 0.01732921600341797
# solve_kpoint (0.133333,0.133333,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 7 iterations.
# tefreqs:, 14, 0.133333, 0.133333, 0, 0.266667, 0.120911, 0.40889, 0.430946, 0.510592
# elapsed time for k point: 0.016080856323242188
# solve_kpoint (0.0666667,0.0666667,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 9 iterations.
# tefreqs:, 15, 0.0666667, 0.0666667, 0, 0.133333, 0.060704, 0.440022, 0.476598, 0.501254
# elapsed time for k point: 0.020738840103149414
# solve_kpoint (0,0,0):
# Solving for bands 2 to 4...
# Finished solving for bands 2 to 4 after 11 iterations.
# tefreqs:, 16, 0, 0, 0, 0, 0, 0.459588, 0.496461, 0.50238
# elapsed time for k point: 0.018389463424682617
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.2652101974612378 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.3003283862476727 at Vector3<0.5, 0.0, 0.0> to 0.459587601997861 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.32684546235575845 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0> to 0.49646074159300224 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.47767502578905824 at Vector3<0.5, 0.0, 0.0> to 0.5594577660284434 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
# Gap from band 1 (0.2652101974612378) to band 2 (0.3003283862476727), 12.419378552785238%
# total elapsed time for run: 0.3929257392883301
# done

# %%
#THz表示
a = 400
c_const = 299792458

fontsize = 18
te_freqs_THz = np.array(te_freqs) * c_const/(a*10**3)
te_gaps_THz = np.array(te_gaps) * c_const/(a*10**3)
#print(te_freqs_THz)

fig, ax = plt.subplots()

x = range(len(te_freqs))

for xz, tez in zip(x, te_freqs_THz):
    ax.scatter([xz]*len(tez), tez, color='navy')

ax.plot(te_freqs_THz, color='navy')
ax.set_ylim([te_freqs_THz.min(), te_freqs_THz.max()])
ax.set_xlim([x[0], x[-1]])

for gap in te_gaps_THz:
    if gap[0] > 1:
        ax.fill_between(x, gap[1], gap[2], color='blue', alpha=0.2)

ax.text(11.5, 0, 'TE bands', color='blue', size=15)

points_in_between = (len(te_freqs) - 4) / 3
tick_locs = [i*points_in_between+i for i in range(4)]
tick_labs = ['Γ', 'K', 'M', 'Γ']
ax.set_xticks(tick_locs)
ax.set_xticklabels(tick_labs, size=fontsize)
ax.set_ylabel('frequency [THz]', size=fontsize)
plt.tick_params(labelsize=fontsize)
ax.grid(True)

plt.show()
