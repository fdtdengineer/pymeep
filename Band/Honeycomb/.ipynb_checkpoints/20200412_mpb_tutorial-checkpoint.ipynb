# %% [markdown]
# 参考
# https://mpb.readthedocs.io/en/latest/Python_Data_Analysis_Tutorial/
# https://beiznotes.org/matplot-cmap-list/

# %%
import math
import meep as mp
from meep import mpb

import numpy as np
import matplotlib.pyplot as plt

# %%
num_bands = 8
resolution = 32
geometry_lattice = mp.Lattice(size=mp.Vector3(1, 1),
                              basis1=mp.Vector3(math.sqrt(3)/2, 0.5),
                              basis2=mp.Vector3(math.sqrt(3)/2, -0.5))
geometry = [mp.Cylinder(0.2, material=mp.Medium(epsilon=12))]
k_points = [
    mp.Vector3(),               # Gamma
    mp.Vector3(y=0.5),          # M
    mp.Vector3(-1./3, 1./3),    # K
    mp.Vector3(),               # Gamma
]
k_points = mp.interpolate(4, k_points)

ms = mpb.ModeSolver(
    geometry=geometry,
    geometry_lattice=geometry_lattice,
    k_points=k_points,
    resolution=resolution,
    num_bands=num_bands
)
ms.run_tm(mpb.output_at_kpoint(mp.Vector3(-1./3, 1./3), mpb.fix_efield_phase,
          mpb.output_efield_z))
tm_freqs = ms.all_freqs
tm_gaps = ms.gap_list
ms.run_te()
te_freqs = ms.all_freqs
te_gaps = ms.gap_list
# Out:
# Initializing eigensolver data
# Computing 8 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 8 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.866025, 0.5, 0)
#      (0.866025, -0.5, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (0.57735, 1, -0)
#      (0.57735, -1, 0)
#      (-0, 0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 1 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.0, 0.1, 0.0>
#   Vector3<0.0, 0.2, 0.0>
#   Vector3<0.0, 0.30000000000000004, 0.0>
#   Vector3<0.0, 0.4, 0.0>
#   Vector3<0.0, 0.5, 0.0>
#   Vector3<-0.06666666666666667, 0.4666666666666667, 0.0>
#   Vector3<-0.13333333333333333, 0.43333333333333335, 0.0>
#   Vector3<-0.2, 0.39999999999999997, 0.0>
#   Vector3<-0.26666666666666666, 0.36666666666666664, 0.0>
#   Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<-0.26666666666666666, 0.26666666666666666, 0.0>
#   Vector3<-0.19999999999999998, 0.19999999999999998, 0.0>
#   Vector3<-0.1333333333333333, 0.1333333333333333, 0.0>
#   Vector3<-0.06666666666666665, 0.06666666666666665, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.02530217170715332
# solve_kpoint (0,0,0):
# Solving for bands 2 to 8...
# Finished solving for bands 2 to 8 after 16 iterations.
# tmfreqs:, 1, 0, 0, 0, 0, 0, 0.560518, 0.560561, 0.593296, 0.837451, 0.837595, 0.994129, 1.09832
# elapsed time for k point: 0.08880114555358887
# solve_kpoint (0,0.1,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 9 iterations.
# tmfreqs:, 2, 0, 0.1, 0, 0.11547, 0.0711319, 0.538981, 0.559429, 0.617095, 0.834123, 0.839462, 0.988272, 1.08637
# elapsed time for k point: 0.040509939193725586
# solve_kpoint (0,0.2,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 3, 0, 0.2, 0, 0.23094, 0.138898, 0.508574, 0.556587, 0.65398, 0.825087, 0.84452, 0.968999, 1.05281
# elapsed time for k point: 0.06039929389953613
# solve_kpoint (0,0.3,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 4, 0, 0.3, 0, 0.34641, 0.198939, 0.479631, 0.553145, 0.693119, 0.813353, 0.850964, 0.932869, 1.02598
# elapsed time for k point: 0.05008554458618164
# solve_kpoint (0,0.4,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 5, 0, 0.4, 0, 0.46188, 0.244064, 0.4557, 0.550414, 0.730028, 0.80289, 0.856372, 0.891379, 1.01409
# elapsed time for k point: 0.046090126037597656
# solve_kpoint (0,0.5,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 6, 0, 0.5, 0, 0.57735, 0.262015, 0.445331, 0.549383, 0.749186, 0.797864, 0.85849, 0.870609, 1.01087
# elapsed time for k point: 0.0670020580291748
# solve_kpoint (-0.0666667,0.466667,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 7, -0.0666667, 0.466667, 0, 0.581187, 0.262984, 0.4475, 0.545804, 0.752448, 0.797093, 0.860461, 0.870245, 0.99895
# elapsed time for k point: 0.05434417724609375
# solve_kpoint (-0.133333,0.433333,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 8, -0.133333, 0.433333, 0, 0.592546, 0.265671, 0.453801, 0.535912, 0.761319, 0.795166, 0.866056, 0.869135, 0.973413
# elapsed time for k point: 0.047745704650878906
# solve_kpoint (-0.2,0.4,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 9, -0.2, 0.4, 0, 0.61101, 0.269404, 0.463648, 0.52172, 0.773443, 0.792931, 0.867201, 0.874681, 0.94487
# elapsed time for k point: 0.05091547966003418
# solve_kpoint (-0.266667,0.366667,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 10, -0.266667, 0.366667, 0, 0.635959, 0.273, 0.476141, 0.505606, 0.78524, 0.791235, 0.864672, 0.885801, 0.918597
# elapsed time for k point: 0.04786276817321777
# solve_kpoint (-0.333333,0.333333,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 11, -0.333333, 0.333333, 0, 0.666667, 0.27469, 0.489984, 0.490239, 0.79072, 0.790832, 0.863041, 0.899109, 0.89925
# elapsed time for k point: 0.039829254150390625
# Fixing e-field (band 1) phase by -1 + 2.25111e-06i; max ampl. = 0.939117
# Outputting fields to e.k11.b01.z.tm.h5...
# Fixing e-field (band 2) phase by 2.25111e-06 + 1i; max ampl. = 1.08316
# Outputting fields to e.k11.b02.z.tm.h5...
# Fixing e-field (band 3) phase by 1 + -2.25111e-06i; max ampl. = 0.877941
# Outputting fields to e.k11.b03.z.tm.h5...
# Fixing e-field (band 4) phase by 1 + -2.25111e-06i; max ampl. = 1.24656
# Outputting fields to e.k11.b04.z.tm.h5...
# Fixing e-field (band 5) phase by 2.25111e-06 + 1i; max ampl. = 1.10167
# Outputting fields to e.k11.b05.z.tm.h5...
# Fixing e-field (band 6) phase by 1 + -2.25111e-06i; max ampl. = 1.76187
# Outputting fields to e.k11.b06.z.tm.h5...
# Fixing e-field (band 7) phase by -1 + 2.25111e-06i; max ampl. = 1.08811
# Outputting fields to e.k11.b07.z.tm.h5...
# Fixing e-field (band 8) phase by -1 + 2.25111e-06i; max ampl. = 1.08096
# Outputting fields to e.k11.b08.z.tm.h5...
# solve_kpoint (-0.266667,0.266667,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 12, -0.266667, 0.266667, 0, 0.533333, 0.2632, 0.47091, 0.51804, 0.764413, 0.795091, 0.864427, 0.896871, 0.932925
# elapsed time for k point: 0.03388619422912598
# solve_kpoint (-0.2,0.2,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 13, -0.2, 0.2, 0, 0.4, 0.222593, 0.476537, 0.539917, 0.715636, 0.806516, 0.856013, 0.929969, 0.977199
# elapsed time for k point: 0.040189266204833984
# solve_kpoint (-0.133333,0.133333,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 14, -0.133333, 0.133333, 0, 0.266667, 0.15856, 0.501245, 0.552927, 0.666818, 0.82116, 0.846938, 0.963589, 1.03113
# elapsed time for k point: 0.04146909713745117
# solve_kpoint (-0.0666667,0.0666667,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 10 iterations.
# tmfreqs:, 15, -0.0666667, 0.0666667, 0, 0.133333, 0.0819275, 0.534465, 0.558896, 0.622523, 0.832982, 0.840137, 0.98638, 1.08149
# elapsed time for k point: 0.04937148094177246
# solve_kpoint (0,0,0):
# Solving for bands 2 to 8...
# Finished solving for bands 2 to 8 after 10 iterations.
# tmfreqs:, 16, 0, 0, 0, 0, 0, 0.560518, 0.560561, 0.593296, 0.837451, 0.837595, 0.994129, 1.09832
# elapsed time for k point: 0.04589223861694336
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.27469022601674814 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.44533108106909824 at Vector3<0.0, 0.5, 0.0> to 0.5605181426627356 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.49023891496896843 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 0.5605607964661271 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.5932960876545491 at Vector3<0.0, 0.0, 0.0> to 0.7907195975678292 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 5 range: 0.790832076496516 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 0.8374511174311544 at Vector3<0.0, 0.0, 0.0>
# Band 6 range: 0.8375948532682681 at Vector3<0.0, 0.0, 0.0> to 0.8672009266363943 at Vector3<-0.2, 0.39999999999999997, 0.0>
# Band 7 range: 0.8691349976047843 at Vector3<-0.13333333333333333, 0.43333333333333335, 0.0> to 0.9941291047700213 at Vector3<0.0, 0.0, 0.0>
# Band 8 range: 0.8992499096210428 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 1.0983183583015097 at Vector3<0.0, 0.0, 0.0>
# Gap from band 1 (0.27469022601674814) to band 2 (0.44533108106909824), 47.398834832537815%
# Gap from band 3 (0.5605607964661271) to band 4 (0.5932960876545491), 5.674064372960551%
# Gap from band 4 (0.7907195975678292) to band 5 (0.790832076496516), 0.014223870206879487%
# Gap from band 5 (0.8374511174311544) to band 6 (0.8375948532682681), 0.017162016998694355%
# Gap from band 6 (0.8672009266363943) to band 7 (0.8691349976047843), 0.22277612775134872%
# total elapsed time for run: 0.9135558605194092
# done
# Initializing eigensolver data
# Computing 8 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 8 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.866025, 0.5, 0)
#      (0.866025, -0.5, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (0.57735, 1, -0)
#      (0.57735, -1, 0)
#      (-0, 0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 1 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.0, 0.1, 0.0>
#   Vector3<0.0, 0.2, 0.0>
#   Vector3<0.0, 0.30000000000000004, 0.0>
#   Vector3<0.0, 0.4, 0.0>
#   Vector3<0.0, 0.5, 0.0>
#   Vector3<-0.06666666666666667, 0.4666666666666667, 0.0>
#   Vector3<-0.13333333333333333, 0.43333333333333335, 0.0>
#   Vector3<-0.2, 0.39999999999999997, 0.0>
#   Vector3<-0.26666666666666666, 0.36666666666666664, 0.0>
#   Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<-0.26666666666666666, 0.26666666666666666, 0.0>
#   Vector3<-0.19999999999999998, 0.19999999999999998, 0.0>
#   Vector3<-0.1333333333333333, 0.1333333333333333, 0.0>
#   Vector3<-0.06666666666666665, 0.06666666666666665, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.02762436866760254
# solve_kpoint (0,0,0):
# Solving for bands 2 to 8...
# Finished solving for bands 2 to 8 after 27 iterations.
# tefreqs:, 1, 0, 0, 0, 0, 0, 0.561229, 0.793929, 0.794659, 1.03341, 1.03342, 1.11597, 1.11681
# elapsed time for k point: 0.11544060707092285
# solve_kpoint (0,0.1,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 14 iterations.
# tefreqs:, 2, 0, 0.1, 0, 0.11547, 0.101865, 0.559805, 0.79146, 0.793258, 0.992126, 1.02845, 1.09799, 1.1151
# elapsed time for k point: 0.06745338439941406
# solve_kpoint (0,0.2,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 14 iterations.
# tefreqs:, 3, 0, 0.2, 0, 0.23094, 0.202662, 0.555133, 0.784265, 0.784932, 0.925328, 1.01804, 1.06979, 1.11298
# elapsed time for k point: 0.07585382461547852
# solve_kpoint (0,0.3,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 11 iterations.
# tefreqs:, 4, 0, 0.3, 0, 0.34641, 0.300756, 0.545003, 0.752836, 0.776604, 0.881528, 1.00851, 1.04494, 1.1117
# elapsed time for k point: 0.05381655693054199
# solve_kpoint (0,0.4,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 10 iterations.
# tefreqs:, 5, 0, 0.4, 0, 0.46188, 0.392756, 0.521577, 0.705571, 0.77011, 0.86865, 1.00251, 1.02766, 1.11107
# elapsed time for k point: 0.04648995399475098
# solve_kpoint (0,0.5,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 9 iterations.
# tefreqs:, 6, 0, 0.5, 0, 0.57735, 0.468428, 0.473072, 0.683225, 0.767661, 0.866987, 1.00052, 1.02137, 1.11088
# elapsed time for k point: 0.04199028015136719
# solve_kpoint (-0.0666667,0.466667,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 11 iterations.
# tefreqs:, 7, -0.0666667, 0.466667, 0, 0.581187, 0.472654, 0.474197, 0.67604, 0.772695, 0.866879, 0.969813, 1.05066, 1.11081
# elapsed time for k point: 0.06097054481506348
# solve_kpoint (-0.133333,0.433333,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 12 iterations.
# tefreqs:, 8, -0.133333, 0.433333, 0, 0.592546, 0.477432, 0.485081, 0.657266, 0.784802, 0.866577, 0.932933, 1.08112, 1.11059
# elapsed time for k point: 0.045473337173461914
# solve_kpoint (-0.2,0.4,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 12 iterations.
# tefreqs:, 9, -0.2, 0.4, 0, 0.61101, 0.48232, 0.50501, 0.630584, 0.799745, 0.866126, 0.900465, 1.09936, 1.11024
# elapsed time for k point: 0.05055999755859375
# solve_kpoint (-0.266667,0.366667,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 11 iterations.
# tefreqs:, 10, -0.266667, 0.366667, 0, 0.635959, 0.487852, 0.531427, 0.598151, 0.814208, 0.865617, 0.875643, 1.10711, 1.10983
# elapsed time for k point: 0.04492592811584473
# solve_kpoint (-0.333333,0.333333,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 11 iterations.
# tefreqs:, 11, -0.333333, 0.333333, 0, 0.666667, 0.491236, 0.563106, 0.563151, 0.821423, 0.865195, 0.865231, 1.10923, 1.10941
# elapsed time for k point: 0.04888486862182617
# solve_kpoint (-0.266667,0.266667,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 12 iterations.
# tefreqs:, 12, -0.266667, 0.266667, 0, 0.533333, 0.446126, 0.532191, 0.637012, 0.806654, 0.86614, 0.893198, 1.10593, 1.10866
# elapsed time for k point: 0.056075334548950195
# solve_kpoint (-0.2,0.2,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 11 iterations.
# tefreqs:, 13, -0.2, 0.2, 0, 0.4, 0.345267, 0.542882, 0.713396, 0.795022, 0.875814, 0.938821, 1.09707, 1.10904
# elapsed time for k point: 0.05365800857543945
# solve_kpoint (-0.133333,0.133333,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 15 iterations.
# tefreqs:, 14, -0.133333, 0.133333, 0, 0.266667, 0.233479, 0.553269, 0.768719, 0.792196, 0.912766, 0.987203, 1.08919, 1.11098
# elapsed time for k point: 0.05165410041809082
# solve_kpoint (-0.0666667,0.0666667,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 17 iterations.
# tefreqs:, 15, -0.0666667, 0.0666667, 0, 0.133333, 0.117556, 0.559323, 0.789736, 0.793576, 0.983043, 1.02374, 1.09661, 1.11448
# elapsed time for k point: 0.05397629737854004
# solve_kpoint (0,0,0):
# Solving for bands 2 to 8...
# Finished solving for bands 2 to 8 after 21 iterations.
# tefreqs:, 16, 0, 0, 0, 0, 0, 0.561229, 0.793929, 0.794659, 1.03341, 1.03342, 1.11597, 1.11681
# elapsed time for k point: 0.0665440559387207
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.49123581641554226 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.47307223980426816 at Vector3<0.0, 0.5, 0.0> to 0.5631059454934053 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 3 range: 0.563150523734039 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 0.7939289547111661 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.7676614802374117 at Vector3<0.0, 0.5, 0.0> to 0.8214230165371808 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 5 range: 0.8651948161669999 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 1.033413029183607 at Vector3<0.0, 0.0, 0.0>
# Band 6 range: 0.8652308007806802 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 1.0334231173223325 at Vector3<0.0, 0.0, 0.0>
# Band 7 range: 1.0213677200947735 at Vector3<0.0, 0.5, 0.0> to 1.1159672179786009 at Vector3<0.0, 0.0, 0.0>
# Band 8 range: 1.1086627112265817 at Vector3<-0.26666666666666666, 0.26666666666666666, 0.0> to 1.1168107961320408 at Vector3<0.0, 0.0, 0.0>
# Gap from band 2 (0.5631059454934053) to band 3 (0.563150523734039), 0.00791617928094476%
# Gap from band 4 (0.8214230165371808) to band 5 (0.8651948161669999), 5.190482251647859%
# total elapsed time for run: 0.9661166667938232
# done

# %%
md = mpb.MPBData(rectify=True, periods=3, resolution=32)
eps = ms.get_epsilon()
converted_eps = md.convert(eps)
# Out:
# epsilon: 1-12, mean 2.59614, harm. mean 1.17149, 17.2852% > 1, 14.5104% "fill"

# %%
plt.imshow(converted_eps.T, interpolation='spline36', cmap='binary')
plt.axis('off')
plt.show()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()
x = range(len(tm_freqs))
# Plot bands
# Scatter plot for multiple y values, see https://stackoverflow.com/a/34280815/2261298
for xz, tmz, tez in zip(x, tm_freqs, te_freqs):
    ax.scatter([xz]*len(tmz), tmz, color='blue')
    ax.scatter([xz]*len(tez), tez, color='red', facecolors='none')
ax.plot(tm_freqs, color='blue')
ax.plot(te_freqs, color='red')
ax.set_ylim([0, 1])
ax.set_xlim([x[0], x[-1]])

# Plot gaps
for gap in tm_gaps:
    if gap[0] > 1:
        ax.fill_between(x, gap[1], gap[2], color='blue', alpha=0.2)

for gap in te_gaps:
    if gap[0] > 1:
        ax.fill_between(x, gap[1], gap[2], color='red', alpha=0.2)


# Plot labels
ax.text(12, 0.04, 'TM bands', color='blue', size=15)
ax.text(13.05, 0.235, 'TE bands', color='red', size=15)

points_in_between = (len(tm_freqs) - 4) / 3
tick_locs = [i*points_in_between+i for i in range(4)]
tick_labs = ['Γ', 'X', 'M', 'Γ']
ax.set_xticks(tick_locs)
ax.set_xticklabels(tick_labs, size=16)
ax.set_ylabel('frequency (c/a)', size=16)
ax.grid(True)

plt.show()

# %%
efields = []

def get_efields(ms, band):
    efields.append(ms.get_efield(band, bloch_phase=True))

ms.run_tm(mpb.output_at_kpoint(mp.Vector3(1 / -3, 1 / 3), mpb.fix_efield_phase,
          get_efields))

# Create an MPBData instance to transform the efields
md = mpb.MPBData(rectify=True, resolution=32, periods=3)

converted = []
for f in efields:
    # Get just the z component of the efields
    f = f[..., 0, 2]
    converted.append(md.convert(f))

for i, f in enumerate(converted):
    plt.subplot(331 + i)
    plt.contour(converted_eps.T, cmap='binary')
    plt.imshow(np.real(f).T, interpolation='spline36', cmap='bwr', alpha=0.9)
    plt.axis('off')

plt.show()
# Out:
# Initializing eigensolver data
# Computing 8 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 8 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.866025, 0.5, 0)
#      (0.866025, -0.5, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (0.57735, 1, -0)
#      (0.57735, -1, 0)
#      (-0, 0, 1)
# Geometric objects:
#      cylinder, center = (0,0,0)
#           radius 0.2, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 1 object nodes (vs. 1 actual objects)
# Initializing epsilon function...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.0, 0.1, 0.0>
#   Vector3<0.0, 0.2, 0.0>
#   Vector3<0.0, 0.30000000000000004, 0.0>
#   Vector3<0.0, 0.4, 0.0>
#   Vector3<0.0, 0.5, 0.0>
#   Vector3<-0.06666666666666667, 0.4666666666666667, 0.0>
#   Vector3<-0.13333333333333333, 0.43333333333333335, 0.0>
#   Vector3<-0.2, 0.39999999999999997, 0.0>
#   Vector3<-0.26666666666666666, 0.36666666666666664, 0.0>
#   Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<-0.26666666666666666, 0.26666666666666666, 0.0>
#   Vector3<-0.19999999999999998, 0.19999999999999998, 0.0>
#   Vector3<-0.1333333333333333, 0.1333333333333333, 0.0>
#   Vector3<-0.06666666666666665, 0.06666666666666665, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.034453630447387695
# solve_kpoint (0,0,0):
# Solving for bands 2 to 8...
# Finished solving for bands 2 to 8 after 18 iterations.
# tmfreqs:, 1, 0, 0, 0, 0, 0, 0.560518, 0.560561, 0.593296, 0.837451, 0.837595, 0.994129, 1.09832
# elapsed time for k point: 0.07621622085571289
# solve_kpoint (0,0.1,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 9 iterations.
# tmfreqs:, 2, 0, 0.1, 0, 0.11547, 0.0711319, 0.538981, 0.559429, 0.617095, 0.834123, 0.839462, 0.988272, 1.08637
# elapsed time for k point: 0.04346585273742676
# solve_kpoint (0,0.2,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 3, 0, 0.2, 0, 0.23094, 0.138898, 0.508574, 0.556587, 0.65398, 0.825087, 0.84452, 0.968999, 1.05281
# elapsed time for k point: 0.04727458953857422
# solve_kpoint (0,0.3,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 4, 0, 0.3, 0, 0.34641, 0.198939, 0.479631, 0.553145, 0.693119, 0.813353, 0.850964, 0.932869, 1.02598
# elapsed time for k point: 0.04737067222595215
# solve_kpoint (0,0.4,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 5, 0, 0.4, 0, 0.46188, 0.244064, 0.4557, 0.550414, 0.730028, 0.80289, 0.856372, 0.891379, 1.01409
# elapsed time for k point: 0.043975830078125
# solve_kpoint (0,0.5,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 6, 0, 0.5, 0, 0.57735, 0.262015, 0.445331, 0.549383, 0.749186, 0.797864, 0.85849, 0.870609, 1.01087
# elapsed time for k point: 0.04667830467224121
# solve_kpoint (-0.0666667,0.466667,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 7, -0.0666667, 0.466667, 0, 0.581187, 0.262984, 0.4475, 0.545804, 0.752448, 0.797093, 0.860461, 0.870245, 0.99895
# elapsed time for k point: 0.04815673828125
# solve_kpoint (-0.133333,0.433333,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 8, -0.133333, 0.433333, 0, 0.592546, 0.265671, 0.453801, 0.535912, 0.761319, 0.795166, 0.866056, 0.869135, 0.973413
# elapsed time for k point: 0.04283452033996582
# solve_kpoint (-0.2,0.4,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 9, -0.2, 0.4, 0, 0.61101, 0.269404, 0.463648, 0.52172, 0.773443, 0.792931, 0.867201, 0.874681, 0.94487
# elapsed time for k point: 0.04124903678894043
# solve_kpoint (-0.266667,0.366667,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 10, -0.266667, 0.366667, 0, 0.635959, 0.273, 0.476141, 0.505606, 0.78524, 0.791235, 0.864672, 0.885801, 0.918597
# elapsed time for k point: 0.045085906982421875
# solve_kpoint (-0.333333,0.333333,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 11, -0.333333, 0.333333, 0, 0.666667, 0.27469, 0.489984, 0.490239, 0.79072, 0.790832, 0.863041, 0.899109, 0.89925
# elapsed time for k point: 0.04377603530883789
# Fixing e-field (band 1) phase by -1 + -8.75278e-07i; max ampl. = 0.939117
# Fixing e-field (band 2) phase by 8.75278e-07 + -1i; max ampl. = 1.08316
# Fixing e-field (band 3) phase by -1 + -8.75278e-07i; max ampl. = 0.877941
# Fixing e-field (band 4) phase by -1 + -8.75278e-07i; max ampl. = 1.24656
# Fixing e-field (band 5) phase by 8.75278e-07 + -1i; max ampl. = 1.10167
# Fixing e-field (band 6) phase by -1 + -8.75278e-07i; max ampl. = 1.76187
# Fixing e-field (band 7) phase by 1 + 8.75278e-07i; max ampl. = 1.08811
# Fixing e-field (band 8) phase by 1 + 8.75278e-07i; max ampl. = 1.08096
# solve_kpoint (-0.266667,0.266667,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 6 iterations.
# tmfreqs:, 12, -0.266667, 0.266667, 0, 0.533333, 0.2632, 0.47091, 0.51804, 0.764413, 0.795091, 0.864427, 0.896871, 0.932925
# elapsed time for k point: 0.040094852447509766
# solve_kpoint (-0.2,0.2,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 7 iterations.
# tmfreqs:, 13, -0.2, 0.2, 0, 0.4, 0.222593, 0.476537, 0.539917, 0.715636, 0.806516, 0.856013, 0.929969, 0.977199
# elapsed time for k point: 0.04538249969482422
# solve_kpoint (-0.133333,0.133333,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 8 iterations.
# tmfreqs:, 14, -0.133333, 0.133333, 0, 0.266667, 0.15856, 0.501245, 0.552927, 0.666818, 0.82116, 0.846938, 0.963589, 1.03113
# elapsed time for k point: 0.04737067222595215
# solve_kpoint (-0.0666667,0.0666667,0):
# Solving for bands 1 to 8...
# Finished solving for bands 1 to 8 after 10 iterations.
# tmfreqs:, 15, -0.0666667, 0.0666667, 0, 0.133333, 0.0819275, 0.534465, 0.558896, 0.622523, 0.832982, 0.840137, 0.98638, 1.08149
# elapsed time for k point: 0.051572322845458984
# solve_kpoint (0,0,0):
# Solving for bands 2 to 8...
# Finished solving for bands 2 to 8 after 10 iterations.
# tmfreqs:, 16, 0, 0, 0, 0, 0, 0.560518, 0.560561, 0.593296, 0.837451, 0.837595, 0.994129, 1.09832
# elapsed time for k point: 0.057894229888916016
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.2746902260167484 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.44533108106909736 at Vector3<0.0, 0.5, 0.0> to 0.5605181434220403 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.4902389149689679 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 0.5605607960831812 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.5932960882624113 at Vector3<0.0, 0.0, 0.0> to 0.7907195975678294 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 5 range: 0.7908320764965171 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 0.8374511194303014 at Vector3<0.0, 0.0, 0.0>
# Band 6 range: 0.8375948534447982 at Vector3<0.0, 0.0, 0.0> to 0.8672009266363935 at Vector3<-0.2, 0.39999999999999997, 0.0>
# Band 7 range: 0.869134997604785 at Vector3<-0.13333333333333333, 0.43333333333333335, 0.0> to 0.9941291094258787 at Vector3<0.0, 0.0, 0.0>
# Band 8 range: 0.8992499096210425 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 1.0983183672757244 at Vector3<0.0, 0.0, 0.0>
# Gap from band 1 (0.2746902260167484) to band 2 (0.44533108106909736), 47.398834832537524%
# Gap from band 3 (0.5605607960831812) to band 4 (0.5932960882624113), 5.674064543593004%
# Gap from band 4 (0.7907195975678294) to band 5 (0.7908320764965171), 0.014223870206991791%
# Gap from band 5 (0.8374511194303014) to band 6 (0.8375948534447982), 0.017161799356485152%
# Gap from band 6 (0.8672009266363935) to band 7 (0.869134997604785), 0.22277612775151498%
# total elapsed time for run: 0.8196914196014404
# done
