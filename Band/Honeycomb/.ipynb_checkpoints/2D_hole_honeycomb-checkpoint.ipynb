# %%
import math
import meep as mp
from meep import mpb

import numpy as np
import matplotlib.pyplot as plt

# %%
#屈折率
n_Air = 1
n_Si = 2.6
r = 0.14


#計算する固有周波数の数
num_bands = 4

#メッシュの細かさ
resolution = 32

#単位格子
geometry_lattice = mp.Lattice(size=mp.Vector3(1, 1),
                              basis1=mp.Vector3(math.sqrt(3)/2, 0.5),
                              basis2=mp.Vector3(math.sqrt(3)/2, -0.5))

#構造
#default_material = mp.Medium(epsilon=n_Si**2)
geometry = [
            mp.Block(material=mp.Medium(epsilon=n_Si**2),
                        size=mp.Vector3(mp.inf, mp.inf)),
            mp.Cylinder(r, center=mp.Vector3(1 / 6, 1 / 6), height=mp.inf,
                        material=mp.Medium(epsilon=n_Air**2)),
            mp.Cylinder(r, center=mp.Vector3(1 / -6, 1 / -6), height=mp.inf,
                        material=mp.Medium(epsilon=n_Air**2))
           ]


#ブリルアンゾーン
k_points = [
    mp.Vector3(),               # Gamma
    mp.Vector3(y=0.5),          # M
    mp.Vector3(-1./3, 1./3),    # K
    mp.Vector3(),               # Gamma
]
k_points = mp.interpolate(4, k_points)

# %%
#計算
ms = mpb.ModeSolver(
    geometry=geometry,
    geometry_lattice=geometry_lattice,
    k_points=k_points,
    resolution=resolution,
    num_bands=num_bands
)

ms.run_tm(mpb.output_at_kpoint(mp.Vector3(-1./3, 1./3),
                               mpb.fix_efield_phase,
                               mpb.output_efield_z))
tm_freqs = ms.all_freqs
tm_gaps = ms.gap_list
ms.run_te()
te_freqs = ms.all_freqs
te_gaps = ms.gap_list
# Out:
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.866025, 0.5, 0)
#      (0.866025, -0.5, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (0.57735, 1, -0)
#      (0.57735, -1, 0)
#      (-0, 0, 1)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1e+20,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      cylinder, center = (0.166667,0.166667,0)
#           radius 0.14, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (-0.166667,-0.166667,0)
#           radius 0.14, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 11 object nodes (vs. 3 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.0, 0.1, 0.0>
#   Vector3<0.0, 0.2, 0.0>
#   Vector3<0.0, 0.30000000000000004, 0.0>
#   Vector3<0.0, 0.4, 0.0>
#   Vector3<0.0, 0.5, 0.0>
#   Vector3<-0.06666666666666667, 0.4666666666666667, 0.0>
#   Vector3<-0.13333333333333333, 0.43333333333333335, 0.0>
#   Vector3<-0.2, 0.39999999999999997, 0.0>
#   Vector3<-0.26666666666666666, 0.36666666666666664, 0.0>
#   Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<-0.26666666666666666, 0.26666666666666666, 0.0>
#   Vector3<-0.19999999999999998, 0.19999999999999998, 0.0>
#   Vector3<-0.1333333333333333, 0.1333333333333333, 0.0>
#   Vector3<-0.06666666666666665, 0.06666666666666665, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.028252363204956055
# solve_kpoint (0,0,0):
# Solving for bands 2 to 4...
# Finished solving for bands 2 to 4 after 41 iterations.
# tmfreqs:, 1, 0, 0, 0, 0, 0, 0.448608, 0.448652, 0.456653
# elapsed time for k point: 0.06716775894165039
# solve_kpoint (0,0.1,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 20 iterations.
# tmfreqs:, 2, 0, 0.1, 0, 0.11547, 0.047364, 0.415764, 0.431592, 0.45568
# elapsed time for k point: 0.03509330749511719
# solve_kpoint (0,0.2,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 6 iterations.
# tmfreqs:, 3, 0, 0.2, 0, 0.23094, 0.0946643, 0.373002, 0.41489, 0.444225
# elapsed time for k point: 0.01682448387145996
# solve_kpoint (0,0.3,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 5 iterations.
# tmfreqs:, 4, 0, 0.3, 0, 0.34641, 0.141818, 0.328333, 0.402448, 0.433328
# elapsed time for k point: 0.01590275764465332
# solve_kpoint (0,0.4,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 5 iterations.
# tmfreqs:, 5, 0, 0.4, 0, 0.46188, 0.188631, 0.282809, 0.394779, 0.426077
# elapsed time for k point: 0.0171964168548584
# solve_kpoint (0,0.5,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 4 iterations.
# tmfreqs:, 6, 0, 0.5, 0, 0.57735, 0.229097, 0.242744, 0.392188, 0.423563
# elapsed time for k point: 0.015403032302856445
# solve_kpoint (-0.0666667,0.466667,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 5 iterations.
# tmfreqs:, 7, -0.0666667, 0.466667, 0, 0.581187, 0.230584, 0.244331, 0.377142, 0.438462
# elapsed time for k point: 0.01569056510925293
# solve_kpoint (-0.133333,0.433333,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 5 iterations.
# tmfreqs:, 8, -0.133333, 0.433333, 0, 0.592546, 0.234964, 0.249026, 0.352678, 0.46247
# elapsed time for k point: 0.015926122665405273
# solve_kpoint (-0.2,0.4,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 5 iterations.
# tmfreqs:, 9, -0.2, 0.4, 0, 0.61101, 0.241987, 0.256645, 0.326964, 0.487344
# elapsed time for k point: 0.011631965637207031
# solve_kpoint (-0.266667,0.366667,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 6 iterations.
# tmfreqs:, 10, -0.266667, 0.366667, 0, 0.635959, 0.251032, 0.266911, 0.301317, 0.511299
# elapsed time for k point: 0.015542745590209961
# solve_kpoint (-0.333333,0.333333,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 7 iterations.
# tmfreqs:, 11, -0.333333, 0.333333, 0, 0.666667, 0.258292, 0.279473, 0.279505, 0.525309
# elapsed time for k point: 0.02117013931274414
# Fixing e-field (band 1) phase by 1 + 5.57578e-06i; max ampl. = 0.726579
# Outputting fields to e.k11.b01.z.tm.h5...
# Fixing e-field (band 2) phase by -1 + -5.57578e-06i; max ampl. = 0.648863
# Outputting fields to e.k11.b02.z.tm.h5...
# Fixing e-field (band 3) phase by -1 + -5.57578e-06i; max ampl. = 0.749208
# Outputting fields to e.k11.b03.z.tm.h5...
# Fixing e-field (band 4) phase by 1 + 5.57578e-06i; max ampl. = 0.755823
# Outputting fields to e.k11.b04.z.tm.h5...
# solve_kpoint (-0.266667,0.266667,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 7 iterations.
# tmfreqs:, 12, -0.266667, 0.266667, 0, 0.533333, 0.217259, 0.296568, 0.310212, 0.50767
# elapsed time for k point: 0.01590251922607422
# solve_kpoint (-0.2,0.2,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 6 iterations.
# tmfreqs:, 13, -0.2, 0.2, 0, 0.4, 0.163615, 0.331547, 0.346125, 0.488776
# elapsed time for k point: 0.018297910690307617
# solve_kpoint (-0.133333,0.133333,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 7 iterations.
# tmfreqs:, 14, -0.133333, 0.133333, 0, 0.266667, 0.109274, 0.370879, 0.38452, 0.474418
# elapsed time for k point: 0.015085935592651367
# solve_kpoint (-0.0666667,0.0666667,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 9 iterations.
# tmfreqs:, 15, -0.0666667, 0.0666667, 0, 0.133333, 0.0546873, 0.412623, 0.421839, 0.46522
# elapsed time for k point: 0.01955270767211914
# solve_kpoint (0,0,0):
# Solving for bands 2 to 4...
# Finished solving for bands 2 to 4 after 17 iterations.
# tmfreqs:, 16, 0, 0, 0, 0, 0, 0.448608, 0.448652, 0.456851
# elapsed time for k point: 0.023507118225097656
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.2582915180279046 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.24274407968103065 at Vector3<0.0, 0.5, 0.0> to 0.44860811590611194 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.2795052137489328 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 0.44865223380732727 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.42356310521865703 at Vector3<0.0, 0.5, 0.0> to 0.5253094560138579 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# total elapsed time for run: 0.41353368759155273
# done
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.866025, 0.5, 0)
#      (0.866025, -0.5, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (0.57735, 1, -0)
#      (0.57735, -1, 0)
#      (-0, 0, 1)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1e+20,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      cylinder, center = (0.166667,0.166667,0)
#           radius 0.14, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (-0.166667,-0.166667,0)
#           radius 0.14, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 11 object nodes (vs. 3 actual objects)
# Initializing epsilon function...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.0, 0.1, 0.0>
#   Vector3<0.0, 0.2, 0.0>
#   Vector3<0.0, 0.30000000000000004, 0.0>
#   Vector3<0.0, 0.4, 0.0>
#   Vector3<0.0, 0.5, 0.0>
#   Vector3<-0.06666666666666667, 0.4666666666666667, 0.0>
#   Vector3<-0.13333333333333333, 0.43333333333333335, 0.0>
#   Vector3<-0.2, 0.39999999999999997, 0.0>
#   Vector3<-0.26666666666666666, 0.36666666666666664, 0.0>
#   Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<-0.26666666666666666, 0.26666666666666666, 0.0>
#   Vector3<-0.19999999999999998, 0.19999999999999998, 0.0>
#   Vector3<-0.1333333333333333, 0.1333333333333333, 0.0>
#   Vector3<-0.06666666666666665, 0.06666666666666665, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.03490042686462402
# solve_kpoint (0,0,0):
# Solving for bands 2 to 4...
# Finished solving for bands 2 to 4 after 33 iterations.
# tefreqs:, 1, 0, 0, 0, 0, 0, 0.449103, 0.457009, 0.482864
# elapsed time for k point: 0.04506111145019531
# solve_kpoint (0,0.1,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 16 iterations.
# tefreqs:, 2, 0, 0.1, 0, 0.11547, 0.0493878, 0.427458, 0.443635, 0.478998
# elapsed time for k point: 0.034214019775390625
# solve_kpoint (0,0.2,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 9 iterations.
# tefreqs:, 3, 0, 0.2, 0, 0.23094, 0.0986961, 0.387705, 0.423599, 0.470976
# elapsed time for k point: 0.031572818756103516
# solve_kpoint (0,0.3,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 7 iterations.
# tefreqs:, 4, 0, 0.3, 0, 0.34641, 0.147804, 0.342544, 0.408104, 0.463384
# elapsed time for k point: 0.025892257690429688
# solve_kpoint (0,0.4,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 7 iterations.
# tefreqs:, 5, 0, 0.4, 0, 0.46188, 0.196353, 0.295741, 0.398467, 0.4583
# elapsed time for k point: 0.02355813980102539
# solve_kpoint (0,0.5,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 6 iterations.
# tefreqs:, 6, 0, 0.5, 0, 0.57735, 0.23572, 0.256883, 0.395197, 0.456532
# elapsed time for k point: 0.01853203773498535
# solve_kpoint (-0.0666667,0.466667,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 6 iterations.
# tefreqs:, 7, -0.0666667, 0.466667, 0, 0.581187, 0.23755, 0.25822, 0.384716, 0.466714
# elapsed time for k point: 0.0209808349609375
# solve_kpoint (-0.133333,0.433333,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 7 iterations.
# tefreqs:, 8, -0.133333, 0.433333, 0, 0.592546, 0.242953, 0.262168, 0.362907, 0.487566
# elapsed time for k point: 0.024359941482543945
# solve_kpoint (-0.2,0.4,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 7 iterations.
# tefreqs:, 9, -0.2, 0.4, 0, 0.61101, 0.251689, 0.268513, 0.337795, 0.510844
# elapsed time for k point: 0.017700910568237305
# solve_kpoint (-0.266667,0.366667,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 8 iterations.
# tefreqs:, 10, -0.266667, 0.366667, 0, 0.635959, 0.263409, 0.276581, 0.312024, 0.533448
# elapsed time for k point: 0.02453899383544922
# solve_kpoint (-0.333333,0.333333,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 9 iterations.
# tefreqs:, 11, -0.333333, 0.333333, 0, 0.666667, 0.277697, 0.277735, 0.294667, 0.55154
# elapsed time for k point: 0.021576642990112305
# solve_kpoint (-0.266667,0.266667,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 12 iterations.
# tefreqs:, 12, -0.266667, 0.266667, 0, 0.533333, 0.226568, 0.312422, 0.317744, 0.526542
# elapsed time for k point: 0.0180513858795166
# solve_kpoint (-0.2,0.2,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 6 iterations.
# tefreqs:, 13, -0.2, 0.2, 0, 0.4, 0.170553, 0.350406, 0.352747, 0.505998
# elapsed time for k point: 0.017633676528930664
# solve_kpoint (-0.133333,0.133333,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 7 iterations.
# tefreqs:, 14, -0.133333, 0.133333, 0, 0.266667, 0.113926, 0.38672, 0.395809, 0.490893
# elapsed time for k point: 0.018327951431274414
# solve_kpoint (-0.0666667,0.0666667,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 9 iterations.
# tefreqs:, 15, -0.0666667, 0.0666667, 0, 0.133333, 0.0570226, 0.423911, 0.436664, 0.482616
# elapsed time for k point: 0.024115562438964844
# solve_kpoint (0,0,0):
# Solving for bands 2 to 4...
# Finished solving for bands 2 to 4 after 12 iterations.
# tefreqs:, 16, 0, 0, 0, 0, 0, 0.449103, 0.457009, 0.482864
# elapsed time for k point: 0.020696640014648438
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.27769650308667326 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.2568827684394606 at Vector3<0.0, 0.5, 0.0> to 0.4491034871197188 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.29466737874303706 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 0.45700933881016303 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.45653245733615955 at Vector3<0.0, 0.5, 0.0> to 0.5515397504865117 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# total elapsed time for run: 0.42639994621276855
# done

# %%
md = mpb.MPBData(rectify=True, periods=5, resolution=64)
eps = ms.get_epsilon()
converted_eps = md.convert(eps)
converted_eps.shape
# Out:
# epsilon: 1-6.76, mean 5.94096, harm. mean 3.92455, 89.8438% > 1, 85.7805% "fill"
# (320, 277)

# %%
import csv
with open('epsilon_distribution.csv', 'wt') as f:
    writer = csv.writer(f)
    writer.writerows(converted_eps)

# %%
plt.imshow(converted_eps, interpolation='spline36', cmap="binary")
plt.axis('off')
plt.show()

# %%
tm_freqs.max()
# Out:
# 0.5253094560138579

# %%
fig, ax = plt.subplots()

x = range(len(tm_freqs))

# Plot bands
# Scatter plot for multiple y values, see https://stackoverflow.com/a/34280815/2261298
for xz, tmz, tez in zip(x, tm_freqs, te_freqs):
    ax.scatter([xz]*len(tmz), tmz, color='blue')
    ax.scatter([xz]*len(tez), tez, color='red', facecolors='none')
ax.plot(tm_freqs, color='blue')
ax.plot(te_freqs, color='red')
ax.set_ylim([tm_freqs.min(), tm_freqs.max()])
ax.set_xlim([x[0], x[-1]])

# Plot gaps
for gap in tm_gaps:
    if gap[0] > 1:
        ax.fill_between(x, gap[1], gap[2], color='blue', alpha=0.2)

for gap in te_gaps:
    if gap[0] > 1:
        ax.fill_between(x, gap[1], gap[2], color='red', alpha=0.2)


# Plot labels
ax.text(12, 0.04, 'TM bands', color='blue', size=15)
ax.text(13.05, 0.235, 'TE bands', color='red', size=15)

points_in_between = (len(tm_freqs) - 4) / 3
tick_locs = [i*points_in_between+i for i in range(4)]
tick_labs = ['Γ', 'X', 'M', 'Γ']
ax.set_xticks(tick_locs)
ax.set_xticklabels(tick_labs, size=16)
ax.set_ylabel('frequency (c/a)', size=16)
ax.grid(True)

plt.show()

# %%
efields = []

def get_efields(ms, band):
    efields.append(ms.get_efield(band, bloch_phase=True))

ms.run_tm(mpb.output_at_kpoint(mp.Vector3(1 / -3, 1 / 3), mpb.fix_efield_phase,
          get_efields))

# Create an MPBData instance to transform the efields
md = mpb.MPBData(rectify=True, resolution=32, periods=3)

converted = []
for f in efields:
    # Get just the z component of the efields
    f = f[..., 0, 2]
    converted.append(md.convert(f))

for i, f in enumerate(converted):
    plt.subplot(331 + i)
    plt.contour(converted_eps.T, cmap='binary')
    plt.imshow(np.real(f).T, interpolation='spline36', cmap='bwr', alpha=0.9)
    plt.axis('off')

plt.show()
# Out:
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 32 x 32 x 1.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.866025, 0.5, 0)
#      (0.866025, -0.5, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (0.57735, 1, -0)
#      (0.57735, -1, 0)
#      (-0, 0, 1)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1e+20,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      cylinder, center = (0.166667,0.166667,0)
#           radius 0.14, height 1e+20, axis (0, 0, 1)
#      cylinder, center = (-0.166667,-0.166667,0)
#           radius 0.14, height 1e+20, axis (0, 0, 1)
# Geometric object tree has depth 1 and 11 object nodes (vs. 3 actual objects)
# Initializing epsilon function...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.0, 0.1, 0.0>
#   Vector3<0.0, 0.2, 0.0>
#   Vector3<0.0, 0.30000000000000004, 0.0>
#   Vector3<0.0, 0.4, 0.0>
#   Vector3<0.0, 0.5, 0.0>
#   Vector3<-0.06666666666666667, 0.4666666666666667, 0.0>
#   Vector3<-0.13333333333333333, 0.43333333333333335, 0.0>
#   Vector3<-0.2, 0.39999999999999997, 0.0>
#   Vector3<-0.26666666666666666, 0.36666666666666664, 0.0>
#   Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<-0.26666666666666666, 0.26666666666666666, 0.0>
#   Vector3<-0.19999999999999998, 0.19999999999999998, 0.0>
#   Vector3<-0.1333333333333333, 0.1333333333333333, 0.0>
#   Vector3<-0.06666666666666665, 0.06666666666666665, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.03239035606384277
# solve_kpoint (0,0,0):
# Solving for bands 2 to 4...
# Finished solving for bands 2 to 4 after 38 iterations.
# tmfreqs:, 1, 0, 0, 0, 0, 0, 0.448608, 0.448652, 0.456653
# elapsed time for k point: 0.042786359786987305
# solve_kpoint (0,0.1,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 21 iterations.
# tmfreqs:, 2, 0, 0.1, 0, 0.11547, 0.047364, 0.415764, 0.431592, 0.45568
# elapsed time for k point: 0.044376373291015625
# solve_kpoint (0,0.2,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 6 iterations.
# tmfreqs:, 3, 0, 0.2, 0, 0.23094, 0.0946643, 0.373002, 0.41489, 0.444225
# elapsed time for k point: 0.021721363067626953
# solve_kpoint (0,0.3,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 5 iterations.
# tmfreqs:, 4, 0, 0.3, 0, 0.34641, 0.141818, 0.328333, 0.402448, 0.433328
# elapsed time for k point: 0.020063400268554688
# solve_kpoint (0,0.4,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 5 iterations.
# tmfreqs:, 5, 0, 0.4, 0, 0.46188, 0.188631, 0.282809, 0.394779, 0.426077
# elapsed time for k point: 0.013630867004394531
# solve_kpoint (0,0.5,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 4 iterations.
# tmfreqs:, 6, 0, 0.5, 0, 0.57735, 0.229097, 0.242744, 0.392188, 0.423563
# elapsed time for k point: 0.014623641967773438
# solve_kpoint (-0.0666667,0.466667,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 5 iterations.
# tmfreqs:, 7, -0.0666667, 0.466667, 0, 0.581187, 0.230584, 0.244331, 0.377142, 0.438462
# elapsed time for k point: 0.0165708065032959
# solve_kpoint (-0.133333,0.433333,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 5 iterations.
# tmfreqs:, 8, -0.133333, 0.433333, 0, 0.592546, 0.234964, 0.249026, 0.352678, 0.46247
# elapsed time for k point: 0.01642322540283203
# solve_kpoint (-0.2,0.4,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 5 iterations.
# tmfreqs:, 9, -0.2, 0.4, 0, 0.61101, 0.241987, 0.256645, 0.326964, 0.487344
# elapsed time for k point: 0.017266511917114258
# solve_kpoint (-0.266667,0.366667,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 6 iterations.
# tmfreqs:, 10, -0.266667, 0.366667, 0, 0.635959, 0.251032, 0.266911, 0.301317, 0.511299
# elapsed time for k point: 0.0219423770904541
# solve_kpoint (-0.333333,0.333333,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 7 iterations.
# tmfreqs:, 11, -0.333333, 0.333333, 0, 0.666667, 0.258292, 0.279473, 0.279505, 0.525309
# elapsed time for k point: 0.01573634147644043
# Fixing e-field (band 1) phase by -1 + 1.05543e-06i; max ampl. = 0.726579
# Fixing e-field (band 2) phase by -1 + 1.05543e-06i; max ampl. = 0.648863
# Fixing e-field (band 3) phase by -1 + 1.05543e-06i; max ampl. = 0.749208
# Fixing e-field (band 4) phase by 1 + -1.05543e-06i; max ampl. = 0.755823
# solve_kpoint (-0.266667,0.266667,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 7 iterations.
# tmfreqs:, 12, -0.266667, 0.266667, 0, 0.533333, 0.217259, 0.296568, 0.310212, 0.50767
# elapsed time for k point: 0.01443791389465332
# solve_kpoint (-0.2,0.2,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 6 iterations.
# tmfreqs:, 13, -0.2, 0.2, 0, 0.4, 0.163615, 0.331547, 0.346125, 0.488776
# elapsed time for k point: 0.019293546676635742
# solve_kpoint (-0.133333,0.133333,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 7 iterations.
# tmfreqs:, 14, -0.133333, 0.133333, 0, 0.266667, 0.109274, 0.370879, 0.38452, 0.474418
# elapsed time for k point: 0.02071237564086914
# solve_kpoint (-0.0666667,0.0666667,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 9 iterations.
# tmfreqs:, 15, -0.0666667, 0.0666667, 0, 0.133333, 0.0546873, 0.412623, 0.421839, 0.46522
# elapsed time for k point: 0.024681806564331055
# solve_kpoint (0,0,0):
# Solving for bands 2 to 4...
# Finished solving for bands 2 to 4 after 17 iterations.
# tmfreqs:, 16, 0, 0, 0, 0, 0, 0.448608, 0.448652, 0.456851
# elapsed time for k point: 0.02970719337463379
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.2582915180279046 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.2427440796810306 at Vector3<0.0, 0.5, 0.0> to 0.4486081121829872 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.2795052137489324 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0> to 0.44865224641635754 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.4235631052186579 at Vector3<0.0, 0.5, 0.0> to 0.5253094560138574 at Vector3<-0.3333333333333333, 0.3333333333333333, 0.0>
# total elapsed time for run: 0.3993864059448242
# done

# %%
#THz表示
a = 400
c_const = 299792458

fontsize = 18
te_freqs_THz = np.array(te_freqs) * c_const/(a*10**3)
te_gaps_THz = np.array(te_gaps) * c_const/(a*10**3)
#print(te_freqs_THz)

fig, ax = plt.subplots()

x = range(len(te_freqs))

for xz, tez in zip(x, te_freqs_THz):
    ax.scatter([xz]*len(tez), tez, color='navy')

ax.plot(te_freqs_THz, color='navy')
ax.set_ylim([te_freqs_THz.min(), te_freqs_THz.max()])
ax.set_xlim([x[0], x[-1]])

for gap in te_gaps_THz:
    if gap[0] > 1:
        ax.fill_between(x, gap[1], gap[2], color='blue', alpha=0.2)

ax.text(11.5, 0, 'TE bands', color='blue', size=15)

points_in_between = (len(te_freqs) - 4) / 3
tick_locs = [i*points_in_between+i for i in range(4)]
tick_labs = ['Γ', 'K', 'M', 'Γ']
ax.set_xticks(tick_locs)
ax.set_xticklabels(tick_labs, size=fontsize)
ax.set_ylabel('frequency [THz]', size=fontsize)
plt.tick_params(labelsize=fontsize)
ax.grid(True)

plt.show()
