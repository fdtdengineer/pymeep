# %%
import math
import meep as mp
from meep import mpb

import numpy as np
import matplotlib.pyplot as plt

# %%
#屈折率
n_Air = 1
n_Si = 2.6

r = 1/10

#三角形の一辺
s = 0.3

#穴シフト
R = 0.9

#計算する固有周波数の数
num_bands = 6

#メッシュの細かさ
resolution = 64

h = 20

#---------------------------------------------------#

#単位格子
geometry_lattice = mp.Lattice(size=mp.Vector3(1, 1),
                              basis1=mp.Vector3(1./2, np.sqrt(3)/2),
                              basis2=mp.Vector3(1./2, -np.sqrt(3)/2))

#三角形
s_param = s/(np.sqrt(3))

# ▷
tri1 = [
        mp.Vector3(-1,-1)*s_param,
        mp.Vector3(1,0)*s_param,
        mp.Vector3(0,1)*s_param
      ]

# ◁
tri2 = [
        mp.Vector3(1,1)*s_param,
        mp.Vector3(-1,0)*s_param,
        mp.Vector3(0,-1)*s_param
      ]

#構造
geometry = [
            mp.Block(material=mp.Medium(epsilon=n_Si**2),
                        size=mp.Vector3(mp.inf, mp.inf)),

            mp.Prism(tri1, center=mp.Vector3(1/3, 1/3)*R, height=h,
                        material=mp.Medium(epsilon=n_Air**2)),
            
            mp.Prism(tri2, center=mp.Vector3(1/3, 0)*R, height=h,
                        material=mp.Medium(epsilon=n_Air**2)),

            mp.Prism(tri1, center=mp.Vector3(0, -1/3)*R, height=h,
                        material=mp.Medium(epsilon=n_Air**2)),

            mp.Prism(tri2, center=mp.Vector3(-1/3, -1/3)*R, height=h,
                        material=mp.Medium(epsilon=n_Air**2)),

            mp.Prism(tri1, center=mp.Vector3(-1/3, 0)*R, height=h,
                        material=mp.Medium(epsilon=n_Air**2)),
    
            mp.Prism(tri2, center=mp.Vector3(0, 1/3)*R, height=h,
                        material=mp.Medium(epsilon=n_Air**2))
    
           ]


#ブリルアンゾーン
k_points = [
    mp.Vector3(),               # Gamma
    mp.Vector3(1./2, 0),          # M
    mp.Vector3(1./3, 1./3),    # K
    mp.Vector3(),               # Gamma
]
k_points = mp.interpolate(4, k_points)

# %%
#計算
ms = mpb.ModeSolver(
    geometry=geometry,
    geometry_lattice=geometry_lattice,
    k_points=k_points,
    resolution=resolution,
    num_bands=num_bands
)

ms.run_tm(mpb.output_at_kpoint(mp.Vector3(-1./3, 1./3),
                               mpb.fix_efield_phase,
                               mpb.output_efield_z))
tm_freqs = ms.all_freqs
tm_gaps = ms.gap_list
ms.run_te()
te_freqs = ms.all_freqs
te_gaps = ms.gap_list
# Out:
# Initializing eigensolver data
# Computing 6 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 64 x 64 x 1.
# Solving for 6 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.5, 0.866025, 0)
#      (0.5, -0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, 0.57735, -0)
#      (1, -0.57735, 0)
#      (-0, 0, 1)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1e+20,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      prism, center = (0.3,0.3,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (0.126795,0.126795,-10)
#           (0.473205,0.3,-10)
#           (0.3,0.473205,-10)
#      prism, center = (0.3,0,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (0.473205,0.173205,-10)
#           (0.126795,0,-10)
#           (0.3,-0.173205,-10)
#      prism, center = (0,-0.3,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-0.173205,-0.473205,-10)
#           (0.173205,-0.3,-10)
#           (0,-0.126795,-10)
#      prism, center = (-0.3,-0.3,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-0.126795,-0.126795,-10)
#           (-0.473205,-0.3,-10)
#           (-0.3,-0.473205,-10)
#      prism, center = (-0.3,0,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-0.473205,-0.173205,-10)
#           (-0.126795,0,-10)
#           (-0.3,0.173205,-10)
#      prism, center = (0,0.3,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (0.173205,0.473205,-10)
#           (-0.173205,0.3,-10)
#           (0,0.126795,-10)
# Geometric object tree has depth 3 and 46 object nodes (vs. 7 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.1, 0.0, 0.0>
#   Vector3<0.2, 0.0, 0.0>
#   Vector3<0.30000000000000004, 0.0, 0.0>
#   Vector3<0.4, 0.0, 0.0>
#   Vector3<0.5, 0.0, 0.0>
#   Vector3<0.4666666666666667, 0.06666666666666667, 0.0>
#   Vector3<0.43333333333333335, 0.13333333333333333, 0.0>
#   Vector3<0.39999999999999997, 0.2, 0.0>
#   Vector3<0.36666666666666664, 0.26666666666666666, 0.0>
#   Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<0.26666666666666666, 0.26666666666666666, 0.0>
#   Vector3<0.19999999999999998, 0.19999999999999998, 0.0>
#   Vector3<0.1333333333333333, 0.1333333333333333, 0.0>
#   Vector3<0.06666666666666665, 0.06666666666666665, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.09498310089111328
# solve_kpoint (0,0,0):
# Solving for bands 2 to 6...
# Finished solving for bands 2 to 6 after 23 iterations.
# tmfreqs:, 1, 0, 0, 0, 0, 0, 0.457242, 0.468909, 0.502042, 0.502153, 0.543921
# elapsed time for k point: 0.18015027046203613
# solve_kpoint (0.1,0,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 14 iterations.
# tmfreqs:, 2, 0.1, 0, 0, 0.11547, 0.0505938, 0.437693, 0.456617, 0.492226, 0.513297, 0.557317
# elapsed time for k point: 0.1339735984802246
# solve_kpoint (0.2,0,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 7 iterations.
# tmfreqs:, 3, 0.2, 0, 0, 0.23094, 0.101127, 0.396729, 0.439567, 0.476605, 0.538333, 0.583381
# elapsed time for k point: 0.06461811065673828
# solve_kpoint (0.3,0,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 6 iterations.
# tmfreqs:, 4, 0.3, 0, 0, 0.34641, 0.151529, 0.349969, 0.42672, 0.463729, 0.567859, 0.613598
# elapsed time for k point: 0.06864118576049805
# solve_kpoint (0.4,0,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 7 iterations.
# tmfreqs:, 5, 0.4, 0, 0, 0.46188, 0.20168, 0.301436, 0.418763, 0.455544, 0.599191, 0.645799
# elapsed time for k point: 0.07939863204956055
# solve_kpoint (0.5,0,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 46 iterations.
# tmfreqs:, 6, 0.5, 0, 0, 0.57735, 0.247591, 0.256001, 0.416068, 0.452749, 0.622502, 0.649402
# elapsed time for k point: 0.3358278274536133
# solve_kpoint (0.466667,0.0666667,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 8 iterations.
# tmfreqs:, 7, 0.466667, 0.0666667, 0, 0.581187, 0.249217, 0.257665, 0.400866, 0.467699, 0.617658, 0.642586
# elapsed time for k point: 0.07517862319946289
# solve_kpoint (0.433333,0.133333,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 7 iterations.
# tmfreqs:, 8, 0.433333, 0.133333, 0, 0.592546, 0.254031, 0.262576, 0.375188, 0.492568, 0.606815, 0.629163
# elapsed time for k point: 0.09144043922424316
# solve_kpoint (0.4,0.2,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 6 iterations.
# tmfreqs:, 9, 0.4, 0.2, 0, 0.61101, 0.261845, 0.270475, 0.347858, 0.51827, 0.594478, 0.61443
# elapsed time for k point: 0.08605265617370605
# solve_kpoint (0.366667,0.266667,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 6 iterations.
# tmfreqs:, 10, 0.366667, 0.266667, 0, 0.635959, 0.272384, 0.280717, 0.320406, 0.542043, 0.583965, 0.599765
# elapsed time for k point: 0.06818175315856934
# solve_kpoint (0.333333,0.333333,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 5 iterations.
# tmfreqs:, 11, 0.333333, 0.333333, 0, 0.666667, 0.285284, 0.285334, 0.300791, 0.553836, 0.585624, 0.585732
# elapsed time for k point: 0.05158090591430664
# solve_kpoint (0.266667,0.266667,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 7 iterations.
# tmfreqs:, 12, 0.266667, 0.266667, 0, 0.533333, 0.232499, 0.316977, 0.329066, 0.537357, 0.56007, 0.630561
# elapsed time for k point: 0.06099057197570801
# solve_kpoint (0.2,0.2,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 12 iterations.
# tmfreqs:, 13, 0.2, 0.2, 0, 0.4, 0.17485, 0.354252, 0.367522, 0.518346, 0.538721, 0.662798
# elapsed time for k point: 0.08783125877380371
# solve_kpoint (0.133333,0.133333,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 7 iterations.
# tmfreqs:, 14, 0.133333, 0.133333, 0, 0.266667, 0.11674, 0.394574, 0.409294, 0.504178, 0.522277, 0.618213
# elapsed time for k point: 0.05456876754760742
# solve_kpoint (0.0666667,0.0666667,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 7 iterations.
# tmfreqs:, 15, 0.0666667, 0.0666667, 0, 0.133333, 0.0584169, 0.434128, 0.449418, 0.49754, 0.510167, 0.572379
# elapsed time for k point: 0.055182456970214844
# solve_kpoint (0,0,0):
# Solving for bands 2 to 6...
# Finished solving for bands 2 to 6 after 9 iterations.
# tmfreqs:, 16, 0, 0, 0, 0, 0, 0.457242, 0.468909, 0.502042, 0.502153, 0.544197
# elapsed time for k point: 0.0659482479095459
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.2852838345052051 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.2560013566941353 at Vector3<0.5, 0.0, 0.0> to 0.4572416255974415 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.3007908266241537 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0> to 0.46890884644266506 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.45274866476436487 at Vector3<0.5, 0.0, 0.0> to 0.5538360221412575 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
# Band 5 range: 0.5021525908513698 at Vector3<0.0, 0.0, 0.0> to 0.6225021956798501 at Vector3<0.5, 0.0, 0.0>
# Band 6 range: 0.5439212119451963 at Vector3<0.0, 0.0, 0.0> to 0.6627979268977598 at Vector3<0.19999999999999998, 0.19999999999999998, 0.0>
# total elapsed time for run: 1.6586129665374756
# done
# Initializing eigensolver data
# Computing 6 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 64 x 64 x 1.
# Solving for 6 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.5, 0.866025, 0)
#      (0.5, -0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, 0.57735, -0)
#      (1, -0.57735, 0)
#      (-0, 0, 1)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1e+20,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      prism, center = (0.3,0.3,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (0.126795,0.126795,-10)
#           (0.473205,0.3,-10)
#           (0.3,0.473205,-10)
#      prism, center = (0.3,0,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (0.473205,0.173205,-10)
#           (0.126795,0,-10)
#           (0.3,-0.173205,-10)
#      prism, center = (0,-0.3,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-0.173205,-0.473205,-10)
#           (0.173205,-0.3,-10)
#           (0,-0.126795,-10)
#      prism, center = (-0.3,-0.3,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-0.126795,-0.126795,-10)
#           (-0.473205,-0.3,-10)
#           (-0.3,-0.473205,-10)
#      prism, center = (-0.3,0,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-0.473205,-0.173205,-10)
#           (-0.126795,0,-10)
#           (-0.3,0.173205,-10)
#      prism, center = (0,0.3,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (0.173205,0.473205,-10)
#           (-0.173205,0.3,-10)
#           (0,0.126795,-10)
# Geometric object tree has depth 3 and 46 object nodes (vs. 7 actual objects)
# Initializing epsilon function...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.1, 0.0, 0.0>
#   Vector3<0.2, 0.0, 0.0>
#   Vector3<0.30000000000000004, 0.0, 0.0>
#   Vector3<0.4, 0.0, 0.0>
#   Vector3<0.5, 0.0, 0.0>
#   Vector3<0.4666666666666667, 0.06666666666666667, 0.0>
#   Vector3<0.43333333333333335, 0.13333333333333333, 0.0>
#   Vector3<0.39999999999999997, 0.2, 0.0>
#   Vector3<0.36666666666666664, 0.26666666666666666, 0.0>
#   Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<0.26666666666666666, 0.26666666666666666, 0.0>
#   Vector3<0.19999999999999998, 0.19999999999999998, 0.0>
#   Vector3<0.1333333333333333, 0.1333333333333333, 0.0>
#   Vector3<0.06666666666666665, 0.06666666666666665, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.0948183536529541
# solve_kpoint (0,0,0):
# Solving for bands 2 to 6...
# Finished solving for bands 2 to 6 after 14 iterations.
# tefreqs:, 1, 0, 0, 0, 0, 0, 0.50942, 0.510374, 0.534214, 0.536115, 0.581368
# elapsed time for k point: 0.0913553237915039
# solve_kpoint (0.1,0,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 10 iterations.
# tefreqs:, 2, 0.1, 0, 0, 0.11547, 0.05523, 0.481029, 0.49192, 0.536835, 0.558, 0.599616
# elapsed time for k point: 0.07771944999694824
# solve_kpoint (0.2,0,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 10 iterations.
# tefreqs:, 3, 0.2, 0, 0, 0.23094, 0.110374, 0.433763, 0.469747, 0.531152, 0.592567, 0.630696
# elapsed time for k point: 0.07014083862304688
# solve_kpoint (0.3,0,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 10 iterations.
# tefreqs:, 4, 0.3, 0, 0, 0.34641, 0.165311, 0.382533, 0.452642, 0.523969, 0.630413, 0.660334
# elapsed time for k point: 0.07160687446594238
# solve_kpoint (0.4,0,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 12 iterations.
# tefreqs:, 5, 0.4, 0, 0, 0.46188, 0.21974, 0.329912, 0.441948, 0.518834, 0.670047, 0.687959
# elapsed time for k point: 0.08586454391479492
# solve_kpoint (0.5,0,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 22 iterations.
# tefreqs:, 6, 0.5, 0, 0, 0.57735, 0.265413, 0.284788, 0.438312, 0.51701, 0.703885, 0.707454
# elapsed time for k point: 0.14296865463256836
# solve_kpoint (0.466667,0.0666667,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 14 iterations.
# tefreqs:, 7, 0.466667, 0.0666667, 0, 0.581187, 0.267264, 0.286442, 0.427564, 0.527554, 0.693224, 0.699882
# elapsed time for k point: 0.09345054626464844
# solve_kpoint (0.433333,0.133333,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 12 iterations.
# tefreqs:, 8, 0.433333, 0.133333, 0, 0.592546, 0.27272, 0.291346, 0.40416, 0.550325, 0.676709, 0.688299
# elapsed time for k point: 0.1334073543548584
# solve_kpoint (0.4,0.2,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 9 iterations.
# tefreqs:, 9, 0.4, 0.2, 0, 0.61101, 0.281467, 0.29933, 0.37655, 0.576797, 0.659965, 0.675876
# elapsed time for k point: 0.09724116325378418
# solve_kpoint (0.366667,0.266667,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 8 iterations.
# tefreqs:, 10, 0.366667, 0.266667, 0, 0.635959, 0.2928, 0.310138, 0.347773, 0.60374, 0.643638, 0.663954
# elapsed time for k point: 0.0722818374633789
# solve_kpoint (0.333333,0.333333,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 8 iterations.
# tefreqs:, 11, 0.333333, 0.333333, 0, 0.666667, 0.302092, 0.322698, 0.32369, 0.626374, 0.628602, 0.656114
# elapsed time for k point: 0.06833457946777344
# solve_kpoint (0.266667,0.266667,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 10 iterations.
# tefreqs:, 12, 0.266667, 0.266667, 0, 0.533333, 0.2535, 0.346748, 0.356014, 0.597369, 0.618477, 0.694954
# elapsed time for k point: 0.06993556022644043
# solve_kpoint (0.2,0.2,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 12 iterations.
# tefreqs:, 13, 0.2, 0.2, 0, 0.4, 0.19099, 0.38875, 0.395526, 0.573278, 0.597543, 0.719901
# elapsed time for k point: 0.0886542797088623
# solve_kpoint (0.133333,0.133333,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 81 iterations.
# tefreqs:, 14, 0.133333, 0.133333, 0, 0.266667, 0.127603, 0.434127, 0.438729, 0.554973, 0.577861, 0.649909
# elapsed time for k point: 0.42069149017333984
# solve_kpoint (0.0666667,0.0666667,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 8 iterations.
# tefreqs:, 15, 0.0666667, 0.0666667, 0, 0.133333, 0.0638721, 0.478935, 0.482187, 0.54246, 0.556604, 0.605798
# elapsed time for k point: 0.06774067878723145
# solve_kpoint (0,0,0):
# Solving for bands 2 to 6...
# Finished solving for bands 2 to 6 after 8 iterations.
# tefreqs:, 16, 0, 0, 0, 0, 0, 0.50942, 0.510374, 0.534214, 0.536115, 0.581368
# elapsed time for k point: 0.06374239921569824
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.30209226547107754 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.28478766569891406 at Vector3<0.5, 0.0, 0.0> to 0.5094197642281681 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.3236900806753953 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0> to 0.5103736214851533 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.517009785808812 at Vector3<0.5, 0.0, 0.0> to 0.6263738835443219 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
# Band 5 range: 0.5361151099450359 at Vector3<0.0, 0.0, 0.0> to 0.7038854831946019 at Vector3<0.5, 0.0, 0.0>
# Band 6 range: 0.581367555792326 at Vector3<0.0, 0.0, 0.0> to 0.7199012546784208 at Vector3<0.19999999999999998, 0.19999999999999998, 0.0>
# Gap from band 3 (0.5103736214851533) to band 4 (0.517009785808812), 1.2918574071850568%
# total elapsed time for run: 1.8125526905059814
# done

# %%
#import csv
#with open('epsilon_distribution.csv', 'wt') as f:
#    writer = csv.writer(f)
#    writer.writerows(converted_eps)

# %%
md = mpb.MPBData(rectify=True, periods=3, resolution=64)
eps = ms.get_epsilon()
converted_eps = md.convert(eps)
converted_eps.shape

plt.figure(figsize=(12,9))
plt.imshow(converted_eps, interpolation='spline36', cmap="binary")
plt.axis('off')
plt.show()
# Out:
# epsilon: 1-6.76, mean 5.20687, harm. mean 2.81709, 78.7598% > 1, 73.036% "fill"

# %%
tm_freqs.max()
# Out:
# 0.6627979268977598

# %%
fig, ax = plt.subplots()

x = range(len(tm_freqs))

# Plot bands
# Scatter plot for multiple y values, see https://stackoverflow.com/a/34280815/2261298
for xz, tmz, tez in zip(x, tm_freqs, te_freqs):
    ax.scatter([xz]*len(tmz), tmz, color='blue')
    ax.scatter([xz]*len(tez), tez, color='red', facecolors='none')
ax.plot(tm_freqs, color='blue')
ax.plot(te_freqs, color='red')
ax.set_ylim([tm_freqs.min(), tm_freqs.max()])
ax.set_xlim([x[0], x[-1]])

# Plot gaps
for gap in tm_gaps:
    if gap[0] > 1:
        ax.fill_between(x, gap[1], gap[2], color='blue', alpha=0.2)

for gap in te_gaps:
    if gap[0] > 1:
        ax.fill_between(x, gap[1], gap[2], color='red', alpha=0.2)


# Plot labels
ax.text(12, 0.04, 'TM bands', color='blue', size=15)
ax.text(13.05, 0.235, 'TE bands', color='red', size=15)

points_in_between = (len(tm_freqs) - 4) / 3
tick_locs = [i*points_in_between+i for i in range(4)]
tick_labs = ['Γ', 'X', 'M', 'Γ']
ax.set_xticks(tick_locs)
ax.set_xticklabels(tick_labs, size=16)
ax.set_ylabel('frequency (c/a)', size=16)
ax.grid(True)

plt.show()

# %%
hfields = []

def get_hfields(ms, band):
    hfields.append(ms.get_hfield(band, bloch_phase=True))

ms.run_te(mpb.output_at_kpoint(mp.Vector3(), mpb.fix_hfield_phase,
          get_hfields))

# Create an MPBData instance to transform the hfields
md = mpb.MPBData(rectify=True, resolution=64, periods=3)

converted = []
for f in hfields:
    # Get just the z component of the hfields
    f = f[..., 0, 2]
    converted.append(md.convert(f))

plt.figure(figsize=(15,10))

for i, f in enumerate(converted):
    plt.subplot(331 + i)
    plt.contour(converted_eps.T, cmap='binary')
    plt.imshow(np.real(f).T, interpolation='spline36', cmap='bwr', alpha=0.9)
    plt.axis('off')

plt.show()
# Out:
# Initializing eigensolver data
# Computing 6 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 64 x 64 x 1.
# Solving for 6 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.5, 0.866025, 0)
#      (0.5, -0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, 0.57735, -0)
#      (1, -0.57735, 0)
#      (-0, 0, 1)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1e+20,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      prism, center = (0.3,0.3,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (0.126795,0.126795,-10)
#           (0.473205,0.3,-10)
#           (0.3,0.473205,-10)
#      prism, center = (0.3,0,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (0.473205,0.173205,-10)
#           (0.126795,0,-10)
#           (0.3,-0.173205,-10)
#      prism, center = (0,-0.3,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-0.173205,-0.473205,-10)
#           (0.173205,-0.3,-10)
#           (0,-0.126795,-10)
#      prism, center = (-0.3,-0.3,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-0.126795,-0.126795,-10)
#           (-0.473205,-0.3,-10)
#           (-0.3,-0.473205,-10)
#      prism, center = (-0.3,0,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (-0.473205,-0.173205,-10)
#           (-0.126795,0,-10)
#           (-0.3,0.173205,-10)
#      prism, center = (0,0.3,0)
#           height 20, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (0.173205,0.473205,-10)
#           (-0.173205,0.3,-10)
#           (0,0.126795,-10)
# Geometric object tree has depth 3 and 46 object nodes (vs. 7 actual objects)
# Initializing epsilon function...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.1, 0.0, 0.0>
#   Vector3<0.2, 0.0, 0.0>
#   Vector3<0.30000000000000004, 0.0, 0.0>
#   Vector3<0.4, 0.0, 0.0>
#   Vector3<0.5, 0.0, 0.0>
#   Vector3<0.4666666666666667, 0.06666666666666667, 0.0>
#   Vector3<0.43333333333333335, 0.13333333333333333, 0.0>
#   Vector3<0.39999999999999997, 0.2, 0.0>
#   Vector3<0.36666666666666664, 0.26666666666666666, 0.0>
#   Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<0.26666666666666666, 0.26666666666666666, 0.0>
#   Vector3<0.19999999999999998, 0.19999999999999998, 0.0>
#   Vector3<0.1333333333333333, 0.1333333333333333, 0.0>
#   Vector3<0.06666666666666665, 0.06666666666666665, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.0751187801361084
# solve_kpoint (0,0,0):
# Solving for bands 2 to 6...
# Finished solving for bands 2 to 6 after 15 iterations.
# tefreqs:, 1, 0, 0, 0, 0, 0, 0.50942, 0.510374, 0.534214, 0.536115, 0.581368
# elapsed time for k point: 0.146514892578125
# Fixing h-field (band 1) phase by 1 + -0i; max ampl. = 1.07457
# Fixing h-field (band 2) phase by 0.996585 + -0.0825765i; max ampl. = 1.92709
# Fixing h-field (band 3) phase by -0.292685 + 0.956209i; max ampl. = 1.95176
# Fixing h-field (band 4) phase by 0.0821121 + -0.996623i; max ampl. = 2.24203
# Fixing h-field (band 5) phase by 0.641329 + -0.767266i; max ampl. = 2.57607
# Fixing h-field (band 6) phase by 0.177345 + 0.984149i; max ampl. = 2.95872
# solve_kpoint (0.1,0,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 10 iterations.
# tefreqs:, 2, 0.1, 0, 0, 0.11547, 0.05523, 0.481029, 0.49192, 0.536835, 0.558, 0.599616
# elapsed time for k point: 0.08795475959777832
# solve_kpoint (0.2,0,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 10 iterations.
# tefreqs:, 3, 0.2, 0, 0, 0.23094, 0.110374, 0.433763, 0.469747, 0.531152, 0.592567, 0.630696
# elapsed time for k point: 0.08038616180419922
# solve_kpoint (0.3,0,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 10 iterations.
# tefreqs:, 4, 0.3, 0, 0, 0.34641, 0.165311, 0.382533, 0.452642, 0.523969, 0.630413, 0.660334
# elapsed time for k point: 0.09311866760253906
# solve_kpoint (0.4,0,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 12 iterations.
# tefreqs:, 5, 0.4, 0, 0, 0.46188, 0.21974, 0.329912, 0.441948, 0.518834, 0.670047, 0.687959
# elapsed time for k point: 0.10471153259277344
# solve_kpoint (0.5,0,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 22 iterations.
# tefreqs:, 6, 0.5, 0, 0, 0.57735, 0.265413, 0.284788, 0.438312, 0.51701, 0.703885, 0.707454
# elapsed time for k point: 0.1601409912109375
# solve_kpoint (0.466667,0.0666667,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 14 iterations.
# tefreqs:, 7, 0.466667, 0.0666667, 0, 0.581187, 0.267264, 0.286442, 0.427564, 0.527554, 0.693224, 0.699882
# elapsed time for k point: 0.10820341110229492
# solve_kpoint (0.433333,0.133333,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 12 iterations.
# tefreqs:, 8, 0.433333, 0.133333, 0, 0.592546, 0.27272, 0.291346, 0.40416, 0.550325, 0.676709, 0.688299
# elapsed time for k point: 0.08063983917236328
# solve_kpoint (0.4,0.2,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 9 iterations.
# tefreqs:, 9, 0.4, 0.2, 0, 0.61101, 0.281467, 0.29933, 0.37655, 0.576797, 0.659965, 0.675876
# elapsed time for k point: 0.07891368865966797
# solve_kpoint (0.366667,0.266667,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 8 iterations.
# tefreqs:, 10, 0.366667, 0.266667, 0, 0.635959, 0.2928, 0.310138, 0.347773, 0.60374, 0.643638, 0.663954
# elapsed time for k point: 0.09444475173950195
# solve_kpoint (0.333333,0.333333,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 8 iterations.
# tefreqs:, 11, 0.333333, 0.333333, 0, 0.666667, 0.302092, 0.322698, 0.32369, 0.626374, 0.628602, 0.656114
# elapsed time for k point: 0.05993962287902832
# solve_kpoint (0.266667,0.266667,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 10 iterations.
# tefreqs:, 12, 0.266667, 0.266667, 0, 0.533333, 0.2535, 0.346748, 0.356014, 0.597369, 0.618477, 0.694954
# elapsed time for k point: 0.10584616661071777
# solve_kpoint (0.2,0.2,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 12 iterations.
# tefreqs:, 13, 0.2, 0.2, 0, 0.4, 0.19099, 0.38875, 0.395526, 0.573278, 0.597543, 0.719901
# elapsed time for k point: 0.09147763252258301
# solve_kpoint (0.133333,0.133333,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 81 iterations.
# tefreqs:, 14, 0.133333, 0.133333, 0, 0.266667, 0.127603, 0.434127, 0.438729, 0.554973, 0.577861, 0.649909
# elapsed time for k point: 0.43015384674072266
# solve_kpoint (0.0666667,0.0666667,0):
# Solving for bands 1 to 6...
# Finished solving for bands 1 to 6 after 8 iterations.
# tefreqs:, 15, 0.0666667, 0.0666667, 0, 0.133333, 0.0638721, 0.478935, 0.482187, 0.54246, 0.556604, 0.605798
# elapsed time for k point: 0.07536149024963379
# solve_kpoint (0,0,0):
# Solving for bands 2 to 6...
# Finished solving for bands 2 to 6 after 8 iterations.
# tefreqs:, 16, 0, 0, 0, 0, 0, 0.50942, 0.510374, 0.534214, 0.536115, 0.581368
# elapsed time for k point: 0.06660652160644531
# Fixing h-field (band 1) phase by 1 + -0i; max ampl. = 1.07457
# Fixing h-field (band 2) phase by 1.22122e-07 + -1i; max ampl. = 1.92706
# Fixing h-field (band 3) phase by 1.22122e-07 + -1i; max ampl. = 1.95175
# Fixing h-field (band 4) phase by 1 + 1.22122e-07i; max ampl. = 2.24202
# Fixing h-field (band 5) phase by 1 + 1.22122e-07i; max ampl. = 2.57593
# Fixing h-field (band 6) phase by 1.22122e-07 + -1i; max ampl. = 2.95849
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.3020922654710774 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.284787665698912 at Vector3<0.5, 0.0, 0.0> to 0.5094197642281679 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.3236900806753953 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0> to 0.5103736214851526 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.5170097858088126 at Vector3<0.5, 0.0, 0.0> to 0.6263738835443183 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
# Band 5 range: 0.5361151091911087 at Vector3<0.0, 0.0, 0.0> to 0.703885483194558 at Vector3<0.5, 0.0, 0.0>
# Band 6 range: 0.5813675557923258 at Vector3<0.0, 0.0, 0.0> to 0.7199012546784318 at Vector3<0.19999999999999998, 0.19999999999999998, 0.0>
# Gap from band 3 (0.5103736214851526) to band 4 (0.5170097858088126), 1.2918574071853162%
# total elapsed time for run: 1.9721813201904297
# done
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-70-cb9cb820b4c4> in <module>
#      19
#      20 for i, f in enumerate(converted):
# ---> 21     plt.subplot(331 + i)
#      22     plt.contour(converted_eps.T, cmap='binary')
#      23     plt.imshow(np.real(f).T, interpolation='spline36', cmap='bwr', alpha=0.9)
#
# ~/.conda/envs/mp/lib/python3.7/site-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1028
#    1029     fig = gcf()
# -> 1030     a = fig.add_subplot(*args, **kwargs)
#    1031     bbox = a.bbox
#    1032     byebye = []
#
# ~/.conda/envs/mp/lib/python3.7/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1417                     self._axstack.remove(ax)
#    1418
# -> 1419             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1420
#    1421         return self._add_axes_internal(key, a)
#
# ~/.conda/envs/mp/lib/python3.7/site-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      64                 if num < 1 or num > rows*cols:
#      65                     raise ValueError(
# ---> 66                         f"num must be 1 <= num <= {rows*cols}, not {num}")
#      67                 self._subplotspec = GridSpec(
#      68                         rows, cols, figure=self.figure)[int(num) - 1]
#
# ValueError: num must be 1 <= num <= 12, not 0

# %%
#THz表示
a = 820
c_const = 299792458

fontsize = 18
te_freqs_THz = np.array(te_freqs) * c_const/(a*10**3)
te_gaps_THz = np.array(te_gaps) * c_const/(a*10**3)
#print(te_freqs_THz)


plt.figure(figsize=(6,8))

fig, ax = plt.subplots()

x = range(len(te_freqs))

for xz, tez in zip(x, te_freqs_THz):
    ax.scatter([xz]*len(tez), tez, color='navy')

ax.plot(te_freqs_THz, color='navy')
ax.set_ylim([te_freqs_THz.min(), te_freqs_THz.max()])
ax.set_xlim([x[0], x[-1]])

for gap in te_gaps_THz:
    if gap[0] > 1:
        ax.fill_between(x, gap[1], gap[2], color='blue', alpha=0.2)

ax.text(11.5, 0, 'TE bands', color='blue', size=15)

points_in_between = (len(te_freqs) - 4) / 3
tick_locs = [i*points_in_between+i for i in range(4)]
tick_labs = ['Γ', 'K', 'M', 'Γ']
ax.set_xticks(tick_locs)
ax.set_xticklabels(tick_labs, size=fontsize)
ax.set_ylabel('frequency [THz]', size=fontsize)
plt.tick_params(labelsize=fontsize)
ax.grid(True)

plt.show()
