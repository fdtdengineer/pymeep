# %%
import math
import meep as mp
from meep import mpb

import numpy as np
import matplotlib.pyplot as plt

# %%
#屈折率
n_Air = 1
n_Si = 2.6

#穴の半径
r = 1/10

#穴シフト
R = 1

#計算する固有周波数の数
num_bands = 10

#メッシュの細かさ
resolution = 64

h = 20

#-------------------------------------------------------------------#

#単位格子
geometry_lattice = mp.Lattice(size=mp.Vector3(1, 1),
                              basis1=mp.Vector3(1./2, np.sqrt(3)/2),
                              basis2=mp.Vector3(1./2, -np.sqrt(3)/2))



#構造
geometry = [
            mp.Cylinder(r, center=mp.Vector3(1/3, 1/3)*R, height=h,
                        material=mp.Medium(epsilon=n_Si**2)),
            
            mp.Cylinder(r, center=mp.Vector3(1/3, 0)*R, height=h,
                        material=mp.Medium(epsilon=n_Si**2)),

            mp.Cylinder(r, center=mp.Vector3(0, -1/3)*R, height=h,
                        material=mp.Medium(epsilon=n_Si**2)),

            mp.Cylinder(r, center=mp.Vector3(-1/3, -1/3)*R, height=h,
                        material=mp.Medium(epsilon=n_Si**2)),

            mp.Cylinder(r, center=mp.Vector3(-1/3, 0)*R, height=h,
                        material=mp.Medium(epsilon=n_Si**2)),
    
            mp.Cylinder(r, center=mp.Vector3(0, 1/3)*R, height=h,
                        material=mp.Medium(epsilon=n_Si**2))
           ]

#ブリルアンゾーン
k_points = [
    mp.Vector3(),               # Gamma
    mp.Vector3(1./2, 0),          # M
    mp.Vector3(1./3, 1./3),    # K
    mp.Vector3(),               # Gamma
]
k_points = mp.interpolate(8, k_points)

# %%
#計算
ms = mpb.ModeSolver(
    geometry=geometry,
    geometry_lattice=geometry_lattice,
    k_points=k_points,
    resolution=resolution,
    num_bands=num_bands
)

ms.run_tm(mpb.output_at_kpoint(mp.Vector3(-1./3, 1./3),
                               mpb.fix_efield_phase,
                               mpb.output_efield_z))
tm_freqs = ms.all_freqs
tm_gaps = ms.gap_list
ms.run_te()
te_freqs = ms.all_freqs
te_gaps = ms.gap_list
# Out:
# Initializing eigensolver data
# Computing 10 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 64 x 64 x 1.
# Solving for 10 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.5, 0.866025, 0)
#      (0.5, -0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, 0.57735, -0)
#      (1, -0.57735, 0)
#      (-0, 0, 1)
# Geometric objects:
#      cylinder, center = (0.3,0.3,0)
#           radius 0.1, height 20, axis (0, 0, 1)
#      cylinder, center = (0.3,0,0)
#           radius 0.1, height 20, axis (0, 0, 1)
#      cylinder, center = (0,-0.3,0)
#           radius 0.1, height 20, axis (0, 0, 1)
#      cylinder, center = (-0.3,-0.3,0)
#           radius 0.1, height 20, axis (0, 0, 1)
#      cylinder, center = (-0.3,0,0)
#           radius 0.1, height 20, axis (0, 0, 1)
#      cylinder, center = (0,0.3,0)
#           radius 0.1, height 20, axis (0, 0, 1)
# Geometric object tree has depth 3 and 6 object nodes (vs. 6 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: tm.
# Initializing fields to random numbers...
# 28 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.05555555555555555, 0.0, 0.0>
#   Vector3<0.1111111111111111, 0.0, 0.0>
#   Vector3<0.16666666666666666, 0.0, 0.0>
#   Vector3<0.2222222222222222, 0.0, 0.0>
#   Vector3<0.2777777777777778, 0.0, 0.0>
#   Vector3<0.3333333333333333, 0.0, 0.0>
#   Vector3<0.38888888888888884, 0.0, 0.0>
#   Vector3<0.4444444444444444, 0.0, 0.0>
#   Vector3<0.5, 0.0, 0.0>
#   Vector3<0.48148148148148145, 0.037037037037037035, 0.0>
#   Vector3<0.46296296296296297, 0.07407407407407407, 0.0>
#   Vector3<0.4444444444444444, 0.1111111111111111, 0.0>
#   Vector3<0.42592592592592593, 0.14814814814814814, 0.0>
#   Vector3<0.4074074074074074, 0.18518518518518517, 0.0>
#   Vector3<0.38888888888888884, 0.2222222222222222, 0.0>
#   Vector3<0.37037037037037035, 0.25925925925925924, 0.0>
#   Vector3<0.35185185185185186, 0.2962962962962963, 0.0>
#   Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<0.2962962962962963, 0.2962962962962963, 0.0>
#   Vector3<0.25925925925925924, 0.25925925925925924, 0.0>
#   Vector3<0.2222222222222222, 0.2222222222222222, 0.0>
#   Vector3<0.18518518518518517, 0.18518518518518517, 0.0>
#   Vector3<0.14814814814814814, 0.14814814814814814, 0.0>
#   Vector3<0.1111111111111111, 0.1111111111111111, 0.0>
#   Vector3<0.07407407407407407, 0.07407407407407407, 0.0>
#   Vector3<0.037037037037037035, 0.037037037037037035, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.06084418296813965
# solve_kpoint (0,0,0):
# Solving for bands 2 to 10...
# Finished solving for bands 2 to 10 after 20 iterations.
# tmfreqs:, 1, 0, 0, 0, 0, 0, 0.629402, 0.629483, 0.68831, 0.688381, 0.898966, 0.963251, 1.01656, 1.32196, 1.32252
# elapsed time for k point: 0.2877192497253418
# solve_kpoint (0.0555556,0,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 10 iterations.
# tmfreqs:, 2, 0.0555556, 0, 0, 0.06415, 0.0427193, 0.623049, 0.626104, 0.689505, 0.692696, 0.897921, 0.96631, 1.01956, 1.32051, 1.32186
# elapsed time for k point: 0.19531702995300293
# solve_kpoint (0.111111,0,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 11 iterations.
# tmfreqs:, 3, 0.111111, 0, 0, 0.1283, 0.0853644, 0.60624, 0.6182, 0.691299, 0.703512, 0.894801, 0.97521, 1.02823, 1.3151, 1.32026
# elapsed time for k point: 0.1978449821472168
# solve_kpoint (0.166667,0,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 12 iterations.
# tmfreqs:, 4, 0.166667, 0, 0, 0.19245, 0.127858, 0.582529, 0.608843, 0.691682, 0.717686, 0.889659, 0.989201, 1.04172, 1.30368, 1.31809
# elapsed time for k point: 0.18864083290100098
# solve_kpoint (0.222222,0,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after 11 iterations.
# t
at Vector3<0.0, 0.0, 0.0>
# Band 10 range: 1.361764684039369 at Vector3<0.5, 0.0, 0.0> to 1.4960728373983763 at Vector3<0.0, 0.0, 0.0>
# total elapsed time for run: 7.661248683929443
# done

# %%
#import csv
#with open('epsilon_distribution.csv', 'wt') as f:
#    writer = csv.writer(f)
#    writer.writerows(converted_eps)

# %%
md = mpb.MPBData(rectify=True, periods=3, resolution=64)
eps = ms.get_epsilon()
converted_eps = md.convert(eps)
converted_eps.shape

plt.figure(figsize=(12,9))
plt.imshow(converted_eps, interpolation='spline36', cmap="binary")
plt.axis('off')
plt.show()
# Out:
# epsilon: 1-6.76, mean 2.25369, harm. mean 1.25222, 26.1719% > 1, 21.7655% "fill"

# %%
tm_freqs.max()
# Out:
# 1.322523801732159

# %%
fig, ax = plt.subplots(figsize=(8,6))

x = range(len(tm_freqs))

# Plot bands
# Scatter plot for multiple y values, see https://stackoverflow.com/a/34280815/2261298
for xz, tmz, tez in zip(x, tm_freqs, te_freqs):
    ax.scatter([xz]*len(tmz), tmz, color='blue')
    ax.scatter([xz]*len(tez), tez, color='red', facecolors='none')
ax.plot(tm_freqs, color='blue')
ax.plot(te_freqs, color='red')
ax.set_ylim([tm_freqs.min(), tm_freqs.max()])
ax.set_xlim([x[0], x[-1]])

# Plot gaps
for gap in tm_gaps:
    if gap[0] > 1:
        ax.fill_between(x, gap[1], gap[2], color='blue', alpha=0.2)

for gap in te_gaps:
    if gap[0] > 1:
        ax.fill_between(x, gap[1], gap[2], color='red', alpha=0.2)


# Plot labels
ax.text(12, 0.04, 'TM bands', color='blue', size=15)
ax.text(13.05, 0.235, 'TE bands', color='red', size=15)

points_in_between = (len(tm_freqs) - 4) / 3
tick_locs = [i*points_in_between+i for i in range(4)]
tick_labs = ['Γ', 'X', 'M', 'Γ']
ax.set_xticks(tick_locs)
ax.set_xticklabels(tick_labs, size=16)
ax.set_ylabel('frequency (c/a)', size=16)
ax.grid(True)

plt.show()

# %%
hfields = []

def get_hfields(ms, band):
    hfields.append(ms.get_hfield(band, bloch_phase=True))

ms.run_te(mpb.output_at_kpoint(mp.Vector3(), mpb.fix_hfield_phase,
          get_hfields))

# Create an MPBData instance to transform the hfields
md = mpb.MPBData(rectify=True, resolution=64, periods=3)

converted = []
for f in hfields:
    # Get just the z component of the hfields
    f = f[..., 0, 2]
    converted.append(md.convert(f))

plt.figure(figsize=(15,10))

for i, f in enumerate(converted):
    plt.subplot(331 + i)
    plt.contour(converted_eps.T, cmap='binary')
    plt.imshow(np.real(f).T, interpolation='spline36', cmap='bwr', alpha=0.9)
    plt.axis('off')

plt.show()
# Out:
# Initializing eigensolver data
# Computing 10 bands with 1e-07 tolerance
# Working in 2 dimensions.
# Grid size is 64 x 64 x 1.
# Solving for 10 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.5, 0.866025, 0)
#      (0.5, -0.866025, 0)
#      (0, 0, 1)
# Cell volume = 0.866025
# Reciprocal lattice vectors (/ 2 pi):
#      (1, 0.57735, -0)
#      (1, -0.57735, 0)
#      (-0, 0, 1)
# Geometric objects:
#      cylinder, center = (0.3,0.3,0)
#           radius 0.1, height 20, axis (0, 0, 1)
#      cylinder, center = (0.3,0,0)
#           radius 0.1, height 20, axis (0, 0, 1)
#      cylinder, center = (0,-0.3,0)
#           radius 0.1, height 20, axis (0, 0, 1)
#      cylinder, center = (-0.3,-0.3,0)
#           radius 0.1, height 20, axis (0, 0, 1)
#      cylinder, center = (-0.3,0,0)
#           radius 0.1, height 20, axis (0, 0, 1)
#      cylinder, center = (0,0.3,0)
#           radius 0.1, height 20, axis (0, 0, 1)
# Geometric object tree has depth 3 and 6 object nodes (vs. 6 actual objects)
# Initializing epsilon function...
# Solving for band polarization: te.
# Initializing fields to random numbers...
# 28 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.05555555555555555, 0.0, 0.0>
#   Vector3<0.1111111111111111, 0.0, 0.0>
#   Vector3<0.16666666666666666, 0.0, 0.0>
#   Vector3<0.2222222222222222, 0.0, 0.0>
#   Vector3<0.2777777777777778, 0.0, 0.0>
#   Vector3<0.3333333333333333, 0.0, 0.0>
#   Vector3<0.38888888888888884, 0.0, 0.0>
#   Vector3<0.4444444444444444, 0.0, 0.0>
#   Vector3<0.5, 0.0, 0.0>
#   Vector3<0.48148148148148145, 0.037037037037037035, 0.0>
#   Vector3<0.46296296296296297, 0.07407407407407407, 0.0>
#   Vector3<0.4444444444444444, 0.1111111111111111, 0.0>
#   Vector3<0.42592592592592593, 0.14814814814814814, 0.0>
#   Vector3<0.4074074074074074, 0.18518518518518517, 0.0>
#   Vector3<0.38888888888888884, 0.2222222222222222, 0.0>
#   Vector3<0.37037037037037035, 0.25925925925925924, 0.0>
#   Vector3<0.35185185185185186, 0.2962962962962963, 0.0>
#   Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<0.2962962962962963, 0.2962962962962963, 0.0>
#   Vector3<0.25925925925925924, 0.25925925925925924, 0.0>
#   Vector3<0.2222222222222222, 0.2222222222222222, 0.0>
#   Vector3<0.18518518518518517, 0.18518518518518517, 0.0>
#   Vector3<0.14814814814814814, 0.14814814814814814, 0.0>
#   Vector3<0.1111111111111111, 0.1111111111111111, 0.0>
#   Vector3<0.07407407407407407, 0.07407407407407407, 0.0>
#   Vector3<0.037037037037037035, 0.037037037037037035, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.04152178764343262
# solve_kpoint (0,0,0):
# Solving for bands 2 to 10...
# Finished solving for bands 2 to 10 after 26 iterations.
# tefreqs:, 1, 0, 0, 0, 0, 0, 0.866596, 0.944694, 0.975234, 0.975252, 0.979647, 0.979715, 1.32536, 1.47612, 1.49605
# elapsed time for k point: 0.2914431095123291
# Fixing h-field (band 1) phase by 1 + -0i; max ampl. = 1.07457
# Fixing h-field (band 2) phase by 0.479973 + -0.877283i; max ampl. = 2.23162
# Fixing h-field (band 3) phase by -0.0835625 + -0.996503i; max ampl. = 1.86309
# Fixing h-field (band 4) phase by 0.647879 + -0.761743i; max ampl. = 2.85003
# Fixing h-field (band 5) phase by -0.997828 + 0.0658762i; max ampl. = 2.52718
# Fixing h-field (band 6) phase by 0.836112 + -0.548558i; max ampl. = 2.87398
# Fixing h-field (band 7) phase by -0.990958 + 0.134169i; max ampl. = 3.25807
# Fixing h-field (band 8) phase by -0.208008 + 0.978127i; max ampl. = 3.8936
# Fixing h-field (band 9) phase by -0.861466 + -0.507816i; max ampl. = 3.83387
# Fixing h-field (band 10) phase by 0.869364 + 0.494172i; max ampl. = 4.34299
# solve_kpoint (0.0555556,0,0):
# Solving for bands 1 to 10...
# Finished solving for bands 1 to 10 after
# solve_kpoint (0,0,0):
# Solving for bands 2 to 10...
# Finished solving for bands 2 to 10 after 15 iterations.
# tefreqs:, 28, 0, 0, 0, 0, 0, 0.866596, 0.944694, 0.975234, 0.975252, 0.979647, 0.979715, 1.32536, 1.47612, 1.49597
# elapsed time for k point: 0.1613318920135498
# Fixing h-field (band 1) phase by 1 + -0i; max ampl. = 1.07457
# Fixing h-field (band 2) phase by -1 + 1.20321e-05i; max ampl. = 2.23162
# Fixing h-field (band 3) phase by -1.20322e-05 + -1i; max ampl. = 1.86308
# Fixing h-field (band 4) phase by 1 + -1.20321e-05i; max ampl. = 2.85002
# Fixing h-field (band 5) phase by 1 + -1.20321e-05i; max ampl. = 2.5272
# Fixing h-field (band 6) phase by -1.20322e-05 + -1i; max ampl. = 2.87393
# Fixing h-field (band 7) phase by -1.20321e-05 + -1i; max ampl. = 3.25802
# Fixing h-field (band 8) phase by 1.20321e-05 + 1i; max ampl. = 3.89282
# Fixing h-field (band 9) phase by -1 + 1.20321e-05i; max ampl. = 3.83349
# Fixing h-field (band 10) phase by -1 + 1.20316e-05i; max ampl. = 4.28559
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.5580279294041318 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.4917442529205599 at Vector3<0.5, 0.0, 0.0> to 0.8665964793075313 at Vector3<0.0, 0.0, 0.0>
# Band 3 range: 0.560693106197352 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0> to 0.9446944366694242 at Vector3<0.0, 0.0, 0.0>
# Band 4 range: 0.8825904500148343 at Vector3<0.5, 0.0, 0.0> to 1.0877248774411292 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
# Band 5 range: 0.9742602270223971 at Vector3<0.037037037037037035, 0.037037037037037035, 0.0> to 1.1833824383903104 at Vector3<0.5, 0.0, 0.0>
# Band 6 range: 0.979646670084308 at Vector3<0.0, 0.0, 0.0> to 1.2166630206403564 at Vector3<0.2222222222222222, 0.2222222222222222, 0.0>
# Band 7 range: 0.9797147066297608 at Vector3<0.0, 0.0, 0.0> to 1.3265676178052919 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
# Band 8 range: 1.2518336718300924 at Vector3<0.5, 0.0, 0.0> to 1.3266646921820324 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
# Band 9 range: 1.3109311823902625 at Vector3<0.4444444444444444, 0.0, 0.0> to 1.4761200045724843 at Vector3<0.0, 0.0, 0.0>
# Band 10 range: 1.3617646839405932 at Vector3<0.5, 0.0, 0.0> to 1.496048805707431 at Vector3<0.0, 0.0, 0.0>
# total elapsed time for run: 5.09675931930542
# done
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-8f3346093a9b> in <module>
#      19
#      20 for i, f in enumerate(converted):
# ---> 21     plt.subplot(331 + i)
#      22     plt.contour(converted_eps.T, cmap='binary')
#      23     plt.imshow(np.real(f).T, interpolation='spline36', cmap='bwr', alpha=0.9)
#
# ~/.conda/envs/mp/lib/python3.7/site-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1028
#    1029     fig = gcf()
# -> 1030     a = fig.add_subplot(*args, **kwargs)
#    1031     bbox = a.bbox
#    1032     byebye = []
#
# ~/.conda/envs/mp/lib/python3.7/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1417                     self._axstack.remove(ax)
#    1418
# -> 1419             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1420
#    1421         return self._add_axes_internal(key, a)
#
# ~/.conda/envs/mp/lib/python3.7/site-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      64                 if num < 1 or num > rows*cols:
#      65                     raise ValueError(
# ---> 66                         f"num must be 1 <= num <= {rows*cols}, not {num}")
#      67                 self._subplotspec = GridSpec(
#      68                         rows, cols, figure=self.figure)[int(num) - 1]
#
# ValueError: num must be 1 <= num <= 12, not 0

# %%
#THz表示
a = 820
c_const = 299792458

fontsize = 18
tm_freqs_THz = np.array(tm_freqs) * c_const/(a*10**3)
tm_gaps_THz = np.array(tm_gaps) * c_const/(a*10**3)
#print(te_freqs_THz)



fig, ax = plt.subplots(figsize=(8,6))

x = range(len(tm_freqs))

for xz, tmz in zip(x, tm_freqs_THz):
    ax.scatter([xz]*len(tmz), tmz, color='olive')

ax.plot(tm_freqs_THz, color='olive')
ax.set_ylim([tm_freqs_THz.min(), tm_freqs_THz.max()])
ax.set_xlim([x[0], x[-1]])

for gap in tm_gaps_THz:
    if gap[0] > 1:
        ax.fill_between(x, gap[1], gap[2], color='olive', alpha=0.2)

ax.text(11.5, 0, 'TM bands', color='olive', size=15)

points_in_between = (len(tm_freqs) - 4) / 3
tick_locs = [i*points_in_between+i for i in range(4)]
tick_labs = ['Γ', 'K', 'M', 'Γ']
ax.set_xticks(tick_locs)
ax.set_xticklabels(tick_labs, size=fontsize)
ax.set_ylabel('frequency [THz]', size=fontsize)
plt.tick_params(labelsize=fontsize)
ax.grid(True)

plt.show()
