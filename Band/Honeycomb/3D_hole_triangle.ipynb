# %%
import math
import meep as mp
from meep import mpb

import numpy as np
import matplotlib.pyplot as plt

# %%
#屈折率
n_Air = 1
n_Si = 3.48

#slab厚さ
h = 0.5

#三角形の一辺
s = 0.7

#計算する固有周波数の数
num_bands = 4

#メッシュの細かさ
resolution = 32

#計算間隔
interpolate = 4

#-------------------------------------------------------------------#

s_param = s/(np.sqrt(3))

#単位格子
geometry_lattice = mp.Lattice(size=mp.Vector3(1, 1, 10*h),
                              basis1=mp.Vector3(1./2, np.sqrt(3)/2),
                              basis2=mp.Vector3(1./2, -np.sqrt(3)/2))

tri1 = [mp.Vector3(1,1,0)*s_param,
       mp.Vector3(-1,0,0)*s_param,
       mp.Vector3(0,-1,0)*s_param
      ]

#構造
#default_material = mp.Medium(epsilon=n_Si**2)
geometry = [
    mp.Block(material=mp.Medium(epsilon=1),
             size=mp.Vector3(mp.inf, mp.inf, 10*h)),
    mp.Block(material=mp.Medium(epsilon=n_Si**2),
             size=mp.Vector3(mp.inf, mp.inf, h)),
    mp.Prism(tri1, center=mp.Vector3(), height=h,
            material=mp.Medium(epsilon=n_Air**2)),
]

#ブリルアンゾーン
k_points = [
    mp.Vector3(),               # Gamma
    mp.Vector3(1./2, 0),          # M
    mp.Vector3(1./3, 1./3),    # K
    mp.Vector3(),               # Gamma
]
k_points = mp.interpolate(interpolate, k_points)

# %%
#計算
ms = mpb.ModeSolver(
    geometry=geometry,
    geometry_lattice=geometry_lattice,
    k_points=k_points,
    resolution=resolution,
    num_bands=num_bands
)

#ms.run_tm(mpb.output_at_kpoint(mp.Vector3(-1./3, 1./3),
#                               mpb.fix_efield_phase,
#                               mpb.output_efield_z))
#tm_freqs = ms.all_freqs
#tm_gaps = ms.gap_list
hfields = []
ms.run_te(mpb.output_at_kpoint(mp.Vector3(), mpb.fix_hfield_phase,get_hfields))

te_freqs = ms.all_freqs
te_gaps = ms.gap_list
# Out:
# Initializing eigensolver data
# Computing 4 bands with 1e-07 tolerance
# Working in 3 dimensions.
# Grid size is 32 x 32 x 160.
# Solving for 4 bands at a time.
# Creating Maxwell data...
# Mesh size is 3.
# Lattice vectors:
#      (0.5, 0.866025, 0)
#      (0.5, -0.866025, 0)
#      (0, 0, 5)
# Cell volume = 4.33013
# Reciprocal lattice vectors (/ 2 pi):
#      (1, 0.57735, -0)
#      (1, -0.57735, 0)
#      (-0, 0, 0.2)
# Geometric objects:
#      block, center = (0,0,0)
#           size (1e+20,1e+20,5)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      block, center = (0,0,0)
#           size (1e+20,1e+20,0.5)
#           axes (1,0,0), (0,1,0), (0,0,1)
#      prism, center = (0,0,0)
#           height 0.5, axis (0,0,1), sidewall angle: 0 radians, 3 vertices:
#           (0.404145,0.404145,-0.25)
#           (-0.404145,0,-0.25)
#           (0,-0.404145,-0.25)
# Geometric object tree has depth 3 and 55 object nodes (vs. 3 actual objects)
# Initializing epsilon function...
# Allocating fields...
# Solving for band polarization: zeven.
# Initializing fields to random numbers...
# 16 k-points
#   Vector3<0.0, 0.0, 0.0>
#   Vector3<0.1, 0.0, 0.0>
#   Vector3<0.2, 0.0, 0.0>
#   Vector3<0.30000000000000004, 0.0, 0.0>
#   Vector3<0.4, 0.0, 0.0>
#   Vector3<0.5, 0.0, 0.0>
#   Vector3<0.4666666666666667, 0.06666666666666667, 0.0>
#   Vector3<0.43333333333333335, 0.13333333333333333, 0.0>
#   Vector3<0.39999999999999997, 0.2, 0.0>
#   Vector3<0.36666666666666664, 0.26666666666666666, 0.0>
#   Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
#   Vector3<0.26666666666666666, 0.26666666666666666, 0.0>
#   Vector3<0.19999999999999998, 0.19999999999999998, 0.0>
#   Vector3<0.1333333333333333, 0.1333333333333333, 0.0>
#   Vector3<0.06666666666666665, 0.06666666666666665, 0.0>
#   Vector3<0.0, 0.0, 0.0>
# elapsed time for initialization: 0.3793673515319824
# solve_kpoint (0,0,0):
# Solving for bands 2 to 4...
# Finished solving for bands 2 to 4 after 43 iterations.
# zevenfreqs:, 1, 0, 0, 0, 0, 0, 0.143626, 0.144039, 0.332399
# elapsed time for k point: 9.187416315078735
# Fixing h-field (band 1) phase by 1 + -0i; max ampl. = 0.480562
# Fixing h-field (band 2) phase by 0.980712 + 0.195458i; max ampl. = 0.662959
# Fixing h-field (band 3) phase by -0.63802 + -0.77002i; max ampl. = 0.689676
# Fixing h-field (band 4) phase by -0.860968 + -0.508659i; max ampl. = 0.820398
# solve_kpoint (0.1,0,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 25 iterations.
# zevenfreqs:, 2, 0.1, 0, 0, 0.11547, 0.083891, 0.175193, 0.182392, 0.349465
# elapsed time for k point: 7.37402606010437
# solve_kpoint (0.2,0,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 24 iterations.
# zevenfreqs:, 3, 0.2, 0, 0, 0.23094, 0.143338, 0.258709, 0.26574, 0.379845
# elapsed time for k point: 7.079895257949829
# solve_kpoint (0.3,0,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 14 iterations.
# zevenfreqs:, 4, 0.3, 0, 0, 0.34641, 0.188233, 0.354889, 0.361864, 0.367445
# elapsed time for k point: 4.220236301422119
# solve_kpoint (0.4,0,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 18 iterations.
# zevenfreqs:, 5, 0.4, 0, 0, 0.46188, 0.224299, 0.334533, 0.395093, 0.42619
# elapsed time for k point: 5.3892600536346436
# solve_kpoint (0.5,0,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 11 iterations.
# zevenfreqs:, 6, 0.5, 0, 0, 0.57735, 0.241577, 0.320432, 0.392119, 0.430191
# elapsed time for k point: 3.3617281913757324
# solve_kpoint (0.466667,0.0666667,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 9 iterations.
# zevenfreqs:, 7, 0.466667, 0.0666667, 0, 0.581187, 0.243215, 0.320903, 0.384938, 0.43748
# elapsed time for k point: 2.788587808609009
# solve_kpoint (0.433333,0.133333,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 9 iterations.
# zevenfreqs:, 8, 0.433333, 0.133333, 0, 0.592546, 0.247857, 0.322338, 0.370626, 0.452211
# elapsed time for k point: 2.781621217727661
# solve_kpoint (0.4,0.2,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 11 iterations.
# zevenfreqs:, 9, 0.4, 0.2, 0, 0.61101, 0.254617, 0.324775, 0.35509, 0.468853
# elapsed time for k point: 3.3565585613250732
# solve_kpoint (0.366667,0.266667,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 13 iterations.
# zevenfreqs:, 10, 0.366667, 0.266667, 0, 0.635959, 0.26162, 0.328226, 0.340982, 0.485741
# elapsed time for k point: 3.942673921585083
# solve_kpoint (0.333333,0.333333,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 21 iterations.
# zevenfreqs:, 11, 0.333333, 0.333333, 0, 0.666667, 0.265061, 0.331225, 0.33332, 0.497612
# elapsed time for k point: 6.1929638385772705
# solve_kpoint (0.266667,0.266667,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 24 iterations.
# zevenfreqs:, 12, 0.266667, 0.266667, 0, 0.533333, 0.247296, 0.342414, 0.343551, 0.483791
# elapsed time for k point: 7.064613103866577
# solve_kpoint (0.2,0.2,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 33 iterations.
# zevenfreqs:, 13, 0.2, 0.2, 0, 0.4, 0.207649, 0.358026, 0.37244, 0.408552
# elapsed time for k point: 9.59527325630188
# solve_kpoint (0.133333,0.133333,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 17 iterations.
# zevenfreqs:, 14, 0.133333, 0.133333, 0, 0.266667, 0.158545, 0.289962, 0.294635, 0.377825
# elapsed time for k point: 5.030422925949097
# solve_kpoint (0.0666667,0.0666667,0):
# Solving for bands 1 to 4...
# Finished solving for bands 1 to 4 after 18 iterations.
# zevenfreqs:, 15, 0.0666667, 0.0666667, 0, 0.133333, 0.0948443, 0.185465, 0.193455, 0.354855
# elapsed time for k point: 5.314451456069946
# solve_kpoint (0,0,0):
# Solving for bands 2 to 4...
# Finished solving for bands 2 to 4 after 10 iterations.
# zevenfreqs:, 16, 0, 0, 0, 0, 0, 0.143626, 0.144039, 0.332399
# elapsed time for k point: 2.1807878017425537
# Fixing h-field (band 1) phase by 1 + -0i; max ampl. = 0.480562
# Fixing h-field (band 2) phase by 0.0398444 + -0.999206i; max ampl. = 0.662949
# Fixing h-field (band 3) phase by 0.0350934 + -0.999384i; max ampl. = 0.689693
# Fixing h-field (band 4) phase by 0.998408 + 0.056407i; max ampl. = 0.818799
# Band 1 range: 0.0 at Vector3<0.0, 0.0, 0.0> to 0.26506100686084116 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
# Band 2 range: 0.1436255577876948 at Vector3<0.0, 0.0, 0.0> to 0.358025763195869 at Vector3<0.19999999999999998, 0.19999999999999998, 0.0>
# Band 3 range: 0.14403900041718584 at Vector3<0.0, 0.0, 0.0> to 0.39509344013491476 at Vector3<0.4, 0.0, 0.0>
# Band 4 range: 0.33239874256909996 at Vector3<0.0, 0.0, 0.0> to 0.49761227558626275 at Vector3<0.3333333333333333, 0.3333333333333333, 0.0>
# total elapsed time for run: 85.59894275665283
# done

# %%
md = mpb.MPBData(rectify=True, periods=3, resolution=32)
eps = ms.get_epsilon()
converted_eps = md.convert(eps)
converted_eps.shape

plt.imshow(converted_eps[:,:,400].T, interpolation='spline36', cmap="binary")
plt.axis('off')
plt.show()
# Out:
# epsilon: 1-12.1104, mean 1.83997, harm. mean 1.08157, 8.53943% > 1, 7.56022% "fill"

# %%
def get_hfields(ms, band):
    hfields.append(ms.get_hfield(band, bloch_phase=True))

#ms.run_te(mpb.output_at_kpoint(mp.Vector3(), mpb.fix_hfield_phase,get_hfields))

# Create an MPBData instance to transform the hfields
md = mpb.MPBData(rectify=True, resolution=32, periods=3)

converted = []
for f in hfields:
    # Get just the z component of the hfields
    f = f[..., 0, 2]
    converted.append(md.convert(f))

plt.figure(figsize=(15,10))

for i, f in enumerate(converted):
    plt.subplot(331 + i)
    plt.contour(converted_eps[:,:,400].T, cmap='binary')
    plt.imshow(np.real(f).T, interpolation='spline36', cmap='bwr', alpha=0.9)
    plt.axis('off')

plt.show()

# %%
#THz表示
a = 400
c_const = 299792458

fontsize = 18
te_freqs_THz = np.array(te_freqs) * c_const/(a*10**3)
te_gaps_THz = np.array(te_gaps) * c_const/(a*10**3)
#print(te_freqs_THz)

fig, ax = plt.subplots()

x = range(len(te_freqs))

for xz, tez in zip(x, te_freqs_THz):
    ax.scatter([xz]*len(tez), tez, color='navy')

ax.plot(te_freqs_THz, color='navy')
ax.set_ylim([te_freqs_THz.min(), te_freqs_THz.max()])
ax.set_xlim([x[0], x[-1]])

for gap in te_gaps_THz:
    if gap[0] > 1:
        ax.fill_between(x, gap[1], gap[2], color='blue', alpha=0.2)

ax.text(11.5, 0, 'TE bands', color='blue', size=15)

points_in_between = (len(te_freqs) - 4) / 3
tick_locs = [i*points_in_between+i for i in range(4)]
tick_labs = ['Γ', 'K', 'M', 'Γ']
ax.set_xticks(tick_locs)
ax.set_xticklabels(tick_labs, size=fontsize)
ax.set_ylabel('frequency [THz]', size=fontsize)
plt.tick_params(labelsize=fontsize)
ax.grid(True)

plt.show()
